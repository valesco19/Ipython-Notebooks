# %%
import urllib
from bs4 import BeautifulSoup
import requests
import os
import time
import pandas as pd
import json
from datetime import datetime
from glob import glob
os.chdir('/home/valesco/Datasets/PGA_Data/PGA/')

# %%
base_url = 'http://pgatour.com/data/r/'

def find_tourny_list(base_url):
    soup = BeautifulSoup(requests.get(base_url, 'lxml').text)
    tourny_list = []
    for a in soup.find_all('a'):
        temp = a.text
        temp = temp.replace('/', '')
        try:
            if int(temp) < 800:
                tourny_list.append(temp)
        except:
            pass
    
    return(tourny_list)

tourny_list = find_tourny_list(base_url)
# Out:
# /home/valesco/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /home/valesco/anaconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
tourny_with_stats = []
for tourny in tourny_list:
    count = 0
    tourny_url = base_url + tourny + '/'
    soup = BeautifulSoup(requests.get(tourny_url, 'lxml').text)
    temp_tourny = []
    for a in soup.find_all('a'):
        temp = a.text
        temp = temp.replace('/', '')
        temp_tourny.append(temp)
            
    year_list = ['2014','2015','2016']
    for year in year_list:
        if any(year in t for t in temp_tourny):
            count = 1
            
    if count == 1:
        tourny_with_stats.append(tourny)
# Out:
# /home/valesco/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /home/valesco/anaconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
schedule = open('/home/valesco/Datasets/PGA_Data/pga_master_files/2017_schedule.json')
sched_data = json.load(schedule)
sched_data
# Out:
# {'_comment': 'This will be replaced with a separate file in the future.',
#  'currentYears': {'c': '2017',
#   'h': '2017',
#   'm': '2017',
#   'r': '2017',
#   's': '2017'},
#  'header': {'version': '0.0'},
#  'thisWeek': {'endDate': '2017-04-02',
#   'startDate': '2017-03-27',
#   'weekNumber': '13'},
#  'years': [{'tours': [{'desc': 'PGA TOUR',
#      'tourCodeLc': 'r',
#      'trns': [{'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,000,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Brendan', 'last': 'Steele', 'middle': ''},
#          'plrNum': '29518',
#          'winningShare': '1,080,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Silverado Resort and Spa North',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Napa', 'country': 'USA', 'state': 'CA'},
#          'number': '552',
#          'rank': '33'}],
#        'date': {'end': '2016-10-16',
#         'start': '2016-10-13',
#         'weekNumber': '41'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '464',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 10\n 13\n 2016\n \n \n 10\n 16\n 2016\n \n'],
#        'timeZone': 'America/Los_Angeles',
#        'trnName': {'long': 'Safeway Open',
#         'medium': 'Safeway Open',
#         'official': 'Safeway Open',
#         'short': 'Safeway Open'},
#        'trnNum': '010',
#        'trnType': 'STD',
#        'winnersShare': '1,080,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '7,000,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Justin', 'last': 'Thomas', 'middle': ''},
#          'plrNum': '33448',
#          'winningShare': '1,260,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'TPC Kuala Lumpur',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Kuala Lumpur', 'country': 'MAS', 'state': ''},
#          'number': '800',
#          'rank': '47'}],
#        'date': {'end': '2016-10-23',
#         'start': '2016-10-20',
#         'weekNumber': '42'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '494',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '1',
#        'subEvents': ['\n \n 10\n 20\n 2016\n \n \n 10\n 23\n 2016\n \n'],
#        'timeZone': 'Asia/Kuala_Lumpur',
#        'trnName': {'long': 'CIMB Classic',
#         'medium': 'CIMB Classic',
#         'official': 'CIMB Classic',
#         'short': 'CIMB Classic'},
#        'trnNum': '020',
#        'trnType': 'STD',
#        'winnersShare': '1,260,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '1,756',
#        'FedExCupWinnerPoints': '300',
#        'Purse': '4,200,000',
#        'champions': [{'FedExCupWinnerShare': '300',
#          'isMember': 'YES',
#          'playerName': {'first': 'Cody', 'last': 'Gribble', 'middle': ''},
#          'plrNum': '39954',
#          'winningShare': '756,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'CC of Jackson',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Jackson', 'country': 'USA', 'state': 'MS'},
#          'number': '746',
#          'rank': '46'}],
#        'date': {'end': '2016-10-30',
#         'start': '2016-10-27',
#         'weekNumber': '43'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '054',
#        'presBy': '',
#        'primaryEvent': 'N',
#        'scored': '3',
#        'subEvents': ['\n \n 10\n 27\n 2016\n \n \n 10\n 30\n 2016\n \n'],
#        'timeZone': 'America/Chicago',
#        'trnName': {'long': 'Sanderson Farms Championship',
#         'medium': 'Sanderson Farms Championship',
#         'official': 'Sanderson Farms Championship',
#         'short': 'Sanderson Farms Championship'},
#        'trnNum': '030',
#        'trnType': 'ALT',
#        'winnersShare': '756,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '3,240',
#        'FedExCupWinnerPoints': '550',
#        'Purse': '9,500,000',
#        'champions': [{'FedExCupWinnerShare': '550',
#          'isMember': 'YES',
#          'playerName': {'first': 'Hideki', 'last': 'Matsuyama', 'middle': ''},
#          'plrNum': '32839',
#          'winningShare': '1,620,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Sheshan International GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Shanghai', 'country': 'CHN', 'state': ''},
#          'number': '766',
#          'rank': '43'}],
#        'date': {'end': '2016-10-30',
#         'start': '2016-10-27',
#         'weekNumber': '43'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.pgatour.com/tournaments/wgc-hsbc-champions.html'}},
#        'official': 'Yes',
#        'permNum': '489',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '1',
#        'subEvents': ['\n \n 10\n 27\n 2016\n \n \n 10\n 30\n 2016\n \n'],
#        'timeZone': 'Asia/Shanghai',
#        'trnName': {'long': 'World Golf Championships-HSBC Champions',
#         'medium': 'World Golf Championships-HSBC Champions',
#         'official': 'World Golf Championships-HSBC Champions',
#         'short': 'WGC-HSBC Champions'},
#        'trnNum': '040',
#        'trnType': 'WGC',
#        'winnersShare': '1,620,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,600,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Rod', 'last': 'Pampling', 'middle': ''},
#          'plrNum': '20572',
#          'winningShare': '1,188,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'TPC Summerlin',
#          'host': 'Yes',
#          'isTpc': 'Yes',
#          'location': {'city': 'Las Vegas', 'country': 'USA', 'state': 'NV'},
#          'number': '538',
#          'rank': '34'}],
#        'date': {'end': '2016-11-06',
#         'start': '2016-11-03',
#         'weekNumber': '44'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '047',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 11\n 03\n 2016\n \n \n 11\n 06\n 2016\n \n'],
#        'timeZone': 'America/Los_Angeles',
#        'trnName': {'long': 'Shriners Hospitals for Children Open',
#         'medium': 'Shriners Hospitals for Children Open',
#         'official': 'Shriners Hospitals for Children Open',
#         'short': 'Shriners Hospitals for Child'},
#        'trnNum': '050',
#        'trnType': 'STD',
#        'winnersShare': '1,188,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '7,000,010',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Pat', 'last': 'Perez', 'middle': ''},
#          'plrNum': '24361',
#          'winningShare': '1,260,001.80'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'El Camaleon GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Playa del Carmen',
#           'country': 'Mex',
#           'state': ''},
#          'number': '733',
#          'rank': '35'}],
#        'date': {'end': '2016-11-13',
#         'start': '2016-11-10',
#         'weekNumber': '45'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '457',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 11\n 10\n 2016\n \n \n 11\n 13\n 2016\n \n'],
#        'timeZone': 'America/Cancun',
#        'trnName': {'long': 'OHL Classic at Mayakoba',
#         'medium': 'OHL Classic at Mayakoba',
#         'official': 'OHL Classic at Mayakoba',
#         'short': 'OHL Classic at Mayakoba'},
#        'trnNum': '060',
#        'trnType': 'STD',
#        'winnersShare': '1,260,001',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,000,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Mackenzie', 'last': 'Hughes', 'middle': ''},
#          'plrNum': '35506',
#          'winningShare': '1,080,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Sea Island Resort (Seaside)',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Sea Island', 'country': 'USA', 'state': 'GA'},
#          'number': '776',
#          'rank': '29'},
#         {'courseName': 'Sea Island Resort (Plantation)',
#          'host': 'No',
#          'isTpc': 'No',
#          'location': {'city': 'Sea Island', 'country': 'USA', 'state': 'GA'},
#          'number': '231',
#          'rank': '42'}],
#        'date': {'end': '2016-11-20',
#         'start': '2016-11-17',
#         'weekNumber': '46'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '493',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 11\n 17\n 2016\n \n \n 11\n 20\n 2016\n \n'],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'The RSM Classic',
#         'medium': 'The RSM Classic',
#         'official': 'The RSM Classic',
#         'short': 'The RSM Classic'},
#        'trnNum': '070',
#        'trnType': 'STD',
#        'winnersShare': '1,080,000',
#        'year': '2017'},
#       {'FedExCup': 'No',
#        'FedExCupPurse': '',
#        'FedExCupWinnerPoints': '',
#        'Purse': '8,000,000',
#        'champions': [{'isMember': '',
#          'playerName': {'first': '', 'last': 'Denmark', 'middle': ''},
#          'plrNum': '00000',
#          'winningShare': '2,560,000.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Kingston Heath Golf Club',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Melbourne', 'country': 'AUS', 'state': ''},
#          'number': '239',
#          'rank': ''}],
#        'date': {'end': '2016-11-27',
#         'start': '2016-11-24',
#         'weekNumber': '47'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'No',
#        'permNum': '169',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '1',
#        'subEvents': ['\n \n 11\n 24\n 2016\n \n \n 11\n 27\n 2016\n \n'],
#        'timeZone': 'Australia/Hobart',
#        'trnName': {'long': 'ISPS HANDA World Cup of Golf',
#         'medium': 'ISPS HANDA World Cup',
#         'official': 'ISPS HANDA World Cup of Golf',
#         'short': 'World Cup'},
#        'trnNum': '080',
#        'trnType': 'OTH',
#        'winnersShare': '',
#        'year': '2017'},
#       {'FedExCup': 'No',
#        'FedExCupPurse': '',
#        'FedExCupWinnerPoints': '',
#        'Purse': '3,500,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Hideki', 'last': 'Matsuyama', 'middle': ''},
#          'plrNum': '32839',
#          'winningShare': '1,000,000.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Albany',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'New Providence', 'country': 'BAH', 'state': ''},
#          'number': '232',
#          'rank': ''}],
#        'date': {'end': '2016-12-04',
#         'start': '2016-12-01',
#         'weekNumber': '48'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'No',
#        'permNum': '478',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '1',
#        'subEvents': ['\n \n 12\n 01\n 2016\n \n \n 12\n 04\n 2016\n \n'],
#        'timeZone': 'America/Nassau',
#        'trnName': {'long': 'Hero World Challenge',
#         'medium': 'Hero World Challenge',
#         'official': 'Hero World Challenge',
#         'short': 'World Challenge'},
#        'trnNum': '090',
#        'trnType': 'OTH',
#        'winnersShare': '',
#        'year': '2017'},
#       {'FedExCup': 'No',
#        'FedExCupPurse': '',
#        'FedExCupWinnerPoints': '',
#        'Purse': '3,100,000',
#        'champions': [{'isMember': 'Yes',
#          'playerName': {'first': 'Harris', 'last': 'English', 'middle': ''},
#          'plrNum': '34099',
#          'winningShare': '385,000.00'},
#         {'isMember': 'Yes',
#          'playerName': {'first': 'Matt', 'last': 'Kuchar', 'middle': ''},
#          'plrNum': '23108',
#          'winningShare': '385,000.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Tiburon GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Naples', 'country': 'USA', 'state': 'FL'},
#          'number': '678',
#          'rank': ''}],
#        'date': {'end': '2016-12-10',
#         'start': '2016-12-08',
#         'weekNumber': '49'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'No',
#        'permNum': '058',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '0',
#        'subEvents': [],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'Franklin Templeton Shootout',
#         'medium': 'Franklin Templeton Shootout',
#         'official': 'Franklin Templeton Shootout',
#         'short': 'Franklin Templeton Shootout'},
#        'trnNum': '100',
#        'trnType': 'OTH',
#        'winnersShare': '',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,100,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Justin', 'last': 'Thomas', 'middle': ''},
#          'plrNum': '33448',
#          'winningShare': '1,220,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Plantation Course at Kapalua',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Kapalua, Maui',
#           'country': 'USA',
#           'state': 'HI'},
#          'number': '656',
#          'rank': '50'}],
#        'date': {'end': '2017-01-08', 'start': '2017-01-05', 'weekNumber': '1'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '016',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 01\n 05\n 2017\n \n \n 01\n 08\n 2017\n \n'],
#        'timeZone': 'Pacific/Honolulu',
#        'trnName': {'long': 'SBS Tournament of Champions',
#         'medium': 'SBS Tournament of Champions',
#         'official': 'SBS Tournament of Champions',
#         'short': 'T of C'},
#        'trnNum': '110',
#        'trnType': 'STD',
#        'winnersShare': '1,220,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,000,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Justin', 'last': 'Thomas', 'middle': ''},
#          'plrNum': '33448',
#          'winningShare': '1,080,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Waialae CC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Honolulu', 'country': 'USA', 'state': 'HI'},
#          'number': '006',
#          'rank': '45'}],
#        'date': {'end': '2017-01-15', 'start': '2017-01-12', 'weekNumber': '2'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '006',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 01\n 12\n 2017\n \n \n 01\n 15\n 2017\n \n'],
#        'timeZone': 'Pacific/Honolulu',
#        'trnName': {'long': 'Sony Open in Hawaii',
#         'medium': 'Sony Open in Hawaii',
#         'official': 'Sony Open in Hawaii',
#         'short': 'Sony Open in Hawaii'},
#        'trnNum': '120',
#        'trnType': 'STD',
#        'winnersShare': '1,080,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '5,800,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Hudson', 'last': 'Swafford', 'middle': ''},
#          'plrNum': '34264',
#          'winningShare': '1,044,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Stadium Course',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'La Quinta', 'country': 'USA', 'state': 'CA'},
#          'number': '704',
#          'rank': '41'},
#         {'courseName': 'Nicklaus Tournament Course',
#          'host': 'No',
#          'isTpc': 'No',
#          'location': {'city': 'La Quinta', 'country': 'USA', 'state': 'CA'},
#          'number': '233',
#          'rank': '49'},
#         {'courseName': 'La Quinta CC',
#          'host': 'No',
#          'isTpc': 'No',
#          'location': {'city': 'La Quinta', 'country': 'USA', 'state': 'CA'},
#          'number': '202',
#          'rank': '48'}],
#        'date': {'end': '2017-01-22', 'start': '2017-01-19', 'weekNumber': '3'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '002',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 01\n 19\n 2017\n \n \n 01\n 22\n 2017\n \n',
#         '\n \n 01\n 19\n 2017\n \n \n 01\n 22\n 2017\n \n'],
#        'timeZone': 'America/Los_Angeles',
#        'trnName': {'long': 'CareerBuilder Challenge',
#         'medium': 'CareerBuilder Challenge',
#         'official': 'CareerBuilder Challenge',
#         'short': 'CareerBuilder'},
#        'trnNum': '130',
#        'trnType': 'STD',
#        'winnersShare': '1,044,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,700,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Jon', 'last': 'Rahm', 'middle': ''},
#          'plrNum': '46970',
#          'winningShare': '1,206,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Torrey Pines GC (South)',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'San Diego', 'country': 'USA', 'state': 'CA'},
#          'number': '004',
#          'rank': '2'},
#         {'courseName': 'Torrey Pines (North)',
#          'host': 'No',
#          'isTpc': 'No',
#          'location': {'city': 'San Diego', 'country': 'USA', 'state': 'CA'},
#          'number': '104',
#          'rank': '38'}],
#        'date': {'end': '2017-01-29', 'start': '2017-01-26', 'weekNumber': '4'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '004',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 01\n 26\n 2017\n \n \n 01\n 29\n 2017\n \n'],
#        'timeZone': 'America/Los_Angeles',
#        'trnName': {'long': 'Farmers Insurance Open',
#         'medium': 'Farmers Insurance Open',
#         'official': 'Farmers Insurance Open',
#         'short': 'Farmers Insurance Open'},
#        'trnNum': '140',
#        'trnType': 'STD',
#        'winnersShare': '1,206,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,700,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Hideki', 'last': 'Matsuyama', 'middle': ''},
#          'plrNum': '32839',
#          'winningShare': '1,206,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'TPC Scottsdale',
#          'host': 'Yes',
#          'isTpc': 'Yes',
#          'location': {'city': 'Scottsdale', 'country': 'USA', 'state': 'AZ'},
#          'number': '510',
#          'rank': '20'}],
#        'date': {'end': '2017-02-05', 'start': '2017-02-02', 'weekNumber': '5'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '003',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 02\n 02\n 2017\n \n \n 02\n 05\n 2017\n \n'],
#        'timeZone': 'America/Phoenix',
#        'trnName': {'long': 'Waste Management Phoenix Open',
#         'medium': 'Waste Management Phoenix Open',
#         'official': 'Waste Management Phoenix Open',
#         'short': 'Phoenix Open'},
#        'trnNum': '150',
#        'trnType': 'STD',
#        'winnersShare': '1,206,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '7,200,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Jordan', 'last': 'Spieth', 'middle': ''},
#          'plrNum': '34046',
#          'winningShare': '1,296,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Pebble Beach GL',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Pebble Beach', 'country': 'USA', 'state': 'CA'},
#          'number': '005',
#          'rank': '16'},
#         {'courseName': 'Monterey Peninsula CC',
#          'host': 'No',
#          'isTpc': 'No',
#          'location': {'city': 'Pebble Beach', 'country': 'USA', 'state': 'CA'},
#          'number': '769',
#          'rank': '25'},
#         {'courseName': 'Spyglass Hill GC',
#          'host': 'No',
#          'isTpc': 'No',
#          'location': {'city': 'Pebble Beach', 'country': 'USA', 'state': 'CA'},
#          'number': '205',
#          'rank': '15'}],
#        'date': {'end': '2017-02-12', 'start': '2017-02-09', 'weekNumber': '6'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '005',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 02\n 09\n 2017\n \n \n 02\n 12\n 2017\n \n',
#         '\n \n 02\n 09\n 2017\n \n \n 02\n 12\n 2017\n \n'],
#        'timeZone': 'America/Los_Angeles',
#        'trnName': {'long': 'AT&T Pebble Beach Pro-Am',
#         'medium': 'AT&T Pebble Beach Pro-Am',
#         'official': 'AT&T Pebble Beach Pro-Am',
#         'short': 'AT&T Pebble Beach'},
#        'trnNum': '160',
#        'trnType': 'STD',
#        'winnersShare': '1,296,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '7,000,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Dustin', 'last': 'Johnson', 'middle': ''},
#          'plrNum': '30925',
#          'winningShare': '1,260,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Riviera CC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Pacific Palisades',
#           'country': 'USA',
#           'state': 'CA'},
#          'number': '500',
#          'rank': '21'}],
#        'date': {'end': '2017-02-19', 'start': '2017-02-16', 'weekNumber': '7'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '007',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 02\n 16\n 2017\n \n \n 02\n 19\n 2017\n \n'],
#        'timeZone': 'America/Los_Angeles',
#        'trnName': {'long': 'Genesis Open',
#         'medium': 'Genesis Open',
#         'official': 'Genesis Open',
#         'short': 'Genesis Open'},
#        'trnNum': '170',
#        'trnType': 'STD',
#        'winnersShare': '1,260,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,400,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Rickie', 'last': 'Fowler', 'middle': ''},
#          'plrNum': '32102',
#          'winningShare': '1,152,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'PGA National (Champion)',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Palm Beach Gardens',
#           'country': 'USA',
#           'state': 'FL'},
#          'number': '734',
#          'rank': '5'}],
#        'date': {'end': '2017-02-26', 'start': '2017-02-23', 'weekNumber': '8'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '010',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 02\n 23\n 2017\n \n \n 02\n 26\n 2017\n \n'],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'The Honda Classic',
#         'medium': 'The Honda Classic',
#         'official': 'The Honda Classic',
#         'short': 'The Honda Classic'},
#        'trnNum': '180',
#        'trnType': 'STD',
#        'winnersShare': '1,152,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '3,240',
#        'FedExCupWinnerPoints': '550',
#        'Purse': '9,750,000',
#        'champions': [{'FedExCupWinnerShare': '550',
#          'isMember': 'YES',
#          'playerName': {'first': 'Dustin', 'last': 'Johnson', 'middle': ''},
#          'plrNum': '30925',
#          'winningShare': '1,660,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Club de Golf Chapultepec',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Mexico City', 'country': 'MEX', 'state': ''},
#          'number': '240',
#          'rank': ''}],
#        'date': {'end': '2017-03-05', 'start': '2017-03-02', 'weekNumber': '9'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.pgatour.com/tournaments/wgc-mexico-championship/en/tickets.html'},
#         'trnLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.pgatour.com/tournaments/wgc-mexico-championship/en.html'}},
#        'official': 'Yes',
#        'permNum': '473',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 03\n 02\n 2017\n \n \n 03\n 05\n 2017\n \n'],
#        'timeZone': 'America/Mexico_City',
#        'trnName': {'long': 'World Golf Championships-Mexico Championship',
#         'medium': 'WGC-Mexico Championship',
#         'official': 'World Golf Championships-Mexico Championship',
#         'short': 'WGC-Mexico Championship'},
#        'trnNum': '190',
#        'trnType': 'WGC',
#        'winnersShare': '1,660,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,300,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Adam', 'last': 'Hadwin', 'middle': ''},
#          'plrNum': '33399',
#          'winningShare': '1,134,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Innisbrook Resort (Copperhead)',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Palm Harbor', 'country': 'USA', 'state': 'FL'},
#          'number': '665',
#          'rank': '6'}],
#        'date': {'end': '2017-03-12',
#         'start': '2017-03-09',
#         'weekNumber': '10'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '475',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 03\n 09\n 2017\n \n \n 03\n 12\n 2017\n \n'],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'Valspar Championship',
#         'medium': 'Valspar Championship',
#         'official': 'Valspar Championship',
#         'short': 'Valspar Champ'},
#        'trnNum': '200',
#        'trnType': 'STD',
#        'winnersShare': '1,134,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '8,700,000',
#        'champions': [{'FedExCupWinnerShare': '500',
#          'isMember': 'YES',
#          'playerName': {'first': 'Marc', 'last': 'Leishman', 'middle': ''},
#          'plrNum': '26851',
#          'winningShare': '1,566,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Bay Hill Club & Lodge',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Orlando', 'country': 'USA', 'state': 'FL'},
#          'number': '009',
#          'rank': '28'}],
#        'date': {'end': '2017-03-19',
#         'start': '2017-03-16',
#         'weekNumber': '11'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '009',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 03\n 16\n 2017\n \n \n 03\n 19\n 2017\n \n'],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'Arnold Palmer Invitational presented by Mastercard',
#         'medium': "Arnold Palmer Invt'l",
#         'official': 'Arnold Palmer Invitational presented by Mastercard',
#         'short': "Arnold Palmer Invt'l"},
#        'trnNum': '210',
#        'trnType': 'STD',
#        'winnersShare': '1,566,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '1,756',
#        'FedExCupWinnerPoints': '300',
#        'Purse': '3,000,000',
#        'champions': [{'FedExCupWinnerShare': '300',
#          'isMember': 'YES',
#          'playerName': {'first': 'D.A.', 'last': 'Points', 'middle': ''},
#          'plrNum': '25240',
#          'winningShare': '540,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Coco Beach Golf & CC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Rio Grande', 'country': 'PUR', 'state': ''},
#          'number': '742',
#          'rank': '24'}],
#        'date': {'end': '2017-03-26',
#         'start': '2017-03-23',
#         'weekNumber': '12'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '483',
#        'presBy': '',
#        'primaryEvent': 'N',
#        'scored': '2',
#        'subEvents': ['\n \n 03\n 23\n 2017\n \n \n 03\n 26\n 2017\n \n'],
#        'timeZone': 'America/Puerto_Rico',
#        'trnName': {'long': 'Puerto Rico Open',
#         'medium': 'Puerto Rico Open',
#         'official': 'Puerto Rico Open',
#         'short': 'Puerto Rico'},
#        'trnNum': '220',
#        'trnType': 'ALT',
#        'winnersShare': '540,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '3,240',
#        'FedExCupWinnerPoints': '550',
#        'Purse': '9,750,000',
#        'champions': [{'FedExCupWinnerShare': '550',
#          'isMember': 'YES',
#          'playerName': {'first': 'Dustin', 'last': 'Johnson', 'middle': ''},
#          'plrNum': '30925',
#          'winningShare': '1,660,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Austin Country Club',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Austin', 'country': 'USA', 'state': 'TX'},
#          'number': '185',
#          'rank': ''}],
#        'date': {'end': '2017-03-26',
#         'start': '2017-03-22',
#         'weekNumber': '12'},
#        'format': 'Match',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.pgatour.com/tournaments/wgc-dell-technologies-match-play.html'}},
#        'official': 'Yes',
#        'permNum': '470',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 03\n 22\n 2017\n \n \n 03\n 26\n 2017\n \n'],
#        'timeZone': 'America/Chicago',
#        'trnName': {'long': 'World Golf Championships-Dell Technologies Match Play',
#         'medium': 'WGC-Dell Tech Match Play',
#         'official': 'World Golf Championships-Dell Technologies Match Play',
#         'short': 'WGC-Match Play'},
#        'trnNum': '230',
#        'trnType': 'WGC',
#        'winnersShare': '1,660,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '7,000,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Jim', 'last': 'Herman', 'middle': ''},
#          'plrNum': '31557',
#          'winningShare': '1,224,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'GC of Houston',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Humble', 'country': 'USA', 'state': 'TX'},
#          'number': '729',
#          'rank': '23'}],
#        'date': {'end': '2017-04-02',
#         'start': '2017-03-30',
#         'weekNumber': '13'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '020',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 03\n 30\n 2017\n \n \n 04\n 02\n 2017\n \n'],
#        'timeZone': 'America/Chicago',
#        'trnName': {'long': 'Shell Houston Open',
#         'medium': 'Shell Houston Open',
#         'official': 'Shell Houston Open',
#         'short': 'Shell Houston Open'},
#        'trnNum': '240',
#        'trnType': 'STD',
#        'winnersShare': '1,260,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '3,375',
#        'FedExCupWinnerPoints': '600',
#        'Purse': '10,000,000',
#        'champions': [{'isMember': 'NO',
#          'playerName': {'first': 'Danny', 'last': 'Willett', 'middle': ''},
#          'plrNum': '32139',
#          'winningShare': '1,800,000.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Augusta National GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Augusta', 'country': 'USA', 'state': 'GA'},
#          'number': '014',
#          'rank': '3'}],
#        'date': {'end': '2017-04-09',
#         'start': '2017-04-06',
#         'weekNumber': '14'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '014',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '1',
#        'subEvents': ['\n \n 04\n 06\n 2017\n \n \n 04\n 09\n 2017\n \n'],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'Masters Tournament',
#         'medium': 'Masters Tournament',
#         'official': 'Masters Tournament',
#         'short': 'Masters Tournament'},
#        'trnNum': '250',
#        'trnType': 'MJR',
#        'winnersShare': '',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,500,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Branden', 'last': 'Grace', 'middle': ''},
#          'plrNum': '29974',
#          'winningShare': '1,062,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'Harbour Town GL',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Hilton Head', 'country': 'USA', 'state': 'SC'},
#          'number': '012',
#          'rank': '8'}],
#        'date': {'end': '2017-04-16',
#         'start': '2017-04-13',
#         'weekNumber': '15'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '012',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 04\n 13\n 2017\n \n \n 04\n 16\n 2017\n \n'],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'RBC Heritage',
#         'medium': 'RBC Heritage',
#         'official': 'RBC Heritage',
#         'short': 'RBC Heritage'},
#        'trnNum': '260',
#        'trnType': 'STD',
#        'winnersShare': '1,170,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '6,200,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Charley', 'last': 'Hoffman', 'middle': ''},
#          'plrNum': '12716',
#          'winningShare': '1,116,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'TPC San Antonio - AT&T Oaks',
#          'host': 'Yes',
#          'isTpc': 'Yes',
#          'location': {'city': 'San Antonio', 'country': 'USA', 'state': 'TX'},
#          'number': '770',
#          'rank': '17'}],
#        'date': {'end': '2017-04-23',
#         'start': '2017-04-20',
#         'weekNumber': '16'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.avis.com/golf'},
#         'flightsLink': {'isLinked': 'y',
#          'overrideUrl': 'http://www.united.com'},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'y', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '041',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '3',
#        'subEvents': ['\n \n 04\n 20\n 2017\n \n \n 04\n 23\n 2017\n \n'],
#        'timeZone': 'America/Chicago',
#        'trnName': {'long': 'Valero Texas Open',
#         'medium': 'Valero Texas Open',
#         'official': 'Valero Texas Open',
#         'short': 'Valero Texas Open'},
#        'trnNum': '270',
#        'trnType': 'STD',
#        'winnersShare': '1,116,000',
#        'year': '2017'},
#       {'FedExCup': 'Yes',
#        'FedExCupPurse': '2,989',
#        'FedExCupWinnerPoints': '500',
#        'Purse': '7,100,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Brian', 'last': 'Stuard', 'middle': ''},
#          'plrNum': '31560',
#          'winningShare': '1,260,000.00'}],
#        'coSponsored': 'Yes',
#        'courses': [{'courseName': 'TPC Louisiana',
#          'host': 'Yes',
# ...
#          'number': '012',
#          'rank': '2'}],
#        'date': {'end': '2017-06-04',
#         'start': '2017-06-01',
#         'weekNumber': '22'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '011',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 06\n 01\n 2017\n \n \n 06\n 04\n 2017\n \n'],
#        'timeZone': 'America/Los_Angeles',
#        'trnName': {'long': 'Freedom 55 Financial Open',
#         'medium': 'Freedom 55 Open',
#         'official': 'Freedom 55 Financial Open',
#         'short': 'Freedom 55'},
#        'trnNum': '060',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '175,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Adam', 'last': 'Cornelson', 'middle': ''},
#          'plrNum': '35415',
#          'winningShare': '31,500.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Uplands GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Victoria, BC', 'country': 'CAN', 'state': ''},
#          'number': '002',
#          'rank': '4'}],
#        'date': {'end': '2017-06-11',
#         'start': '2017-06-08',
#         'weekNumber': '23'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '002',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 06\n 08\n 2017\n \n \n 06\n 11\n 2017\n \n'],
#        'timeZone': 'America/Los_Angeles',
#        'trnName': {'long': 'Bayview Place DC Payments Open presented by Times Colonist',
#         'medium': 'Bayview Place DC Payments Open',
#         'official': 'Bayview Place DC Payments Open presented by Times Colonist',
#         'short': 'Bayview Place DC Payments'},
#        'trnNum': '070',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '175,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Dan', 'last': 'McCarthy', 'middle': ''},
#          'plrNum': '29675',
#          'winningShare': '31,500.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': "Gallagher's Canyon G&CC",
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Kelowna, BC', 'country': 'CAN', 'state': ''},
#          'number': '802',
#          'rank': '6'}],
#        'date': {'end': '2017-06-18',
#         'start': '2017-06-15',
#         'weekNumber': '24'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '039',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 06\n 15\n 2017\n \n \n 06\n 18\n 2017\n \n'],
#        'timeZone': 'America/Los_Angeles',
#        'trnName': {'long': 'GolfBC Championship',
#         'medium': 'GolfBC Champ',
#         'official': 'GolfBC Championship',
#         'short': 'GolfBC Chp'},
#        'trnNum': '080',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '175,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Dan', 'last': 'McCarthy', 'middle': ''},
#          'plrNum': '29675',
#          'winningShare': '31,500.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Pine Ridge GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Winnipeg, Manitoba',
#           'country': 'CAN',
#           'state': ''},
#          'number': '006',
#          'rank': ''}],
#        'date': {'end': '2017-07-09',
#         'start': '2017-07-06',
#         'weekNumber': '27'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '006',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 07\n 06\n 2017\n \n \n 07\n 09\n 2017\n \n'],
#        'timeZone': 'America/Chicago',
#        'trnName': {'long': 'The Players Cup',
#         'medium': 'The Players Cup',
#         'official': 'Players Cup',
#         'short': 'The Players Cup'},
#        'trnNum': '090',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '175,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Taylor', 'last': 'Moore', 'middle': ''},
#          'plrNum': '49947',
#          'winningShare': '31,500.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Whitewater GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Thunder Bay, ON',
#           'country': 'CAN',
#           'state': ''},
#          'number': '013',
#          'rank': '3'}],
#        'date': {'end': '2017-07-16',
#         'start': '2017-07-13',
#         'weekNumber': '28'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '012',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 07\n 13\n 2017\n \n \n 07\n 16\n 2017\n \n'],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'Staal Foundation Open presented by Tbaytel',
#         'medium': 'Staal Foundtn.',
#         'official': 'Staal Foundation Open presented by Tbaytel',
#         'short': 'Staal Foundtn.'},
#        'trnNum': '100',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '175,000',
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Club de Golf Quatre Domaines',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Mirabel, QC', 'country': 'CAN', 'state': ''},
#          'number': '024',
#          'rank': ''}],
#        'date': {'end': '2017-07-23',
#         'start': '2017-07-20',
#         'weekNumber': '29'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '044',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': [],
#        'timeZone': 'America/Toronto',
#        'trnName': {'long': 'Mackenzie Investments Open',
#         'medium': 'Mackenzie Open',
#         'official': 'Mackenzie Investments Open presented by Jaguar Laval',
#         'short': 'Mackenzie Investments Open'},
#        'trnNum': '110',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '175,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Aaron', 'last': 'Wise', 'middle': ''},
#          'plrNum': '49964',
#          'winningShare': '31,500.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Windermere G&CC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Edmonton, AB', 'country': 'CAN', 'state': ''},
#          'number': '023',
#          'rank': ''}],
#        'date': {'end': '2017-08-06',
#         'start': '2017-08-03',
#         'weekNumber': '31'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '040',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 08\n 03\n 2017\n \n \n 08\n 06\n 2017\n \n'],
#        'timeZone': 'America/Denver',
#        'trnName': {'long': 'Oil Country Championship',
#         'medium': 'Oil Country Champ',
#         'official': 'Syncrude Oil Country Championship presented by AECON',
#         'short': 'Oil Champ'},
#        'trnNum': '120',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '175,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Charlie', 'last': 'Bull', 'middle': ''},
#          'plrNum': '47652',
#          'winningShare': '31,500.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Country Hills GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Calgary, AB', 'country': 'CAN', 'state': ''},
#          'number': '003',
#          'rank': '8'}],
#        'date': {'end': '2017-08-13',
#         'start': '2017-08-10',
#         'weekNumber': '32'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '003',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 08\n 10\n 2017\n \n \n 08\n 13\n 2017\n \n'],
#        'timeZone': 'America/Denver',
#        'trnName': {'long': 'ATB Financial Classic',
#         'medium': 'ATB Financial Classic',
#         'official': 'ATB Financial Classic',
#         'short': 'ATB Financial Classic'},
#        'trnNum': '130',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '175,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Brock', 'last': 'Mackenzie', 'middle': ''},
#          'plrNum': '27768',
#          'winningShare': '31,500.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Hylands GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Ottawa, ON', 'country': 'CAN', 'state': ''},
#          'number': '014',
#          'rank': '7'}],
#        'date': {'end': '2017-08-20',
#         'start': '2017-08-17',
#         'weekNumber': '33'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '013',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 08\n 17\n 2017\n \n \n 08\n 20\n 2017\n \n'],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'National Capital Open to Support Our Troops',
#         'medium': 'National Capital Open to Support Our Tro',
#         'official': 'National Capital Open to Support Our Troops',
#         'short': 'National Capital Open to Sup'},
#        'trnNum': '140',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '175,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Dan', 'last': 'McCarthy', 'middle': ''},
#          'plrNum': '29675',
#          'winningShare': '31,500.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Bell Bay GC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'Baddeck, NS', 'country': 'CAN', 'state': ''},
#          'number': '805',
#          'rank': '5'}],
#        'date': {'end': '2017-09-03',
#         'start': '2017-08-31',
#         'weekNumber': '35'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '009',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 08\n 31\n 2017\n \n \n 09\n 03\n 2017\n \n'],
#        'timeZone': 'Atlantic/Bermuda',
#        'trnName': {'long': 'Cape Breton Open',
#         'medium': 'Cape Breton Open',
#         'official': 'Cape Breton Open',
#         'short': 'Cape Breton'},
#        'trnNum': '150',
#        'trnType': '',
#        'winnersShare': '31,500',
#        'year': '2017'},
#       {'': '',
#        'Purse': '200,000',
#        'champions': [{'isMember': 'YES',
#          'playerName': {'first': 'Paul', 'last': 'Barjon', 'middle': ''},
#          'plrNum': '37212',
#          'winningShare': '36,000.00'}],
#        'coSponsored': 'No',
#        'courses': [{'courseName': 'Highland CC',
#          'host': 'Yes',
#          'isTpc': 'No',
#          'location': {'city': 'London, ON', 'country': 'CAN', 'state': ''},
#          'number': '021',
#          'rank': '12'}],
#        'date': {'end': '2017-09-17',
#         'start': '2017-09-14',
#         'weekNumber': '37'},
#        'format': 'Stroke',
#        'links': {'carsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'flightsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'hotelsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'lbLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'ticketsLink': {'isLinked': 'n', 'overrideUrl': ''},
#         'trnLink': {'isLinked': 'y', 'overrideUrl': ''}},
#        'official': 'Yes',
#        'permNum': '010',
#        'presBy': '',
#        'primaryEvent': 'Y',
#        'scored': '2',
#        'subEvents': ['\n \n 09\n 14\n 2017\n \n \n 09\n 17\n 2017\n \n'],
#        'timeZone': 'America/New_York',
#        'trnName': {'long': 'Freedom 55 Financial Championship',
#         'medium': 'Freedom 55 Financial Championship',
#         'official': 'Freedom 55 Financial Championship',
#         'short': 'Freedom 55 Financial Champ'},
#        'trnNum': '170',
#        'trnType': '',
#        'winnersShare': '36,000',
#        'year': '2017'}]}],
#    'year': '2017'}]}

# %%
now = datetime.now()

os.chdir('/home/valesco/Datasets/PGA_Data/PGA/')
folders = glob('*')
folders

tourny_ls = []

for tourny in sched_data['years'][0]['tours'][0]['trns']:
    start = pd.to_datetime(tourny['date']['end'])
    year = start.year
    tourny_num = tourny['permNum']
    tourny_id = tourny_num + '_' + str(year)
    if start < now:
        tourny_ls.append(tourny_id)
                            
for tourny in tourny_ls:
    if tourny in folders:
        tourny_ls.remove(tourny)
        
tourny_ls
# Out:
# ['494_2016',
#  '489_2016',
#  '457_2016',
#  '169_2016',
#  '058_2016',
#  '016_2017',
#  '006_2017',
#  '002_2017',
#  '004_2017',
#  '003_2017',
#  '005_2017',
#  '007_2017',
#  '010_2017',
#  '473_2017',
#  '475_2017',
#  '009_2017',
#  '483_2017',
#  '470_2017',
#  '020_2017']

# %%
tournsum_file = open('/home/valesco/Datasets/PGA_Data/PGA/032_2016/032_2016_tournsum.json')
tournsum_data = json.load(tournsum_file)
tournsum_data['years'][0]['tours'][0]['trns'][0]['plrs'][0]['plrNum']
# Out:
# '27064'

# %%
for tournament_id in tourny:
    time.sleep(1)        
    exists = 0
    tournament = tournament_id.split('_')[0]
    year = tournament_id.split('_')[1]
    base_url = 'http://www.pgatour.com/data/r/'
    complete_url = base_url + tournament + '/' + year + '/'
    request = requests.get(complete_url)

    #try:
        #create base path
    path = '/home/valesco/Datasets/PGA_Data/PGA/' + tournament + '_' + year

    #check to see if data has already been downloaded
    if os.path.isdir(path) is True:
        print(tournament + '_' + year + ' already exists')
        pass

    else:                
        #make and change directory
        os.mkdir(path)
        os.chdir(path)
        print('Directory Created: ' + path)

        #download course.json file
        course_url = complete_url + 'course.json'
        course_filename = tournament + '_' + year + '_' + 'course.json'
        urllib.request.urlretrieve(course_url, course_filename)

        time.sleep(.5)
        #download leaderboard.json file
        leaderboard_url = complete_url + 'leaderboard-v2.json'
        leaderboard_filename = tournament + '_' + year + '_' + 'leaderboard-v2.json'
        urllib.request.urlretrieve(leaderboard_url, leaderboard_filename)

        time.sleep(.5)
        #download player_stats.json file
        stats_url = complete_url + 'player_stats.json'
        stats_filename = tournament + '_' + year + '_' + 'player_stats.json'
        urllib.request.urlretrieve(stats_url, stats_filename)

        time.sleep(.5)
        #download teetimes.json file
        teetimes_url = complete_url + 'teetimes.json'
        teetimes_filename = tournament + '_' + year + '_' + 'teetimes.json'
        urllib.request.urlretrieve(teetimes_url, teetimes_filename)

        time.sleep(.5)
        #download tourny summary json file
        tournsum_url = complete_url + 'tournsum.json'
        tournsum_filename = tournament + '_' + year + '_' + 'tournsum.json'
        urllib.request.urlretrieve(tournsum_url, tournsum_filename)
    
        time.sleep(.5)
        money_url = complete_url + 'money.json'
        money_filename = tournament + '_' + year + '_' + 'money.json'
        urllib.request.urlretrieve(money_url, money_filename)
        
        time.sleep(.5)
        playoff_url = complete_url + 'playoff_info.json'
        playoff_filename = tournament + '_' + year + '_' + 'playoff_info.json'
        urllib.request.urlretrieve(playoff_url, playoff_filename)
        
        time.sleep(.5)
        tournsum_url = complete_url + 'tournsum.json'
        tournsum_filename = tournament + '_' + year + '_' + 'tournsum.json'
        urllib.request.urlretrieve(tournsum_url, tournsum_filename)

        
        time.sleep(.5)
        json_setup_url = complete_url + 'setup.json'
        json_setup_filename = tournament + '_' + year + '_' + 'setup.json'
        urllib.request.urlretrieve(json_setup_url, json_setup_filename)

        time.sleep(.5)
        xml_setup_url = complete_url + 'setup.xml'
        xml_setup_filename = tournament + '_' + year + '_' + 'setup.xml'
        urllib.request.urlretrieve(xml_setup_url, xml_setup_filename)

        time.sleep(.5)
        course_stat_url = complete_url + 'coursestat.json'
        course_stat_filename = tournament + '_' + year + '_' + 'coursestat.json'
        urllib.request.urlretrieve(course_stat_url, course_stat_filename)

        tournsum_file = open(tournsum_filename)
        tournsum_data = json.load(tournsum_file)
        
        player_ls = []
        for player in tournsum_data['years'][0]['tours'][0]['trns'][0]['plrs']:
            player_ls.append(player['plrNum'])

        #create and change to directory to store player summaries
        new_path = path + '/PlayerScoreCards/'
        os.mkdir(new_path)
        os.chdir(new_path)

        #iterate through player href's
        for player in player_ls:
            temp_path = players_url + temp
            urllib.request.urlretrieve(temp_path, temp)

        print('Players JSON Files Saved')
    #except:
        #print("Exception for " + complete_url)
# Out:
# 002_2016 already exists
# 003_2016 already exists
# 004_2016 already exists
# 005_2016 already exists
# 006_2016 already exists
# 007_2016 already exists
# 009_2016 already exists
# 010_2016 already exists
# 011_2016 already exists
# 012_2016 already exists
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/013_2016
# /home/valesco/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /home/valesco/anaconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Players JSON Files Saved
# 014_2016 already exists
# 016_2016 already exists
# 018_2016 already exists
# 019_2016 already exists
# 020_2016 already exists
# 021_2016 already exists
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/023_2016
# Exception for http://www.pgatour.com/data/r/023/2016/
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/025_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/026_2016
# Exception for http://www.pgatour.com/data/r/026/2016/
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/027_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/028_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/030_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/032_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/033_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/034_2016
# Players JSON Files Saved
# 041_2016 already exists
# 047_2016 already exists
# 054_2016 already exists
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/058_2016
# Exception for http://www.pgatour.com/data/r/058/2016/
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/060_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/100_2016
# Players JSON Files Saved
# 457_2016 already exists
# 464_2016 already exists
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/468_2016
# Exception for http://www.pgatour.com/data/r/468/2016/
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/470_2016
# Exception for http://www.pgatour.com/data/r/470/2016/
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/471_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/472_2016
# Players JSON Files Saved
# 473_2016 already exists
# 475_2016 already exists
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/476_2016
# Players JSON Files Saved
# 478_2016 already exists
# 480_2016 already exists
# 483_2016 already exists
# 489_2016 already exists
# 493_2016 already exists
# 494_2016 already exists
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/505_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/518_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/519_2016
# Players JSON Files Saved
# Directory Created: /home/valesco/Datasets/PGA_Data/PGA/650_2016
# Exception for http://www.pgatour.com/data/r/650/2016/

# %%
base_url = 'http://pgatour.com/data/r/'

os.chdir('/home/valesco/Datasets/PGA_Data/PGA/')

folders = os.walk(os.getcwd())
folder_dirs = []
for f in folders:
    if 'PlayerScoreCards' in f[0]:
        folder_dirs.append(f[0])
        
tourny_names = []
for z in folder_dirs:
    z = z.replace('/PlayerScoreCards', '')
    z = z.replace('/home/valesco/Datasets/PGA_Data/PGA/','')
    z = z.split('_')[0]
    if z not in tourny_names:
        tourny_names.append(z)
tourny_names
# Out:
# ['013',
#  '021',
#  '483',
#  '020',
#  '060',
#  '034',
#  '026',
#  '100',
#  '010',
#  '023',
#  '471',
#  '464',
#  '493',
#  '027',
#  '476',
#  '028',
#  '030',
#  '505',
#  '007',
#  '472',
#  '518',
#  '473',
#  '475',
#  '006',
#  '457',
#  '490',
#  '018',
#  '041',
#  '002',
#  '011',
#  '478',
#  '494',
#  '014',
#  '016',
#  '019',
#  '032',
#  '480',
#  '005',
#  '003',
#  '047',
#  '519',
#  '025',
#  '033',
#  '012',
#  '054',
#  '009',
#  'Old',
#  '004',
#  '489',
#  '500']

# %%
year_list = ['2016']

for tournament in tourny_names:
    for year in year_list:
        exists = 0
        base_url = 'http://www.pgatour.com/data/r/'
        complete_url = base_url + tournament + '/' + year + '/'
        request = requests.get(complete_url)
        if request.status_code == 200:
            exists = 1
        if exists == 1:
            try:
                pga_dir ='/home/valesco/Datasets/PGA_Data/PGA/'+ tournament + '_' + year
                os.chdir(pga_dir)

                money_url = complete_url + 'money.json'
                money_filename = tournament + '_' + year + '_' + 'money.json'
                urllib.request.urlretrieve(money_url, money_filename)

                playoff_url = complete_url + 'playoff_info.json'
                playoff_filename = tournament + '_' + year + '_' + 'playoff_info.json'
                urllib.request.urlretrieve(playoff_url, playoff_filename)
                
                tournsum_url = complete_url + 'tournsum.json'
                tournsum_filename = tournament + '_' + year + '_' + 'tournsum.json'
                urllib.request.urlretrieve(tournsum_url, tournsum_filename)
                
                json_setup_url = complete_url + 'setup.json'
                json_setup_filename = tournament + '_' + year + '_' + 'setup.json'
                urllib.request.urlretrieve(json_setup_url, json_setup_filename)
                
                xml_setup_url = complete_url + 'setup.xml'
                xml_setup_filename = tournament + '_' + year + '_' + 'setup.xml'
                urllib.request.urlretrieve(xml_setup_url, xml_setup_filename)
                
                course_stat_url = complete_url + 'coursestat.json'
                course_stat_filename = tournament + '_' + year + '_' + 'coursestat.json'
                urllib.request.urlretrieve(course_stat_url, course_stat_filename)
                                             
                print('files saved for: ', complete_url)
            except:
                print("Exception for " + complete_url)
# Out:
# files saved for:  http://www.pgatour.com/data/r/013/2016/
# files saved for:  http://www.pgatour.com/data/r/021/2016/
# files saved for:  http://www.pgatour.com/data/r/483/2016/
# files saved for:  http://www.pgatour.com/data/r/020/2016/
# files saved for:  http://www.pgatour.com/data/r/060/2016/
# files saved for:  http://www.pgatour.com/data/r/034/2016/
# Exception for http://www.pgatour.com/data/r/026/2016/
# files saved for:  http://www.pgatour.com/data/r/100/2016/
# files saved for:  http://www.pgatour.com/data/r/010/2016/
# files saved for:  http://www.pgatour.com/data/r/023/2016/
# files saved for:  http://www.pgatour.com/data/r/471/2016/
# files saved for:  http://www.pgatour.com/data/r/464/2016/
# files saved for:  http://www.pgatour.com/data/r/493/2016/
# files saved for:  http://www.pgatour.com/data/r/027/2016/
# files saved for:  http://www.pgatour.com/data/r/476/2016/
# files saved for:  http://www.pgatour.com/data/r/028/2016/
# files saved for:  http://www.pgatour.com/data/r/030/2016/
# files saved for:  http://www.pgatour.com/data/r/505/2016/
# files saved for:  http://www.pgatour.com/data/r/007/2016/
# files saved for:  http://www.pgatour.com/data/r/472/2016/
# files saved for:  http://www.pgatour.com/data/r/518/2016/
# files saved for:  http://www.pgatour.com/data/r/473/2016/
# files saved for:  http://www.pgatour.com/data/r/475/2016/
# files saved for:  http://www.pgatour.com/data/r/006/2016/
# files saved for:  http://www.pgatour.com/data/r/457/2016/
# files saved for:  http://www.pgatour.com/data/r/018/2016/
# files saved for:  http://www.pgatour.com/data/r/041/2016/
# files saved for:  http://www.pgatour.com/data/r/002/2016/
# files saved for:  http://www.pgatour.com/data/r/011/2016/
# files saved for:  http://www.pgatour.com/data/r/478/2016/
# files saved for:  http://www.pgatour.com/data/r/494/2016/
# files saved for:  http://www.pgatour.com/data/r/014/2016/
# files saved for:  http://www.pgatour.com/data/r/016/2016/
# files saved for:  http://www.pgatour.com/data/r/019/2016/
# files saved for:  http://www.pgatour.com/data/r/032/2016/
# files saved for:  http://www.pgatour.com/data/r/480/2016/
# files saved for:  http://www.pgatour.com/data/r/005/2016/
# files saved for:  http://www.pgatour.com/data/r/003/2016/
# files saved for:  http://www.pgatour.com/data/r/047/2016/
# files saved for:  http://www.pgatour.com/data/r/519/2016/
# files saved for:  http://www.pgatour.com/data/r/025/2016/
# files saved for:  http://www.pgatour.com/data/r/033/2016/
# files saved for:  http://www.pgatour.com/data/r/012/2016/
# files saved for:  http://www.pgatour.com/data/r/054/2016/
# files saved for:  http://www.pgatour.com/data/r/009/2016/
# files saved for:  http://www.pgatour.com/data/r/004/2016/
# files saved for:  http://www.pgatour.com/data/r/489/2016/

# %%
money_url
# Out:
# 'http://www.pgatour.com/data/r/009/2016/money.json'

# %%
urllib.request.urlretrieve(money_url, money_filename)
# Out:
# ('009_2016_money.json', <http.client.HTTPMessage at 0x7f2356fb0ac8>)
