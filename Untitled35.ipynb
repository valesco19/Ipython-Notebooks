# %%
import json
import os
import glob
import pandas as pd
import requests
import time
from datetime import datetime, timedelta
from random import randint
from pga.return_pid import return_pid
from pga.fuzz_match import return_tid
from sqlalchemy import create_engine
from pandas.io import sql


def return_tourny_avg(row):
    event_id = row['event_id']
    weekend = row['weekend']

    avg_points = grouped_df['actual_points']['mean'].loc[(grouped_df['event_id'] == event_id) & (grouped_df['weekend'] == weekend)].values[0]

    return avg_points

def return_tourny_std(row):
    event_id = row['event_id']
    weekend = row['weekend']

    std_points = grouped_df['actual_points']['std'].loc[(grouped_df['event_id'] == event_id) & (grouped_df['weekend'] == weekend)].values[0]

    return std_points

def norm_points(row):
    return (row['actual_points'] - row['tourny_avg_points']) / row['tourny_std_points']

now = datetime.now()
final_dict = {}
final_dict['salary'] = {}
final_dict['events'] = {}
final_dict['ownership'] = {}
final_dict['source'] = {}


#Retrieve data from last week

for i in range(1,2):
    date_str = (now - timedelta(i)).strftime('%-m_%-d_%Y')


    #Get salary data
    sal_url = 'http://www.fantasylabs.com/api/playermodel/5/{}/?modelId=313179'.format(date_str)

    sal_resp = requests.get(sal_url)
    sal_data = json.loads(sal_resp.text)
    
    try:
        if len(sal_data['PlayerModels']) > 0:
            sal_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/salary_data/{}_salary_data.json'.format(date_str)

            if os.path.isfile(sal_file_name) is False:

                final_dict['salary'][date_str] = sal_data
                with open(sal_file_name, 'w') as outfile:
                    json.dump(sal_data, outfile)

                print(date_str + ' salary file saved!')
    except:
        pass

    wait = 1
    time.sleep(wait)

    #Get sportevents data
    event_url = 'http://www.fantasylabs.com/api/sportevents/5/{}'.format(date_str)

    event_resp = requests.get(event_url)
    event_data = json.loads(event_resp.text)



    if len(event_data) > 0:
        event_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/sportevent_data/{}_sportevent_data.json'.format(date_str)

        if os.path.isfile(event_file_name) is False:

            final_dict['events'][date_str] = event_data

            with open(event_file_name, 'w') as outfile:
                json.dump(event_data, outfile)

                print(date_str + ' sportevents file saved')

    time.sleep(wait)

    #get ownership data
    own_url = 'http://www.fantasylabs.com/api/contest-ownership/5/{}/4'.format(date_str)

    own_resp = requests.get(own_url)
    own_data = json.loads(own_resp.text)

    if len(own_data) > 0:
        own_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/ownership_data/{}_ownership_data.json'.format(date_str)

        if os.path.isfile(own_file_name) is False:

            final_dict['ownership'][date_str] = own_data

            with open(own_file_name, 'w') as outfile:
                json.dump(own_data, outfile)

                print(date_str + ' ownership file saved')
                
                
    #get source data
    
    source_url = 'http://www.fantasylabs.com/api/sourcedata/5/{}'.format(date_str)
    
    source_data = requests.get(source_url).json()

    
    if len(source_data) > 0:
        source_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/source_data/{}_source_data.json'.format(date_str)
        
        if os.path.isfile(source_file_name) is False:
            
            final_dict['source'][date_str] = source_data
            
            with open(source_file_name, 'w') as outfile:
                json.dump(source_data, outfile)
                
                print(date_str + ' source data saved')
                
        
#Parse Results

sal_keys = final_dict['salary'].keys()


pga_salary = pd.DataFrame(columns = ['player_name', 'player_id', 'date_obj', 'event_id', 'tournament_name', 
                        'tournament_id', 'tourny_date', 'tourny_course', 'tour', 'salary', 'actual_points',
                        'imp_points', 'proj_points', 'score', 'plus_minus', 'injury_status', 'source',
                        'fantasy_id', 'weekend'])
count = 0

for sal_key in sal_keys:

    date_obj = datetime.strptime(sal_key, '%m_%d_%Y')

    for player in final_dict['salary'][sal_key]['PlayerModels']:
        switch = 0
        player_name = player['Properties']['Player_Name']
        player_id = return_pid(player_name)
        salary = player['Properties']['Salary']
        actual_points = player['Properties']['ActualPoints']
        imp_points = player['Properties']['ImpPts']
        proj_points = player['ProjPoints']
        score = player['Properties']['Score']
        injury_status = player['Properties']['InjuryStatus']
        plus_minus = player['Properties']['Plus_Minus']
        source = player['Properties']['SourceId']
        fantasy_id = player['FantasyResultId']


        if source == 4:
            event_id = player['Properties']['EventId']

            for event in final_dict['events'][sal_key]:
                if event['EventId'] == event_id:
                    tourny_name = event['HomeTeam']
                    tourny_date = event['EventDate']
                    tourny_course = event['StadiumName']
                    tournament_id = return_tid(tourny_name)
                    tour = event['VisitorTeam']
                    switch = 1

            if switch == 0:
                print('SWITCH ENGAGED!!!', tourny_name, tourny_date, file)
                tourny_name = np.nan
                tourny_date = np.nan
                tourny_course = np.nan
                tour = np.nan

            pga_salary.loc[count] = [player_name, player_id, date_obj, tourny_id, tourny_name, tournament_id,
                                     tourny_date, tourny_course, tour,
                                     salary, actual_points, imp_points, proj_points,
                                     score, plus_minus, injury_status, source, fantasy_id, 0]

            count += 1

#Find unique tournaments in df and retrieve year
tournaments = pga_salary['tournament_name'].unique()
year = pd.to_datetime(pga_salary['tourny_date'].loc[0]).year

#Connect to mysql db
engine = create_engine('mysql+pymysql://root:v1933@127.0.0.1:3306/pga?charset=utf8')
conn = engine.connect()

#Check if tournament and year exist in db, if not insert results
for tournament in tournaments:
    temp_results = conn.execute('SELECT * FROM pga.dk_salaries WHERE tournament_name = "{}" AND \
            YEAR(tourny_date) = {}'.format(tournament, year))

    temp_ls = []

    for result in temp_results:
        temp_ls.append(result)

    if len(temp_ls) < 1:
        agg_dict = {'actual_points': ['mean', 'std']}

        temp_df = pga_salary.loc[pga_salary['tournament_name'] == tournament]
        
        #Separate Weekend salaries from main contest salaries
        
        players = temp_df['player_name'].unique()

        temp_df.sort_values('fantasy_id', inplace = True)
        temp_df.reset_index(inplace = True, drop = True)

        for player in players:
            indices = sorted(temp_df.index[temp_df['player_name'] == player])
            
            if len(indices) > 1:
                temp_df['weekend'][indices[1]] = 1
        
        # Create grouped df to calc tourny std and avg
        grouped_df = temp_df[['event_id', 'weekend', 'actual_points']].groupby(['event_id', 'weekend']).agg(agg_dict)
        grouped_df.reset_index(inplace = True)

        temp_df['tourny_std_points'] = temp_df.apply(return_tourny_std, axis = 1)
        temp_df['tourny_avg_points'] = temp_df.apply(return_tourny_avg, axis = 1)
        temp_df['norm_points'] = temp_df.apply(norm_points, axis = 1)

        #temp_df.to_sql('dk_salaries', engine,
                        #if_exists = 'append', index = False)
# Out:
# 7_23_2017 salary file saved!
# 7_23_2017 sportevents file saved
# /home/valesco/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:219: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
source_data
# Out:
# {'ContestGroups': [{'AdminEdit': False,
#    'ContestEndDate': '2017-07-23T01:35:00',
#    'ContestGroupId': 15077,
#    'ContestStartDate': '2017-07-20T01:35:00',
#    'ContestSuffix': ' (PGA)',
#    'DisplayName': '1:35AM ET (PGA) - 4 Games',
#    'DraftGroupId': 14130,
#    'Events': [{'ContestGroupId': 15077, 'SportEventId': 3453281}],
#    'GameCount': 4,
#    'IsOpen': False,
#    'IsPrimary': False,
#    'IsProjected': False,
#    'SourceId': 4,
#    'SportId': 5},
#   {'AdminEdit': False,
#    'ContestEndDate': '2017-07-23T04:20:00',
#    'ContestGroupId': 15235,
#    'ContestStartDate': '2017-07-22T04:20:00',
#    'ContestSuffix': ' (Weekend PGA)',
#    'DisplayName': '4:20AM ET (Weekend PGA) - 2 Games',
#    'DraftGroupId': 14354,
#    'Events': [],
#    'GameCount': 2,
#    'IsOpen': False,
#    'IsPrimary': False,
#    'IsProjected': False,
#    'SourceId': 4,
#    'SportId': 5},
#   {'AdminEdit': False,
#    'ContestEndDate': '0001-01-01T00:00:00',
#    'ContestGroupId': 15094,
#    'ContestStartDate': '2017-07-20T01:35:00',
#    'ContestSuffix': '(Main)',
#    'DisplayName': '1:35AM ET(Main) - 1 Games',
#    'DraftGroupId': 20062,
#    'Events': [{'ContestGroupId': 15094, 'SportEventId': 3453281}],
#    'GameCount': 1,
#    'IsOpen': False,
#    'IsPrimary': False,
#    'IsProjected': False,
#    'SourceId': 3,
#    'SportId': 5},
#   {'AdminEdit': False,
#    'ContestEndDate': '2017-07-23T13:00:00',
#    'ContestGroupId': 15080,
#    'ContestStartDate': '2017-07-20T01:35:00',
#    'ContestSuffix': '',
#    'DisplayName': '1:35AM ET - 1 Games',
#    'DraftGroupId': 2063,
#    'Events': [{'ContestGroupId': 15080, 'SportEventId': 3453281}],
#    'GameCount': 1,
#    'IsOpen': False,
#    'IsPrimary': False,
#    'IsProjected': False,
#    'SourceId': 7,
#    'SportId': 5}],
#  'SourcePositionGroups': [{'DisplayCount': 6,
#    'ExternalPositionId': 0,
#    'GroupName': 'G',
#    'IncludeInStack': False,
#    'IsLite': True,
#    'MaximumCount': 6,
#    'MinimumCount': 6,
#    'OverrideMaximum': None,
#    'OverrideMinimum': None,
#    'PlayerString': None,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'SortOrder': 1,
#    'SourceId': 4,
#    'SourcePositionGroupId': 85,
#    'SportId': 5,
#    'TotalExposure': None,
#    'VisibleLite': True},
#   {'DisplayCount': 7,
#    'ExternalPositionId': 0,
#    'GroupName': 'G',
#    'IncludeInStack': False,
#    'IsLite': False,
#    'MaximumCount': 7,
#    'MinimumCount': 7,
#    'OverrideMaximum': None,
#    'OverrideMinimum': None,
#    'PlayerString': None,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'SortOrder': 1,
#    'SourceId': 7,
#    'SourcePositionGroupId': 110,
#    'SportId': 5,
#    'TotalExposure': None,
#    'VisibleLite': False},
#   {'DisplayCount': 8,
#    'ExternalPositionId': 0,
#    'GroupName': 'G',
#    'IncludeInStack': False,
#    'IsLite': True,
#    'MaximumCount': 8,
#    'MinimumCount': 8,
#    'OverrideMaximum': None,
#    'OverrideMinimum': None,
#    'PlayerString': None,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'SortOrder': 1,
#    'SourceId': 3,
#    'SourcePositionGroupId': 111,
#    'SportId': 5,
#    'TotalExposure': None,
#    'VisibleLite': True}],
#  'SourcePositions': [{'PositionName': 'G',
#    'SourcePositionGroupId': 85,
#    'SourcePositionId': 381},
#   {'PositionName': 'G', 'SourcePositionGroupId': 110, 'SourcePositionId': 507},
#   {'PositionName': 'G',
#    'SourcePositionGroupId': 111,
#    'SourcePositionId': 508}],
#  'Sources': [{'DisplayName': 'DraftKings',
#    'IsActive': True,
#    'IsPrimary': False,
#    'MaxSalary': 12000,
#    'MinSalary': 6000,
#    'OrphanCount': 0,
#    'SourceId': 4,
#    'SourceName': 'draftkings.com',
#    'UIDisplayOrder': 1},
#   {'DisplayName': 'FanDuel',
#    'IsActive': True,
#    'IsPrimary': False,
#    'MaxSalary': 10400,
#    'MinSalary': 4500,
#    'OrphanCount': 0,
#    'SourceId': 3,
#    'SourceName': 'fanduel.com',
#    'UIDisplayOrder': 2},
#   {'DisplayName': 'FantasyDraft',
#    'IsActive': True,
#    'IsPrimary': False,
#    'MaxSalary': 18400,
#    'MinSalary': 10400,
#    'OrphanCount': 0,
#    'SourceId': 7,
#    'SourceName': 'fantasydraft.com',
#    'UIDisplayOrder': 3}]}

# %%
for p, player in enumerate(sal_data['PlayerModels']):
    if player['Properties']['SourceId'] == 4:
        if player['Properties']['Player_Name'] == 'Jimmy Walker':
            print(p)
# Out:
# 307
# 308

# %%
main_dict = final_dict['salary']['7_23_2017']['PlayerModels'][300]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-9a5d7064b12c> in <module>()
# ----> 1 main_dict = final_dict['salary']['7_23_2017']['PlayerModels'][300]
#
# KeyError: '7_23_2017'

# %%
main_dict = sal_data['PlayerModels'][309]

# %%
weeknd_dict = sal_data['PlayerModels'][312]

# %%
##Iterate and find which fields are different

for key in main_dict.keys():
    if isinstance(main_dict[key], dict):
        for key1 in main_dict[key].keys():
            if main_dict[key][key1] != weeknd_dict[key][key1]:
                print('main_dict[{}][{}] = {}, weeknd_dict[{}][{}] = {}'.format(key, key1, 
                    main_dict[key][key1], key, key1, weeknd_dict[key][key1]))
                
    else:
        if main_dict[key] != weeknd_dict[key]:
            print('main_dict[{}] = {}, weeknd_dict[{}] = {}'.format(key, main_dict[key], key, weeknd_dict[key]))
# Out:
# main_dict[FantasyResultId] = 1005921, weeknd_dict[FantasyResultId] = 1005003
# main_dict[Salary] = 10100, weeknd_dict[Salary] = 11600
# main_dict[Properties][Site_Salary] = 77, weeknd_dict[Properties][Site_Salary] = 37
# main_dict[Properties][Salary] = 10100, weeknd_dict[Properties][Salary] = 11600
# main_dict[Properties][Month_Salary_Change] = -1300, weeknd_dict[Properties][Month_Salary_Change] = 200
# main_dict[Properties][Season_Salary_Change] = -1400, weeknd_dict[Properties][Season_Salary_Change] = 100
# main_dict[Properties][FantasyResultId] = 1005921, weeknd_dict[Properties][FantasyResultId] = 1005003
# main_dict[Properties][Pro_Pct] = 91, weeknd_dict[Properties][Pro_Pct] = 87
# main_dict[Properties][ImpPts] = 65.71, weeknd_dict[Properties][ImpPts] = 74.58

# %%
## Weekend salary has the higher FantasyResultId
for player in sal_data['PlayerModels']:
    for player1 in sal_data['PlayerModels']:
        if player['Properties']['Player_Name'] == player1['Properties']['Player_Name'] and player['Properties']['Salary'] != player1['Properties']['Salary'] and player['Properties']['SourceId'] == 4 and player1['Properties']['SourceId'] == 4:
            print(player['Properties']['Player_Name'], player['Properties']['Salary'], player['Properties']['FantasyResultId'])
            print(player1['Properties']['Player_Name'], player1['Properties']['Salary'], player1['Properties']['FantasyResultId'])
            print('\n')
# Out:
# Jon Rahm 11400 1005064
# Jon Rahm 9600 1005981
#
#
# Jon Rahm 9600 1005981
# Jon Rahm 11400 1005064
#
#
# Kyle Stanley 6600 1005047
# Kyle Stanley 7400 1005964
#
#
# Kyle Stanley 7400 1005964
# Kyle Stanley 6600 1005047
#
#
# Bernd Wiesberger 7600 1005039
# Bernd Wiesberger 7500 1005955
#
#
# Bernd Wiesberger 7500 1005955
# Bernd Wiesberger 7600 1005039
#
#
# Justin Rose 10300 1004968
# Justin Rose 9200 1005888
#
#
# Justin Rose 9200 1005888
# Justin Rose 10300 1004968
#
#
# Louis Oosthuizen 8300 1004983
# Louis Oosthuizen 7200 1005901
#
#
# Louis Oosthuizen 7200 1005901
# Louis Oosthuizen 8300 1004983
#
#
# Paul Casey 8100 1004976
# Paul Casey 9100 1005895
#
#
# Paul Casey 9100 1005895
# Paul Casey 8100 1004976
#
#
# Adam Hadwin 7200 1005922
# Adam Hadwin 6800 1005004
#
#
# Adam Hadwin 6800 1005004
# Adam Hadwin 7200 1005922
#
#
# David Horsey 6400 1005076
# David Horsey 7200 1005994
#
#
# David Horsey 7200 1005994
# David Horsey 6400 1005076
#
#
# Mike Lorenzo-Vera 6400 1005079
# Mike Lorenzo-Vera 7100 1005997
#
#
# Mike Lorenzo-Vera 7100 1005997
# Mike Lorenzo-Vera 6400 1005079
#
#
# Tony Finau 7500 1005911
# Tony Finau 6800 1005871
#
#
# Tony Finau 6800 1005871
# Tony Finau 7500 1005911
#
#
# Steve Stricker 7600 1005931
# Steve Stricker 6900 1005014
#
#
# Sergio Garcia 9400 1005936
# Sergio Garcia 10600 1005019
#
#
# Francesco Molinari 7700 1005941
# Francesco Molinari 7300 1005025
#
#
# David Lipsky 6500 1005061
# David Lipsky 7100 1005978
#
#
# David Lipsky 7100 1005978
# David Lipsky 6500 1005061
#
#
# Steve Stricker 6900 1005014
# Steve Stricker 7600 1005931
#
#
# Sergio Garcia 10600 1005019
# Sergio Garcia 9400 1005936
#
#
# Francesco Molinari 7300 1005025
# Francesco Molinari 7700 1005941
#
#
# Peter Uihlein 6800 1005040
# Peter Uihlein 7500 1005956
#
#
# Peter Uihlein 7500 1005956
# Peter Uihlein 6800 1005040
#
#
# Russell Henley 7600 1005920
# Russell Henley 7000 1005002
#
#
# Marc Leishman 7800 1004990
# Marc Leishman 8300 1005907
#
#
# Marc Leishman 8300 1005907
# Marc Leishman 7800 1004990
#
#
# Hao-Tong Li 6400 1005077
# Hao-Tong Li 7100 1005995
#
#
# Hao-Tong Li 7100 1005995
# Hao-Tong Li 6400 1005077
#
#
# Joost Luiten 6700 1005038
# Joost Luiten 7300 1005954
#
#
# Rickie Fowler 9500 1005916
# Rickie Fowler 9200 1004998
#
#
# Rickie Fowler 9200 1004998
# Rickie Fowler 9500 1005916
#
#
# Russell Henley 7000 1005002
# Russell Henley 7600 1005920
#
#
# Joost Luiten 7300 1005954
# Joost Luiten 6700 1005038
#
#
# Xander Schauffele 6500 1005073
# Xander Schauffele 7400 1005991
#
#
# Xander Schauffele 7400 1005991
# Xander Schauffele 6500 1005073
#
#
# Stewart Cink 6300 1004962
# Stewart Cink 7200 1005882
#
#
# Stewart Cink 7200 1005882
# Stewart Cink 6300 1004962
#
#
# Brian Harman 6600 1004987
# Brian Harman 7600 1005904
#
#
# Brian Harman 7600 1005904
# Brian Harman 6600 1004987
#
#
# Jamie Lovemark 6400 1005041
# Jamie Lovemark 7300 1005957
#
#
# Jamie Lovemark 7300 1005957
# Jamie Lovemark 6400 1005041
#
#
# Rafael Cabrera-Bello 7700 1005945
# Rafael Cabrera-Bello 6700 1005029
#
#
# Rafael Cabrera-Bello 6700 1005029
# Rafael Cabrera-Bello 7700 1005945
#
#
# Cameron Smith 6400 1005062
# Cameron Smith 7200 1005979
#
#
# Cameron Smith 7200 1005979
# Cameron Smith 6400 1005062
#
#
# Daniel Berger 7700 1005926
# Daniel Berger 6700 1005009
#
#
# Daniel Berger 6700 1005009
# Daniel Berger 7700 1005926
#
#
# Wesley Bryan 6600 1005088
# Wesley Bryan 7200 1006007
#
#
# Wesley Bryan 7200 1006007
# Wesley Bryan 6600 1005088
#
#
# David Drysdale 6300 1005075
# David Drysdale 6900 1005993
#
#
# David Drysdale 6900 1005993
# David Drysdale 6300 1005075
#
#
# Hideki Matsuyama 9000 1005924
# Hideki Matsuyama 9500 1005007
#
#
# Hideki Matsuyama 9500 1005007
# Hideki Matsuyama 9000 1005924
#
#
# Phil Mickelson 8700 1004961
# Phil Mickelson 8400 1005881
#
#
# Phil Mickelson 8400 1005881
# Phil Mickelson 8700 1004961
#
#
# Kevin Kisner 7500 1005910
# Kevin Kisner 6700 1004993
#
#
# Kevin Kisner 6700 1004993
# Kevin Kisner 7500 1005910
#
#
# Hideto Tanihara 7400 1005948
# Hideto Tanihara 6700 1005032
#
#
# Hideto Tanihara 6700 1005032
# Hideto Tanihara 7400 1005948
#
#
# Brooks Koepka 8900 1005925
# Brooks Koepka 9000 1005008
#
#
# Ross Fisher 6700 1005035
# Ross Fisher 7700 1005951
#
#
# Ross Fisher 7700 1005951
# Ross Fisher 6700 1005035
#
#
# Brooks Koepka 9000 1005008
# Brooks Koepka 8900 1005925
#
#
# Anirban Lahiri 6600 1005873
# Anirban Lahiri 7300 1005972
#
#
# Anirban Lahiri 7300 1005972
# Anirban Lahiri 6600 1005873
#
#
# Jason Dufner 6600 1004979
# Jason Dufner 7500 1005898
#
#
# Jason Dufner 7500 1005898
# Jason Dufner 6600 1004979
#
#
# Martin Kaymer 7700 1005034
# Martin Kaymer 7600 1005950
#
#
# Brandon Stone 6800 1005074
# Brandon Stone 7300 1005992
#
#
# Brandon Stone 7300 1005992
# Brandon Stone 6800 1005074
#
#
# Thorbjorn Olesen 7000 1005056
# Thorbjorn Olesen 7500 1005974
#
#
# Thorbjorn Olesen 7500 1005974
# Thorbjorn Olesen 7000 1005056
#
#
# Bryson DeChambeau 6700 1005874
# Bryson DeChambeau 7500 1005983
#
#
# Bryson DeChambeau 7500 1005983
# Bryson DeChambeau 6700 1005874
#
#
# Branden Grace 8000 1005045
# Branden Grace 8100 1005962
#
#
# Branden Grace 8100 1005962
# Branden Grace 8000 1005045
#
#
# Jimmy Walker 7000 1004978
# Jimmy Walker 7300 1005897
#
#
# Jimmy Walker 7300 1005897
# Jimmy Walker 7000 1004978
#
#
# Jordan Spieth 10100 1005921
# Jordan Spieth 11600 1005003
#
#
# Thomas Pieters 8400 1005072
# Thomas Pieters 8000 1005990
#
#
# Thomas Pieters 8000 1005990
# Thomas Pieters 8400 1005072
#
#
# Jordan Spieth 11600 1005003
# Jordan Spieth 10100 1005921
#
#
# J.B. Holmes 7400 1004985
# J.B. Holmes 7600 1005903
#
#
# J.B. Holmes 7600 1005903
# J.B. Holmes 7400 1004985
#
#
# Matthew Fitzpatrick 7400 1005068
# Matthew Fitzpatrick 7700 1005986
#
#
# Matthew Fitzpatrick 7700 1005986
# Matthew Fitzpatrick 7400 1005068
#
#
# Dylan Frittelli 6700 1005087
# Dylan Frittelli 7200 1006006
#
#
# Dylan Frittelli 7200 1006006
# Dylan Frittelli 6700 1005087
#
#
# Jason Day 10000 1004989
# Jason Day 8200 1005906
#
#
# Jason Day 8200 1005906
# Jason Day 10000 1004989
#
#
# Adam Bland 7000 1005944
# Adam Bland 6100 1005028
#
#
# Adam Bland 6100 1005028
# Adam Bland 7000 1005944
#
#
# Todd Hamilton 7000 1005943
# Todd Hamilton 6000 1005027
#
#
# Todd Hamilton 6000 1005027
# Todd Hamilton 7000 1005943
#
#
# Tom Lehman 6900 1005930
# Tom Lehman 6100 1005013
#
#
# Soren Kjeldsen 7600 1005935
# Soren Kjeldsen 6900 1005018
#
#
# Soren Kjeldsen 6900 1005018
# Soren Kjeldsen 7600 1005935
#
#
# Kent Bulle 6000 1005090
# Kent Bulle 7000 1006009
#
#
# Tom Lehman 6100 1005013
# Tom Lehman 6900 1005930
#
#
# Kent Bulle 7000 1006009
# Kent Bulle 6000 1005090
#
#
# Connor Syme 6100 1005098
# Connor Syme 6800 1006018
#
#
# Connor Syme 6800 1006018
# Connor Syme 6100 1005098
#
#
# Hayden McCullen 6000 1005108
# Hayden McCullen 6800 1006028
#
#
# Hayden McCullen 6800 1006028
# Hayden McCullen 6000 1005108
#
#
# Joe Dean 6000 1005109
# Joe Dean 6800 1006029
#
#
# Joe Dean 6800 1006029
# Joe Dean 6000 1005109
#
#
# Ashley Hall 6100 1005106
# Ashley Hall 7000 1006026
#
#
# Ashley Hall 7000 1006026
# Ashley Hall 6100 1005106
#
#
# Yikeun Chang 6000 1005112
# Yikeun Chang 7000 1006032
#
#
# Younghan Song 6300 1005091
# Younghan Song 6900 1006011
#
#
# Younghan Song 6900 1006011
# Younghan Song 6300 1005091
#
#
# Roberto Castro 6400 1005051
# Roberto Castro 7100 1005968
#
#
# Roberto Castro 7100 1005968
# Roberto Castro 6400 1005051
#
#
# Si Woo Kim 7500 1005070
# Si Woo Kim 7300 1005988
#
#
# Si Woo Kim 7300 1005988
# Si Woo Kim 7500 1005070
#
#
# Bubba Watson 7100 1004980
# Bubba Watson 7500 1005899
#
#
# Bubba Watson 7500 1005899
# Bubba Watson 7100 1004980
#
#
# Stuart Manley 6100 1005086
# Stuart Manley 7300 1006005
#
#
# Stuart Manley 7300 1006005
# Stuart Manley 6100 1005086
#
#
# Danny Willett 6500 1005050
# Danny Willett 7200 1005967
#
#
# Danny Willett 7200 1005967
# Danny Willett 6500 1005050
#
#
# Toby Tree 6100 1005097
# Toby Tree 6900 1006017
#
#
# Toby Tree 6900 1006017
# Toby Tree 6100 1005097
#
#
# Prayad Marksaeng 6200 1005069
# Prayad Marksaeng 6900 1005987
#
#
# Prayad Marksaeng 6900 1005987
# Prayad Marksaeng 6200 1005069
#
#
# Matthew Griffin 6100 1005099
# Matthew Griffin 6800 1006019
#
#
# Matthew Griffin 6800 1006019
# Matthew Griffin 6100 1005099
#
#
# Kyung-tae Kim 6200 1005089
# Kyung-tae Kim 7000 1006008
#
#
# Kyung-tae Kim 7000 1006008
# Kyung-tae Kim 6200 1005089
#
#
# Yusaku Miyazato 7100 1005946
# Yusaku Miyazato 6200 1005030
#
#
# Yusaku Miyazato 6200 1005030
# Yusaku Miyazato 7100 1005946
#
#
# Rory McIlroy 11000 1005037
# Rory McIlroy 8700 1005953
#
#
# Rory McIlroy 8700 1005953
# Rory McIlroy 11000 1005037
#
#
# Jeunghun Wang 6300 1005084
# Jeunghun Wang 7000 1006003
#
#
# Jeunghun Wang 7000 1006003
# Jeunghun Wang 6300 1005084
#
#
# David Duval 6800 1005928
# David Duval 6000 1005011
#
#
# David Duval 6000 1005011
# David Duval 6800 1005928
#
#
# Luca Cianchetti 6100 1005093
# Luca Cianchetti 7000 1006013
#
#
# Luca Cianchetti 7000 1006013
# Luca Cianchetti 6100 1005093
#
#
# Giwhan Kim 6000 1005100
# Giwhan Kim 6900 1006020
#
#
# Giwhan Kim 6900 1006020
# Giwhan Kim 6000 1005100
#
#
# John Daly 7000 1005932
# John Daly 6100 1005015
#
#
# John Daly 6100 1005015
# John Daly 7000 1005932
#
#
# Sandy Lyle 6800 1005933
# Sandy Lyle 6000 1005016
#
#
# Sandy Lyle 6000 1005016
# Sandy Lyle 6800 1005933
#
#
# Darren Clarke 6800 1005934
# Darren Clarke 6000 1005017
#
#
# Darren Clarke 6000 1005017
# Darren Clarke 6800 1005934
#
#
# Mark O'Meara 6800 1005927
# Mark O'Meara 6000 1005010
#
#
# Mark O'Meara 6000 1005010
# Mark O'Meara 6800 1005927
#
#
# Chan Kim 6100 1005103
# Chan Kim 6900 1006023
#
#
# Chan Kim 6900 1006023
# Chan Kim 6100 1005103

# %%
#  'LineupCount': 0,
#  'MinExposure': None,
#  'PlayerId': 8872,
#  'Points': 0.0,
#  'Position': 'G',
#  'PositionCount': 1,
#  'PositionId': 501,
#  'Positions': ['G'],
#  'ProjPoints': 0.0,
#  'Properties': {'ActualPoints': 46.0,
#   'Consistency': 95,
#   'EventId': 3453281,
#   'EventTeamId': 0,
#   'FantasyResultId': 1004978,
#   'FullName': '',
#   'ImpPts': 50.75,
#   'InjuryStatus': None,
#   'IsProjected': None,
#   'Month_Count': 3,
#   'Month_PPG': 60.2,
#   'Month_Salary_Change': -800,
#   'Month_X0': 33,
#   'Month_X1': 66,
#   'Month_X2': 66,
#   'MyTrends': 0,
#   'OwnRank': 90,
#   'OwnRank_Slate': None,
#   'PlayerId': 8872,
#   'Player_Name': 'Jimmy Walker',
#   'Plus_Minus': 53,
#   'Position': 'G',
#   'PositionId': 501,
#   'ProTrendsPercentile_Slate': None,
#   'Pro_Pct': 40,
#   'Salary': 7000,
#   'Score': 53.0,
#   'Season_Count': 19,
#   'Season_PPG': 56.7,
#   'Season_PPG_Percentile': 56,
#   'Season_Plus_Minus': -0.2,
#   'Season_Salary_Change': -400,
#   'Season_X0': 36,
#   'Season_X1': 63,
#   'Season_X2': 36,
#   'SiteDiffPercentile_Slate': None,
#   'Site_Salary': 58,
#   'SourceId': 4,
#   'Team': '',
#   'Upside': 62,
#   'adjrd_c_rank': 56.7,
#   'adjrd_c_slate': 41.25,
#   'adjrd_diff_rank': 81,
#   'adjrd_diff_slate': 71.25,
#   'adjrd_l_rank': 56.7,
#   'adjrd_l_slate': 41.25,
#   'adjrd_r_rank': 41.8,
#   'adjrd_r_slate': 26.88,
#   'birdies_l': 11.9,
#   'birdies_l_rank': 58.0,
#   'birdies_l_slate': 45.63,
#   'birdies_r_rank': 42.3,
#   'birdies_r_slate': 30.0,
#   'bogies_l': 9.9,
#   'bogies_l_rank': 44.3,
#   'bogies_l_slate': 30.63,
#   'bogies_r_rank': 55.7,
#   'bogies_r_slate': 63.75,
#   'cnt_c_pct': 20.7,
#   'cnt_c_slate': 91.88,
#   'cnt_l': 38.0,
#   'cnt_l_pct': 72.3,
#   'cnt_l_slate': 68.13,
#   'cnt_r_pct': 52.7,
#   'cnt_r_slate': 61.88,
#   'da_c_rank': 26.3,
#   'da_l': 51.7,
#   'da_l_rank': 26.3,
#   'da_l_slate': 3.13,
#   'da_r_rank': 49.7,
#   'da_r_slate': 53.13,
#   'dd_c_rank': 66.9,
#   'dd_l': 298.6,
#   'dd_l_rank': 66.9,
#   'dd_l_slate': 71.25,
#   'dd_r_rank': 75.7,
#   'dd_r_slate': 83.75,
#   'eagles_l': 0.4,
#   'eagles_l_rank': 65.7,
#   'eagles_l_slate': 79.38,
#   'eagles_r_rank': 50.0,
#   'eagles_r_slate': 30.63,
#   'gir_c_rank': 56.7,
#   'gir_c_slate': 26.88,
#   'gir_diff_rank': 49,
#   'gir_diff_slate': 41.25,
#   'gir_l': 62.6,
#   'gir_l_rank': 48.9,
#   'gir_l_slate': 19.38,
#   'gir_r_rank': 49.3,
#   'gir_r_slate': 36.88,
#   'mc_l_slate': 32.5,
#   'mc_pct_l': 34.0,
#   'mc_pct_l_pct': 58.0,
#   'mc_pct_r_pct': 20.6,
#   'mc_r_slate': 31.88,
#   'odds': 0.6,
#   'odds_pct': 4.2,
#   'par3_l': 1.9,
#   'par4_l': 1.6,
#   'par5_l': -3.6,
#   'ppr_c_rank': 57.1,
#   'ppr_diff_rank': 65,
#   'ppr_diff_slate': 66.88,
#   'ppr_l': 29.1,
#   'ppr_l_rank': 57.1,
#   'ppr_l_slate': 71.88,
#   'ppr_r_rank': 50.8,
#   'ppr_r_slate': 54.38,
#   'precip_pct': 34.1,
#   'sagarin_l_rank': 94.2,
#   'sagarin_l_slate': 93.75,
#   'sagarin_r_rank': 91.4,
#   'sagarin_r_slate': 86.25,
#   'sc_l': 55.1,
#   'sc_l_rank': 49.4,
#   'sc_l_slate': 23.13,
#   'sc_r_rank': 23.5,
#   'sc_r_slate': 10.63,
#   'temp': 60.6,
#   'temp_pct': 21.6,
#   'wind': 26.7,
#   'wind_pct': 1.3},
#  'Salary': 7000,
#  'Score': 53.0,
#  'TeamName': ''}

# %%
sal_data['PlayerModels'][308]
# Out:
# {'ActualPoints': 46.0,
#  'Cnt': 0,
#  'Correlation': 0.0,
#  'CurrentExposure': 0.0,
#  'Exposure': None,
#  'FantasyResultId': 1005897,
#  'FirstPosition': 'G',
#  'FullName': '',
#  'IsExcluded': False,
#  'IsLiked': False,
#  'IsLocked': False,
#  'LineupCount': 0,
#  'MinExposure': None,
#  'PlayerId': 8872,
#  'Points': 0.0,
#  'Position': 'G',
#  'PositionCount': 1,
#  'PositionId': 501,
#  'Positions': ['G'],
#  'ProjPoints': 0.0,
#  'Properties': {'ActualPoints': 46.0,
#   'Consistency': 95,
#   'EventId': 3453281,
#   'EventTeamId': 0,
#   'FantasyResultId': 1005897,
#   'FullName': '',
#   'ImpPts': 52.0,
#   'InjuryStatus': None,
#   'IsProjected': None,
#   'Month_Count': 3,
#   'Month_PPG': 60.2,
#   'Month_Salary_Change': -500,
#   'Month_X0': 33,
#   'Month_X1': 66,
#   'Month_X2': 66,
#   'MyTrends': 0,
#   'OwnRank': 90,
#   'OwnRank_Slate': None,
#   'PlayerId': 8872,
#   'Player_Name': 'Jimmy Walker',
#   'Plus_Minus': 53,
#   'Position': 'G',
#   'PositionId': 501,
#   'ProTrendsPercentile_Slate': None,
#   'Pro_Pct': 40,
#   'Salary': 7300,
#   'Score': 53.0,
#   'Season_Count': 19,
#   'Season_PPG': 56.7,
#   'Season_PPG_Percentile': 56,
#   'Season_Plus_Minus': -0.2,
#   'Season_Salary_Change': -100,
#   'Season_X0': 36,
#   'Season_X1': 63,
#   'Season_X2': 36,
#   'SiteDiffPercentile_Slate': None,
#   'Site_Salary': 49,
#   'SourceId': 4,
#   'Team': '',
#   'Upside': 62,
#   'adjrd_c_rank': 56.7,
#   'adjrd_c_slate': 41.25,
#   'adjrd_diff_rank': 81,
#   'adjrd_diff_slate': 71.25,
#   'adjrd_l_rank': 56.7,
#   'adjrd_l_slate': 41.25,
#   'adjrd_r_rank': 41.8,
#   'adjrd_r_slate': 26.88,
#   'birdies_l': 11.9,
#   'birdies_l_rank': 58.0,
#   'birdies_l_slate': 45.63,
#   'birdies_r_rank': 42.3,
#   'birdies_r_slate': 30.0,
#   'bogies_l': 9.9,
#   'bogies_l_rank': 44.3,
#   'bogies_l_slate': 30.63,
#   'bogies_r_rank': 55.7,
#   'bogies_r_slate': 63.75,
#   'cnt_c_pct': 20.7,
#   'cnt_c_slate': 91.88,
#   'cnt_l': 38.0,
#   'cnt_l_pct': 72.3,
#   'cnt_l_slate': 68.13,
#   'cnt_r_pct': 52.7,
#   'cnt_r_slate': 61.88,
#   'da_c_rank': 26.3,
#   'da_l': 51.7,
#   'da_l_rank': 26.3,
#   'da_l_slate': 3.13,
#   'da_r_rank': 49.7,
#   'da_r_slate': 53.13,
#   'dd_c_rank': 66.9,
#   'dd_l': 298.6,
#   'dd_l_rank': 66.9,
#   'dd_l_slate': 71.25,
#   'dd_r_rank': 75.7,
#   'dd_r_slate': 83.75,
#   'eagles_l': 0.4,
#   'eagles_l_rank': 65.7,
#   'eagles_l_slate': 79.38,
#   'eagles_r_rank': 50.0,
#   'eagles_r_slate': 30.63,
#   'gir_c_rank': 56.7,
#   'gir_c_slate': 26.88,
#   'gir_diff_rank': 49,
#   'gir_diff_slate': 41.25,
#   'gir_l': 62.6,
#   'gir_l_rank': 48.9,
#   'gir_l_slate': 19.38,
#   'gir_r_rank': 49.3,
#   'gir_r_slate': 36.88,
#   'mc_l_slate': 32.5,
#   'mc_pct_l': 34.0,
#   'mc_pct_l_pct': 58.0,
#   'mc_pct_r_pct': 20.6,
#   'mc_r_slate': 31.88,
#   'odds': 0.6,
#   'odds_pct': 4.2,
#   'par3_l': 1.9,
#   'par4_l': 1.6,
#   'par5_l': -3.6,
#   'ppr_c_rank': 57.1,
#   'ppr_diff_rank': 65,
#   'ppr_diff_slate': 66.88,
#   'ppr_l': 29.1,
#   'ppr_l_rank': 57.1,
#   'ppr_l_slate': 71.88,
#   'ppr_r_rank': 50.8,
#   'ppr_r_slate': 54.38,
#   'precip_pct': 34.1,
#   'sagarin_l_rank': 94.2,
#   'sagarin_l_slate': 93.75,
#   'sagarin_r_rank': 91.4,
#   'sagarin_r_slate': 86.25,
#   'sc_l': 55.1,
#   'sc_l_rank': 49.4,
#   'sc_l_slate': 23.13,
#   'sc_r_rank': 23.5,
#   'sc_r_slate': 10.63,
#   'temp': 60.6,
#   'temp_pct': 21.6,
#   'wind': 26.7,
#   'wind_pct': 1.3},
#  'Salary': 7300,
#  'Score': 53.0,
#  'TeamName': ''}

# %%
#Retrieve data from last week

for i in range(80):
    date_str = (now - timedelta(i)).strftime('%-m_%-d_%Y')


    #Get salary data
    sal_url = 'http://www.fantasylabs.com/api/playermodel/5/{}/?modelId=313179'.format(date_str)

    sal_resp = requests.get(sal_url)
    sal_data = json.loads(sal_resp.text)
    
    try:
        if len(sal_data['PlayerModels']) > 0:
            sal_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/salary_data/{}_salary_data.json'.format(date_str)

            if os.path.isfile(sal_file_name) is False:

                final_dict['salary'][date_str] = sal_data
                with open(sal_file_name, 'w') as outfile:
                    json.dump(sal_data, outfile)

                print(date_str + ' salary file saved!')
    except:
        pass

    wait = 1
    time.sleep(wait)

    #Get sportevents data
    event_url = 'http://www.fantasylabs.com/api/sportevents/5/{}'.format(date_str)

    event_resp = requests.get(event_url)
    event_data = json.loads(event_resp.text)



    if len(event_data) > 0:
        event_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/sportevent_data/{}_sportevent_data.json'.format(date_str)

        if os.path.isfile(event_file_name) is False:

            final_dict['events'][date_str] = event_data

            with open(event_file_name, 'w') as outfile:
                json.dump(event_data, outfile)

                print(date_str + ' sportevents file saved')

    time.sleep(wait)

    #get ownership data
    own_url = 'http://www.fantasylabs.com/api/contest-ownership/5/{}/4'.format(date_str)

    own_resp = requests.get(own_url)
    own_data = json.loads(own_resp.text)

    if len(own_data) > 0:
        own_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/ownership_data/{}_ownership_data.json'.format(date_str)

        if os.path.isfile(own_file_name) is False:

            final_dict['ownership'][date_str] = own_data

            with open(own_file_name, 'w') as outfile:
                json.dump(own_data, outfile)

                print(date_str + ' ownership file saved')
                
                
    #get source data
    
    source_url = 'http://www.fantasylabs.com/api/sourcedata/5/{}'.format(date_str)
    
    source_data = requests.get(source_url).json()

    
    if len(source_data) > 0:
        source_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/source_data/{}_source_data.json'.format(date_str)
        
        if os.path.isfile(source_file_name) is False:
            
            final_dict['source'][date_str] = source_data
            
            with open(source_file_name, 'w') as outfile:
                json.dump(source_data, outfile)
                
                print(date_str + ' source data saved')
# Out:
# 7_24_2017 source data saved
# 7_22_2017 source data saved
# 7_21_2017 source data saved
# 7_20_2017 source data saved
# 7_19_2017 source data saved
# 7_18_2017 source data saved
# 7_17_2017 source data saved
# 7_16_2017 salary file saved!
# 7_16_2017 sportevents file saved
# 7_16_2017 ownership file saved
# 7_16_2017 source data saved
# 7_15_2017 source data saved
# 7_14_2017 source data saved
# 7_13_2017 source data saved
# 7_12_2017 source data saved
# 7_11_2017 source data saved
# 7_10_2017 source data saved
# 7_9_2017 salary file saved!
# 7_9_2017 sportevents file saved
# 7_9_2017 ownership file saved
# 7_9_2017 source data saved
# 7_8_2017 source data saved
# 7_7_2017 source data saved
# 7_6_2017 source data saved
# 7_5_2017 source data saved
# 7_4_2017 source data saved
# 7_3_2017 source data saved
# 7_2_2017 salary file saved!
# 7_2_2017 sportevents file saved
# 7_2_2017 ownership file saved
# 7_2_2017 source data saved
# 7_1_2017 source data saved
# 6_30_2017 source data saved
# 6_29_2017 source data saved
# 6_28_2017 source data saved
# 6_27_2017 source data saved
# 6_26_2017 source data saved
# 6_25_2017 salary file saved!
# 6_25_2017 sportevents file saved
# 6_25_2017 ownership file saved
# 6_25_2017 source data saved
# 6_24_2017 source data saved
# 6_23_2017 source data saved
# 6_22_2017 source data saved
# 6_21_2017 source data saved
# 6_20_2017 source data saved
# 6_19_2017 source data saved
# 6_18_2017 salary file saved!
# 6_18_2017 sportevents file saved
# 6_18_2017 ownership file saved
# 6_18_2017 source data saved
# 6_17_2017 source data saved
# 6_16_2017 source data saved
# 6_15_2017 source data saved
# 6_14_2017 source data saved
# 6_13_2017 source data saved
# 6_12_2017 source data saved
# 6_11_2017 salary file saved!
# 6_11_2017 sportevents file saved
# 6_11_2017 ownership file saved
# 6_11_2017 source data saved
# 6_10_2017 source data saved
# 6_9_2017 source data saved
# 6_8_2017 source data saved
# 6_7_2017 source data saved
# 6_6_2017 source data saved
# 6_5_2017 source data saved
# 6_4_2017 salary file saved!
# 6_4_2017 sportevents file saved
# 6_4_2017 ownership file saved
# 6_4_2017 source data saved
# 6_3_2017 source data saved
# 6_2_2017 source data saved
# 6_1_2017 source data saved
# 5_31_2017 source data saved
# 5_30_2017 source data saved
# 5_29_2017 source data saved
# 5_28_2017 source data saved
# 5_27_2017 source data saved
# 5_26_2017 source data saved
# 5_25_2017 source data saved
# 5_24_2017 source data saved
# 5_23_2017 source data saved
# 5_22_2017 source data saved
# 5_21_2017 source data saved
# 5_20_2017 source data saved
# 5_19_2017 source data saved
# 5_18_2017 source data saved
# 5_17_2017 source data saved
# 5_16_2017 source data saved
# 5_15_2017 source data saved
# 5_14_2017 source data saved
# 5_13_2017 source data saved
# 5_12_2017 source data saved
# 5_11_2017 source data saved
# 5_10_2017 source data saved
# 5_9_2017 source data saved
# 5_8_2017 source data saved
# 5_7_2017 source data saved
# 5_6_2017 source data saved

# %%
from pga.fuzz_match import return_tid

return_tid('Humana Challenge')
# Out:
# 2.0

# %%
import json
import os
import glob
import pandas as pd
import requests
import time
from datetime import datetime, timedelta
from random import randint
from pga.return_pid import return_pid
from pga.fuzz_match import return_tid
from sqlalchemy import create_engine
from pandas.io import sql
from tqdm import tqdm
import numpy as np

def return_tourny_avg(row):
    event_id = row['event_id']
    weekend = row['weekend']

    avg_points = grouped_df['actual_points']['mean'].loc[(grouped_df['event_id'] == event_id) & (grouped_df['weekend'] == weekend)].values[0]

    return avg_points

def return_tourny_std(row):
    event_id = row['event_id']
    weekend = row['weekend']

    std_points = grouped_df['actual_points']['std'].loc[(grouped_df['event_id'] == event_id) & (grouped_df['weekend'] == weekend)].values[0]

    return std_points

def norm_points(row):
    return (row['actual_points'] - row['tourny_avg_points']) / row['tourny_std_points']

now = datetime.now()



os.chdir('/home/valesco/Datasets/PGA_Data/fantasylabs_data/salary_data/')

salary_folders = glob.glob('*')


for sal in tqdm(salary_folders):
    #try:
    final_dict = {}
    final_dict['salary'] = {}
    final_dict['events'] = {}
    
    sal_ls = sal.split('_') 
    sal_date = sal_ls[0] + '_' + sal_ls[1] + '_' + sal_ls[2]

    sal_file = open(sal)
    sal_data = json.load(sal_file)

    event_name_str = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/sportevent_data/{}'.format(sal_date + '_sportevent_data.json')
    event_file_name = open(event_name_str)
    event_data = json.load(event_file_name)

    #Parse Results

    final_dict['salary'][sal_date] = sal_data
    final_dict['events'][sal_date] = event_data

    sal_keys = final_dict['salary'].keys()


    pga_salary = pd.DataFrame(columns = ['player_name', 'player_id', 'date_obj', 'event_id', 'tournament_name', 
                            'tournament_id', 'tourny_date', 'tourny_course', 'tour', 'salary', 'actual_points',
                            'imp_points', 'proj_points', 'score', 'plus_minus', 'injury_status', 'source',
                            'fantasy_id', 'weekend'])
    count = 0

    for sal_key in sal_keys:

        date_obj = datetime.strptime(sal_key, '%m_%d_%Y')

        for player in final_dict['salary'][sal_key]['PlayerModels']:
            switch = 0
            event_id = player['Properties']['EventId']
            player_name = player['Properties']['Player_Name']
            try:
                player_id = return_pid(player_name)
            except:
                player_id = np.nan
            salary = player['Properties']['Salary']
            actual_points = player['Properties']['ActualPoints']
            imp_points = player['Properties']['ImpPts']
            proj_points = player['ProjPoints']
            score = player['Properties']['Score']
            injury_status = player['Properties']['InjuryStatus']
            plus_minus = player['Properties']['Plus_Minus']
            source = player['Properties']['SourceId']
            fantasy_id = player['FantasyResultId']


            if source == 4:
                event_id = player['Properties']['EventId']

                for event in final_dict['events'][sal_key]:
                    if event['EventId'] == event_id:
                        tourny_name = event['HomeTeam']
                        tourny_date = event['EventDate']
                        tourny_course = event['StadiumName']
                        try:
                            tournament_id = return_tid(tourny_name)
                        except:
                            tournament_id = -999
                        tour = event['VisitorTeam']
                        switch = 1

                if switch == 0:
                    print('SWITCH ENGAGED!!!', tourny_name, tourny_date, file)
                    tourny_name = np.nan
                    tourny_date = np.nan
                    tourny_course = np.nan
                    tour = np.nan

                pga_salary.loc[count] = [player_name, player_id, date_obj, event_id, tourny_name, tournament_id,
                                         tourny_date, tourny_course, tour,
                                         salary, actual_points, imp_points, proj_points,
                                         score, plus_minus, injury_status, source, fantasy_id, 0]

                count += 1

    #Find unique tournaments in df and retrieve year
    tournaments = pga_salary['tournament_name'].unique()
    year = pd.to_datetime(pga_salary['tourny_date'].loc[0]).year

    #Connect to mysql db
    engine = create_engine('mysql+pymysql://root:v1933@127.0.0.1:3306/pga?charset=utf8')
    conn = engine.connect()

    #Check if tournament and year exist in db, if not insert results
    #for tournament in tournaments:
        #temp_results = conn.execute('SELECT * FROM pga.dk_salaries WHERE tournament_name = "{}" AND \
                #YEAR(tourny_date) = {}'.format(tournament, year))

        #temp_ls = []

        #for result in temp_results:
         #   temp_ls.append(result)

        #if len(temp_ls) < 1:
    agg_dict = {'actual_points': ['mean', 'std']}

    temp_df = pga_salary.loc[pga_salary['tournament_name'] == tourny_name]

    #Separate Weekend salaries from main contest salaries

    players = temp_df['player_name'].unique()

    temp_df.sort_values('fantasy_id', inplace = True)
    temp_df.reset_index(inplace = True, drop = True)

    for player in players:
        indices = sorted(temp_df.index[temp_df['player_name'] == player])

        if len(indices) > 1:
            temp_df['weekend'][indices[1]] = 1

    # Create grouped df to calc tourny std and avg
    grouped_df = temp_df[['event_id', 'weekend', 'actual_points']].groupby(['event_id', 'weekend']).agg(agg_dict)
    grouped_df.reset_index(inplace = True)

    temp_df['tourny_std_points'] = temp_df.apply(return_tourny_std, axis = 1)
    temp_df['tourny_avg_points'] = temp_df.apply(return_tourny_avg, axis = 1)
    temp_df['norm_points'] = temp_df.apply(norm_points, axis = 1)

    temp_df.to_sql('dk_salaries', engine, if_exists = 'append', index = False)

    #except:
        #print(sal)
# Out:
#   3%|▎         | 5/153 [00:13<06:37,  2.68s/it]/home/valesco/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/valesco/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/valesco/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/valesco/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   5%|▌         | 8/153 [00:41<15:27,  6.40s/it]/home/valesco/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#  24%|██▍       | 37/153 [03:17<07:21,  3.81s/it]/home/valesco/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#  31%|███       | 47/153 [03:57<07:32,  4.27s/it]
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
# Shenzhen International was not matched
#  91%|█████████ | 139/153 [13:51<00:53,  3.81s/it]
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# Trophee Hassan II was not matched
# 100%|██████████| 153/153 [15:07<00:00,  3.05s/it]

# %%
os.chdir('/home/valesco/Datasets/PGA_Data/fantasylabs_data/salary_data/')

salary_folders = glob.glob('*')


for sal in salary_folders[:1]:
    sal_ls = sal.split('_') 
    sal_date = sal_ls[0] + '_' + sal_ls[1] + '_' + sal_ls[2]
    
    sal_file = open(sal)
    sal_data = json.load(sal_file)
    
    event_name_str = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/sportevent_data/{}'.format(sal_date + '_sportevent_data.json')
    event_file_name = open(event_name_str)
    event_data = json.load(event_file_name)
    
sal_data
# Out:
# {'Key': '10406b82-61c4-4755-95e3-7d095e738605',
#  'PlayerModels': [{'ActualPoints': 48.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549714,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8832,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 48.0,
#     'Consistency': 94,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549714,
#     'FullName': '',
#     'ImpPts': 46.59,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': 1,
#     'Month_PPG': 72.0,
#     'Month_Salary_Change': -900,
#     'Month_X0': 0,
#     'Month_X1': 100,
#     'Month_X2': 100,
#     'MyTrends': 0,
#     'PlayerId': 8832,
#     'Player_Name': 'Davis Love III',
#     'Plus_Minus': 39,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 40,
#     'Salary': 5900,
#     'Salary_Movement': 82,
#     'Score': 39.0,
#     'Season_Count': 17,
#     'Season_PPG': 45.5,
#     'Season_PPG_Percentile': 18,
#     'Season_Plus_Minus': -3.0,
#     'Season_Salary_Change': -2200,
#     'Season_X0': 41,
#     'Season_X1': 58,
#     'Season_X2': 23,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 31,
#     'adjrd_c_rank': 43.3,
#     'adjrd_l_rank': 43.2,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 10.0,
#     'birdies_l_rank': 43.1,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 7.4,
#     'bogies_l_rank': 51.2,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 92.8,
#     'cnt_l': 28.0,
#     'cnt_l_pct': 19.0,
#     'cnt_r_pct': 7.1,
#     'da_l': 65.0,
#     'da_l_rank': 58.1,
#     'da_r_rank': 50.0,
#     'dd_l': 297.3,
#     'dd_l_rank': 69.8,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.1,
#     'eagles_l_rank': 53.5,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 49.2,
#     'gir_l': 68.7,
#     'gir_l_rank': 59.9,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 50.0,
#     'mc_pct_l_pct': 19.8,
#     'mc_pct_r_pct': 88.5,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 1.1,
#     'par4_l': 1.2,
#     'par5_l': -3.0,
#     'ppr_l': 30.1,
#     'ppr_l_rank': 37.7,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 68.3,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 55.0,
#     'sc_l_rank': 44.1,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 5900,
#    'Score': 39.0,
#    'TeamName': ''},
#   {'ActualPoints': 77.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549715,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8833,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 77.5,
#     'Consistency': 96,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549715,
#     'FullName': '',
#     'ImpPts': 46.24,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8833,
#     'Player_Name': 'Vijay Singh',
#     'Plus_Minus': 83,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 50,
#     'Salary': 5800,
#     'Salary_Movement': 50,
#     'Score': 83.0,
#     'Season_Count': 23,
#     'Season_PPG': 55.0,
#     'Season_PPG_Percentile': 50,
#     'Season_Plus_Minus': 7.5,
#     'Season_Salary_Change': -900,
#     'Season_X0': 30,
#     'Season_X1': 69,
#     'Season_X2': 56,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 91,
#     'adjrd_c_rank': 55.1,
#     'adjrd_l_rank': 57.2,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 12.4,
#     'birdies_l_rank': 61.6,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.6,
#     'bogies_l_rank': 40.3,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 97.5,
#     'cnt_l': 33.0,
#     'cnt_l_pct': 37.3,
#     'cnt_r_pct': 1.5,
#     'da_l': 59.6,
#     'da_l_rank': 42.4,
#     'da_r_rank': 50.0,
#     'dd_l': 290.7,
#     'dd_l_rank': 55.5,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.4,
#     'eagles_l_rank': 65.2,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 57.0,
#     'gir_l': 66.8,
#     'gir_l_rank': 56.3,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 24.0,
#     'mc_pct_l_pct': 77.5,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.6,
#     'par4_l': 1.4,
#     'par5_l': -4.5,
#     'ppr_l': 29.3,
#     'ppr_l_rank': 48.9,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 73.6,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 60.3,
#     'sc_l_rank': 54.7,
#     'sc_r_rank': 50.0,
#     'temp': 75.0,
#     'temp_pct': 75.5,
#     'wind': None,
#     'wind_pct': None},
#    'Salary': 5800,
#    'Score': 83.0,
#    'TeamName': ''},
#   {'ActualPoints': 97.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549716,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8836,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 97.5,
#     'Consistency': 95,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549716,
#     'FullName': '',
#     'ImpPts': 52.47,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8836,
#     'Player_Name': 'Jerry Kelly',
#     'Plus_Minus': 73,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 13,
#     'Salary': 7400,
#     'Salary_Movement': 50,
#     'Score': 73.0,
#     'Season_Count': 21,
#     'Season_PPG': 55.4,
#     'Season_PPG_Percentile': 51,
#     'Season_Plus_Minus': 4.2,
#     'Season_Salary_Change': -200,
#     'Season_X0': 38,
#     'Season_X1': 61,
#     'Season_X2': 47,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 81,
#     'adjrd_c_rank': 68.8,
#     'adjrd_l_rank': 62.8,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 12.8,
#     'birdies_l_rank': 59.4,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.1,
#     'bogies_l_rank': 46.7,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 97.5,
#     'cnt_l': 31.0,
#     'cnt_l_pct': 29.3,
#     'cnt_r_pct': 1.5,
#     'da_l': 70.1,
#     'da_l_rank': 76.5,
#     'da_r_rank': 50.0,
#     'dd_l': 277.9,
#     'dd_l_rank': 21.8,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.1,
#     'eagles_l_rank': 54.5,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 39.6,
#     'gir_l': 64.9,
#     'gir_l_rank': 52.0,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 29.0,
#     'mc_pct_l_pct': 67.3,
#     'mc_pct_r_pct': None,
#     'odds': 1.2,
#     'odds_pct': 8.4,
#     'par3_l': -0.2,
#     'par4_l': -0.1,
#     'par5_l': -3.3,
#     'ppr_l': 28.7,
#     'ppr_l_rank': 60.0,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 84.0,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 64.7,
#     'sc_l_rank': 68.6,
#     'sc_r_rank': 50.0,
#     'temp': 73.2,
#     'temp_pct': 69.3,
#     'wind': 5.6,
#     'wind_pct': 76.5},
#    'Salary': 7400,
#    'Score': 73.0,
#    'TeamName': ''},
#   {'ActualPoints': 82.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549717,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8837,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 82.0,
#     'Consistency': 95,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549717,
#     'FullName': '',
#     'ImpPts': 47.31,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8837,
#     'Player_Name': 'Stewart Cink',
#     'Plus_Minus': 74,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 60,
#     'Salary': 6100,
#     'Salary_Movement': 50,
#     'Score': 74.0,
#     'Season_Count': 22,
#     'Season_PPG': 52.3,
#     'Season_PPG_Percentile': 39,
#     'Season_Plus_Minus': 4.4,
#     'Season_Salary_Change': -2000,
#     'Season_X0': 36,
#     'Season_X1': 63,
#     'Season_X2': 45,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 79,
#     'adjrd_c_rank': 60.7,
#     'adjrd_l_rank': 59.8,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 13.0,
#     'birdies_l_rank': 60.2,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.1,
#     'bogies_l_rank': 43.8,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 92.8,
#     'cnt_l': 32.0,
#     'cnt_l_pct': 33.2,
#     'cnt_r_pct': 1.5,
#     'da_l': 58.4,
#     'da_l_rank': 36.6,
#     'da_r_rank': 50.0,
#     'dd_l': 292.8,
#     'dd_l_rank': 61.2,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.1,
#     'eagles_l_rank': 54.3,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 69.9,
#     'gir_l': 73.2,
#     'gir_l_rank': 77.1,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 31.0,
#     'mc_pct_l_pct': 62.7,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.4,
#     'par4_l': 0.4,
#     'par5_l': -4.1,
#     'ppr_l': 30.4,
#     'ppr_l_rank': 34.2,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 82.8,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 54.3,
#     'sc_l_rank': 47.6,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 6100,
#    'Score': 74.0,
#    'TeamName': ''},
#   {'ActualPoints': 71.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549718,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8839,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 71.0,
#     'Consistency': 76,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549718,
#     'FullName': '',
#     'ImpPts': 52.9,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': 1,
#     'Month_PPG': 103.5,
#     'Month_Salary_Change': 700,
#     'Month_X0': 0,
#     'Month_X1': 100,
#     'Month_X2': 100,
#     'MyTrends': 0,
#     'PlayerId': 8839,
#     'Player_Name': 'Padraig Harrington',
#     'Plus_Minus': 31,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 13,
#     'Salary': 7500,
#     'Salary_Movement': 22,
#     'Score': 31.0,
#     'Season_Count': 17,
#     'Season_PPG': 44.5,
#     'Season_PPG_Percentile': 15,
#     'Season_Plus_Minus': -4.6,
#     'Season_Salary_Change': -100,
#     'Season_X0': 58,
#     'Season_X1': 41,
#     'Season_X2': 23,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 31,
#     'adjrd_c_rank': 50.0,
#     'adjrd_l_rank': 45.0,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 11.3,
#     'birdies_l_rank': 49.1,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.7,
#     'bogies_l_rank': 42.7,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 15.2,
#     'cnt_l': 39.0,
#     'cnt_l_pct': 63.4,
#     'cnt_r_pct': 7.1,
#     'da_l': 53.4,
#     'da_l_rank': 30.6,
#     'da_r_rank': 50.0,
#     'dd_l': 290.6,
#     'dd_l_rank': 53.6,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.3,
#     'eagles_l_rank': 62.4,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 50.0,
#     'gir_l': 62.9,
#     'gir_l_rank': 36.7,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 46.0,
#     'mc_pct_l_pct': 27.4,
#     'mc_pct_r_pct': 88.5,
#     'odds': 1.2,
#     'odds_pct': 8.4,
#     'par3_l': 0.7,
#     'par4_l': 2.3,
#     'par5_l': -3.4,
#     'ppr_l': 29.2,
#     'ppr_l_rank': 57.0,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 71.3,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 57.0,
#     'sc_l_rank': 52.8,
#     'sc_r_rank': 50.0,
#     'temp': 75.0,
#     'temp_pct': 75.5,
#     'wind': None,
#     'wind_pct': None},
#    'Salary': 7500,
#    'Score': 31.0,
#    'TeamName': ''},
#   {'ActualPoints': 31.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549719,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8840,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 31.5,
#     'Consistency': 95,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549719,
#     'FullName': '',
#     'ImpPts': 48.05,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': 1,
#     'Month_PPG': 80.0,
#     'Month_Salary_Change': -700,
#     'Month_X0': 0,
#     'Month_X1': 100,
#     'Month_X2': 100,
#     'MyTrends': 0,
#     'PlayerId': 8840,
#     'Player_Name': 'Alex Cejka',
#     'Plus_Minus': 85,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 40,
#     'Salary': 6300,
#     'Salary_Movement': 77,
#     'Score': 85.0,
#     'Season_Count': 26,
#     'Season_PPG': 55.4,
#     'Season_PPG_Percentile': 51,
#     'Season_Plus_Minus': 8.3,
#     'Season_Salary_Change': -100,
#     'Season_X0': 38,
#     'Season_X1': 61,
#     'Season_X2': 38,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 67,
#     'adjrd_c_rank': 43.4,
#     'adjrd_l_rank': 55.5,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 11.8,
#     'birdies_l_rank': 52.9,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 7.5,
#     'bogies_l_rank': 51.9,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 48.6,
#     'cnt_l': 40.0,
#     'cnt_l_pct': 67.5,
#     'cnt_r_pct': 7.1,
#     'da_l': 64.4,
#     'da_l_rank': 59.6,
#     'da_r_rank': 50.0,
#     'dd_l': 283.9,
#     'dd_l_rank': 32.3,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.3,
#     'eagles_l_rank': 59.9,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 60.2,
#     'gir_l': 66.3,
#     'gir_l_rank': 53.6,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 30.0,
#     'mc_pct_l_pct': 65.0,
#     'mc_pct_r_pct': 88.5,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.1,
#     'par4_l': 0.7,
#     'par5_l': -3.8,
#     'ppr_l': 29.2,
#     'ppr_l_rank': 51.9,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 76.1,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 61.1,
#     'sc_l_rank': 59.1,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 6300,
#    'Score': 85.0,
#    'TeamName': ''},
#   {'ActualPoints': 95.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549720,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8842,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 95.0,
#     'Consistency': 97,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549720,
#     'FullName': '',
#     'ImpPts': 63.57,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8842,
#     'Player_Name': 'Charles Howell III',
#     'Plus_Minus': 81,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 60,
#     'Salary': 9700,
#     'Salary_Movement': 50,
#     'Score': 81.0,
#     'Season_Count': 29,
#     'Season_PPG': 59.8,
#     'Season_PPG_Percentile': 68,
#     'Season_Plus_Minus': 6.5,
#     'Season_Salary_Change': 200,
#     'Season_X0': 20,
#     'Season_X1': 79,
#     'Season_X2': 34,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 58,
#     'adjrd_c_rank': 85.9,
#     'adjrd_l_rank': 59.2,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 12.0,
#     'birdies_l_rank': 56.3,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.8,
#     'bogies_l_rank': 36.4,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 97.5,
#     'cnt_l': 40.0,
#     'cnt_l_pct': 67.5,
#     'cnt_r_pct': 7.1,
#     'da_l': 52.4,
#     'da_l_rank': 21.8,
#     'da_r_rank': 50.0,
#     'dd_l': 302.9,
#     'dd_l_rank': 85.0,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.3,
#     'eagles_l_rank': 63.5,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 69.4,
#     'gir_l': 68.1,
#     'gir_l_rank': 62.2,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 25.0,
#     'mc_pct_l_pct': 75.6,
#     'mc_pct_r_pct': 88.5,
#     'odds': 2.4,
#     'odds_pct': 16.8,
#     'par3_l': 0.8,
#     'par4_l': 0.8,
#     'par5_l': -4.4,
#     'ppr_l': 29.6,
#     'ppr_l_rank': 42.7,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 84.2,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 58.4,
#     'sc_l_rank': 51.5,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 9700,
#    'Score': 81.0,
#    'TeamName': ''},
#   {'ActualPoints': 98.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549721,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8844,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 98.0,
#     'Consistency': 100,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549721,
#     'FullName': '',
#     'ImpPts': 74.01,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8844,
#     'Player_Name': 'Matt Kuchar',
#     'Plus_Minus': 79,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 81,
#     'Salary': 11500,
#     'Salary_Movement': 50,
#     'Score': 79.0,
#     'Season_Count': 22,
#     'Season_PPG': 73.8,
#     'Season_PPG_Percentile': 94,
#     'Season_Plus_Minus': 6.0,
#     'Season_Salary_Change': 1200,
#     'Season_X0': 4,
#     'Season_X1': 95,
#     'Season_X2': 22,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 29,
#     'adjrd_c_rank': 77.3,
#     'adjrd_l_rank': 72.2,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 15.0,
#     'birdies_l_rank': 70.6,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.9,
#     'bogies_l_rank': 46.7,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 92.8,
#     'cnt_l': 33.0,
#     'cnt_l_pct': 37.3,
#     'cnt_r_pct': 1.5,
#     'da_l': 63.6,
#     'da_l_rank': 57.1,
#     'da_r_rank': 50.0,
#     'dd_l': 287.4,
#     'dd_l_rank': 42.7,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.5,
#     'eagles_l_rank': 66.2,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 58.6,
#     'gir_l': 67.2,
#     'gir_l_rank': 59.4,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 3.0,
#     'mc_pct_l_pct': 98.0,
#     'mc_pct_r_pct': None,
#     'odds': 4.8,
#     'odds_pct': 33.6,
#     'par3_l': 0.7,
#     'par4_l': -0.8,
#     'par5_l': -5.0,
#     'ppr_l': 28.6,
#     'ppr_l_rank': 64.4,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 86.1,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 63.2,
#     'sc_l_rank': 66.3,
#     'sc_r_rank': 50.0,
#     'temp': 73.2,
#     'temp_pct': 69.3,
#     'wind': 5.6,
#     'wind_pct': 76.5},
#    'Salary': 11500,
#    'Score': 79.0,
#    'TeamName': ''},
#   {'ActualPoints': 90.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549722,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8845,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 90.5,
#     'Consistency': 67,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549722,
#     'FullName': '',
#     'ImpPts': 46.59,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8845,
#     'Player_Name': 'Tim Clark',
#     'Plus_Minus': 14,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 13,
#     'Salary': 5900,
#     'Salary_Movement': 50,
#     'Score': 14.0,
#     'Season_Count': 11,
#     'Season_PPG': 39.6,
#     'Season_PPG_Percentile': 8,
#     'Season_Plus_Minus': -9.9,
#     'Season_Salary_Change': -600,
#     'Season_X0': 63,
#     'Season_X1': 36,
#     'Season_X2': 18,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 22,
#     'adjrd_c_rank': 71.7,
#     'adjrd_l_rank': 42.0,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 10.5,
#     'birdies_l_rank': 42.8,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.3,
#     'bogies_l_rank': 40.6,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 92.8,
#     'cnt_l': 23.0,
#     'cnt_l_pct': 7.6,
#     'cnt_r_pct': 1.5,
#     'da_l': 69.8,
#     'da_l_rank': 75.7,
#     'da_r_rank': 50.0,
#     'dd_l': 273.4,
#     'dd_l_rank': 9.7,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.1,
#     'eagles_l_rank': 54.8,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 67.2,
#     'gir_l': 66.2,
#     'gir_l_rank': 45.7,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 43.0,
#     'mc_pct_l_pct': 33.9,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.3,
#     'par4_l': 1.3,
#     'par5_l': -2.8,
#     'ppr_l': 29.8,
#     'ppr_l_rank': 43.8,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 83.2,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 54.7,
#     'sc_l_rank': 42.2,
#     'sc_r_rank': 50.0,
#     'temp': 73.2,
#     'temp_pct': 69.3,
#     'wind': 5.6,
#     'wind_pct': 76.5},
#    'Salary': 5900,
#    'Score': 14.0,
#    'TeamName': ''},
#   {'ActualPoints': 69.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549723,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8846,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 69.0,
#     'Consistency': 90,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549723,
#     'FullName': '',
#     'ImpPts': 45.54,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8846,
#     'Player_Name': 'Jason Gore',
#     'Plus_Minus': 77,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 13,
#     'Salary': 5600,
#     'Salary_Movement': 50,
#     'Score': 77.0,
#     'Season_Count': 20,
#     'Season_PPG': 52.3,
#     'Season_PPG_Percentile': 39,
#     'Season_Plus_Minus': 5.4,
#     'Season_Salary_Change': -1900,
#     'Season_X0': 50,
#     'Season_X1': 50,
#     'Season_X2': 35,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 60,
#     'adjrd_c_rank': 34.2,
#     'adjrd_l_rank': 51.7,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 12.3,
#     'birdies_l_rank': 53.9,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.1,
#     'bogies_l_rank': 42.8,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 29.7,
#     'cnt_l': 36.0,
#     'cnt_l_pct': 50.4,
#     'cnt_r_pct': 1.5,
#     'da_l': 66.4,
#     'da_l_rank': 65.4,
#     'da_r_rank': 50.0,
#     'dd_l': 291.7,
#     'dd_l_rank': 54.6,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.4,
#     'eagles_l_rank': 63.8,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 66.4,
#     'gir_l': 68.6,
#     'gir_l_rank': 59.4,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 38.0,
#     'mc_pct_l_pct': 45.7,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.2,
#     'par4_l': 0.5,
#     'par5_l': -3.4,
#     'ppr_l': 29.6,
#     'ppr_l_rank': 45.0,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 70.4,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 55.1,
#     'sc_l_rank': 46.3,
#     'sc_r_rank': 50.0,
#     'temp': 73.2,
#     'temp_pct': 69.3,
#     'wind': 5.6,
#     'wind_pct': 76.5},
#    'Salary': 5600,
#    'Score': 77.0,
#    'TeamName': ''},
#   {'ActualPoints': 23.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549724,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8847,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 23.0,
#     'Consistency': 95,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549724,
#     'FullName': '',
#     'ImpPts': 47.31,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8847,
#     'Player_Name': 'Mark Wilson',
#     'Plus_Minus': 76,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 40,
#     'Salary': 6100,
#     'Salary_Movement': 50,
#     'Score': 76.0,
#     'Season_Count': 24,
#     'Season_PPG': 51.4,
#     'Season_PPG_Percentile': 35,
#     'Season_Plus_Minus': 4.9,
#     'Season_Salary_Change': -1500,
#     'Season_X0': 37,
#     'Season_X1': 62,
#     'Season_X2': 41,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 73,
#     'adjrd_c_rank': 59.0,
#     'adjrd_l_rank': 49.7,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 11.1,
#     'birdies_l_rank': 51.0,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 7.6,
#     'bogies_l_rank': 45.5,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 97.5,
#     'cnt_l': 33.0,
#     'cnt_l_pct': 37.3,
#     'cnt_r_pct': 1.5,
#     'da_l': 64.7,
#     'da_l_rank': 63.9,
#     'da_r_rank': 50.0,
#     'dd_l': 276.6,
#     'dd_l_rank': 19.9,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.2,
#     'eagles_l_rank': 57.2,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 67.6,
#     'gir_l': 67.4,
#     'gir_l_rank': 56.9,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 42.0,
#     'mc_pct_l_pct': 36.2,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.3,
#     'par4_l': 0.7,
#     'par5_l': -2.8,
#     'ppr_l': 29.7,
#     'ppr_l_rank': 45.1,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 80.7,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 58.9,
#     'sc_l_rank': 52.0,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 6100,
#    'Score': 76.0,
#    'TeamName': ''},
#   {'ActualPoints': 100.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549725,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8848,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 100.5,
#     'Consistency': 96,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549725,
#     'FullName': '',
#     'ImpPts': 59.43,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8848,
#     'Player_Name': 'Ryan Palmer',
#     'Plus_Minus': 79,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 81,
#     'Salary': 8900,
#     'Salary_Movement': 50,
#     'Score': 79.0,
#     'Season_Count': 21,
#     'Season_PPG': 65.7,
#     'Season_PPG_Percentile': 84,
#     'Season_Plus_Minus': 5.8,
#     'Season_Salary_Change': -400,
#     'Season_X0': 33,
#     'Season_X1': 66,
#     'Season_X2': 38,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 67,
#     'adjrd_c_rank': 62.9,
#     'adjrd_l_rank': 69.8,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 14.5,
#     'birdies_l_rank': 69.5,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 9.1,
#     'bogies_l_rank': 45.6,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 97.5,
#     'cnt_l': 32.0,
#     'cnt_l_pct': 33.2,
#     'cnt_r_pct': 1.5,
#     'da_l': 56.4,
#     'da_l_rank': 37.8,
#     'da_r_rank': 50.0,
#     'dd_l': 306.1,
#     'dd_l_rank': 83.4,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.5,
#     'eagles_l_rank': 69.7,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 64.1,
#     'gir_l': 66.4,
#     'gir_l_rank': 60.3,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 18.0,
#     'mc_pct_l_pct': 87.0,
#     'mc_pct_r_pct': None,
#     'odds': 2.0,
#     'odds_pct': 14.0,
#     'par3_l': 0.4,
#     'par4_l': -0.6,
#     'par5_l': -3.9,
#     'ppr_l': 28.8,
#     'ppr_l_rank': 59.0,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 84.5,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 59.2,
#     'sc_l_rank': 55.2,
#     'sc_r_rank': 50.0,
#     'temp': 75.0,
#     'temp_pct': 75.5,
#     'wind': None,
#     'wind_pct': None},
#    'Salary': 8900,
#    'Score': 79.0,
#    'TeamName': ''},
#   {'ActualPoints': 59.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549726,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8849,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 59.5,
#     'Consistency': 93,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549726,
#     'FullName': '',
#     'ImpPts': 46.59,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': 1,
#     'Month_PPG': 47.0,
#     'Month_Salary_Change': -800,
#     'Month_X0': 0,
#     'Month_X1': 100,
#     'Month_X2': 0,
#     'MyTrends': 0,
#     'PlayerId': 8849,
#     'Player_Name': 'J.J. Henry',
#     'Plus_Minus': 40,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 13,
#     'Salary': 5900,
#     'Salary_Movement': 80,
#     'Score': 40.0,
#     'Season_Count': 25,
#     'Season_PPG': 47.2,
#     'Season_PPG_Percentile': 22,
#     'Season_Plus_Minus': -2.6,
#     'Season_Salary_Change': -2600,
#     'Season_X0': 44,
#     'Season_X1': 56,
#     'Season_X2': 40,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 71,
#     'adjrd_c_rank': 55.1,
#     'adjrd_l_rank': 48.3,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 10.4,
#     'birdies_l_rank': 45.7,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.3,
#     'bogies_l_rank': 41.8,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 48.6,
#     'cnt_l': 38.0,
#     'cnt_l_pct': 59.1,
#     'cnt_r_pct': 7.1,
#     'da_l': 61.1,
#     'da_l_rank': 52.4,
#     'da_r_rank': 50.0,
#     'dd_l': 291.6,
#     'dd_l_rank': 54.0,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.3,
#     'eagles_l_rank': 61.8,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 51.6,
#     'gir_l': 68.4,
#     'gir_l_rank': 60.4,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 36.0,
#     'mc_pct_l_pct': 50.6,
#     'mc_pct_r_pct': 88.5,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.8,
#     'par4_l': 1.5,
#     'par5_l': -3.5,
#     'ppr_l': 30.3,
#     'ppr_l_rank': 28.6,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 76.0,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 54.8,
#     'sc_l_rank': 44.7,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 5900,
#    'Score': 40.0,
#    'TeamName': ''},
#   {'ActualPoints': 68.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549727,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8851,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 68.5,
#     'Consistency': 95,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549727,
#     'FullName': '',
#     'ImpPts': 48.82,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8851,
#     'Player_Name': 'Chad Campbell',
#     'Plus_Minus': 82,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 13,
#     'Salary': 6500,
#     'Salary_Movement': 50,
#     'Score': 82.0,
#     'Season_Count': 28,
#     'Season_PPG': 54.1,
#     'Season_PPG_Percentile': 46,
#     'Season_Plus_Minus': 6.9,
#     'Season_Salary_Change': -1600,
#     'Season_X0': 35,
#     'Season_X1': 64,
#     'Season_X2': 46,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 80,
#     'adjrd_c_rank': 58.6,
#     'adjrd_l_rank': 57.2,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 11.4,
#     'birdies_l_rank': 53.1,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 7.9,
#     'bogies_l_rank': 46.7,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 92.8,
#     'cnt_l': 40.0,
#     'cnt_l_pct': 67.5,
#     'cnt_r_pct': 1.5,
#     'da_l': 64.6,
#     'da_l_rank': 64.5,
#     'da_r_rank': 50.0,
#     'dd_l': 286.7,
#     'dd_l_rank': 38.9,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.2,
#     'eagles_l_rank': 55.0,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 76.8,
#     'gir_l': 68.1,
#     'gir_l_rank': 61.8,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 42.0,
#     'mc_pct_l_pct': 36.2,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': -0.2,
#     'par4_l': 1.6,
#     'par5_l': -3.9,
#     'ppr_l': 29.5,
#     'ppr_l_rank': 45.2,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 79.0,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 58.5,
#     'sc_l_rank': 49.3,
#     'sc_r_rank': 50.0,
#     'temp': 75.8,
#     'temp_pct': 78.0,
#     'wind': 8.4,
#     'wind_pct': 62.5},
#    'Salary': 6500,
#    'Score': 82.0,
#    'TeamName': ''},
#   {'ActualPoints': 118.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549728,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8852,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 118.5,
#     'Consistency': 94,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549728,
#     'FullName': '',
#     'ImpPts': 45.54,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8852,
#     'Player_Name': 'Greg Owen',
#     'Plus_Minus': 75,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 13,
#     'Salary': 5600,
#     'Salary_Movement': 50,
#     'Score': 75.0,
#     'Season_Count': 15,
#     'Season_PPG': 52.6,
#     'Season_PPG_Percentile': 40,
#     'Season_Plus_Minus': 4.5,
#     'Season_Salary_Change': -2100,
#     'Season_X0': 40,
#     'Season_X1': 60,
#     'Season_X2': 40,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 71,
#     'adjrd_c_rank': 33.4,
#     'adjrd_l_rank': 52.5,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 11.7,
#     'birdies_l_rank': 52.1,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 7.4,
#     'bogies_l_rank': 51.1,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 48.6,
#     'cnt_l': 30.0,
#     'cnt_l_pct': 25.6,
#     'cnt_r_pct': 1.5,
#     'da_l': 59.9,
#     'da_l_rank': 46.1,
#     'da_r_rank': 50.0,
#     'dd_l': 297.2,
#     'dd_l_rank': 69.1,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.2,
#     'eagles_l_rank': 59.4,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 60.9,
#     'gir_l': 69.0,
#     'gir_l_rank': 60.7,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 43.0,
#     'mc_pct_l_pct': 33.9,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.9,
#     'par4_l': 0.2,
#     'par5_l': -3.4,
#     'ppr_l': 30.0,
#     'ppr_l_rank': 38.2,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 71.4,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 56.8,
#     'sc_l_rank': 53.5,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 5600,
#    'Score': 75.0,
#    'TeamName': ''},
#   {'ActualPoints': 77.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549729,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8853,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 77.5,
#     'Consistency': 90,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549729,
#     'FullName': '',
#     'ImpPts': 49.99,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8853,
#     'Player_Name': 'John Senden',
#     'Plus_Minus': 45,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 40,
#     'Salary': 6800,
#     'Salary_Movement': 50,
#     'Score': 45.0,
#     'Season_Count': 20,
#     'Season_PPG': 49.6,
#     'Season_PPG_Percentile': 29,
#     'Season_Plus_Minus': -1.7,
#     'Season_Salary_Change': -1200,
#     'Season_X0': 50,
#     'Season_X1': 50,
#     'Season_X2': 25,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 36,
#     'adjrd_c_rank': 66.7,
#     'adjrd_l_rank': 56.2,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 12.1,
#     'birdies_l_rank': 52.4,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 9.0,
#     'bogies_l_rank': 47.0,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 92.8,
#     'cnt_l': 39.0,
#     'cnt_l_pct': 63.4,
#     'cnt_r_pct': 7.1,
#     'da_l': 64.7,
#     'da_l_rank': 63.6,
#     'da_r_rank': 50.0,
#     'dd_l': 290.3,
#     'dd_l_rank': 48.2,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.3,
#     'eagles_l_rank': 61.3,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 71.4,
#     'gir_l': 67.1,
#     'gir_l_rank': 60.1,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 28.0,
#     'mc_pct_l_pct': 69.5,
#     'mc_pct_r_pct': 88.5,
#     'odds': 1.2,
#     'odds_pct': 8.4,
#     'par3_l': 0.2,
#     'par4_l': 1.8,
#     'par5_l': -3.4,
#     'ppr_l': 29.5,
#     'ppr_l_rank': 48.6,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 77.5,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 55.1,
#     'sc_l_rank': 48.3,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 6800,
#    'Score': 45.0,
#    'TeamName': ''},
#   {'ActualPoints': 31.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549730,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8854,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 31.0,
#     'Consistency': 95,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549730,
#     'FullName': '',
#     'ImpPts': 48.82,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8854,
#     'Player_Name': 'Rory Sabbatini',
#     'Plus_Minus': 81,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 40,
#     'Salary': 6500,
#     'Salary_Movement': 50,
#     'Score': 81.0,
#     'Season_Count': 24,
#     'Season_PPG': 57.5,
#     'Season_PPG_Percentile': 60,
#     'Season_Plus_Minus': 6.6,
#     'Season_Salary_Change': -1500,
#     'Season_X0': 37,
#     'Season_X1': 62,
#     'Season_X2': 54,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 90,
#     'adjrd_c_rank': 66.9,
#     'adjrd_l_rank': 57.2,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 12.5,
#     'birdies_l_rank': 55.2,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 7.5,
#     'bogies_l_rank': 51.2,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 97.5,
#     'cnt_l': 31.0,
#     'cnt_l_pct': 29.3,
#     'cnt_r_pct': 1.5,
#     'da_l': 59.4,
#     'da_l_rank': 46.6,
#     'da_r_rank': 50.0,
#     'dd_l': 290.2,
#     'dd_l_rank': 55.3,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.3,
#     'eagles_l_rank': 59.6,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 64.1,
#     'gir_l': 65.9,
#     'gir_l_rank': 54.0,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 41.0,
#     'mc_pct_l_pct': 38.5,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.5,
#     'par4_l': 0.0,
#     'par5_l': -3.4,
#     'ppr_l': 28.9,
#     'ppr_l_rank': 52.0,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 85.1,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 60.1,
#     'sc_l_rank': 56.0,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 6500,
#    'Score': 81.0,
#    'TeamName': ''},
#   {'ActualPoints': 90.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549731,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8856,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 90.0,
#     'Consistency': 93,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549731,
#     'FullName': '',
#     'ImpPts': 58.44,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8856,
#     'Player_Name': 'Luke Donald',
#     'Plus_Minus': 45,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 40,
#     'Salary': 8700,
#     'Salary_Movement': 50,
#     'Score': 45.0,
#     'Season_Count': 19,
#     'Season_PPG': 55.3,
#     'Season_PPG_Percentile': 51,
#     'Season_Plus_Minus': -1.6,
#     'Season_Salary_Change': 500,
#     'Season_X0': 42,
#     'Season_X1': 57,
#     'Season_X2': 15,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 18,
#     'adjrd_c_rank': 55.0,
#     'adjrd_l_rank': 62.8,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 12.9,
#     'birdies_l_rank': 59.7,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.9,
#     'bogies_l_rank': 47.8,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 48.6,
#     'cnt_l': 34.0,
#     'cnt_l_pct': 41.6,
#     'cnt_r_pct': 1.5,
#     'da_l': 59.3,
#     'da_l_rank': 46.7,
#     'da_r_rank': 50.0,
#     'dd_l': 276.2,
#     'dd_l_rank': 15.1,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.2,
#     'eagles_l_rank': 58.3,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 46.5,
#     'gir_l': 66.3,
#     'gir_l_rank': 55.3,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 20.0,
#     'mc_pct_l_pct': 84.2,
#     'mc_pct_r_pct': None,
#     'odds': 2.4,
#     'odds_pct': 16.8,
#     'par3_l': 0.2,
#     'par4_l': 1.0,
#     'par5_l': -3.6,
#     'ppr_l': 29.2,
#     'ppr_l_rank': 57.9,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 83.4,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 60.9,
#     'sc_l_rank': 65.0,
#     'sc_r_rank': 50.0,
#     'temp': 75.0,
#     'temp_pct': 75.5,
#     'wind': None,
#     'wind_pct': None},
#    'Salary': 8700,
#    'Score': 45.0,
#    'TeamName': ''},
#   {'ActualPoints': 85.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549732,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8857,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 85.5,
#     'Consistency': 97,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549732,
#     'FullName': '',
#     'ImpPts': 72.77,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': 1,
#     'Month_PPG': 88.5,
#     'Month_Salary_Change': 1800,
#     'Month_X0': 0,
#     'Month_X1': 100,
#     'Month_X2': 100,
#     'MyTrends': 0,
#     'PlayerId': 8857,
#     'Player_Name': 'Zach Johnson',
#     'Plus_Minus': 74,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 81,
#     'Salary': 11300,
#     'Salary_Movement': 4,
#     'Score': 74.0,
#     'Season_Count': 24,
#     'Season_PPG': 67.9,
#     'Season_PPG_Percentile': 88,
#     'Season_Plus_Minus': 4.5,
#     'Season_Salary_Change': -1300,
#     'Season_X0': 25,
#     'Season_X1': 75,
#     'Season_X2': 45,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 79,
#     'adjrd_c_rank': 67.4,
#     'adjrd_l_rank': 67.4,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 13.9,
#     'birdies_l_rank': 60.9,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.5,
#     'bogies_l_rank': 52.1,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 97.5,
#     'cnt_l': 32.0,
#     'cnt_l_pct': 33.2,
#     'cnt_r_pct': 7.1,
#     'da_l': 70.7,
#     'da_l_rank': 77.2,
#     'da_r_rank': 50.0,
#     'dd_l': 282.1,
#     'dd_l_rank': 28.7,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.2,
#     'eagles_l_rank': 57.5,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 50.0,
#     'gir_l': 67.9,
#     'gir_l_rank': 62.5,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 18.0,
#     'mc_pct_l_pct': 87.0,
#     'mc_pct_r_pct': 88.5,
#     'odds': 4.8,
#     'odds_pct': 33.6,
#     'par3_l': 0.2,
#     'par4_l': -0.2,
#     'par5_l': -4.2,
#     'ppr_l': 29.0,
#     'ppr_l_rank': 57.7,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 89.3,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 60.2,
#     'sc_l_rank': 60.5,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 11300,
#    'Score': 74.0,
#    'TeamName': ''},
#   {'ActualPoints': 95.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549733,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 8860,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 95.0,
#     'Consistency': 95,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549733,
#     'FullName': '',
#     'ImpPts': 49.2,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 8860,
#     'Player_Name': "Sean O'Hair",
#     'Plus_Minus': 88,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 50,
#     'Salary': 6600,
#     'Salary_Movement': 50,
#     'Score': 88.0,
#     'Season_Count': 26,
#     'Season_PPG': 60.8,
#     'Season_PPG_Percentile': 72,
#     'Season_Plus_Minus': 9.9,
#     'Season_Salary_Change': -900,
#     'Season_X0': 34,
#     'Season_X1': 65,
#     'Season_X2': 57,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 92,
#     'adjrd_c_rank': 37.5,
#     'adjrd_l_rank': 51.7,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 11.9,
#     'birdies_l_rank': 54.8,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.5,
#     'bogies_l_rank': 41.4,
# ...
#     'Season_Plus_Minus': None,
#     'Season_Salary_Change': 0,
#     'Season_X0': None,
#     'Season_X1': None,
#     'Season_X2': None,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 50,
#     'adjrd_c_rank': 50.0,
#     'adjrd_l_rank': 43.5,
#     'adjrd_r_rank': 30.8,
#     'birdies_l': 12.4,
#     'birdies_l_rank': 48.7,
#     'birdies_r_rank': 43.7,
#     'bogies_l': 8.9,
#     'bogies_l_rank': 44.6,
#     'bogies_r_rank': 18.4,
#     'cnt_c_pct': 15.2,
#     'cnt_l': 34.0,
#     'cnt_l_pct': 41.6,
#     'cnt_r_pct': 22.2,
#     'da_l': 57.1,
#     'da_l_rank': 54.8,
#     'da_r_rank': 55.5,
#     'dd_l': 284.5,
#     'dd_l_rank': 73.3,
#     'dd_r_rank': 67.8,
#     'eagles_l': 0.3,
#     'eagles_l_rank': 63.6,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 50.0,
#     'gir_l': 65.6,
#     'gir_l_rank': 53.5,
#     'gir_r_rank': 46.9,
#     'mc_pct_l': 26.0,
#     'mc_pct_l_pct': 73.7,
#     'mc_pct_r_pct': 88.5,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 1.3,
#     'par4_l': 0.5,
#     'par5_l': -3.5,
#     'ppr_l': 29.4,
#     'ppr_l_rank': 39.6,
#     'ppr_r_rank': 39.7,
#     'sagarin_l_rank': 34.4,
#     'sagarin_r_rank': 56.9,
#     'sc_l': 50.1,
#     'sc_l_rank': 34.9,
#     'sc_r_rank': 25.9,
#     'temp': 73.2,
#     'temp_pct': 69.3,
#     'wind': 5.6,
#     'wind_pct': 76.5},
#    'Salary': 5600,
#    'Score': 50.0,
#    'TeamName': ''},
#   {'ActualPoints': 77.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549846,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 22447,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 77.5,
#     'Consistency': 97,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549846,
#     'FullName': '',
#     'ImpPts': 44.87,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 22447,
#     'Player_Name': 'Shane Bertsch',
#     'Plus_Minus': 58,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 50,
#     'Salary': 5400,
#     'Salary_Movement': 50,
#     'Score': 58.0,
#     'Season_Count': 4,
#     'Season_PPG': 45.8,
#     'Season_PPG_Percentile': 18,
#     'Season_Plus_Minus': 1.0,
#     'Season_Salary_Change': 300,
#     'Season_X0': 25,
#     'Season_X1': 75,
#     'Season_X2': 0,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 10,
#     'adjrd_c_rank': 48.1,
#     'adjrd_l_rank': 44.2,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 11.9,
#     'birdies_l_rank': 50.1,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 7.5,
#     'bogies_l_rank': 44.9,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 92.8,
#     'cnt_l': 34.0,
#     'cnt_l_pct': 41.6,
#     'cnt_r_pct': 1.5,
#     'da_l': 66.1,
#     'da_l_rank': 65.5,
#     'da_r_rank': 50.0,
#     'dd_l': 285.5,
#     'dd_l_rank': 22.4,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.2,
#     'eagles_l_rank': 60.1,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 26.0,
#     'gir_l': 66.4,
#     'gir_l_rank': 43.8,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 44.0,
#     'mc_pct_l_pct': 31.7,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 1.0,
#     'par4_l': -0.6,
#     'par5_l': -2.6,
#     'ppr_l': 29.2,
#     'ppr_l_rank': 54.8,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 45.7,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 57.1,
#     'sc_l_rank': 48.9,
#     'sc_r_rank': 50.0,
#     'temp': 74.5,
#     'temp_pct': 73.9,
#     'wind': None,
#     'wind_pct': None},
#    'Salary': 5400,
#    'Score': 58.0,
#    'TeamName': ''},
#   {'ActualPoints': 19.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549847,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 22448,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 19.5,
#     'Consistency': 50,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549847,
#     'FullName': '',
#     'ImpPts': 44.87,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 22448,
#     'Player_Name': 'Shawn Lu',
#     'Plus_Minus': 50,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 50,
#     'Salary': 5400,
#     'Salary_Movement': 50,
#     'Score': 50.0,
#     'Season_Count': 0,
#     'Season_PPG': None,
#     'Season_PPG_Percentile': 50,
#     'Season_Plus_Minus': None,
#     'Season_Salary_Change': 0,
#     'Season_X0': None,
#     'Season_X1': None,
#     'Season_X2': None,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 50,
#     'adjrd_c_rank': 50.0,
#     'adjrd_l_rank': 50.0,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': None,
#     'birdies_l_rank': 50.0,
#     'birdies_r_rank': 50.0,
#     'bogies_l': None,
#     'bogies_l_rank': 50.0,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 15.2,
#     'cnt_l': 0.0,
#     'cnt_l_pct': 0.0,
#     'cnt_r_pct': 1.5,
#     'da_l': None,
#     'da_l_rank': 50.0,
#     'da_r_rank': 50.0,
#     'dd_l': None,
#     'dd_l_rank': 50.0,
#     'dd_r_rank': 50.0,
#     'eagles_l': None,
#     'eagles_l_rank': 50.0,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 50.0,
#     'gir_l': None,
#     'gir_l_rank': 50.0,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': None,
#     'mc_pct_l_pct': None,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': None,
#     'par4_l': None,
#     'par5_l': None,
#     'ppr_l': None,
#     'ppr_l_rank': 50.0,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 50.0,
#     'sagarin_r_rank': 50.0,
#     'sc_l': None,
#     'sc_l_rank': 50.0,
#     'sc_r_rank': 50.0,
#     'temp': 73.2,
#     'temp_pct': 69.3,
#     'wind': 5.6,
#     'wind_pct': 76.5},
#    'Salary': 5400,
#    'Score': 50.0,
#    'TeamName': ''},
#   {'ActualPoints': 109.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549848,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 22449,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 109.5,
#     'Consistency': 97,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549848,
#     'FullName': '',
#     'ImpPts': 46.59,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 22449,
#     'Player_Name': 'Si Woo Kim',
#     'Plus_Minus': 96,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 50,
#     'Salary': 5900,
#     'Salary_Movement': 50,
#     'Score': 96.0,
#     'Season_Count': 4,
#     'Season_PPG': 67.6,
#     'Season_PPG_Percentile': 87,
#     'Season_Plus_Minus': 21.0,
#     'Season_Salary_Change': 200,
#     'Season_X0': 25,
#     'Season_X1': 75,
#     'Season_X2': 75,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 97,
#     'adjrd_c_rank': 50.0,
#     'adjrd_l_rank': 58.1,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 13.5,
#     'birdies_l_rank': 58.1,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 8.2,
#     'bogies_l_rank': 49.9,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 15.2,
#     'cnt_l': 33.0,
#     'cnt_l_pct': 37.3,
#     'cnt_r_pct': 1.5,
#     'da_l': 64.8,
#     'da_l_rank': 58.7,
#     'da_r_rank': 50.0,
#     'dd_l': 298.0,
#     'dd_l_rank': 58.7,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.4,
#     'eagles_l_rank': 63.6,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 50.0,
#     'gir_l': 69.5,
#     'gir_l_rank': 52.5,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 33.0,
#     'mc_pct_l_pct': 58.0,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.7,
#     'par4_l': -0.2,
#     'par5_l': -4.5,
#     'ppr_l': 29.3,
#     'ppr_l_rank': 55.9,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 43.8,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 61.9,
#     'sc_l_rank': 60.6,
#     'sc_r_rank': 50.0,
#     'temp': 73.2,
#     'temp_pct': 69.3,
#     'wind': 5.6,
#     'wind_pct': 76.5},
#    'Salary': 5900,
#    'Score': 96.0,
#    'TeamName': ''},
#   {'ActualPoints': 37.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549849,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 22450,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 37.5,
#     'Consistency': 100,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549849,
#     'FullName': '',
#     'ImpPts': 45.89,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 22450,
#     'Player_Name': 'Sung Kang',
#     'Plus_Minus': 82,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 40,
#     'Salary': 5700,
#     'Salary_Movement': 50,
#     'Score': 82.0,
#     'Season_Count': 2,
#     'Season_PPG': 53.8,
#     'Season_PPG_Percentile': 45,
#     'Season_Plus_Minus': 7.0,
#     'Season_Salary_Change': -400,
#     'Season_X0': 0,
#     'Season_X1': 100,
#     'Season_X2': 0,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 10,
#     'adjrd_c_rank': 11.0,
#     'adjrd_l_rank': 48.9,
#     'adjrd_r_rank': 82.1,
#     'birdies_l': 12.0,
#     'birdies_l_rank': 48.2,
#     'birdies_r_rank': 71.4,
#     'bogies_l': 7.6,
#     'bogies_l_rank': 51.2,
#     'bogies_r_rank': 57.7,
#     'cnt_c_pct': 48.6,
#     'cnt_l': 42.0,
#     'cnt_l_pct': 75.0,
#     'cnt_r_pct': 22.2,
#     'da_l': 59.8,
#     'da_l_rank': 43.2,
#     'da_r_rank': 53.2,
#     'dd_l': 295.5,
#     'dd_l_rank': 55.3,
#     'dd_r_rank': 58.2,
#     'eagles_l': 0.2,
#     'eagles_l_rank': 59.1,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 26.4,
#     'gir_l': 67.6,
#     'gir_l_rank': 53.1,
#     'gir_r_rank': 80.9,
#     'mc_pct_l': 40.0,
#     'mc_pct_l_pct': 40.9,
#     'mc_pct_r_pct': 88.5,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 0.3,
#     'par4_l': 0.9,
#     'par5_l': -3.4,
#     'ppr_l': 29.5,
#     'ppr_l_rank': 51.9,
#     'ppr_r_rank': 47.0,
#     'sagarin_l_rank': 39.6,
#     'sagarin_r_rank': 29.7,
#     'sc_l': 54.1,
#     'sc_l_rank': 47.8,
#     'sc_r_rank': 34.7,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 5700,
#    'Score': 82.0,
#    'TeamName': ''},
#   {'ActualPoints': 26.0,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549850,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 22453,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 26.0,
#     'Consistency': 50,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549850,
#     'FullName': '',
#     'ImpPts': 45.54,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 22453,
#     'Player_Name': 'Toshinori Muto',
#     'Plus_Minus': 50,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 40,
#     'Salary': 5600,
#     'Salary_Movement': 50,
#     'Score': 50.0,
#     'Season_Count': 0,
#     'Season_PPG': None,
#     'Season_PPG_Percentile': 50,
#     'Season_Plus_Minus': None,
#     'Season_Salary_Change': 0,
#     'Season_X0': None,
#     'Season_X1': None,
#     'Season_X2': None,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 50,
#     'adjrd_c_rank': 46.3,
#     'adjrd_l_rank': 54.5,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 13.2,
#     'birdies_l_rank': 59.1,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 9.3,
#     'bogies_l_rank': 46.0,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 48.6,
#     'cnt_l': 38.0,
#     'cnt_l_pct': 59.1,
#     'cnt_r_pct': 7.1,
#     'da_l': 54.5,
#     'da_l_rank': 52.1,
#     'da_r_rank': 50.0,
#     'dd_l': 284.3,
#     'dd_l_rank': 72.3,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.2,
#     'eagles_l_rank': 59.0,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 68.3,
#     'gir_l': 65.5,
#     'gir_l_rank': 53.6,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 21.0,
#     'mc_pct_l_pct': 82.7,
#     'mc_pct_r_pct': 88.5,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': 1.3,
#     'par4_l': 0.0,
#     'par5_l': -3.7,
#     'ppr_l': 29.3,
#     'ppr_l_rank': 45.4,
#     'ppr_r_rank': 50.0,
#     'sagarin_l_rank': 30.8,
#     'sagarin_r_rank': 50.0,
#     'sc_l': 51.5,
#     'sc_l_rank': 49.0,
#     'sc_r_rank': 50.0,
#     'temp': 77.3,
#     'temp_pct': 82.3,
#     'wind': 11.1,
#     'wind_pct': 47.2},
#    'Salary': 5600,
#    'Score': 50.0,
#    'TeamName': ''},
#   {'ActualPoints': 27.5,
#    'Cnt': 0,
#    'Correlation': 0.0,
#    'CurrentExposure': 0.0,
#    'ErrorList': {},
#    'Exposure': None,
#    'FantasyResultId': 549851,
#    'FirstPosition': 'G',
#    'FullName': '',
#    'IsExcluded': False,
#    'IsLiked': False,
#    'IsLocked': False,
#    'LineupCount': 0,
#    'MinExposure': None,
#    'PlayerId': 22455,
#    'Points': 0.0,
#    'Position': 'G',
#    'PositionCount': 1,
#    'PositionId': 501,
#    'Positions': ['G'],
#    'ProjPoints': 0.0,
#    'Properties': {'ActualPoints': 27.5,
#     'Consistency': 97,
#     'EventId': -98998274,
#     'EventTeamId': 0,
#     'FantasyResultId': 549851,
#     'FullName': '',
#     'ImpPts': 45.89,
#     'InjuryStatus': None,
#     'IsProjected': None,
#     'Month_Count': None,
#     'Month_PPG': None,
#     'Month_Salary_Change': None,
#     'Month_X0': None,
#     'Month_X1': None,
#     'Month_X2': None,
#     'MyTrends': 0,
#     'PlayerId': 22455,
#     'Player_Name': 'Tyler Aldridge',
#     'Plus_Minus': 92,
#     'Position': 'G',
#     'PositionId': 501,
#     'Pro_Pct': 50,
#     'Salary': 5700,
#     'Salary_Movement': 50,
#     'Score': 92.0,
#     'Season_Count': 4,
#     'Season_PPG': 58.4,
#     'Season_PPG_Percentile': 63,
#     'Season_Plus_Minus': 12.8,
#     'Season_Salary_Change': 700,
#     'Season_X0': 25,
#     'Season_X1': 75,
#     'Season_X2': 75,
#     'SourceId': 4,
#     'Team': '',
#     'Upside': 97,
#     'adjrd_c_rank': 0.2,
#     'adjrd_l_rank': 57.1,
#     'adjrd_r_rank': 50.0,
#     'birdies_l': 12.5,
#     'birdies_l_rank': 58.0,
#     'birdies_r_rank': 50.0,
#     'bogies_l': 6.3,
#     'bogies_l_rank': 56.8,
#     'bogies_r_rank': 50.0,
#     'cnt_c_pct': 29.7,
#     'cnt_l': 32.0,
#     'cnt_l_pct': 33.2,
#     'cnt_r_pct': 1.5,
#     'da_l': 59.8,
#     'da_l_rank': 44.9,
#     'da_r_rank': 50.0,
#     'dd_l': 295.5,
#     'dd_l_rank': 48.5,
#     'dd_r_rank': 50.0,
#     'eagles_l': 0.2,
#     'eagles_l_rank': 61.6,
#     'eagles_r_rank': 50.0,
#     'gir_c_rank': 3.3,
#     'gir_l': 69.2,
#     'gir_l_rank': 55.3,
#     'gir_r_rank': 50.0,
#     'mc_pct_l': 34.0,
#     'mc_pct_l_pct': 55.5,
#     'mc_pct_r_pct': None,
#     'odds': 0.0,
#     'odds_pct': 0.0,
#     'par3_l': -0.8,
#     'par4_l': 0.0,
#     'par5_l': -3.5,
#     'ppr_l': 29.2,
