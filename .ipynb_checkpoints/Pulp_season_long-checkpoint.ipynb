# %%
from pulp import *
import pandas as pd
import numpy as np
from random import randint
import os
import csv
os.chdir('/home/valesco/Documents/')

# %%
#Beer Delivery

prob = LpProblem('Beer Dist', LpMinimize)

warehouses = ['A', 'B']
supply = {'A': 1000, 'B': 4000}
bars = ['1','2','3','4','5']
demand = {'1': 500, '2': 900, '3': 1800, '4': 200, '5': 700}
costs = [
         #Costs for warehouse A to bars
        [2,4,5,2,1],
         #Costs for warehouse B to bars
        [3,1,3,2,3]
    
]

costs = makeDict([warehouses, bars], costs,0)
routes = [(w,b) for w in warehouses for b in bars]

# %%
x = LpVariable.dicts('route', (warehouses, bars), lowBound = 0, cat= LpInteger)

# %%
prob += sum([x[w][b] * costs[w][b] for (w,b) in routes]) # Sum Transportation Costs

# %%
for w in warehouses:
    prob += sum([x[w][b] for b in bars]) <= supply[w]

# %%
# Demand minimum constraints are added to prob for each demand node (bar)

for b in bars:
    prob += sum([x[w][b] for w in warehouses]) >= demand[b]

# %%
prob.solve()

print('Status: ', LpStatus[prob.status])
# Out:
# Status:  Optimal

# %%
for v in prob.variables():
    print(v.name, ' = ', v.varValue)
# Out:
# route_A_1  =  300.0
# route_A_2  =  0.0
# route_A_3  =  0.0
# route_A_4  =  0.0
# route_A_5  =  700.0
# route_B_1  =  200.0
# route_B_2  =  900.0
# route_B_3  =  1800.0
# route_B_4  =  200.0
# route_B_5  =  0.0

# %%
# Wedding Problem

max_tables = 5
max_table_size = 4
guests = 'A B C D E F G I J K L M N O P Q R'.split(' ')
def happiness(table):
    for t in table:
        sum_table = guest_dict[t]
    return sum_table
 #create list of all possible tables
possible_tables = [tuple(c) for c in pulp.allcombinations(guests,max_table_size)]
#create a binary variable to state that a table setting is used
x = pulp.LpVariable.dicts('table', possible_tables,
    lowBound = 0,
    upBound = 1,
    cat = pulp.LpInteger)
seating_model = pulp.LpProblem("Wedding Seating Model", pulp.LpMaximize)
seating_model += sum([happiness(table) * x[table] for table in possible_tables])
#specify the maximum number of tables
seating_model += sum([x[table] for table in possible_tables]) <= max_tables, "Maximum_number_of_tables"
#A guest must seated at one and only one table
for guest in guests:
    seating_model += sum([x[table] for table in possible_tables if guest in table]) == 1

# %%
seating_model.solve()

print('The choosen tables are: ')
for table in possible_tables:
    if x[table].value() == 1.0:
        print(table.replace(''))
# Out:
# The choosen tables are:
# ('A',)
# ('B', 'N', 'P', 'R')
# ('C', 'D', 'I', 'K')
# ('E', 'F', 'G', 'O')
# ('J', 'L', 'M', 'Q')

# %%
guest_dict = {}
for g in guests:
    x = randint(0, 10)
    guest_dict[g] = x

# %%
x = pulp.LpVariable.dicts('table', possible_tables,
    lowBound = 0,
    upBound = 1,
    cat = pulp.LpInteger)

for i, table in enumerate(possible_tables):
    if i == 1000:
        print(table[0], table[-1])
# Out:
# A R

# %%
in_file = "f_proj.csv"
player_df = pd.read_csv(in_file)
players = player_df['player'].tolist()

# %%
teams = 10
max_players = 9

def calc_sum(team):
    for t in team:
        sum_team = player_df[t]
    return sum_team

#create list of all possible tables
possible_tables = [tuple(c) for c in pulp.allcombinations(guests,max_table_size)]
# Out:
# ['Cam Newton',
#  'Aaron Rodgers',
#  'Russell Wilson',
#  'Andrew Luck',
#  'Drew Brees',
#  'Blake Bortles',
#  'Philip Rivers',
#  'Ben Roethlisberger',
#  'Tyrod Taylor',
#  'Eli Manning',
#  'Jameis Winston',
#  'Kirk Cousins',
#  'Carson Palmer',
#  'Derek Carr',
#  'Ryan Tannehill',
#  'Matt Ryan',
#  'Tony Romo',
#  'Marcus Mariota',
#  'Andy Dalton',
#  'Matthew Stafford',
#  'Joe Flacco',
#  'Alex Smith',
#  'Brock Osweiler',
#  'Jay Cutler',
#  'Tom Brady  Risk',
#  'Teddy Bridgewater',
#  'Robert Griffin III',
#  'Blaine Gabbert',
#  'David Johnson',
#  'Antonio Brown',
#  'Jared Goff',
#  'Lamar Miller Upside',
#  'Sam Bradford',
#  'Mark Sanchez',
#  'Adrian Peterson',
#  'Julio Jones',
#  'Jamaal Charles',
#  'Todd Gurley',
#  "Le'Veon Bell  Risk",
#  'Odell Beckham Jr.',
#  'DeAndre Hopkins',
#  'Devonta Freeman',
#  'Dez Bryant',
#  'Allen Robinson',
#  'Ezekiel Elliott',
#  'Jordy Nelson',
#  'A.J. Green',
#  'Keenan Allen Upside',
#  'Mark Ingram',
#  'Eddie Lacy',
#  'Matt Forte',
#  'Rob Gronkowski',
#  'Alshon Jeffery',
#  'LeSean McCoy',
#  'DeMarco Murray',
#  'Doug Martin',
#  'Brandon Marshall  Risk',
#  'Mike Evans',
#  'T.Y. Hilton',
#  'C.J. Anderson',
#  'Amari Cooper',
#  'Jeremy Hill',
#  'Jeremy Langford',
#  'Brandin Cooks',
#  'Sammy Watkins  Risk',
#  'Matt Jones',
#  'Larry Fitzgerald',
#  'Kelvin Benjamin',
#  'Latavius Murray',
#  'Melvin Gordon',
#  'Demaryius Thomas',
#  'Jarvis Landry',
#  'DeSean Jackson',
#  'Jeremy Maclin',
#  'Golden Tate',
#  'Jonathan Stewart',
#  'Dion Lewis  Risk',
#  'Donte Moncrief',
#  'Michael Floyd',
#  'Jordan Reed  Risk',
#  'Jay Ajayi',
#  'Stephen Gostkowski',
#  'Randall Cobb',
#  'Danny Woodhead',
#  'Carlos Hyde',
#  'Eric Decker',
#  'Giovani Bernard',
#  'DeVante Parker Upside',
#  'Doug Baldwin',
#  'Duke Johnson',
#  'Tavon Austin',
#  'Greg Olsen',
#  'Ryan Mathews',
#  'Ameer Abdullah  Risk',
#  'Thomas Rawls Upside Risk',
#  'Steve Hauschka',
#  'Graham Gano',
#  'Steve Smith',
#  'Allen Hurns',
#  'Chandler Catanzaro',
#  'Justin Tucker',
#  'John Brown',
#  'Michael Crabtree',
#  'Brandon McManus',
#  'Mason Crosby',
#  'Tyler Eifert  Risk',
#  'Robbie Gould',
#  'Delanie Walker',
#  'T.J. Yeldon',
#  'Frank Gore',
#  'Nick Folk',
#  'Tyler Lockett',
#  'Jordan Matthews',
#  'Dan Bailey',
#  'Isaiah Crowell',
#  'Cairo Santos',
#  'Josh Brown',
#  'Rashad Jennings',
#  'Chris Boswell',
#  'Julian Edelman',
#  'Travis Kelce',
#  'Torrey Smith',
#  'Willie Snead',
#  'Marvin Jones',
#  'Mike Nugent',
#  'Blair Walsh',
#  'Markus Wheaton Upside',
#  'Antonio Gates',
#  'Charles Sims',
#  'Stefon Diggs',
#  'Dan Carpenter',
#  'Karlos Williams',
#  'Gary Barnidge',
#  'Coby Fleener Upside',
#  'Kevin White',
#  'Kai Forbath  Risk',
#  'Corey Coleman',
#  'LeGarrette Blount',
#  'Jason Myers',
#  'Dustin Hopkins',
#  'Emmanuel Sanders',
#  'Matt Prater',
#  'Travis Coons',
#  'Justin Forsett',
#  'Sebastian Janikowski',
#  'Josh Lambo',
#  'Nick Novak',
#  'Arizona Cardinals',
#  'Adam Vinatieri',
#  'Matt Bryant',
#  'Phil Dawson',
#  'Kansas City Chiefs',
#  'Dwayne Allen Upside',
#  'Denver Broncos',
#  'Ronnie Hillman',
#  'Roberto Aguayo',
#  'Caleb Sturgis',
#  'Julius Thomas',
#  'Jimmy Graham  Risk',
#  'Greg Zuerlein',
#  'Chris Ivory',
#  'Andrew Franks',
#  'Ladarius Green  Risk',
#  'Dorial Green-Beckham',
#  'Vincent Jackson',
#  'Zach Ertz',
#  'Philadelphia Eagles',
#  'Eric Ebron',
#  'Darren Sproles',
#  'Jason Witten',
#  'Rishard Matthews',
#  'Zach Miller',
#  'Carolina Panthers',
#  'Darren McFadden  Risk',
#  'Theo Riddick',
#  'Los Angeles Rams',
#  'Mike Wallace',
#  'Mohamed Sanu',
#  'Minnesota Vikings',
#  'Kenny Britt',
#  'Ryan Succop',
#  'Houston Texans',
#  'Javorius Allen',
#  'Pittsburgh Steelers',
#  'New England Patriots',
#  'Oakland Raiders',
#  'Seattle Seahawks',
#  'Jacksonville Jaguars',
#  'Jaelen Strong  Risk',
#  'Richard Rodgers',
#  'Jordan Cameron',
#  'Terrance Williams',
#  'Austin Seferian-Jenkins',
#  'Green Bay Packers',
#  'Shane Vereen',
#  'Jimmy Garoppolo',
#  'Ted Ginn Jr.',
#  'Cincinnati Bengals',
#  'Shaun Draughn',
#  'Travis Benjamin',
#  'Bilal Powell',
#  'Christine Michael',
#  'Buffalo Bills',
#  'Chris Hogan',
#  'Charles Clay',
#  'Benny Cunningham',
#  'Ben Watson',
#  'Tampa Bay Buccaneers',
#  'DeAngelo Williams Upside',
#  'Phillip Dorsett',
#  'Detroit Lions',
#  'Jacob Tamme',
#  'Nelson Agholor',
#  'Kyle Rudolph',
#  'New York Jets',
#  'Robert Woods',
#  'Will Tye',
#  'Robert Turbin',
#  'Washington Redskins',
#  'Pierre Garcon',
#  'Sterling Shepard',
#  'Kendall Wright',
#  'Miami Dolphins',
#  'Paxton Lynch',
#  'Jerome Simpson',
#  'Chris Thompson',
#  'Clive Walford',
#  'James Starks',
#  'Indianapolis Colts',
#  'Jeff Janis Upside',
#  'Tennessee Titans',
#  'San Francisco 49ers',
#  'Baltimore Ravens',
#  'Laquon Treadwell',
#  'Tevin Coleman',
#  'Danny Amendola',
#  'Martellus Bennett Upside',
#  'Derrick Henry',
#  'Dallas Cowboys',
#  'New York Giants',
#  'New Orleans Saints',
#  'C.J. Spiller',
#  'Seth Roberts',
#  'Kenyan Drake',
#  'Atlanta Falcons',
#  'Tim Hightower',
#  'Paul Perkins',
#  'Michael Thomas Upside',
#  'Jarius Wright',
#  'San Diego Chargers',
#  'Chicago Bears',
#  'Breshad Perriman  Risk',
#  'DeAndre Washington Upside',
#  'Sammie Coates Upside',
#  'Jerick McKinnon',
#  'Cole Beasley',
#  'Jeff Heuerman',
#  'Spencer Ware Upside',
#  'Kenny Bell',
#  'DeAndre Smelter',
#  'Devin Funchess',
#  'Steve Johnson',
#  'Cleveland Browns',
#  'C.J. Prosise',
#  'Kamar Aiken',
#  'Josh McCown',
#  'Alfred Blue',
#  'Andrew Hawkins',
#  'Albert Wilson',
#  'Kenneth Dixon',
#  'Crockett Gillmore',
#  'Zach Zenner',
#  'Chris Johnson',
#  'Brandon LaFell',
#  'Cecil Shorts',
#  'Jace Amaro',
#  'Dexter McCluster',
#  'Victor Cruz Upside Risk',
#  'Wendell Smallwood',
#  'Mike Tolbert',
#  'Devontae Booker',
#  'Jordan Howard',
#  'Jermaine Kearse',
#  'Rueben Randle',
#  'Taylor Gabriel',
#  'Chase Daniel',
#  'Quincy Enunwa',
#  'Marqise Lee',
#  'Jamison Crowder',
#  'Luke Willson',
#  'Bennie Fowler',
#  'Dwayne Harris',
#  'Colin Kaepernick',
#  'Kenny Stills',
#  'Damien Williams',
#  'Andre Ellington',
#  'Vance McDonald',
#  'Garrett Celek',
#  'Eddie Royal',
#  'Hunter Henry',
#  'Jeremy Kerley',
#  'Cameron Artis-Payne',
#  'Terrelle Pryor',
#  'Andre Holmes',
#  'Justin Hardy',
#  'Chris Conley',
#  'Jordan Todman',
#  'Tyler Boyd',
#  'Charcandrick West',
#  'Will Fuller',
#  'Darren Fells',
#  'Jared Cook',
#  'Brent Celek',
#  'Darrius Heyward-Bey',
#  "Ka'Deem Carey",
#  'Khiry Robinson',
#  'Marcel Reece',
#  'Ryan Griffin',
#  'Larry Donnell',
#  'Lance Kendricks',
#  'C.J. Fiedorowicz',
#  'Anthony Fasano',
#  'Josh Hill',
#  'Branden Oliver',
#  'Tre Mason  Risk',
#  'Antonio Andrews',
#  'Stevan Ridley',
#  'James White',
#  'Tyler Kroft',
#  'Mychal Rivera',
#  'Geno Smith',
#  'Bruce Gradkowski',
#  'Niles Paul',
#  'Marcedes Lewis',
#  'Gavin Escobar',
#  'Jesse James Upside',
#  'Virgil Green',
#  'Brandon Bolden',
#  'AJ McCarron',
#  'Jonathan Williams',
#  'Matt Cassel',
#  'Brian Hoyer',
#  'Orleans Darkwa',
#  'Silas Redd',
#  'Jonathan Grimes',
#  'Alfred Morris',
#  'Dwayne Washington',
#  'Brandon Weeden',
#  'Aaron Murray',
#  'Drew Stanton',
#  'Donald Brown',
#  'EJ Manuel',
#  'Denard Robinson',
#  'Jamize Olawale',
#  'Dan Orlovsky',
#  'Ryan Mallett',
#  'Shaun Hill',
#  'Mike James',
#  'Trevone Boykin',
#  "De'Anthony Thomas",
#  'Colt McCoy',
#  'Lance Dunbar',
#  'Andre Williams',
#  'Mike Davis']
