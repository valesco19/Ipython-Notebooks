# %%
import pandas as pd
import numpy as np
from datetime import datetime
import json
import time
import os
from tqdm import tqdm
from scipy import stats
import networkx as nx
from itertools import combinations
from collections import Counter
from fuzzywuzzy import process
from glob import glob
import zipfile
from pga.return_pid import return_pid

# %%
player_ids = pd.read_csv('/home/valesco/Datasets/PGA_Data/pga_master_files/player_ids.csv', sep = ';')
player_ids_name_ls = player_ids['player_name'].values

def fuzz_match(x):
    matched = process.extractOne(x, player_ids_name_ls)
    if matched[1] > 89:
        return player_ids['player_id'].loc[player_ids['player_name'] == matched[0]].values[0]
    else:
        return 'NULL'
    
def create_pid_ls(ls):
    pid_ls = []
    for player in ls:
        pid_ls.append(pid_dict[player])
    return pid_ls

def return_player_ls(csv_file):
    contest = pd.read_csv(csv_file)
    
    own_df = contest[['Player', '%Drafted', 'FPTS']]
    own_df.columns = ['player_name', 'own_percent', 'actual_points']
    contest_df = contest.drop(['Player', '%Drafted', 'Unnamed: 6',
                            'FPTS'], axis = 1)

    contest_df.columns = ['rank', 'entry_id', 'entry_name', 'time_remaining', 
                    'team_points', 'lineup']

    contest_df.dropna(inplace = True)
    contest_df['lineup'] = contest_df['lineup'].apply(lambda x: x.replace(' G ',','))
    contest_df['lineup'] = contest_df['lineup'].apply(lambda x:\
                    x.replace('G ','').split(','))
    contest_df[['player_1', 'player_2', 'player_3', 'player_4', 
               'player_5', 'player_6']] = contest_df['lineup'].apply(pd.Series)

    for col in ['player_1', 'player_2', 'player_3', 'player_4', 
               'player_5', 'player_6']:
        contest_df = contest_df.merge(own_df[['player_name', 'own_percent']], left_on = col, 
                    right_on = 'player_name')

    for col in ['player_1', 'player_2', 'player_3', 'player_4', 
               'player_5', 'player_6']:
        contest_df = contest_df.merge(own_df[['player_name', 'actual_points']], left_on = col, 
                    right_on = 'player_name')

    contest_df.columns = ['team_rank', 'entry_id', 'dfs_player', 'time_remaining', 
            'team_points', 'lineup', 'player_1', 'player_2', 'player_3', 
            'player_4', 'player_5', 'player_6', 'p1', 'p1_own', 'p2', 'p2_own',
            'p3', 'p3_own', 'p4', 'p4_own', 'p5', 'p5_own', 'p6', 'p6_own',
            'p1a', 'p1_points', 'p2a', 'p2_points', 'p3', 'p3_points', 'p4', 
            'p4_points', 'p5', 'p5_points', 'p6', 'p6_points']

    contest_df = contest_df[['team_rank', 'entry_id', 'dfs_player', 'time_remaining',
            'team_points', 'lineup', 'player_1', 'p1_own', 'p1_points', 'player_2', 'p2_own',
            'p2_points', 'player_3', 'p3_own', 'p3_points', 'player_4', 'p4_own', 'p4_points',
            'player_5', 'p5_own', 'p5_points', 'player_6', 'p6_own', 'p6_points']]

    player_ids_name_ls = player_ids['player_name'].values   

    player_ls = []

    for col in ['player_1', 'player_2', 'player_3', 'player_4', 'player_5', 'player_6']:
        temp_unique = contest_df[col].unique()

        for player in temp_unique:
            if player not in player_ls:
                player_ls.extend([player])

    pid_dict = {}
    for player in player_ls:
        pid = return_pid(player)
        if pid == 'NULL':
            print(player)
        pid_dict[player] = int(pid)

    return sorted(player_ls)

# %%
masters_ls = ['Fred Couples', 'Bernhard Langer', 'Sandy Lyle', 'Phil Mickelson',
       'Larry Mize', "Mark O'Meara", 'Ian Woosnam', 'Jose Maria Olazabal',
       'Ernie Els', 'Steve Stricker', 'Vijay Singh', 'Tiger Woods',
       'Mike Weir', 'Jim Furyk', 'Charley Hoffman', 'Lee Westwood',
       'Rod Pampling', 'Angel Cabrera', 'Sergio Garcia', 'Hideto Tanihara',
       'Henrik Stenson', 'Chris Wood', 'Trevor Immelman', 'Justin Rose',
       'Soren Kjeldsen', 'Matt Kuchar', 'Zach Johnson', "Sean O'Hair",
       'Pat Perez', 'Adam Scott', 'Bill Haas', 'Francesco Molinari',
       'Paul Casey', 'Kevin Na', 'Jimmy Walker', 'Jason Dufner',
       'Bubba Watson', 'Scott Piercy', 'Daniel Summerhays',
       'Louis Oosthuizen', 'Charl Schwartzel', 'Rafael Cabrera-Bello',
       'Ryan Moore', 'Marc Leishman', 'Yuta Ikeda', 'Jhonattan Vegas',
       'J.B. Holmes', 'Alexander Noren', 'Martin Kaymer',
       'Brandt Snedeker', 'Ross Fisher', 'Jason Day', 'Rory McIlroy',
       'Webb Simpson', 'Billy Hurley', 'Bernd Wiesberger', 'Kevin Kisner',
       'Brendan Steele', 'Branden Grace', 'Tommy Fleetwood',
       'Dustin Johnson', 'William McGirt', 'Gary Woodland', 'Brian Stuard',
       'Emiliano Grillo', 'Rickie Fowler', 'Danny Willett',
       'Roberto Castro', 'Kevin Chappell', 'James Hahn',
       'Hideki Matsuyama', 'Russell Knox', 'Shane Lowry', 'Thomas Pieters',
       'Adam Hadwin', 'Justin Thomas', 'Byeong-Hun An', 'Jordan Spieth',
       'Russell Henley', 'Hudson Swafford', 'Patrick Reed',
       'Tyrrell Hatton', 'Andy Sullivan', 'Mackenzie Hughes',
       'Brooks Koepka', 'Curtis Luck', 'Si Woo Kim', 'Jeunghun Wang',
       'Daniel Berger', 'Matthew Fitzpatrick', 'Jon Rahm', 'Brad Dalke',
       'Scott Gregory']


os.chdir('/home/valesco/Datasets/dk_downloads/5_5_2017/')

files = glob('*')


for file in files:
    if '.zip' in file and 'contest-standings' in file:
        try:
            csv_file = zipfile.ZipFile(file, 'r')
            new_file_name = file.replace('.zip', '.csv')
            csv_file = csv_file.open(new_file_name)
            player_ls = return_player_ls(csv_file)

            in_masters = 0
            out_masters = 0

            for player in player_ls:
                if player in masters_ls:
                    in_masters += 1
                else:
                    out_masters += 1
            
            ratio = in_masters/ out_masters
            
            if ratio > 1:
                print(file, ratio)
        except:
            pass
# Out:
# /home/valesco/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# contest-standings-35244077.zip 4.428571428571429
# contest-standings-37906113.zip 4.5
# contest-standings-37170728.zip 1.5789473684210527
# contest-standings-38055316.zip 9.166666666666666
# contest-standings-36022101.zip 4.428571428571429
# contest-standings-37906109.zip 4.846153846153846
# contest-standings-38055320.zip 5.9
# contest-standings-39085500.zip 90.0
# contest-standings-37839155.zip 5.545454545454546
# contest-standings-37906110.zip 4.5
# contest-standings-38055318.zip 5.166666666666667
# contest-standings-37906111.zip 4.5

# %%
masters_contest = [
    'contest-standings-38055316.zip',
    ''
]
# Out:
# ['contest-standings-37030921.zip',
#  'contest-standings-35855775.csv',
#  'DKSalaries (19).csv',
#  'contest-standings-37173652.csv',
#  'contest-standings-37173652.zip',
#  'DKSalaries (21).csv',
#  'DKSalaries_temp_week4.csv',
#  'contest-standings-37419195.zip',
#  'contest-standings-37293933.zip',
#  'contest-standings-26510926 (1).zip',
#  'contest-standings-37170731.csv',
#  'contest-standings-34439732.zip',
#  'contest-standings-36058804.zip',
#  'contest-standings-26511649.zip',
#  'DKSalaries (30).csv',
#  'contest-standings-37419195.csv',
#  'DKSalaries (18).csv',
#  'DKSalaries (29).csv',
#  'DKSalaries (9).csv',
#  'contest-standings-37169783.csv',
#  'contest-standings-37170734.zip',
#  'contest-standings-38327100 (1).zip',
#  'contest-standings-38327101.zip',
#  'contest-standings-27752976.zip',
#  'contest-standings-35244077.zip',
#  'contest-standings-38327101.csv',
#  'DKSalaries (36).csv',
#  'contest-standings-29630243.csv',
#  'contest-standings-37293932.csv',
#  'contest-standings-36249479 (1).csv',
#  'contest-standings-37419188.zip',
#  'DKSalaries (34).csv',
#  'contest-standings-37030920.zip',
#  'contest-standings-28678578.csv',
#  'contest-standings-26504876.zip',
#  'contest-standings-34439732.csv',
#  'contest-standings-37906113.zip',
#  'contest-standings-37293937 (1).zip',
#  'contest-standings-26510926.csv',
#  'contest-standings-37418756.csv',
#  'contest-standings-38174501.csv',
#  'contest-standings-37170728.zip',
#  'contest-standings-38055316.csv',
#  'contest-standings-38174498.csv',
#  'contest-standings-37784650.csv',
#  'contest-standings-38054720.csv',
#  'contest-standings-36058804.csv',
#  'contest-standings-36249477.csv',
#  'contest-standings-37841261.csv',
#  'contest-standings-38904899.zip',
#  'contest-standings-27381119.csv',
#  'contest-standings-38327103.csv',
#  'contest-standings-38174501.zip',
#  'DKSalaries (5).csv',
#  'contest-standings-26511649.csv',
#  'DKSalaries (14).csv',
#  'DKSalaries (1).csv',
#  'contest-standings-29933080.zip',
#  'contest-standings-37418504.csv',
#  'contest-standings-26510962.zip',
#  'contest-standings-26513500.csv',
#  'contest-standings-37841262.zip',
#  'contest-standings-36058806.zip',
#  'contest-standings-37906109.csv',
#  'contest-standings-37784649.csv',
#  'DKSalaries (8).csv',
#  'contest-standings-38327156.csv',
#  'contest-standings-37784651.zip',
#  'contest-standings-38327156.zip',
#  'DKSalaries (11).csv',
#  'contest-standings-27381119.zip',
#  'contest-standings-37784648.zip',
#  'contest-standings-38055316.zip',
#  'contest-standings-37030925.csv',
#  'contest-standings-28230320.csv',
#  'contest-standings-37293932.zip',
#  'DKSalaries (17).csv',
#  'contest-standings-26509992.zip',
#  'contest-standings-37784648.csv',
#  'contest-standings-38174494.csv',
#  'contest-standings-37784654.zip',
#  'contest-standings-38327102.zip',
#  'contest-standings-37069924.csv',
#  'contest-standings-37170734.csv',
#  'contest-standings-26510926.zip',
#  'contest-standings-37293938.zip',
#  'contest-standings-36174635.csv',
#  'contest-standings-37170902.zip',
#  'contest-standings-36022101.csv',
#  'contest-standings-38307452.zip',
#  'contest-standings-37418502.csv',
#  'contest-standings-35244077.csv',
#  'contest-standings-36249479.csv',
#  'contest-standings-38174496.csv',
#  'contest-standings-38174495.csv',
#  'contest-standings-28678578.zip',
#  'contest-standings-36022101.zip',
#  'contest-standings-37170902.csv',
#  'contest-standings-38307450.csv',
#  'rbc_heritage_salaries.csv',
#  'contest-standings-35855775.zip',
#  'DKSalaries (3).csv',
#  'DKSalaries.csv',
#  'contest-standings-35882740.csv',
#  'contest-standings-37906109.zip',
#  'contest-standings-36408646.zip',
#  'contest-standings-38174494.zip',
#  'contest-standings-37030925.zip',
#  'contest-standings-37069924.zip',
#  'contest-standings-38327100.zip',
#  'contest-standings-28931680.zip',
#  'contest-standings-36174635.zip',
#  'contest-standings-36249477 (1).csv',
#  'DKSalaries (7).csv',
#  'contest-standings-26696259.zip',
#  'DKSalaries (6).csv',
#  'contest-standings-38055320.csv',
#  'DKSalaries (20).csv',
#  'contest-standings-38307452.csv',
#  'contest-standings-38055320.zip',
#  'contest-standings-37268754 (1).zip',
#  'contest-standings-37293935.csv',
#  'contest-standings-38174498 (1).zip',
#  'contest-standings-37419188.csv',
#  'contest-standings-28230320.zip',
#  'DKSalaries (39).gnumeric',
#  'DKSalaries (31).csv',
#  'contest-standings-33576618.csv',
#  'DKSalaries (25).csv',
#  'contest-standings-27752976.csv',
#  'contest-standings-37784653.csv',
#  'DKSalaries (27).csv',
#  'contest-standings-37841261.zip',
#  'contest-standings-38174499.zip',
#  'contest-standings-36408643.zip',
#  'contest-standings-38904895.csv',
#  'contest-standings-27261554.csv',
#  'contest-standings-37784649.zip',
#  'contest-standings-37293935 (1).zip',
#  'contest-standings-37419186.zip',
#  'contest-standings-31528187.zip',
#  'contest-standings-37784652.csv',
#  'contest-standings-26508884.zip',
#  'contest-standings-37840246.csv',
#  'contest-standings-38174499 (1).zip',
#  'contest-standings-37906110.csv',
#  'DKSalaries (39).csv',
#  'contest-standings-37170730.csv',
#  'contest-standings-37293938.csv',
#  'contest-standings-37170728.csv',
#  'contest-standings-27266301.csv',
#  'DKSalaries (4).csv',
#  'DKSalaries (22).csv',
#  'contest-standings-37784652.zip',
#  'contest-standings-37293936.zip',
#  'contest-standings-27317921.csv',
#  'DKSalaries (26).csv',
#  'contest-standings-26504876.csv',
#  'contest-standings-38174498.zip',
#  'contest-standings-37293937.zip',
#  'contest-standings-38054721.csv',
#  'contest-standings-37840245.csv',
#  'contest-standings-28269733.csv',
#  'contest-standings-38904895.zip',
#  'contest-standings-28229529.zip',
#  'contest-standings-37784650.zip',
#  'contest-standings-27266301.zip',
#  'contest-standings-37293935.zip',
#  'contest-standings-37293936.csv',
#  'contest-standings-31528187.csv',
#  'contest-standings-28269733.zip',
#  'DKSalaries (16).csv',
#  'contest-standings-33576618.zip',
#  'contest-standings-37418756.zip',
#  'contest-standings-29933080.csv',
#  'contest-standings-29630246.zip',
#  'contest-standings-29630246.csv',
#  'contest-standings-26696259.csv',
#  'contest-standings-26513500.zip',
#  'contest-standings-28229529.csv',
#  'contest-standings-37784653.zip',
#  'contest-standings-36058806.csv',
#  'DKSalaries (12).csv',
#  'DKSalaries (13).csv',
#  'contest-standings-28931680.csv',
#  'contest-standings-38327100.csv',
#  'DKSalaries (10).csv',
#  'DKSalaries (32).csv',
#  'contest-standings-37841264.csv',
#  'DKSalaries (37).csv',
#  'contest-standings-36408643.csv',
#  'contest-standings-38174499.csv',
#  'contest-standings-27317921.zip',
#  'contest-standings-37030921.csv',
#  'DKSalaries (23).csv',
#  'contest-standings-37784654.csv',
#  'contest-standings-37839155.zip',
#  'contest-standings-36408646.csv',
#  'contest-standings-27261554.zip',
#  'contest-standings-26510962.csv',
#  'contest-standings-38327102.csv',
#  'DKSalaries (33).csv',
#  'contest-standings-38055322.csv',
#  'contest-standings-37906110.zip',
#  'contest-standings-26509992.csv',
#  'contest-standings-38055318.zip',
#  'contest-standings-37906111.zip',
#  'contest-standings-37841262.csv',
#  'contest-standings-36249480.zip',
#  'DKSalaries (24).csv',
#  'contest-standings-37268754.zip',
#  'contest-standings-37030920.csv',
#  'contest-standings-37841276.zip',
#  'contest-standings-38174496.zip',
#  'contest-standings-37293937.csv',
#  'contest-standings-28686260.csv',
#  'contest-standings-38904899.csv',
#  'contest-standings-37784651.csv',
#  'contest-standings-36249480.csv',
#  'contest-standings-38055318.csv',
#  'contest-standings-38174495.zip',
#  'contest-standings-30138698.zip',
#  'contest-standings-37174080.csv',
#  'contest-standings-37841276.csv',
#  'contest-standings-37906111.csv',
#  'DKSalaries (2).csv',
#  'contest-standings-28686260.zip',
#  'contest-standings-37419186.csv',
#  'contest-standings-37293933.csv',
#  'DKSalaries (28).csv',
#  'DKSalaries (15).csv',
#  'contest-standings-37170730.zip',
#  'contest-standings-37268754.csv',
#  'contest-standings-29630243.zip',
#  'contest-standings-26508884.csv',
#  'contest-standings-37839155.csv',
#  'contest-standings-30138698.csv',
#  'contest-standings-37906113.csv']
