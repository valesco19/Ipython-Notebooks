# %%
import urllib
from bs4 import BeautifulSoup
import requests
import os
os.chdir('/home/valesco/Datasets/PGA_Data/PGA/')

# %%
base_url = 'http://pgatour.com/data/r/'

def find_tourny_list(base_url):
    soup = BeautifulSoup(requests.get(base_url, 'lxml').text)
    tourny_list = []
    for a in soup.find_all('a'):
        temp = a.text
        temp = temp.replace('/', '')
        try:
            if int(temp) < 800:
                tourny_list.append(temp)
        except:
            pass
    
    return(tourny_list)

tourny_list = find_tourny_list(base_url)
# Out:
# /home/valesco/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
tourny_with_stats = []
for tourny in tourny_list:
    count = 0
    tourny_url = base_url + tourny + '/'
    soup = BeautifulSoup(requests.get(tourny_url, 'lxml').text)
    temp_tourny = []
    for a in soup.find_all('a'):
        temp = a.text
        temp = temp.replace('/', '')
        temp_tourny.append(temp)
            
    year_list = ['2014','2015','2016']
    for year in year_list:
        if any(year in t for t in temp_tourny):
            count = 1
            
    if count == 1:
        tourny_with_stats.append(tourny)
# Out:
# C:\Users\valesco\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
year_list = ['2014', '2015', '2016']

for tournament in tourny_with_stats:
    for year in year_list: 
        exists = 0
        base_url = 'http://www.pgatour.com/data/r/'
        complete_url = base_url + tournament + '/' + year + '/'
        request = requests.get(complete_url)
        if request.status_code == 200:
            exists = 1
        if exists == 1:
            try:
                #create base path
                path = 'D://Datasets/PGA/' + tournament + '_' + year

                #make and change directory
                os.mkdir(path)
                os.chdir(path)
                print('Directory Created: ' + path)

                #download course.json file
                course_url = complete_url + 'course.json'
                course_filename = tournament + '_' + year + '_' + 'course.json'
                urllib.request.urlretrieve(course_url, course_filename)

                #download leaderboard.json file
                leaderboard_url = complete_url + 'leaderboard-v2.json'
                leaderboard_filename = tournament + '_' + year + '_' + 'leaderboard-v2.json'
                urllib.request.urlretrieve(leaderboard_url, leaderboard_filename)

                #download player_stats.json file
                stats_url = complete_url + 'player_stats.json'
                stats_filename = tournament + '_' + year + '_' + 'player_stats.json'
                urllib.request.urlretrieve(stats_url, stats_filename)

                #download teetimes.json file
                teetimes_url = complete_url + 'teetimes.json'
                teetimes_filename = tournament + '_' + year + '_' + 'teetimes.json'
                urllib.request.urlretrieve(teetimes_url, teetimes_filename)

                #download tourny summary json file
                tournsum_url = complete_url + 'tournsum.json'
                tournsum_filename = tournament + '_' + year + '_' + 'tournsum.json'

                #create and change to directory to store player summaries
                new_path = path + '/PlayerScoreCards/'
                os.mkdir(new_path)
                os.chdir(new_path)

                #use BS to retrieve list of player id's in Dir
                player_list = []
                players_url = complete_url + 'scorecards/'
                soup_players = BeautifulSoup(requests.get(players_url, 'lxml').text)

                #iterate through player href's
                for a in soup_players.find_all('a'):
                    temp = a.text
                    if '.json' in temp:
                        temp_path = players_url + temp
                        urllib.request.urlretrieve(temp_path, temp)

                print('Players JSON Files Saved')
            except:
                print("Exception for " + complete_url)
# Out:
# Directory Created: D://Datasets/PGA/006_2014
# Exception for http://www.pgatour.com/data/r/006/2014/
# Directory Created: D://Datasets/PGA/006_2015
# Players JSON Files Saved
# Directory Created: D://Datasets/PGA
2015
# Players JSON Files Saved
# Directory Created: D://Datasets/PGA/494_2016
# Players JSON Files Saved
# Directory Created: D://Datasets/PGA/500_2015
# Players JSON Files Saved
# Directory Created: D://Datasets/PGA/504_2014
# Exception for http://www.pgatour.com/data/r/504/2014/
# Directory Created: D://Datasets/PGA/504_2015
# Exception for http://www.pgatour.com/data/r/504/2015/
# Directory Created: D://Datasets/PGA/505_2014
# Players JSON Files Saved
# Directory Created: D://Datasets/PGA/505_2015
# Players JSON Files Saved
# Directory Created: D://Datasets/PGA/518_2015
# Players JSON Files Saved
# Directory Created: D://Datasets/PGA/524_2014
# Exception for http://www.pgatour.com/data/r/524/2014/
# C:\Users\valesco\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
base_url = 'http://pgatour.com/data/r/'


folders = os.walk(os.getcwd())
folder_dirs = []
for f in folders:
    if 'PlayerScoreCards' in f[0]:
        folder_dirs.append(f[0])
        
tourny_names = []
for z in folder_dirs:
    z = z.replace('/PlayerScoreCards', '')
    z = z.replace('/home/valesco/Datasets/PGA_Data/PGA/','')
    z = z.split('_')[0]
    if z not in tourny_names:
        tourny_names.append(z)

# %%
year_list = ['2014', '2015', '2016']

for tournament in tourny_names:
    for year in year_list:
        exists = 0
        base_url = 'http://www.pgatour.com/data/r/'
        complete_url = base_url + tournament + '/' + year + '/'
        request = requests.get(complete_url)
        if request.status_code == 200:
            exists = 1
        if exists == 1:
            try:
                pga_dir ='/home/valesco/Datasets/PGA_Data/PGA/'+tournament + '_' + year
                os.chdir(pga_dir)

                money_url = complete_url + 'money.json'
                money_filename = tournament + '_' + year + '_' + 'money.json'
                urllib.request.urlretrieve(money_url, money_filename)

                playoff_url = complete_url + 'playoff_info.json'
                playoff_filename = tournament + '_' + year + '_' + 'playoff_info.json'
                urllib.request.urlretrieve(playoff_url, playoff_filename)
                
                tournsum_url = complete_url + 'tournsum.json'
                tournsum_filename = tournament + '_' + year + '_' + 'tournsum.json'
                urllib.request.urlretrieve(tournsum_url, tournsum_filename)
                                             
                print('files saved for: ', complete_url)
            except:
                print("Exception for " + complete_url)
# Out:
# files saved for:  http://www.pgatour.com/data/r/483/2014/
# files saved for:  http://www.pgatour.com/data/r/483/2015/
# files saved for:  http://www.pgatour.com/data/r/483/2016/
# files saved for:  http://www.pgatour.com/data/r/007/2014/
# files saved for:  http://www.pgatour.com/data/r/007/2015/
# files saved for:  http://www.pgatour.com/data/r/007/2016/
# Exception for http://www.pgatour.com/data/r/054/2014/
# files saved for:  http://www.pgatour.com/data/r/054/2015/
# files saved for:  http://www.pgatour.com/data/r/054/2016/
# files saved for:  http://www.pgatour.com/data/r/004/2014/
# files saved for:  http://www.pgatour.com/data/r/004/2015/
# files saved for:  http://www.pgatour.com/data/r/004/2016/
# files saved for:  http://www.pgatour.com/data/r/027/2014/
# files saved for:  http://www.pgatour.com/data/r/027/2015/
# Exception for http://www.pgatour.com/data/r/457/2014/
# files saved for:  http://www.pgatour.com/data/r/457/2015/
# files saved for:  http://www.pgatour.com/data/r/457/2016/
# files saved for:  http://www.pgatour.com/data/r/009/2014/
# files saved for:  http://www.pgatour.com/data/r/009/2015/
# files saved for:  http://www.pgatour.com/data/r/009/2016/
# Exception for http://www.pgatour.com/data/r/047/2014/
# files saved for:  http://www.pgatour.com/data/r/494/2015/
# files saved for:  http://www.pgatour.com/data/r/494/2016/
# files saved for:  http://www.pgatour.com/data/r/003/2014/
# files saved for:  http://www.pgatour.com/data/r/003/2015/
# files saved for:  http://www.pgatour.com/data/r/003/2016/
# files saved for:  http://www.pgatour.com/data/r/505/2014/
# files saved for:  http://www.pgatour.com/data/r/505/2015/
# files saved for:  http://www.pgatour.com/data/r/010/2014/
# files saved for:  http://www.pgatour.com/data/r/010/2015/
# files saved for:  http://www.pgatour.com/data/r/010/2016/
# files saved for:  http://www.pgatour.com/data/r/041/2014/
# files saved for:  http://www.pgatour.com/data/r/041/2015/
# files saved for:  http://www.pgatour.com/data/r/041/2016/
# Exception for http://www.pgatour.com/data/r/016/2014/
# files saved for:  http://www.pgatour.com/data/r/016/2015/
# files saved for:  http://www.pgatour.com/data/r/016/2016/
# files saved for:  http://www.pgatour.com/data/r/014/2014/
# files saved for:  http://www.pgatour.com/data/r/014/2015/
# files saved for:  http://www.pgatour.com/data/r/014/2016/
# files saved for:  http://www.pgatour.com/data/r/019/2014/
# files saved for:  http://www.pgatour.com/data/r/019/2015/
# files saved for:  http://www.pgatour.com/data/r/019/2016/
# files saved for:  http://www.pgatour.com/data/r/023/2014/
# files saved for:  http://www.pgatour.com/data/r/023/2015/
# Exception for http://www.pgatour.com/data/r/023/2016/
# files saved for:  http://www.pgatour.com/data/r/473/2014/
# files saved for:  http://www.pgatour.com/data/r/473/2015/
# files saved for:  http://www.pgatour.com/data/r/473/2016/
# files saved for:  http://www.pgatour.com/data/r/034/2014/
# files saved for:  http://www.pgatour.com/data/r/034/2015/
# files saved for:  http://www.pgatour.com/data/r/021/2014/
# files saved for:  http://www.pgatour.com/data/r/021/2015/
# Exception for http://www.pgatour.com/data/r/021/2016/
# files saved for:  http://www.pgatour.com/data/r/060/2014/
# files saved for:  http://www.pgatour.com/data/r/060/2015/
# files saved for:  http://www.pgatour.com/data/r/476/2014/
# files saved for:  http://www.pgatour.com/data/r/476/2015/
# files saved for:  http://www.pgatour.com/data/r/025/2014/
# files saved for:  http://www.pgatour.com/data/r/025/2015/
# files saved for:  http://www.pgatour.com/data/r/013/2014/
# files saved for:  http://www.pgatour.com/data/r/013/2015/
# Exception for http://www.pgatour.com/data/r/478/2014/
# files saved for:  http://www.pgatour.com/data/r/478/2015/
# files saved for:  http://www.pgatour.com/data/r/478/2016/
# files saved for:  http://www.pgatour.com/data/r/472/2014/
# files saved for:  http://www.pgatour.com/data/r/472/2015/
# Exception for http://www.pgatour.com/data/r/493/2014/
# files saved for:  http://www.pgatour.com/data/r/493/2015/
# files saved for:  http://www.pgatour.com/data/r/493/2016/
# Exception for http://www.pgatour.com/data/r/500/2015/

# %%
money_url
# Out:
# 'http://www.pgatour.com/data/r/009/2016/money.json'

# %%
urllib.request.urlretrieve(money_url, money_filename)
# Out:
# ('009_2016_money.json', <http.client.HTTPMessage at 0x7f2356fb0ac8>)
