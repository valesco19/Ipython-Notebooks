# %%
import requests
import pandas as pd
import os
from datetime import datetime, timedelta
import time
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.application import MIMEApplication
import smtplib

# %%
intro_email = """

<html>
<head>
<meta charset="utf-8">
<title>velop_launch_email_add</title>
<meta content="width=device-width, initial-scale=1" name="viewport">
<meta content="Webflow" name="generator">
<link href="css/normalize.css" rel="stylesheet" type="text/css">
<link href="css/webflow.css" rel="stylesheet" type="text/css">
<link href="css/velop-launch-email-add.webflow.css" rel="stylesheet" type="text/css">
<script src="https://ajax.googleapis.com/ajax/libs/webfont/1.4.7/webfont.js" type="text/javascript"></script>
<script type="text/javascript">WebFont.load({  google: {    families: ["Josefin Sans:300,regular,600,700","Josefin Slab:100,300,regular,600,700"]  }});</script>
<!-- [if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js" type="text/javascript"></script><![endif] -->
<script type="text/javascript">!function(o,c){var n=c.documentElement,t=" w-mod-";n.className+=t+"js",("ontouchstart"in o||o.DocumentTouch&&c instanceof DocumentTouch)&&(n.className+=t+"touch")}(window,document);</script>
<link href="https://daks2k3a4ib2z.cloudfront.net/img/favicon.ico" rel="shortcut icon" type="image/x-icon">
<link href="https://daks2k3a4ib2z.cloudfront.net/img/webclip.png" rel="apple-touch-icon">
<link href="https://fonts.googleapis.com/css?family=Josefin+Sans" rel="stylesheet">
<style>
.body {
  background-color: #39425a;
  padding-bottom:100px;
}

.header_div {
  padding-top: 20px;
  display: block;
  width: 100%;
  height: 120px;
  background-color: #fff;
}

.image_div {
  display: block;
  content-alignment: center;
  max-width: 300px;
  margin-left: auto;
  margin-right: auto;
}

.image {
    max-width: 300px;
    margin-left: auto;
    margin-right: auto;
}

.intro_heading {
  display: block;
  width: 65%;
  margin-top: 30px;
  margin-right: auto;
  margin-left: auto;
  font-family: 'Josefin Sans', sans-serif;
  color: #fff;
  font-size: 32px;
  font-weight: 300;
  text-align: center;
}

.intro_text {
  display: block;
  width: 60%;
  margin: 30px auto 25px;
  font-family: 'Josefin Sans', sans-serif;
  color: #fff;
  font-size: 22px;
  line-height: 24px;
  font-weight: 100;
  text-align: center;
}

.heading {
  margin-top: -10px;
  font-family: 'Josefin Sans', sans-serif;
  color: #ff3b3f;
  font-size: 24px;
  font-weight: 600;
  text-align: center;
}

.heading-2 {
  font-family: 'Josefin Sans', sans-serif;
  margin-top: -10px;
  color: #ff3b3f;
  text-align: center;
}

.paragraph {
  margin-bottom: -10px;
  font-family: 'Josefin Sans', sans-serif;
  color: #fff;
  text-align: center;
}

.button {
  display: block;
  width: 155px;
  height: 30px;
  margin: 35px auto 40px;
  padding-top: 10px;
  border: 1px solid #ff3b3f;
  background-color: transparent;
  font-family: 'Josefin Sans', sans-serif;
  color: #fff;
  text-align: center;
  letter-spacing: 1px;
}

</style>
</head>
<body class="body">
  <div class="header_div">
   <div class="image_div">
     <img src="https://i.imgur.com/WBR2bNH.png?1" class="image">
   </div>
  </div>
  <div>
    <h1 class="intro_heading">The internet has been great for a lot of things, individual privacy is not one of those.</h1>
    <h1 class="intro_text">Searched for your private information lately? If you don&#x27;t take continuous steps to protect your private information, your
                    personal details are almost certainly displayed on dozens of websites. Making things like your 
                    home address, phone numbers, family members, email address and much more displayed for all to 
                    see. Including</h1>
  </div>
  <h2 class="heading">Criminals</h2>
  <h2 class="heading">Identity Thieves</h2>
  <h2 class="heading">Scammers</h2>
  <h2 class="heading">Spammers</h2>
  <h1 class="intro_text">We utilize the cutting edge web scanning and machine learning technologies daily to locate
                         and remove your private information from the internet, keeping your private information
                         ... private.</h1>
  <p class="paragraph">*Limited Time Coupon Code</p>
  <h2 class="heading-2">ANDYLOVESJESUS</h2><a href="https://www.veloptechnologies.com" class="button w-button">Find out More</a>
  <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.2.0/jquery.min.js" type="text/javascript"></script>
  <script src="js/webflow.js" type="text/javascript"></script>
  <!-- [if lte IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/placeholders/3.0.2/placeholders.min.js"></script><![endif] -->
</body>
</html>

"""

# %%
sender = 'support@veloptechnologies.com'
receiver = 'al2239@gmail.com'

def send_email(message, sender, receiver):
    now_string = time.strftime('%m_%d_%Y_%H:%M')
    msg = MIMEMultipart('alternative')
    msg['Subject'] = "Keep your private information...private"
    msg['From'] = sender
    msg['To'] = receiver
    body = MIMEText(message, 'html')
    msg.attach(body)
    
    gmail_user = 'veloptechnologies@gmail.com'
    gmail_pwd = '!Z3c5b7m9.'

    server = smtplib.SMTP('smtp.gmail.com',587)
    server.ehlo()
    server.starttls()
    server.login(gmail_user, gmail_pwd)
    server.sendmail(sender, receiver, msg.as_string())
    server.close()
    
    #file = '/home/valesco/Datasets/crypto/reddit_scrapes/reddit_scrap' + now_string + '.txt'
    #with open(file, 'w') as f:
        #f.write("\n".join(map(lambda x: str(x), message)))
        #f.close()
    print('email sent ' + now_string)

    
send_email(intro_email, sender, receiver)
# Out:
# email sent 02_28_2018_01:05
