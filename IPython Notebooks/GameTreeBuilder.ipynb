# %%
# Turn tree builder
#Inputs: pot = starting pot size in SB, node = starting node number, 
# array = EQarray 

def flopTreeBldr (sln, pot, index, array):
    node = index
    # leaf = final decision point, 'Nature' if another street in Game Tree, 'Leaf' if final DecPt
    leaf = 'Nature'
    for i in range(27):
        sbCIP = pot/2.0
        bbCIP = pot/2.0
        if i == 0:
            player = 'BB'
            action = ""
        elif i == 1:
            player = 'SB'
            action = 'check'
        elif i == 2:
            player = leaf
            action = 'check'
        elif i == 3:
            player = 'BB'
            action = 'bet'
            sbCIP += 1.0
        elif i == 4:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 1.0
        elif i == 5:
            player = leaf
            action = 'call'
            sbCIP += 1.0
            bbCIP += 1.0
        elif i == 6:
            player = 'SB'
            action = "raise"
            sbCIP += 1.0
            bbCIP += 2.0
        elif i == 7:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 1.0
            bbCIP += 2.0
        elif i == 8:
            player = leaf
            action = 'call'
            sbCIP += 2.0
            bbCIP += 2.0
        elif i == 9:
            player = 'BB'
            action = 'raise'
            sbCIP += 3.0
            bbCIP += 2.0
        elif i == 10:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 3.0
            bbCIP += 2.0
        elif i == 11:
            player = leaf
            action = 'call'
            sbCIP += 3.0
            bbCIP += 3.0
        elif i == 12:
            player = 'SB'
            action = 'raise'
            sbCIP += 3.0
            bbCIP += 4.0
        elif i == 13:
            player = 'Leaf'
            action = "fold"
            sbCIP += 3.0
            bbCIP += 4.0
        elif i == 14:
            player = leaf
            action = 'call'
            sbCIP += 4.0
            bbCIP += 4.0
        elif i == 15:
            player = 'SB'
            action = 'bet'
            sbCIP += 0.0
            bbCIP += 1.0
        elif i == 16:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 0.0
            bbCIP += 1.0
        elif i == 17:
            player = leaf
            action = 'call'
            sbCIP += 1.0
            bbCIP += 1.0
        elif i == 18:
            player = 'BB'
            action = 'raise'
            sbCIP += 2.0
            bbCIP += 1.0
        elif i == 19:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 2.0
            bbCIP += 1.0
        elif i == 20:
            player = leaf
            action = "call"
            sbCIP += 2.0
            bbCIP += 2.0
        elif i == 21:
            player = 'SB'
            action = 'raise'
            sbCIP += 2.0
            bbCIP += 3.0
        elif i == 22:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 2.0
            bbCIP += 3.0
        elif i == 23:
            player = leaf
            action = 'call'
            sbCIP += 3.0
            bbCIP += 3.0
        elif i == 24:
            player = 'BB'
            action = 'raise'
            sbCIP += 4.0
            bbCIP += 3.0
        elif i == 25:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 4.0
            bbCIP += 3.0
        elif i == 26:
            player = leaf
            action = 'call'
            sbCIP += 4.0
            bbCIP += 4.0
        else:
            print ("ERROR in Tree")
        print ("point" + str(node) + "= DecPt ('" + str(player) + "', " + str(sbCIP) + ", " + str(bbCIP) + ", " + \
               str(array) + ", '" + action + "')")
        node += 1

    child = index
    

    for i in range(27):
        n = i + index
        if i == 0:
            print (" ")
        elif i == 1 or i == 2 or i == 4 or i == 7 or i == 10 or i == 13 or i == 16 or i == 19 or i == 22 or i == 25:
            child = n - 1
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        elif i == 3 or i == 5 or i == 8 or i == 11 or i == 14 or i == 17 or i == 20 or i == 23 or i == 26:
            child = n - 2
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        elif i == 6 or i == 9 or i == 12  or i == 18 or i == 21 or i == 24:
            child = n - 3
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        elif i == 15:
            child = n - 15
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        else:
            print ("ERROR in Tree")
        child += 1

# %%
# Turn tree builder
#Inputs: pot = starting pot size in SB, node = starting node number, 
# array = EQarray 

def turnTreeBldr (sln, pot, index, array):
    node = index
    leaf = 'Leaf'
    for i in range(27):
        sbCIP = pot/2.0
        bbCIP = pot/2.0
        if i == 0:
            player = 'BB'
            action = ""
        elif i == 1:
            player = 'SB'
            action = 'check'
        elif i == 2:
            player = leaf
            action = 'check'
        elif i == 3:
            player = 'BB'
            action = 'bet'
            sbCIP += 2.0
        elif i == 4:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 2.0
        elif i == 5:
            player = leaf
            action = 'call'
            sbCIP += 2.0
            bbCIP += 2.0
        elif i == 6:
            player = 'SB'
            action = "raise"
            sbCIP += 2.0
            bbCIP += 4.0
        elif i == 7:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 2.0
            bbCIP += 4.0
        elif i == 8:
            player = leaf
            action = 'call'
            sbCIP += 4.0
            bbCIP += 4.0
        elif i == 9:
            player = 'BB'
            action = 'raise'
            sbCIP += 6.0
            bbCIP += 4.0
        elif i == 10:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 6.0
            bbCIP += 4.0
        elif i == 11:
            player = leaf
            action = 'call'
            sbCIP += 6.0
            bbCIP += 6.0
        elif i == 12:
            player = 'SB'
            action = 'raise'
            sbCIP += 6.0
            bbCIP += 8.0
        elif i == 13:
            player = 'Leaf'
            action = "fold"
            sbCIP += 6.0
            bbCIP += 8.0
        elif i == 14:
            player = leaf
            action = 'call'
            sbCIP += 8.0
            bbCIP += 8.0
        elif i == 15:
            player = 'SB'
            action = 'bet'
            sbCIP += 0.0
            bbCIP += 2.0
        elif i == 16:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 0.0
            bbCIP += 2.0
        elif i == 17:
            player = leaf
            action = 'call'
            sbCIP += 2.0
            bbCIP += 2.0
        elif i == 18:
            player = 'BB'
            action = 'raise'
            sbCIP += 4.0
            bbCIP += 2.0
        elif i == 19:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 4.0
            bbCIP += 2.0
        elif i == 20:
            player = leaf
            action = "call"
            sbCIP += 4.0
            bbCIP += 4.0
        elif i == 21:
            player = 'SB'
            action = 'raise'
            sbCIP += 4.0
            bbCIP += 6.0
        elif i == 22:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 4.0
            bbCIP += 6.0
        elif i == 23:
            player = leaf
            action = 'call'
            sbCIP += 6.0
            bbCIP += 6.0
        elif i == 24:
            player = 'BB'
            action = 'raise'
            sbCIP += 8.0
            bbCIP += 6.0
        elif i == 25:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 8.0
            bbCIP += 6.0
        elif i == 26:
            player = leaf
            action = 'call'
            sbCIP += 8.0
            bbCIP += 8.0
        else:
            print ("ERROR in Tree")
        print ("point" + str(node) + "= DecPt ('" + str(player) + "', " + str(sbCIP) + ", " + str(bbCIP) + ", " + \
               str(array) + ", '" + action + "')")
        node += 1

    child = index
    

    for i in range(27):
        n = i + index
        if i == 0:
            print (" ")
        elif i == 1 or i == 2 or i == 4 or i == 7 or i == 10 or i == 13 or i == 16 or i == 19 or i == 22 or i == 25:
            child = n - 1
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        elif i == 3 or i == 5 or i == 8 or i == 11 or i == 14 or i == 17 or i == 20 or i == 23 or i == 26:
            child = n - 2
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        elif i == 6 or i == 9 or i == 12  or i == 18 or i == 21 or i == 24:
            child = n - 3
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        elif i == 15:
            child = n - 15
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        else:
            print ("ERROR in Tree")
        child += 1

# %%
# River tree builder
#Inputs: pot = starting pot size in SB, node = starting node number, 
# array = EQarray 

def riverTreeBldr (sln, pot, index, array):
    #array = 'riverEArray'
    node = index
    for i in range(27):
        sbCIP = pot/2.0
        bbCIP = pot/2.0
        if i == 0:
            player = 'BB'
            action = ""
        elif i == 1:
            player = 'SB'
            action = 'check'
        elif i == 2:
            player = 'Leaf'
            action = 'check'
        elif i == 3:
            player = 'BB'
            action = 'bet'
            sbCIP += 2.0
        elif i == 4:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 2.0
        elif i == 5:
            player = 'Leaf'
            action = 'call'
            sbCIP += 2.0
            bbCIP += 2.0
        elif i == 6:
            player = 'SB'
            action = "raise"
            sbCIP += 2.0
            bbCIP += 4.0
        elif i == 7:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 2.0
            bbCIP += 4.0
        elif i == 8:
            player = 'Leaf'
            action = 'call'
            sbCIP += 4.0
            bbCIP += 4.0
        elif i == 9:
            player = 'BB'
            action = 'raise'
            sbCIP += 6.0
            bbCIP += 4.0
        elif i == 10:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 6.0
            bbCIP += 4.0
        elif i == 11:
            player = 'Leaf'
            action = 'call'
            sbCIP += 6.0
            bbCIP += 6.0
        elif i == 12:
            player = 'SB'
            action = 'raise'
            sbCIP += 6.0
            bbCIP += 8.0
        elif i == 13:
            player = 'Leaf'
            action = "fold"
            sbCIP += 6.0
            bbCIP += 8.0
        elif i == 14:
            player = 'Leaf'
            action = 'call'
            sbCIP += 8.0
            bbCIP += 8.0
        elif i == 15:
            player = 'SB'
            action = 'bet'
            sbCIP += 0.0
            bbCIP += 2.0
        elif i == 16:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 0.0
            bbCIP += 2.0
        elif i == 17:
            player = 'Leaf'
            action = 'call'
            sbCIP += 2.0
            bbCIP += 2.0
        elif i == 18:
            player = 'BB'
            action = 'raise'
            sbCIP += 4.0
            bbCIP += 2.0
        elif i == 19:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 4.0
            bbCIP += 2.0
        elif i == 20:
            player = 'Leaf'
            action = "call"
            sbCIP += 4.0
            bbCIP += 4.0
        elif i == 21:
            player = 'SB'
            action = 'raise'
            sbCIP += 4.0
            bbCIP += 6.0
        elif i == 22:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 4.0
            bbCIP += 6.0
        elif i == 23:
            player = 'Leaf'
            action = 'call'
            sbCIP += 6.0
            bbCIP += 6.0
        elif i == 24:
            player = 'BB'
            action = 'raise'
            sbCIP += 8.0
            bbCIP += 6.0
        elif i == 25:
            player = 'Leaf'
            action = 'fold'
            sbCIP += 8.0
            bbCIP += 6.0
        elif i == 26:
            player = 'Leaf'
            action = 'call'
            sbCIP += 8.0
            bbCIP += 8.0
        else:
            print ("ERROR in Tree")
        print ("point" + str(node) + "= DecPt ('" + str(player) + "', " + str(sbCIP) + ", " + str(bbCIP) + ", " + \
               str(array) + ", '" + action + "')")
        node += 1

    child = index
    

    for i in range(27):
        n = i + index
        if i == 0:
            print (" ")
        elif i == 1 or i == 2 or i == 4 or i == 7 or i == 10 or i == 13 or i == 16 or i == 19 or i == 22 or i == 25:
            child = n - 1
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        elif i == 3 or i == 5 or i == 8 or i == 11 or i == 14 or i == 17 or i == 20 or i == 23 or i == 26:
            child = n - 2
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        elif i == 6 or i == 9 or i == 12  or i == 18 or i == 21 or i == 24:
            child = n - 3
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        elif i == 15:
            child = n - 15
            print (str(sln) + ".addDecPt(point" + str(n) + ", point" + str(child) + ")")
        else:
            print ("ERROR in Tree")
        child += 1

# %%
turnTreeBldr ('flopTurnSln', 12.5, 486, 'turnBEArray')
# Out:
# point486= DecPt ('BB', 6.25, 6.25, turnBEArray, '')
# point487= DecPt ('SB', 6.25, 6.25, turnBEArray, 'check')
# point488= DecPt ('Leaf', 6.25, 6.25, turnBEArray, 'check')
# point489= DecPt ('BB', 8.25, 6.25, turnBEArray, 'bet')
# point490= DecPt ('Leaf', 8.25, 6.25, turnBEArray, 'fold')
# point491= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
# point492= DecPt ('SB', 8.25, 10.25, turnBEArray, 'raise')
# point493= DecPt ('Leaf', 8.25, 10.25, turnBEArray, 'fold')
# point494= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
# point495= DecPt ('BB', 12.25, 10.25, turnBEArray, 'raise')
# point496= DecPt ('Leaf', 12.25, 10.25, turnBEArray, 'fold')
# point497= DecPt ('Leaf', 12.25, 12.25, turnBEArray, 'call')
# point498= DecPt ('SB', 12.25, 14.25, turnBEArray, 'raise')
# point499= DecPt ('Leaf', 12.25, 14.25, turnBEArray, 'fold')
# point500= DecPt ('Leaf', 14.25, 14.25, turnBEArray, 'call')
# point501= DecPt ('SB', 6.25, 8.25, turnBEArray, 'bet')
# ...

# %%
point0= DecPt ('BB', 2.0, 2.0, flopEArray, '')
point1= DecPt ('SB', 2.0, 2.0, flopEArray, 'check')
point2= DecPt ('Nature', 2.0, 2.0, flopEArray, 'check')
point3= DecPt ('BB', 3.0, 2.0, flopEArray, 'bet')
point4= DecPt ('Leaf', 3.0, 2.0, flopEArray, 'fold')
point5= DecPt ('Nature', 3.0, 3.0, flopEArray, 'call')
point6= DecPt ('SB', 3.0, 4.0, flopEArray, 'raise')
point7= DecPt ('Leaf', 3.0, 4.0, flopEArray, 'fold')
point8= DecPt ('Nature', 4.0, 4.0, flopEArray, 'call')
point9= DecPt ('BB', 5.0, 4.0, flopEArray, 'raise')
point10= DecPt ('Leaf', 5.0, 4.0, flopEArray, 'fold')
point11= DecPt ('Nature', 5.0, 5.0, flopEArray, 'call')
point12= DecPt ('SB', 5.0, 6.0, flopEArray, 'raise')
point13= DecPt ('Leaf', 5.0, 6.0, flopEArray, 'fold')
point14= DecPt ('Nature', 6.0, 6.0, flopEArray, 'call')
point15= DecPt ('SB', 2.0, 3.0, flopEArray, 'bet')
point16= DecPt ('Leaf', 2.0, 3.0, flopEArray, 'fold')
point17= DecPt ('Nature', 3.0, 3.0, flopEArray, 'call')
point18= DecPt ('BB', 4.0, 3.0, flopEArray, 'raise')
point19= DecPt ('Leaf', 4.0, 3.0, flopEArray, 'fold')
point20= DecPt ('Nature', 4.0, 4.0, flopEArray, 'call')
point21= DecPt ('SB', 4.0, 5.0, flopEArray, 'raise')
point22= DecPt ('Leaf', 4.0, 5.0, flopEArray, 'fold')
point23= DecPt ('Nature', 5.0, 5.0, flopEArray, 'call')
point24= DecPt ('BB', 6.0, 5.0, flopEArray, 'raise')
point25= DecPt ('Leaf', 6.0, 5.0, flopEArray, 'fold')
point26= DecPt ('Nature', 6.0, 6.0, flopEArray, 'call')
point27= DecPt ('BB', 2.25, 2.25, turnAEArray, '5d7cQdJh__')
point28= DecPt ('BB', 2.25, 2.25, turnBEArray, '5d7cQd6h__')
point29= DecPt ('BB', 3.25, 3.25, turnAEArray, '5d7cQdJh__')
point30= DecPt ('BB', 3.25, 3.25, turnBEArray, '5d7cQd6h__')
point31= DecPt ('BB', 4.25, 4.25, turnAEArray, '5d7cQdJh__')
point32= DecPt ('BB', 4.25, 4.25, turnBEArray, '5d7cQd6h__')
point33= DecPt ('BB', 5.25, 5.25, turnAEArray, '5d7cQdJh__')
point34= DecPt ('BB', 5.25, 5.25, turnBEArray, '5d7cQd6h__')
point35= DecPt ('BB', 6.25, 6.25, turnAEArray, '5d7cQdJh__')
point36= DecPt ('BB', 6.25, 6.25, turnBEArray, '5d7cQd6h__')
point37= DecPt ('BB', 3.25, 3.25, turnAEArray, '5d7cQdJh__')
point38= DecPt ('BB', 3.25, 3.25, turnBEArray, '5d7cQd6h__')
point39= DecPt ('BB', 4.25, 4.25, turnAEArray, '5d7cQdJh__')
point40= DecPt ('BB', 4.25, 4.25, turnBEArray, '5d7cQd6h__')
point41= DecPt ('BB', 5.25, 5.25, turnAEArray, '5d7cQdJh__')
point42= DecPt ('BB', 5.25, 5.25, turnBEArray, '5d7cQd6h__')
point43= DecPt ('BB', 6.25, 6.25, turnAEArray, '5d7cQdJh__')
point44= DecPt ('BB', 6.25, 6.25, turnBEArray, '5d7cQd6h__')
point45= DecPt ('BB', 2.0, 2.0, turnAEArray, '')
point46= DecPt ('SB', 2.0, 2.0, turnAEArray, 'check')
point47= DecPt ('Nature', 2.0, 2.0, turnAEArray, 'check')
point48= DecPt ('BB', 4.0, 2.0, turnAEArray, 'bet')
point49= DecPt ('Leaf', 4.0, 2.0, turnAEArray, 'fold')
point50= DecPt ('Nature', 4.0, 4.0, turnAEArray, 'call')
point51= DecPt ('SB', 4.0, 6.0, turnAEArray, 'raise')
point52= DecPt ('Leaf', 4.0, 6.0, turnAEArray, 'fold')
point53= DecPt ('Nature', 6.0, 6.0, turnAEArray, 'call')
point54= DecPt ('BB', 8.0, 6.0, turnAEArray, 'raise')
point55= DecPt ('Leaf', 8.0, 6.0, turnAEArray, 'fold')
point56= DecPt ('Nature', 8.0, 8.0, turnAEArray, 'call')
point57= DecPt ('SB', 8.0, 10.0, turnAEArray, 'raise')
point58= DecPt ('Leaf', 8.0, 10.0, turnAEArray, 'fold')
point59= DecPt ('Nature', 10.0, 10.0, turnAEArray, 'call')
point60= DecPt ('SB', 2.0, 4.0, turnAEArray, 'bet')
point61= DecPt ('Leaf', 2.0, 4.0, turnAEArray, 'fold')
point62= DecPt ('Nature', 4.0, 4.0, turnAEArray, 'call')
point63= DecPt ('BB', 6.0, 4.0, turnAEArray, 'raise')
point64= DecPt ('Leaf', 6.0, 4.0, turnAEArray, 'fold')
point65= DecPt ('Nature', 6.0, 6.0, turnAEArray, 'call')
point66= DecPt ('SB', 6.0, 8.0, turnAEArray, 'raise')
point67= DecPt ('Leaf', 6.0, 8.0, turnAEArray, 'fold')
point68= DecPt ('Nature', 8.0, 8.0, turnAEArray, 'call')
point69= DecPt ('BB', 10.0, 8.0, turnAEArray, 'raise')
point70= DecPt ('Leaf', 10.0, 8.0, turnAEArray, 'fold')
point71= DecPt ('Nature', 10.0, 10.0, turnAEArray, 'call')



flopTurnSln = Tree (S, point0) 
flopTurnSln.addDecPt(point1, point0)
flopTurnSln.addDecPt(point2, point1)
flopTurnSln.addDecPt(point3, point1)
flopTurnSln.addDecPt(point4, point3)
flopTurnSln.addDecPt(point5, point3)
flopTurnSln.addDecPt(point6, point3)
flopTurnSln.addDecPt(point7, point6)
flopTurnSln.addDecPt(point8, point6)
flopTurnSln.addDecPt(point9, point6)
flopTurnSln.addDecPt(point10, point9)
flopTurnSln.addDecPt(point11, point9)
flopTurnSln.addDecPt(point12, point9)
flopTurnSln.addDecPt(point13, point12)
flopTurnSln.addDecPt(point14, point12)
flopTurnSln.addDecPt(point15, point0)
flopTurnSln.addDecPt(point16, point15)
flopTurnSln.addDecPt(point17, point15)
flopTurnSln.addDecPt(point18, point15)
flopTurnSln.addDecPt(point19, point18)
flopTurnSln.addDecPt(point20, point18)
flopTurnSln.addDecPt(point21, point18)
flopTurnSln.addDecPt(point22, point21)
flopTurnSln.addDecPt(point23, point21)
flopTurnSln.addDecPt(point24, point21)
flopTurnSln.addDecPt(point25, point24)
flopTurnSln.addDecPt(point26, point24)
flopTurnSln.addDecPt(point27, point2)
flopTurnSln.addDecPt(point28, point2)
flopTurnSln.addDecPt(point29, point5)
flopTurnSln.addDecPt(point30, point5)
flopTurnSln.addDecPt(point31, point8)
flopTurnSln.addDecPt(point32, point8)
flopTurnSln.addDecPt(point33, point11)
flopTurnSln.addDecPt(point34, point11)
flopTurnSln.addDecPt(point35, point14)
flopTurnSln.addDecPt(point36, point14)
flopTurnSln.addDecPt(point37, point17)
flopTurnSln.addDecPt(point38, point17)
flopTurnSln.addDecPt(point39, point20)
flopTurnSln.addDecPt(point40, point20)
flopTurnSln.addDecPt(point41, point23)
flopTurnSln.addDecPt(point42, point23)
flopTurnSln.addDecPt(point43, point26)
flopTurnSln.addDecPt(point44, point26)
