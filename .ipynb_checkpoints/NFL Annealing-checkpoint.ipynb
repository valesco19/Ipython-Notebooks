# %%
import pandas as pd
import requests 
import json
from pandas.io.json import json_normalize
import os
import scipy.linalg as linalg
from pulp import *
import csv
import itertools
from tqdm import tqdm
import statsmodels.stats.moment_helpers as stats
import scipy
import matplotlib.pyplot as plt
import math
import matplotlib.mlab as mlab
from datetime import datetime
import numpy as np
from random import randint
from collections import Counter
os.chdir('/home/valesco/Datasets/NFL_projs')
pd.set_option('display.max_columns', 106)
pd.set_option('display.max_rows', 100)

# %%
url = 'http://www.fantasylabs.com/api/playermodel/1/10_11_2017/?modelId=1196314&projOnly=true'

headers = {
            'Access-Control-Allow-Credentials':'true',
            'Access-Control-Allow-Headers':'Access-Control-Allow-Headers,Origin,Accept, X-Requested-With,Content-Type,Access-Control-Request-Method, Access-Control-Request-Headers',
            'Access-Control-Allow-Methods':'GET,OPTIONS,POST,PUT',
            'Access-Control-Allow-Origin':'*',
            'Cache-Control':'max-age=60',
            'CF-RAY':'3ad7cc6d63475933-DFW',
            'Content-Encoding':'gzip',
            'Content-Type':'application/json; charset=utf-8',
            'Date':'Sat, 14 Oct 2017 04:29:36 GMT'
           }


response = requests.get(url, headers = headers)
json_data = response.json()
response.text
# Out:
# 'null'

# %%
week14_all = json_normalize(json_data['PlayerModels'])
week14_all.to_csv('week14_projs.csv')
with open('week14_projs.json', 'w') as outfile:
    json.dump(json_data['PlayerModels'], outfile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c5eebbbd9aa3> in <module>()
# ----> 1 week14_all = json_normalize(json_data['PlayerModels'])
#       2 week14_all.to_csv('week14_projs.csv')
#       3 with open('week14_projs.json', 'w') as outfile:
#       4     json.dump(json_data['PlayerModels'], outfile)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
week14_dk = week14_all.loc[week14_all['Properties.SourceId'] == 4]
week14_dk.head()
# Out:
#     ActualPoints  Cnt  Correlation  CurrentExposure Exposure  FantasyResultId  \
# 0            0.0    0          0.0              0.0     None           713904
# 5            0.0    0          0.0              0.0     None           713968
# 6            0.0    0          0.0              0.0     None           713680
# 11           0.0    0          0.0              0.0     None           713790
# 12           0.0    0          0.0              0.0     None           714919
#
#    FirstPosition FullName IsExcluded IsLiked IsLocked  LineupCount  \
# 0             WR               False   False    False            0
# 5             WR               False   False    False            0
# 6             TE               False   False    False            0
# 11            RB               False   False    False            0
# 12            WR               False   False    False            0
#
#    MinExposure  PlayerId  Points Position  PositionCount  PositionId  \
# 0         None       926     0.0       WR              1         103
# 5         None       969     0.0       WR              1         103
# 6         None      1007     0.0       TE              1         104
# 11        None      1124     0.0       RB              1         102
# 12        None      1150     0.0       WR              1         103
#
#    Positions  ProjPoints Properties.ActualPoints  Properties.AdjYPA  \
# 0       [WR]         0.0                    None                NaN
# 5       [WR]         0.0                    None                NaN
# 6       [TE]         0.0                    None                NaN
# 11      [RB]         0.0                    None                NaN
# 12      [WR]         0.0                    None                NaN
#
#     Properties.AvgPts  Properties.Ceiling  Properties.CeilingPct  \
# 0                13.0                21.6                     89
# 5                 4.9                10.7                     47
# 6                 8.0                18.0                     95
# 11                9.3                16.9                     79
# 12               11.2                18.9                     81
#
#    Properties.Confirmed  Properties.Consistency  Properties.EventId  \
# 0                  None                      67             3356030
# 5                  None                      67             3356170
# 6                  None                      61             3355940
# 11                 None                      69             3355990
# 12                 None                      53             3356040
#
#     Properties.EventTeamId  Properties.ExpectedSacksPct  \
# 0                 33560302                           28
# 5                 33561701                           83
# 6                 33559402                           41
# 11                33559901                           10
# 12                33560402                           24
#
#     Properties.FantasyResultId  Properties.Floor  Properties.FloorPct  \
# 0                       713904               5.0                   54
# 5                       713968               0.7                   16
# 6                       713680               2.9                   52
# 11                      713790               2.7                   42
# 12                      714919               3.2                   40
#
#     Properties.FloorPtPerDPct Properties.FullName  Properties.ImpPts  \
# 0                          54                                  11.71
# 5                          16                                   5.98
# 6                          52                                   4.57
# 11                         42                                   5.63
# 12                         40                                   8.04
#
#    Properties.InjuryStatus  Properties.InterceptionPct Properties.IsProjected  \
# 0                     None                        3.63                   True
# 5                     None                        4.49                   True
# 6                     None                        2.11                   True
# 11                    None                        4.55                   True
# 12                    None                        2.24                   True
#
#     Properties.MktShrPct  Properties.Month_FPOpp  Properties.Month_FPSnap  \
# 0                   86.0                     0.0                     0.26
# 5                   55.0                     0.0                     0.16
# 6                   59.0                     0.0                     0.30
# 11                  59.0                     0.0                     0.40
# 12                  83.0                     0.0                     0.18
#
#     Properties.MyTrends  Properties.OffensiveSnapsMarketShare  \
# 0                     0                                  79.8
# 5                     0                                  61.4
# 6                     0                                  56.5
# 11                    0                                  36.6
# 12                    0                                  74.7
#
#     Properties.OppPlusMinusPct  Properties.OpportunitiesRedZone  \
# 0                           69                             0.88
# 5                           54                             0.06
# 6                           90                             0.40
# 11                          78                             1.13
# 12                          69                             0.75
#
#     Properties.OpportunitiesRedZone10  Properties.OpportunitiesRedZone5  \
# 0                                0.50                              0.31
# 5                                0.00                              0.00
# 6                                0.20                              0.13
# 11                               0.73                              0.53
# 12                               0.31                              0.00
#
#    Properties.Opposing_TeamFB  Properties.OwnRank  Properties.PassINTPct  \
# 0                         SEA                  80                    NaN
# 5                         @NE                  50                    NaN
# 6                         HOU                  80                    NaN
# 11                       @JAX                  90                    NaN
# 12                        ATL                  90                    NaN
#
#     Properties.PassSackPct  Properties.PassTDPct  \
# 0                      NaN                   NaN
# 5                      NaN                   NaN
# 6                      NaN                   NaN
# 11                     NaN                   NaN
# 12                     NaN                   NaN
#
#     Properties.PassingAttemptsRBPct  Properties.PassingAttemptsTEPct  \
# 0                               NaN                              NaN
# 5                               NaN                              NaN
# 6                               NaN                              NaN
# 11                              NaN                              NaN
# 12                              NaN                              NaN
#
#     Properties.PassingAttemptsWRPct  Properties.PassingSuccessfulPct  \
# 0                               NaN                            45.53
# 5                               NaN                            52.53
# 6                               NaN                            50.12
# 11                              NaN                            45.19
# 12                              NaN                            46.98
#
#     Properties.PlayerId Properties.Player_Name  Properties.Plus_Minus  \
# 0                   926          Davante Adams                     90
# 5                   969            Kamar Aiken                     53
# 6                  1007           Dwayne Allen                     76
# 11                 1124            Matt Asiata                     71
# 12                 1150           Tavon Austin                     76
#
#    Properties.Position  Properties.PositionId  Properties.Pro_Pct  \
# 0                   WR                    103                  79
# 5                   WR                    103                  14
# 6                   TE                    104                  69
# 11                  RB                    102                  82
# 12                  WR                    103                  57
#
#     Properties.ProjPct  Properties.ProjPlaysPct  Properties.ProjPlusMinusPct  \
# 0                   77                       55                           63
# 5                   34                       88                           37
# 6                   70                       17                           83
# 11                  65                       72                           83
# 12                  68                       18                           85
#
#     Properties.PtPerDPct  Properties.ReceivingTargetsMarketShare  \
# 0                     64                                    18.6
# 5                     35                                    12.0
# 6                     94                                     8.8
# 11                    84                                     6.4
# 12                    89                                    20.3
#
#     Properties.ReceivingTouchdownsMarketShare  \
# 0                                        23.5
# 5                                         5.3
# 6                                        20.0
# 11                                        0.0
# 12                                       25.0
#
#     Properties.ReceivingTouchdownsRedZonePct  \
# 0                                       21.4
# 5                                        0.0
# 6                                       40.0
# 11                                       NaN
# 12                                      22.2
#
#     Properties.ReceivingYardsMarketShare  Properties.RedZoneSnaps  \
# 0                                   22.4                     7.50
# 5                                   14.7                     6.27
# 6                                    8.3                    10.75
# 11                                   5.1                     7.20
# 12                                  15.0                     9.82
#
#     Properties.RedZoneSnaps10  Properties.RedZoneSnaps5  \
# 0                        3.80                      2.75
# 5                        3.11                      2.88
# 6                        5.75                      3.67
# 11                       3.33                      1.88
# 12                       5.09                      3.33
#
#     Properties.RedZoneTouchdownPct  Properties.RushingFantasyPct  \
# 0                            21.33                           NaN
# 5                            23.19                           NaN
# 6                            19.38                           NaN
# 11                           18.06                           NaN
# 12                           19.44                           NaN
#
#     Properties.RushingSuccessfulAllowedPct  Properties.RushingSuccessfulPct  \
# 0                                    43.70                              NaN
# 5                                    40.15                              NaN
# 6                                    48.29                            100.0
# 11                                   44.25                             30.2
# 12                                   43.75                             52.8
#
#     Properties.RushingSuccessfulPctRedZone  \
# 0                                      NaN
# 5                                      NaN
# 6                                    100.0
# 11                                    47.1
# 12                                    66.7
#
#     Properties.RushingTouchdownsMarketShare  \
# 0                                       0.0
# 5                                       0.0
# 6                                       0.0
# 11                                     41.7
# 12                                      9.1
#
#     Properties.RushingTouchdownsRedZonePct  \
# 0                                      NaN
# 5                                      NaN
# 6                                      0.0
# 11                                    11.8
# 12                                     0.0
#
#     Properties.RushingYardsMarketShare  Properties.SackPct  Properties.Salary  \
# 0                                  0.0               11.45               5500
# 5                                  0.0               10.39               3000
# 6                                  0.1                9.13               2600
# 11                                26.3               12.03               3300
# 12                                13.9                6.94               3900
#
#     Properties.Salary_Movement  Properties.Score  Properties.Season_FPOpp  \
# 0                           93              64.0                      0.0
# 5                           83              33.0                      0.0
# 6                           91              76.0                      0.0
# 11                          88              71.0                      0.0
# 12                          79              60.0                      0.0
#
#     Properties.Season_FPSnap  Properties.Season_PPG  \
# 0                       0.24                   13.9
# 5                       0.18                    7.7
# 6                       0.17                    7.4
# 11                      0.31                    7.2
# 12                      0.22                   10.6
#
#     Properties.Season_PPG_Percentile  Properties.Season_Plus_Minus  \
# 0                                 82                           3.9
# 5                                 54                          -0.2
# 6                                 71                           2.1
# 11                                58                           1.3
# 12                                68                           2.0
#
#     Properties.Season_Salary_Change  Properties.Season_X0  \
# 0                              1200                  25.0
# 5                             -1700                  18.0
# 6                              -600                  30.0
# 11                                0                  26.0
# 12                            -1100                  33.0
#
#     Properties.Season_X1  Properties.Season_X2  Properties.Site_Salary  \
# 0                   75.0                  37.0                      19
# 5                   75.0                  18.0                      58
# 6                   69.0                  30.0                      86
# 11                  73.0                  46.0                      97
# 12                  66.0                  33.0                      21
#
#     Properties.SourceId  Properties.TakeawayPct Properties.Team  \
# 0                     4                    2.13              GB
# 5                     4                    2.56             BAL
# 6                     4                    1.21             IND
# 11                    4                    2.85             MIN
# 12                    4                    1.38              LA
#
#     Properties.TouchdownAllowedPct  Properties.Upside  Properties.Vegas  \
# 0                             3.76                 64                44
# 5                             4.76                 33                24
# 6                             4.41                 50                89
# 11                            3.00                 76                44
# 12                            3.54                 60                28
#
#     Properties.YardsPerPassingAttempt  Salary  Score TeamName
# 0                                7.27    5500   64.0       GB
# 5                                7.03    3000   33.0      BAL
# 6                                7.68    2600   76.0      IND
# 11                               6.44    3300   71.0      MIN
# 12                               6.70    3900   60.0       LA

# %%
cols = ['PlayerId',
 'Properties.Player_Name',
 'Salary',
 'TeamName',
 'Properties.Opposing_TeamFB',
 'Properties.AvgPts',
 'Properties.Floor',
 'Properties.FloorPct',
 'Properties.FloorPtPerDPct',
 'Properties.Ceiling',
 'Properties.CeilingPct',
 'Properties.Consistency',
 'Position',
 'PositionCount',
 'PositionId',
 'Positions',
 'Properties.AdjYPA',
 'Properties.EventTeamId',
 'Properties.ExpectedSacksPct',
 'Properties.ImpPts',
 'Properties.InterceptionPct',
 'Properties.IsProjected',
 'Properties.MktShrPct',
 'Properties.Month_FPOpp',
 'Properties.Month_FPSnap',
 'Properties.OffensiveSnapsMarketShare',
 'Properties.OppPlusMinusPct',
 'Properties.OpportunitiesRedZone',
 'Properties.OpportunitiesRedZone10',
 'Properties.OpportunitiesRedZone5',
 'Properties.PassINTPct',
 'Properties.PassSackPct',
 'Properties.PassTDPct',
 'Properties.PassingAttemptsRBPct',
 'Properties.PassingAttemptsTEPct',
 'Properties.PassingAttemptsWRPct',
 'Properties.PassingSuccessfulPct',
 'Properties.Plus_Minus',
 'Properties.Position',
 'Properties.PositionId',
 'Properties.Pro_Pct',
 'Properties.ProjPct',
 'Properties.ProjPlaysPct',
 'Properties.ProjPlusMinusPct',
 'Properties.PtPerDPct',
 'Properties.ReceivingTargetsMarketShare',
 'Properties.ReceivingTouchdownsMarketShare',
 'Properties.ReceivingTouchdownsRedZonePct',
 'Properties.ReceivingYardsMarketShare',
 'Properties.RedZoneSnaps',
 'Properties.RedZoneSnaps10',
 'Properties.RedZoneSnaps5',
 'Properties.RedZoneTouchdownPct',
 'Properties.RushingFantasyPct',
 'Properties.RushingSuccessfulAllowedPct',
 'Properties.RushingSuccessfulPct',
 'Properties.RushingSuccessfulPctRedZone',
 'Properties.RushingTouchdownsMarketShare',
 'Properties.RushingTouchdownsRedZonePct',
 'Properties.RushingYardsMarketShare',
 'Properties.SackPct',
 'Properties.Salary',
 'Properties.Salary_Movement',
 'Properties.Score',
 'Properties.Season_FPOpp',
 'Properties.Season_FPSnap',
 'Properties.Season_PPG',
 'Properties.Season_PPG_Percentile',
 'Properties.Season_Plus_Minus',
 'Properties.Season_Salary_Change',
 'Properties.Season_X0',
 'Properties.Season_X1',
 'Properties.Season_X2',
 'Properties.Site_Salary',
 'Properties.SourceId',
 'Properties.TakeawayPct',
 'Properties.Team',
 'Properties.TouchdownAllowedPct',
 'Properties.Upside',
 'Properties.Vegas',
 'Properties.YardsPerPassingAttempt',
 'Score']

week14_dk = week14_dk[cols]

# %%
new_cols = ['player_id',
 'name',
 'salary',
 'team',
 'opponent',
 'points_avg',
 'points_floor',
 'floor_pct',
 'floor_pt_per_dpct',
 'points_ceiling',
 'ceiling_pct',
 'consistency',
 'position',
 'position_count',
 'position_id',
 'positions',
 'adj_ypa',
 'event_team_id',
 'expected_sack_pct',
 'Properties.ImpPts',
 'Properties.InterceptionPct',
 'Properties.IsProjected',
 'Properties.MktShrPct',
 'Properties.Month_FPOpp',
 'Properties.Month_FPSnap',
 'Properties.OffensiveSnapsMarketShare',
 'Properties.OppPlusMinusPct',
 'Properties.OpportunitiesRedZone',
 'Properties.OpportunitiesRedZone10',
 'Properties.OpportunitiesRedZone5',
 'Properties.PassINTPct',
 'Properties.PassSackPct',
 'Properties.PassTDPct',
 'Properties.PassingAttemptsRBPct',
 'Properties.PassingAttemptsTEPct',
 'Properties.PassingAttemptsWRPct',
 'Properties.PassingSuccessfulPct',
 'Properties.Plus_Minus',
 'Properties.Position',
 'Properties.PositionId',
 'Properties.Pro_Pct',
 'Properties.ProjPct',
 'Properties.ProjPlaysPct',
 'Properties.ProjPlusMinusPct',
 'Properties.PtPerDPct',
 'Properties.ReceivingTargetsMarketShare',
 'Properties.ReceivingTouchdownsMarketShare',
 'Properties.ReceivingTouchdownsRedZonePct',
 'Properties.ReceivingYardsMarketShare',
 'Properties.RedZoneSnaps',
 'Properties.RedZoneSnaps10',
 'Properties.RedZoneSnaps5',
 'Properties.RedZoneTouchdownPct',
 'Properties.RushingFantasyPct',
 'Properties.RushingSuccessfulAllowedPct',
 'Properties.RushingSuccessfulPct',
 'Properties.RushingSuccessfulPctRedZone',
 'Properties.RushingTouchdownsMarketShare',
 'Properties.RushingTouchdownsRedZonePct',
 'Properties.RushingYardsMarketShare',
 'Properties.SackPct',
 'Properties.Salary',
 'Properties.Salary_Movement',
 'Properties.Score',
 'Properties.Season_FPOpp',
 'Properties.Season_FPSnap',
 'Properties.Season_PPG',
 'Properties.Season_PPG_Percentile',
 'Properties.Season_Plus_Minus',
 'Properties.Season_Salary_Change',
 'Properties.Season_X0',
 'Properties.Season_X1',
 'Properties.Season_X2',
 'Properties.Site_Salary',
 'Properties.SourceId',
 'Properties.TakeawayPct',
 'Properties.Team',
 'Properties.TouchdownAllowedPct',
 'Properties.Upside',
 'Properties.Vegas',
 'Properties.YardsPerPassingAttempt',
 'Score']

week14_dk.columns = new_cols

# %%
week14_dk.to_csv('week14_dk_proj.csv', index = False)

# %%
week14_dk = pd.read_csv('week14_main_slate.csv')

def home_away(x):
    if '@' in x:
        return 'away'
    else:
        return 'home'

proj_df = week14_dk
cov_df = pd.read_csv('nfl_covariance_matrix.csv', index_col = 0)

#number of games in spreadsheet plus one
#num_of_games = 14


proj_df['matchup'] = tuple(zip(proj_df['team'], proj_df['opponent']))
#proj_df['salary'] = proj_df['salary'].apply(lambda x: x.replace('$',''))
#proj_df['salary'] = proj_df['salary'].apply(lambda x: float(x.replace('K', '')))
#proj_df['salary'] = proj_df['salary'].apply(lambda x: x * 1000)
proj_df['rank'] = proj_df.groupby(['team', 'position'])['points_avg'].rank(ascending = False, method = 'max')

proj_df['rank'].fillna(value = 9999, inplace = True)
proj_df['salary'].fillna(value = 9999, inplace = True)
proj_df['points_avg'].fillna(value = -9.999, inplace = True)
proj_df['rank'] = proj_df['rank'].apply(lambda x: str(int(x)))
proj_df['home_away'] = proj_df['opponent'].apply(lambda x: home_away(x))
proj_df['rank'] = proj_df['home_away'] + '_' + proj_df['position'] + proj_df['rank']

proj_df.to_csv('2016_week14_proj_process.csv')
proj_df.head()
# Out:
#    player_id             name  salary team opponent  points_avg  points_floor  \
# 0       1830      Trey Burton    2500  PHI      WAS         4.2           0.0
# 1       2797        Zach Ertz    4900  PHI      WAS        12.5           4.7
# 2       4972     Ryan Mathews    4000  PHI      WAS         7.3           2.0
# 3       4987  Jordan Matthews    5400  PHI      WAS        15.5           7.9
# 4       6948   Darren Sproles    4400  PHI      WAS        12.9           5.6
#
#    floor_pct  floor_pt_per_dpct  points_ceiling  ceiling_pct  consistency  \
# 0          1                  1             7.9           56           43
# 1         67                 67            19.0           96           75
# 2         35                 35            14.8           73           60
# 3         76                 76            27.5           97           45
# 4         63                 63            21.4           91           73
#
#   position  position_count  position_id positions  adj_ypa  event_team_id  \
# 0       TE               1          104    ['TE']      NaN       33560102
# 1       TE               1          104    ['TE']      NaN       33560102
# 2       RB               1          102    ['RB']      NaN       33560102
# 3       WR               1          103    ['WR']      NaN       33560102
# 4       RB               1          102    ['RB']      NaN       33560102
#
#    expected_sack_pct  Properties.ImpPts  Properties.InterceptionPct  \
# 0                  5               4.38                        2.51
# 1                  5               8.94                        2.51
# 2                  5               7.61                        2.51
# 3                  5              11.48                        2.51
# 4                  5               8.75                        2.51
#
#   Properties.IsProjected  Properties.MktShrPct  Properties.Month_FPOpp  \
# 0                   True                  40.0                     0.0
# 1                   True                  91.0                     0.0
# 2                   True                  71.0                     0.0
# 3                   True                  92.0                     0.0
# 4                   True                  77.0                     0.0
#
#    Properties.Month_FPSnap  Properties.OffensiveSnapsMarketShare  \
# 0                     0.19                                  20.4
# 1                     0.22                                  71.8
# 2                     0.60                                  23.0
# 3                     0.14                                  79.2
# 4                     0.40                                  46.6
#
#    Properties.OppPlusMinusPct  Properties.OpportunitiesRedZone  \
# 0                          92                             0.19
# 1                          92                             0.38
# 2                          50                             1.44
# 3                          23                             0.63
# 4                          34                             1.25
#
#    Properties.OpportunitiesRedZone10  Properties.OpportunitiesRedZone5  \
# 0                               0.06                              0.06
# 1                               0.19                              0.00
# 2                               1.13                              0.75
# 3                               0.31                              0.25
# 4                               0.31                              0.06
#
#    Properties.PassINTPct  Properties.PassSackPct  Properties.PassTDPct  \
# 0                    NaN                     NaN                   NaN
# 1                    NaN                     NaN                   NaN
# 2                    NaN                     NaN                   NaN
# 3                    NaN                     NaN                   NaN
# 4                    NaN                     NaN                   NaN
#
#    Properties.PassingAttemptsRBPct  Properties.PassingAttemptsTEPct  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    Properties.PassingAttemptsWRPct  Properties.PassingSuccessfulPct  \
# 0                              NaN                            44.72
# 1                              NaN                            44.72
# 2                              NaN                            44.72
# 3                              NaN                            44.72
# 4                              NaN                            44.72
#
#    Properties.Plus_Minus Properties.Position  Properties.PositionId  \
# 0                     53                  TE                    104
# 1                     95                  TE                    104
# 2                     65                  RB                    102
# 3                     80                  WR                    103
# 4                     85                  RB                    102
#
#    Properties.Pro_Pct  Properties.ProjPct  Properties.ProjPlaysPct  \
# 0                   1                  48                       45
# 1                  69                  92                       45
# 2                  15                  58                       45
# 3                  93                  87                       45
# 4                  74                  80                       45
#
#    Properties.ProjPlusMinusPct  Properties.PtPerDPct  \
# 0                           47                    52
# 1                           84                    81
# 2                           50                    53
# 3                           92                    89
# 4                           87                    88
#
#    Properties.ReceivingTargetsMarketShare  \
# 0                                     6.1
# 1                                    18.2
# 2                                     3.2
# 3                                    19.8
# 4                                    12.9
#
#    Properties.ReceivingTouchdownsMarketShare  \
# 0                                        5.6
# 1                                       16.7
# 2                                        5.6
# 3                                       38.9
# 4                                        5.6
#
#    Properties.ReceivingTouchdownsRedZonePct  \
# 0                                      33.3
# 1                                       0.0
# 2                                      33.3
# 3                                      60.0
# 4                                       0.0
#
#    Properties.ReceivingYardsMarketShare  Properties.RedZoneSnaps  \
# 0                                   5.3                     9.55
# 1                                  21.4                     9.55
# 2                                   2.9                     9.55
# 3                                  24.3                     9.55
# 4                                  11.5                     9.55
#
#    Properties.RedZoneSnaps10  Properties.RedZoneSnaps5  \
# 0                       5.44                      3.13
# 1                       5.44                      3.13
# 2                       5.44                      3.13
# 3                       5.44                      3.13
# 4                       5.44                      3.13
#
#    Properties.RedZoneTouchdownPct  Properties.RushingFantasyPct  \
# 0                           19.05                           NaN
# 1                           19.05                           NaN
# 2                           19.05                           NaN
# 3                           19.05                           NaN
# 4                           19.05                           NaN
#
#    Properties.RushingSuccessfulAllowedPct  Properties.RushingSuccessfulPct  \
# 0                                    50.5                              NaN
# 1                                    50.5                              NaN
# 2                                    50.5                             39.6
# 3                                    50.5                              0.0
# 4                                    50.5                             36.2
#
#    Properties.RushingSuccessfulPctRedZone  \
# 0                                     NaN
# 1                                     NaN
# 2                                    55.0
# 3                                     NaN
# 4                                    46.7
#
#    Properties.RushingTouchdownsMarketShare  \
# 0                                      0.0
# 1                                      0.0
# 2                                     47.1
# 3                                      0.0
# 4                                     17.6
#
#    Properties.RushingTouchdownsRedZonePct  Properties.RushingYardsMarketShare  \
# 0                                     NaN                                 0.0
# 1                                     NaN                                 0.0
# 2                                    25.0                                32.2
# 3                                     NaN                                 0.1
# 4                                    13.3                                25.2
#
#    Properties.SackPct  Properties.Salary  Properties.Salary_Movement  \
# 0                8.29               2500                          80
# 1                8.29               4900                           2
# 2                8.29               4000                          18
# 3                8.29               5400                          88
# 4                8.29               4400                          23
#
#    Properties.Score  Properties.Season_FPOpp  Properties.Season_FPSnap  \
# 0                53                      0.0                      0.26
# 1                95                      0.0                      0.21
# 2                65                      0.0                      0.51
# 3                53                      0.0                      0.25
# 4                85                      0.0                      0.35
#
#    Properties.Season_PPG  Properties.Season_PPG_Percentile  \
# 0                    4.2                                50
# 1                   12.2                                89
# 2                    9.3                                69
# 3                   14.6                                84
# 4                   11.1                                78
#
#    Properties.Season_Plus_Minus  Properties.Season_Salary_Change  \
# 0                          -0.3                                0
# 1                           5.7                              600
# 2                           0.6                            -1700
# 3                           2.4                            -1300
# 4                           3.2                              200
#
#    Properties.Season_X0  Properties.Season_X1  Properties.Season_X2  \
# 0                  50.0                  50.0                  25.0
# 1                  18.0                  81.0                  50.0
# 2                  33.0                  66.0                  33.0
# 3                  37.0                  62.0                  31.0
# 4                  25.0                  75.0                  37.0
#
#    Properties.Site_Salary  Properties.SourceId  Properties.TakeawayPct  \
# 0                      69                    4                    1.44
# 1                       4                    4                    1.44
# 2                       1                    4                    1.44
# 3                       9                    4                    1.44
# 4                      13                    4                    1.44
#
#   Properties.Team  Properties.TouchdownAllowedPct  Properties.Upside  \
# 0             PHI                            3.71                 43
# 1             PHI                            3.71                 86
# 2             PHI                            3.71                 58
# 3             PHI                            3.71                 53
# 4             PHI                            3.71                 62
#
#    Properties.Vegas  Properties.YardsPerPassingAttempt  Score     matchup  \
# 0                59                               7.15     53  (PHI, WAS)
# 1                59                               7.15     95  (PHI, WAS)
# 2                59                               7.15     65  (PHI, WAS)
# 3                59                               7.15     53  (PHI, WAS)
# 4                59                               7.15     85  (PHI, WAS)
#
#        rank home_away
# 0  home_TE2      home
# 1  home_TE1      home
# 2  home_RB2      home
# 3  home_WR1      home
# 4  home_RB1      home

# %%
players = list(proj_df['name'].values)
salary = list(proj_df['salary'].values)
points = list(proj_df['points_avg'].values)
position = list(proj_df['position'].values)

player_dict = dict((z[0], list(z[1:])) for z in zip(players, salary, points, position))

# %%
away_teams = proj_df['team'].loc[proj_df['home_away'] == 'away'].unique()

print(away_teams)

player_cols = []
count = 0

for team in away_teams:
    temp1 = proj_df.loc[proj_df['team'] == team]
    temp2 = proj_df.loc[proj_df['opponent'] == team]
    temp_df = pd.concat([temp1, temp2], axis = 0)
    
    cols = cov_df.columns

    player_ls = []
    for c in cols:
        player = pd.DataFrame(temp_df.loc[temp_df['rank'] == c])
        
        if len(player) < 1:
            name = 'Not Available_' + str(count)
            count += 1
        else:
            name = player.iloc[0]['name']
        player_ls.append(name)
        
    player_cols.extend(player_ls)
    

arr_cov = np.asarray(cov_df)
for i in range(1, 15):
    arr_new = np.asarray(cov_df)
    arr_cov = linalg.block_diag(arr_cov, arr_new)
    
comp_cov_df = pd.DataFrame(data = arr_cov, index = player_cols, columns = player_cols)
comp_cov_df.head()
# Out:
# ['DEN' 'NO' 'NYJ' 'LA' 'WAS' 'DAL' 'ARI' 'ATL' 'MIN' 'HOU' 'SEA' 'CHI'
#  'CIN' 'SD' 'PIT']
#                    Tennessee Defense  Marcus Mariota  DeMarco Murray  \
# Tennessee Defense               1.00           -0.08            0.11
# Marcus Mariota                 -0.08            1.00            0.08
# DeMarco Murray                  0.11            0.08            1.00
# Derrick Henry                   0.03            0.06           -0.13
# Delanie Walker                 -0.08            0.33           -0.06
#
#                    Derrick Henry  Delanie Walker  Rishard Matthews  \
# Tennessee Defense           0.03           -0.08              0.01
# Marcus Mariota              0.06            0.33              0.46
# DeMarco Murray             -0.13           -0.06              0.03
# Derrick Henry               1.00            0.04             -0.03
# Delanie Walker              0.04            1.00             -0.04
#
#                    Tajae Sharpe  Kendall Wright  Denver Defense  \
# Tennessee Defense          0.00           -0.09           -0.24
# Marcus Mariota             0.33            0.28           -0.41
# DeMarco Murray            -0.03           -0.07           -0.25
# Derrick Henry             -0.07            0.00           -0.13
# Delanie Walker            -0.06            0.00           -0.09
#
#                    Trevor Siemian  Devontae Booker  Not Available_0  \
# Tennessee Defense           -0.41            -0.25            -0.13
# Marcus Mariota               0.20             0.03            -0.01
# DeMarco Murray               0.03            -0.01            -0.06
# Derrick Henry               -0.01            -0.06            -0.05
# Delanie Walker               0.09             0.03             0.00
#
#                    A.J. Derby  Not Available_1  Emmanuel Sanders  \
# Tennessee Defense       -0.09            -0.18             -0.12
# Marcus Mariota           0.09             0.09              0.07
# DeMarco Murray           0.03             0.00              0.01
# Derrick Henry            0.00            -0.02             -0.03
# Delanie Walker           0.04             0.02              0.04
#
#                    Jordan Taylor  Tampa Bay Defense  Jameis Winston  \
# Tennessee Defense          -0.05                0.0             0.0
# Marcus Mariota              0.13                0.0             0.0
# DeMarco Murray              0.03                0.0             0.0
# Derrick Henry               0.00                0.0             0.0
# Delanie Walker              0.03                0.0             0.0
#
#                    Doug Martin  Jacquizz Rodgers  Cameron Brate  Mike Evans  \
# Tennessee Defense          0.0               0.0            0.0         0.0
# Marcus Mariota             0.0               0.0            0.0         0.0
# DeMarco Murray             0.0               0.0            0.0         0.0
# Derrick Henry              0.0               0.0            0.0         0.0
# Delanie Walker             0.0               0.0            0.0         0.0
#
#                    Freddie Martino  Russell Shepard  New Orleans Defense  \
# Tennessee Defense              0.0              0.0                  0.0
# Marcus Mariota                 0.0              0.0                  0.0
# DeMarco Murray                 0.0              0.0                  0.0
# Derrick Henry                  0.0              0.0                  0.0
# Delanie Walker                 0.0              0.0                  0.0
#
#                    Drew Brees  Mark Ingram  Tim Hightower  Coby Fleener  \
# Marcus Mariota                 0.0           0.0           0.0
# DeMarco Murray                 0.0           0.0           0.0
# Derrick Henry                  0.0           0.0           0.0
# Delanie Walker                 0.0           0.0           0.0
#
#                    Mike Gillislee  Charles Clay  Sammy Watkins  Robert Woods  \
# Tennessee Defense             0.0           0.0            0.0           0.0
# Marcus Mariota                0.0           0.0            0.0           0.0
# DeMarco Murray                0.0           0.0            0.0           0.0
# Derrick Henry                 0.0           0.0            0.0           0.0
# Delanie Walker                0.0           0.0            0.0           0.0
#
#                    Marquise Goodwin  Pittsburgh Defense  Ben Roethlisberger  \
# Tennessee Defense               0.0                 0.0                 0.0
# Marcus Mariota                  0.0                 0.0                 0.0
# DeMarco Murray                  0.0                 0.0                 0.0
# Derrick Henry                   0.0                 0.0                 0.0
# Delanie Walker                  0.0                 0.0                 0.0
#
#                    Le'Veon Bell  DeAngelo Williams  Ladarius Green  \
# Tennessee Defense           0.0                0.0             0.0
# Marcus Mariota              0.0                0.0             0.0
# DeMarco Murray              0.0                0.0             0.0
# Derrick Henry               0.0                0.0             0.0
# Delanie Walker              0.0                0.0             0.0
#
#                    Antonio Brown  Eli Rogers  Cobi Hamilton
# Tennessee Defense            0.0         0.0            0.0
# Marcus Mariota               0.0         0.0            0.0
# DeMarco Murray               0.0         0.0            0.0
# Derrick Henry                0.0         0.0            0.0
# Delanie Walker               0.0         0.0            0.0
#
# [5 rows x 240 columns]

# %%
position_std = {'QB': 8.096014, 'WR': 9.813933, 'RB': 8.702397, 'TE': 8.096014, 'D': 6.09265}
position_mu = {'QB': 19.861207, 'WR': 12.67457, 'RB': 12.900904, 'TE': 12.50152, 'D': 7.447265}

# %%
main_slate = pd.read_csv('week14_main_slate.csv')


players = list(main_slate['name'].values)
salary = list(main_slate['salary'].values)
points = list(main_slate['points_avg'].values)
position = list(main_slate['position'].values)

player_dict = dict((z[0], list(z[1:])) for z in zip(players, salary, points, position))

# %%
# Set position lists
qbs = []
wrs = []
rbs = []
tes = []
dsts = []
flexs = [] 

for player, ls in player_dict.items():
    if ls[2] == 'QB':
        if ls[1] > 15:
            qbs.append(player)
    if ls[2] == 'WR':
        if ls[1] > 7:
            wrs.append(player)
    if ls[2] == 'RB':
        if ls[1] > 8:
            rbs.append(player)
    if ls[2] == 'TE':
        if ls[1] > 7:
            tes.append(player)
    if ls[2] == 'D':
        if ls[1] > 4:
            dsts.append(player)
    if ls[2] == 'WR' or ls[2] == 'TE' or ls[2] == 'WR':
        if ls[1] > 8:
            flexs.append(player)

# %%
#select random starting team

def create_first_team(mydict, **kwargs):
    while True:
        qb = qbs[randint(0,len(qbs) - 1)]
        wr1 = wrs[randint(0,len(wrs) - 1)]
        wr2 = wrs[randint(0,len(wrs) - 1)]
        wr3 = wrs[randint(0,len(wrs) - 1)]
        rb1 = rbs[randint(0,len(rbs) - 1)]
        rb2 = rbs[randint(0,len(rbs) - 1)]
        te = tes[randint(0,len(tes) - 1)]
        d = dsts[randint(0,len(dsts) - 1)]
        flex = flexs[randint(0,len(flexs) - 1)]

        player_list =  [qb, rb1, rb2, wr1, wr2, wr3, te, flex, d]
            
        team_salary = 0

        for player in player_list:
            team_salary += player_dict[player][0]

        duplicates = Counter(player_list)

        if team_salary <= 50000 and team_salary >= 47000 and sum(duplicates.values()) == 9:
            for key, value in mydict.items():
                if key == 'QB':
                    z = 0
                elif key == 'RB1':
                    z = 1
                elif key == 'RB2':
                    z = 2
                elif key == 'WR1': 
                    z = 3
                elif key == 'WR2':
                    z = 4
                elif key == 'WR3':
                    z = 5
                elif key == 'TE':
                    z = 6
                elif key == 'FLEX':
                    z = 7
                elif key == 'DST' or key == 'D' or key == 'DEF':
                    z = 8
                else:
                    print('Waaat')

                player_list[z] = value
            break
                
    return player_list

# %%
#Simulated annealing
def update_temp(i, t):
    temp = t / log(i)
    return temp

def cost(ls):
    qb = ls[0]
    rb1 = ls[1]
    rb2 = ls[2]
    wr1 = ls[3]
    wr2 = ls[4]
    wr3 = ls[5]
    te = ls[6]
    flex = ls[7]
    dst = ls[8]
    flex_pos = player_dict[flex][2]
    
    qb_mu = player_dict[qb][1]
    wr1_mu = player_dict[wr1][1]
    wr2_mu = player_dict[wr2][1]
    wr3_mu = player_dict[wr3][1]
    rb1_mu = player_dict[rb1][1]
    rb2_mu = player_dict[rb2][1]
    te_mu = player_dict[te][1]
    dst_mu = player_dict[dst][1]
    flex_mu = player_dict[flex][1]
    
    qb_std = position_std['QB']
    wr_std = position_std['WR']
    rb_std = position_std['RB']
    te_std = position_std['TE']
    dst_std = position_std['D']
    
    if flex_pos == 'WR':
        flex_std = wr_std
    elif flex_pos == 'RB':
        flex_std = rb_std
    elif flex_pos == 'TE':
        flex_std = te_std
    else:
        print('Waat')
        
    #create covariance matrix
    corr_array = []
    
    
    for player1 in ls:
        temp_ls = []
        for player2 in ls:
            try:
                corr = comp_cov_df[player1][player2]
            except:
                corr = 0
            temp_ls.append(corr)
            
        corr_array.append(temp_ls)
        
    corr_matrix = np.array(corr_array)
    cov_matrix = stats.corr2cov(corr_matrix, [qb_std, wr_std, wr_std, wr_std, rb_std, rb_std, te_std,
                                             dst_std, flex_std])
    cov_sum = 0
    
    for i in range(9):
        for x in range(9):
            if i > x:
                cov_sum += cov_matrix[x,i]
    
    #Calculate team variance
    
    team_var = (qb_std ** 2 + wr_std ** 2 + wr_std ** 2 + wr_std ** 2 + rb_std ** 2 + rb_std ** 2 +
                te_std ** 2 + dst_std ** 2 + flex_std ** 2 + 2 * cov_sum)
    
    team_mu = qb_mu + wr1_mu + wr2_mu + wr3_mu + rb1_mu + rb2_mu + te_mu + dst_mu + flex_mu
    
    team_ppf = scipy.stats.norm(team_mu, np.sqrt(team_var)).ppf(.95)
    
    return team_ppf

def random_except(length, except_ls):
    while True:
        r = randint(0, length - 1 )
        if r not in except_ls:
            return r
            break

    
    
def create_team(ls, except_ls, player_except):
    counter = 0
    while True:
        temp_best = ls[:]
        r = random_except(len(temp_best), except_ls)

        if r == 0:
            new_player = qbs[randint(0,len(qbs) - 1)]
        elif r > 0 and r <= 2:
            new_player = rbs[randint(0, len(rbs) - 1)]
        elif r > 2 and r <= 5:
            new_player = wrs[randint(0, len(wrs) - 1)]
        elif r == 6:
            new_player = tes[randint(0, len(tes) - 1)]
        elif r == 7:
            new_player = flexs[randint(0, len(flexs) - 1)]
        elif r == 8:
            new_player = dsts[randint(0, len(dsts) - 1)]
        else:
            print('Waaat')

        temp_best[r] = new_player

        team_salary = 0

        for player in temp_best:
            team_salary += player_dict[player][0]

        duplicates = Counter(temp_best)

        if team_salary <= 50000 and team_salary >= 47000 and len(duplicates.values()) == 9:
                break
                
        counter += 1
        
        if counter > 1000:
            temp_best = create_first_team(player_except)
            break
            
    return temp_best

final_teams = []


except_ls = []
player_except = {}

for z in tqdm(range(100)):
    player_list = create_first_team(player_except)

    max_iters = 2000
    best_team = player_list[:]
    current_best = player_list[:]
    temp = 100
    temp_change = .995
    ppf_list = []
    temp_ls = []
    count = 0

    for i in range(max_iters):
        new_team = create_team(current_best, except_ls, player_except)   

        cost_new = cost(new_team)
        cost_curr = cost(current_best)

        if cost_new > cost_curr:
            current_best = new_team[:]
            ppf_list.append([i, cost_new])
        else:
            temp = temp * temp_change
            if temp < 0:
                temp = 100 - count
                if count < 100:
                    count += 7
            r = randint(1,120)

            if r < temp:
                temp_ls.append([r, temp])
                current_best = new_team[:]
                ppf_list.append([i, cost_new])

    pff_current = cost(current_best)
    current_best.append(pff_current)
    final_teams.append(current_best)
    print(current_best)


final_df = pd.DataFrame(columns = ['QB', 'RB', 'RB', 'WR', 'WR', 'WR', 'TE', 'FLEX', 'DST', 'PPF'])


for a, team in enumerate(final_teams):
    final_df.loc[a] = final_teams[a]

#title_name = 'final_df' + str(k + 4) + '.csv'  
#final_df.sort_values('PPF', ascending = False, inplace = True)
#final_df.to_csv(title_name)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-3e5fc7295d51> in <module>()
#     148         new_team = create_team(current_best, except_ls, player_except)
#     149
# --> 150         cost_new = cost(new_team)
#     151         cost_curr = cost(current_best)
#     152
#
# <ipython-input-30-3e5fc7295d51> in cost(ls)
#      56         corr_array.append(temp_ls)
#      57
# ---> 58     corr_matrix = np.array(corr_array)
#      59     cov_matrix = stats.corr2cov(corr_matrix, [qb_std, wr_std, wr_std, wr_std, rb_std, rb_std, te_std,
#      60                                              dst_std, flex_std])
#
# ValueError: setting an array element with a sequence.

# %%
final_df = pd.DataFrame(columns = ['QB', 'RB1', 'RB2', 'WR1', 'WR2', 'WR3', 'TE', 'FLEX', 'DST', 'PPF'])


for i, team in enumerate(final_teams):
    final_df.loc[i] = final_teams[i]
    
#final_df.to_pickle('week5_ppf_lineups.p')

# %%
final_df.sort_values('PPF', ascending = False, inplace = True)
#final_df.to_csv('final_carr_amari.csv')
final_df.head(15)
# Out:
#                   QB              RB1            RB2               WR1  \
# 23        Alex Smith    Melvin Gordon   Le'Veon Bell      Mohamed Sanu
# 84        Alex Smith     Le'Veon Bell  Melvin Gordon      Mohamed Sanu
