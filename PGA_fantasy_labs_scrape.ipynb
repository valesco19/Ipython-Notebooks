# %%
import json
import os
import glob
import pandas as pd
import requests
import time
from datetime import datetime, timedelta
from random import randint
from pga.return_pid import return_pid
from sqlalchemy import create_engine
from pandas.io import sql
from tqdm import tqdm

# %%
url = 'http://www.fantasylabs.com/api/playermodel/5/1_20_2014/?modelId=313179'
http://www.fantasylabs.com/api/sourcedata/3/6_22_2016

# %%
#data = json.loads(data.text)
os.path.isfile('/home/valesco/Datasets/PGA_Data/fantasylabs_data/salary_data/6_28_2017_salary_data.json')
# Out:
# False

# %%
#http://www.fantasylabs.com/api/playermodel/5/2_2_2015/?modelId=313179

now = datetime.now()
final_dict = {}
final_dict['salary'] = {}
final_dict['events'] = {}
final_dict['ownership'] = {}

for i in tqdm(range(360)):
    try:
        date_str = (now - timedelta(i)).strftime('%-m_%-d_%Y')

        sal_url = 'http://www.fantasylabs.com/api/playermodel/5/{}/?modelId=313179'.format(date_str) 

        sal_resp = requests.get(sal_url)
        sal_data = json.loads(sal_resp.text)



        if len(sal_data['PlayerModels']) > 0:      
            sal_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/salary_data/{}_salary_data.json'.format(date_str)

            if os.path.isfile(sal_file_name) is False:

                final_dict['salary'][date_str] = sal_data
                with open(sal_file_name, 'w') as outfile:
                    json.dump(sal_data, outfile)

                print(date_str + ' salary file saved!')
    except:
        pass

        wait = .5
        time.sleep(wait)

        event_url = 'http://www.fantasylabs.com/api/sportevents/5/{}'.format(date_str)

        event_resp = requests.get(event_url)
        event_data = json.loads(event_resp.text)


    try:
        if len(event_data) > 0:
            event_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/sportevent_data/{}_sportevent_data.json'.format(date_str)

            if os.path.isfile(event_file_name) is False:

                final_dict['events'][date_str] = event_data

                with open(event_file_name, 'w') as outfile:
                    json.dump(event_data, outfile)

                    print(date_str + ' sportevents file saved')

        time.sleep(wait)
    except:
        pass
        own_url = url = 'http://www.fantasylabs.com/api/contest-ownership/5/{}/4'.format(date_str) 

        own_resp = requests.get(own_url)
        own_data = json.loads(own_resp.text)

    try:
        if len(own_data) > 0:
            own_file_name = '/home/valesco/Datasets/PGA_Data/fantasylabs_data/ownership_data/{}_ownership_data.json'.format(date_str)

            if os.path.isfile(own_file_name) is False:

                final_dict['ownership'][date_str] = own_data

                with open(own_file_name, 'w') as outfile:
                    json.dump(own_data, outfile)

                    print(date_str + ' ownership file saved')
    except:
        pass
# Out:
#  17%|█▋        | 62/360 [01:32<07:22,  1.48s/it]
# 1_21_2018 salary file saved!
#  19%|█▉        | 69/360 [01:43<07:46,  1.60s/it]
# 1_14_2018 salary file saved!
#  21%|██        | 76/360 [01:55<07:43,  1.63s/it]
# 1_7_2018 salary file saved!
#  29%|██▉       | 104/360 [02:39<06:39,  1.56s/it]
# 12_10_2017 salary file saved!
#  31%|███       | 111/360 [02:50<06:17,  1.52s/it]
# 12_3_2017 salary file saved!
#  33%|███▎      | 118/360 [03:01<05:51,  1.45s/it]
# 11_26_2017 salary file saved!
#  35%|███▍      | 125/360 [03:13<06:21,  1.62s/it]
# 11_19_2017 salary file saved!
#  37%|███▋      | 132/360 [03:26<06:47,  1.79s/it]
# 11_12_2017 salary file saved!
#  39%|███▊      | 139/360 [03:39<06:17,  1.71s/it]
# 11_5_2017 salary file saved!
#  41%|████      | 146/360 [03:55<07:44,  2.17s/it]
# 10_29_2017 salary file saved!
#  42%|████▎     | 153/360 [04:08<06:26,  1.87s/it]
# 10_22_2017 salary file saved!
#  44%|████▍     | 160/360 [04:17<04:12,  1.26s/it]
# 10_15_2017 salary file saved!
#  46%|████▋     | 167/360 [04:28<04:51,  1.51s/it]
# 10_8_2017 salary file saved!
#  48%|████▊     | 174/360 [04:40<04:55,  1.59s/it]
# 10_1_2017 salary file saved!
#  50%|█████     | 181/360 [04:50<04:14,  1.42s/it]
# 9_24_2017 salary file saved!
#  52%|█████▏    | 188/360 [05:01<03:56,  1.38s/it]
# 9_17_2017 salary file saved!
#  54%|█████▍    | 195/360 [05:11<03:38,  1.33s/it]
# 9_10_2017 salary file saved!
#  56%|█████▌    | 202/360 [05:20<03:24,  1.30s/it]
# 9_3_2017 salary file saved!
#  58%|█████▊    | 209/360 [05:31<03:31,  1.40s/it]
# 8_27_2017 salary file saved!
#  60%|██████    | 216/360 [05:42<03:26,  1.43s/it]
# 8_20_2017 salary file saved!
#  62%|██████▏   | 223/360 [05:53<03:22,  1.48s/it]
# 8_13_2017 salary file saved!
#  64%|██████▍   | 230/360 [06:02<02:42,  1.25s/it]
# 8_6_2017 salary file saved!
#  66%|██████▌   | 237/360 [06:13<02:47,  1.36s/it]
# 7_30_2017 salary file saved!
# 100%|██████████| 360/360 [09:27<00:00,  1.74s/it]

# %%
sal_keys = final_dict['salary'].keys()


pga_salary = pd.DataFrame(columns = ['player_name', 'player_id', 'date_obj', 'event_id', 'tournament_name', 
                        'tourny_date', 'tourny_course', 'tour', 'salary', 'actual_points', 'imp_points', 
                        'proj_points', 'score', 'plus_minus', 'injury_status', 'source'])
count = 0

for sal_key in sal_keys:
    
    date_obj = datetime.strptime(sal_key, '%m_%d_%Y')

    for player in final_dict['salary'][sal_key]['PlayerModels']:
        switch = 0
        player_name = player['Properties']['Player_Name']
        player_id = return_pid(player_name)
        salary = player['Properties']['Salary']
        actual_points = player['Properties']['ActualPoints']
        imp_points = player['Properties']['ImpPts']
        proj_points = player['ProjPoints'] 
        score = player['Properties']['Score']
        injury_status = player['Properties']['InjuryStatus']
        plus_minus = player['Properties']['Plus_Minus']
        source = player['Properties']['SourceId']
        
        if source == 4:
            tourny_id = player['Properties']['EventId']
            
            for event in final_dict['events'][sal_key]:
                if event['EventId'] == tourny_id:
                    tourny_name = event['HomeTeam']
                    tourny_date = event['EventDate']
                    tourny_course = event['StadiumName']
                    tour = event['VisitorTeam']
                    switch = 1
                    
            if switch == 0:
                print('SWITCH ENGAGED!!!', tourny_name, tourny_date, file)
                tourny_name = np.nan
                tourny_date = np.nan
                tourny_course = np.nan
                tour = np.nan
            
            pga_salary.loc[count] = [player_name, player_id, date_obj, tourny_id, tourny_name,
                                     tourny_date, tourny_course, tour,
                                     salary, actual_points, imp_points, proj_points,
                                     score, plus_minus, injury_status, source]

            count += 1

tournaments = pga_salary['tournament_name'].unique()            
year = pd.to_datetime(pga_salary['tourny_date'].loc[0]).year

engine = create_engine('mysql+pymysql://root:v1933@127.0.0.1:3306/pga?charset=utf8')
conn = engine.connect()

for tournament in tournaments:
    temp_results = conn.execute('SELECT * FROM pga.dk_salaries WHERE tournament_name = "{}" AND \
            YEAR(tourny_date) = {}'.format(tournament, year))
    
    temp_ls = []
    
    for result in temp_results:
        temp_ls.append(result)
        
    if len(temp_ls) < 1:
        pga_salary.loc[pga_salary['tournament_name'] == tournament].to_sql('dk_salaries', engine,
                        if_exists = 'append', index = False)

# %%
date_str = '5_7_2017'
event_url = 'http://www.fantasylabs.com/api/sportevents/5/{}'.format(date_str)
    
event_resp = requests.get(event_url)
event_data = json.loads(event_resp.text)

# %%
for event in event_data:
    if event['VisitorTeam'] == 'PGA':
        print(event['HomeTeam'])
# Out:
# Wells Fargo Championship

# %%
engine = create_engine('mysql+pymysql://root:v1933@127.0.0.1:3306/pga?charset=utf8')
conn = engine.connect()
pga_salaries = conn.execute('SELECT * FROM pga.dk_salaries WHERE tournament_name = "Phoenix Open" AND \
            YEAR(tourny_date) = 2017')

# %%
result_ls = []

for result in pga_salaries:
    result_ls.append(result)
    
print(len(result_ls))
# Out:
# 126

# %%
os.chdir('/home/valesco/Datasets/PGA_Data/fantasylabs_data/sportevent_data/')

for day in range(31):
    for month in range(1,13):
        for year in ['2017']:
            date_str = str(month + 1) + '_' + str(day + 1) + '_' + year 
            
            url = 'http://www.fantasylabs.com/api/sportevents/5/{}'.format(date_str) 
            
            resp = requests.get(url)
            data = json.loads(resp.text)
            
            if len(data) > 0:      
                file_name = date_str + '_sportevent_data.json'

                with open(file_name, 'w') as outfile:
                    json.dump(data, outfile)

                print(date_str + ' filed saved!')
     
            wait = .5
            time.sleep(wait)
# Out:
# 10_1_2017 filed saved!
# 4_2_2017 filed saved!
# 7_2_2017 filed saved!
# 9_3_2017 filed saved!
# 12_3_2017 filed saved!
# 6_4_2017 filed saved!
# 2_5_2017 filed saved!
# 3_5_2017 filed saved!
# 11_5_2017 filed saved!
# 8_6_2017 filed saved!
# 5_7_2017 filed saved!
# 10_8_2017 filed saved!
# 4_9_2017 filed saved!
# 7_9_2017 filed saved!
# 9_10_2017 filed saved!
# 12_10_2017 filed saved!
# 6_11_2017 filed saved!
# 2_12_2017 filed saved!
# 3_12_2017 filed saved!
# 11_12_2017 filed saved!
# 8_13_2017 filed saved!
# 5_14_2017 filed saved!
# 10_15_2017 filed saved!
# 4_16_2017 filed saved!
# 7_16_2017 filed saved!
# 9_17_2017 filed saved!
# 6_18_2017 filed saved!
# 2_19_2017 filed saved!
# 3_19_2017 filed saved!
# 11_19_2017 filed saved!
# 8_20_2017 filed saved!
# 5_21_2017 filed saved!
# 10_22_2017 filed saved!
# 4_23_2017 filed saved!
# 7_23_2017 filed saved!
# 9_24_2017 filed saved!
# 6_25_2017 filed saved!
# 2_26_2017 filed saved!
# 3_26_2017 filed saved!
# 11_26_2017 filed saved!
# 8_27_2017 filed saved!
# 5_28_2017 filed saved!
# 10_29_2017 filed saved!
# 4_30_2017 filed saved!
# 7_30_2017 filed saved!

# %%
os.chdir('/home/valesco/Datasets/NFL_projs/betting_data/')

for day in range(6):
    for month in range(1,2):
        for year in range(9,17):
            if len(str(year)) == 1:
                year = '200' + str(year)
            else:
                year = '20' + str(year)
                
            date_str = str(month + 1) + '-' + str(day + 1) + '-' + year 
            
            url = 'http://www.fantasylabs.com/api/sportevents/1/' + date_str + '/vegas/'
            
            resp = requests.get(url)
            data = json.loads(resp.text)
            
            if len(data) > 0:      
                file_name = date_str + '_nfl_betting_data.json'

                with open(file_name, 'w') as outfile:
                    json.dump(data, outfile)

                print(date_str + ' filed saved!')
     
            time.sleep(1)
# Out:
# 2-1-2011 filed saved!
# 2-1-2012 filed saved!
# 2-1-2013 filed saved!
# 2-1-2014 filed saved!
# 2-1-2015 filed saved!
# 2-1-2016 filed saved!
# 2-2-2011 filed saved!
# 2-2-2012 filed saved!
# 2-2-2013 filed saved!
# 2-2-2014 filed saved!
# 2-2-2015 filed saved!
# 2-2-2016 filed saved!
# 2-3-2011 filed saved!
# 2-3-2012 filed saved!
# 2-3-2013 filed saved!
# 2-3-2014 filed saved!
# 2-3-2015 filed saved!
# 2-3-2016 filed saved!
# 2-4-2011 filed saved!
# 2-4-2012 filed saved!
# 2-4-2013 filed saved!
# 2-4-2014 filed saved!
# 2-4-2016 filed saved!
# 2-5-2011 filed saved!
# 2-5-2012 filed saved!
# 2-5-2013 filed saved!
# 2-5-2016 filed saved!
# 2-6-2011 filed saved!
# 2-6-2012 filed saved!
# 2-6-2016 filed saved!

# %%
os.chdir('/home/valesco/Datasets/MLB_Data/lineup_data/')

for day in range(31):
    for month in range(3,9):
        for year in ['2011','2012','2013', '2014', '2015', '2016']:
            date_str = str(month + 1) + '_' + str(day + 1) + '_' + year 
            
            url = 'http://www.fantasylabs.com/api/lineuptracker/3/' + date_str 
            
            resp = requests.get(url)
            data = json.loads(resp.text)
            
            if len(data) > 0:      
                file_name = date_str + '_mlb_lineup_data.json'

                with open(file_name, 'w') as outfile:
                    json.dump(data, outfile)

                print(date_str + ' filed saved!')
     
            wait = randint(0,3)
            time.sleep(wait)
# Out:
# 4_1_2013 filed saved!
# 4_1_2014 filed saved!
# 5_1_2012 filed saved!
# 5_1_2013 filed saved!
# 5_1_2014 filed saved!
# 5_1_2015 filed saved!
# 5_1_2016 filed saved!
# 6_1_2012 filed saved!
# 6_1_2013 filed saved!
# 6_1_2014 filed saved!
# 6_1_2015 filed saved!
# 6_1_2016 filed saved!
# 7_1_2012 filed saved!
# 7_1_2013 filed saved!
# 7_1_2014 filed saved!
# 7_1_2015 filed saved!
# 7_1_2016 filed saved!
# 8_1_2011 filed saved!
# 8_1_2012 filed saved!
# 8_1_2013 filed saved!
# 8_1_2014 filed saved!
# 8_1_2015 filed saved!
# 8_1_2016 filed saved!
# 9_1_2011 filed saved!
# 9_1_2012 filed saved!
# 9_1_2013 filed saved!
# 9_1_2014 filed saved!
# 9_1_2015 filed saved!
# 9_1_2016 filed saved!
# 4_2_2013 filed saved!
# 4_2_2014 filed saved!
# 5_2_2012 filed saved!
# 5_2_2013 filed saved!
# 5_2_2014 filed saved!
# 5_2_2015 filed saved!
# 5_2_2016 filed saved!
# 6_2_2012 filed saved!
# 4_12_2013 filed saved!
# 4_12_2014 filed saved!
# 4_12_2015 filed saved!
# 4_12_2016 filed saved!
# 5_12_2012 filed saved!
# 5_12_2013 filed saved!
# 5_12_2014 filed saved!
# 5_12_2015 filed saved!
# 5_12_2016 filed saved!
# 6_12_2012 filed saved!
# 6_12_2013 filed saved!
# 6_12_2014 filed saved!
# 6_12_2015 filed saved!
# 6_12_2016 filed saved!
# 7_12_2013 filed saved!
# 7_12_2014 filed saved!
# 7_12_2015 filed saved!
# 8_12_2011 filed saved!
# 8_12_2012 filed saved!
# 8_12_2013 filed saved!
# 8_12_2014 filed saved!
# 8_12_2015 filed saved!
# 8_12_2016 filed saved!
# 9_12_2011 filed saved!
# 9_12_2012 filed saved!
# 9_12_2013 filed saved!
# 9_12_2014 filed saved!
# 9_12_2015 filed saved!
# 9_12_2016 filed saved!
# 4_13_2012 filed saved!
# 4_13_2013 filed saved!
# 4_13_2014 filed saved!
# 4_13_2015 filed saved!
# 4_13_2016 filed saved!
# 5_13_2012 filed saved!
# 5_13_2013 filed saved!
# 5_13_2014 filed saved!
# 5_13_2015 filed saved!
# 5_13_2016 filed saved!
# 6_13_2012 filed saved!
# 6_13_2013 filed saved!
# 6_13_2014 filed saved!
# 6_13_2015 filed saved!
# 6_13_2016 filed saved!
# 7_13_2012 filed saved!
# 7_13_2013 filed saved!
# 7_13_2014 filed saved!
# 8_13_2011 filed saved!
# 8_13_2012 filed saved!
# 8_13_2013 filed saved!
# 8_13_2014 filed saved!
# 8_13_2015 filed saved!
# 8_13_2016 filed saved!
# 9_13_2011 filed saved!
# 9_13_2012 filed saved!
# 9_13_2013 filed saved!
# 9_13_2014 filed saved!
# 9_13_2015 filed saved!
# 9_13_2016 filed saved!
# 4_14_2012 filed saved!
# 4_14_2013 filed saved!
# 4_14_2014 filed saved!
# 4_14_2015 filed saved!
# 4_14_2016 filed saved!
# 5_14_2012 filed saved!
# 5_14_2013 filed saved!
# 5_14_2014 filed saved!
# 5_14_2015 filed saved!
# 5_14_2016 filed saved!
# 6_14_2012 filed saved!
# 6_14_2013 filed saved!
# 6_14_2014 filed saved!
# 6_14_2015 filed saved!
# 6_14_2016 filed saved!
# 7_14_2011 filed saved!
# 7_14_2012 filed saved!
# 7_14_2013 filed saved!
# 7_14_2015 filed saved!
# 8_14_2011 filed saved!
# 8_14_2012 filed saved!
# 8_14_2013 filed saved!
# 8_14_2014 filed saved!
# 8_14_2015 filed saved!
# 8_14_2016 filed saved!
# 9_14_2011 filed saved!
# 9_14_2012 filed saved!
# 9_14_2013 filed saved!
# 9_14_2014 filed saved!
# 9_14_2015 filed saved!
# 9_14_2016 filed saved!
# 4_15_2012 filed saved!
# 4_15_2013 filed saved!
# 4_15_2014 filed saved!
# 4_15_2015 filed saved!
# 4_15_2016 filed saved!
# 5_15_2012 filed saved!
# 5_15_2013 filed saved!
# 5_15_2014 filed saved!
# 5_15_2015 filed saved!
# 5_15_2016 filed saved!
# 6_15_2012 filed saved!
# 6_15_2013 filed saved!
# 6_15_2014 filed saved!
# 6_15_2015 filed saved!
# 6_15_2016 filed saved!
# 7_15_2011 filed saved!
# 7_15_2012 filed saved!
# 7_15_2016 filed saved!
# 8_15_2011 filed saved!
# 8_15_2012 filed saved!
# 8_15_2013 filed saved!
# 8_15_2014 filed saved!
# 8_15_2015 filed saved!
# 8_15_2016 filed saved!
# 9_15_2011 filed saved!
# 9_15_2012 filed saved!
# 9_15_2013 filed saved!
# 9_15_2014 filed saved!
# 9_15_2015 filed saved!
# 9_15_2016 filed saved!
# 4_16_2012 filed saved!
# 4_16_2013 filed saved!
# 4_16_2014 filed saved!
# 4_16_2015 filed saved!
# 4_16_2016 filed saved!
# 5_16_2012 filed saved!
# 5_16_2013 filed saved!
# 5_16_2014 filed saved!
# 5_16_2015 filed saved!
# 5_16_2016 filed saved!
# 6_16_2012 filed saved!
# 6_16_2013 filed saved!
# 6_16_2014 filed saved!
# 6_16_2015 filed saved!
# 6_16_2016 filed saved!
# 7_16_2011 filed saved!
# 7_16_2012 filed saved!
# 7_16_2016 filed saved!
# 8_16_2011 filed saved!
# 8_16_2012 filed saved!
# 8_16_2013 filed saved!
# 8_16_2014 filed saved!
# 8_16_2015 filed saved!
# 8_16_2016 filed saved!
# 9_16_2011 filed saved!
# 9_16_2012 filed saved!
# 9_16_2013 filed saved!
# 9_16_2014 filed saved!
# 9_16_2015 filed saved!
# 9_16_2016 filed saved!
# 4_17_2012 filed saved!
# 4_17_2013 filed saved!
# 4_17_2014 filed saved!
# 4_17_2015 filed saved!
# 4_17_2016 filed saved!
# 5_17_2012 filed saved!
# 5_17_2013 filed saved!
# 5_17_2014 filed saved!
# 5_17_2015 filed saved!
# 5_17_2016 filed saved!
# 6_17_2012 filed saved!
# 6_17_2013 filed saved!
# 6_17_2014 filed saved!
# 6_17_2015 filed saved!
# 6_17_2016 filed saved!
# 7_17_2011 filed saved!
# 7_17_2012 filed saved!
# 7_17_2015 filed saved!
# 7_17_2016 filed saved!
# 8_17_2011 filed saved!
# 8_17_2012 filed saved!
# 8_17_2013 filed saved!
# 8_17_2014 filed saved!
# 8_17_2015 filed saved!
# 8_17_2016 filed saved!
# 9_17_2011 filed saved!
# 9_17_2012 filed saved!
# 9_17_2013 filed saved!
# 9_17_2014 filed saved!
# 9_17_2015 filed saved!
# 9_17_2016 filed saved!
# 4_18_2012 filed saved!
# 4_18_2013 filed saved!
# 4_18_2014 filed saved!
# 4_18_2015 filed saved!
# 4_18_2016 filed saved!
# 5_18_2012 filed saved!
# 5_18_2013 filed saved!
# 5_18_2014 filed saved!
# 5_18_2015 filed saved!
# 5_18_2016 filed saved!
# 6_18_2012 filed saved!
# 6_18_2013 filed saved!
# 6_18_2014 filed saved!
# 6_18_2015 filed saved!
# 6_18_2016 filed saved!
# 7_18_2011 filed saved!
# 7_18_2012 filed saved!
# 7_18_2014 filed saved!
# 7_18_2015 filed saved!
# 7_18_2016 filed saved!
# 8_18_2011 filed saved!
# 8_18_2012 filed saved!
# 8_18_2013 filed saved!
# 8_18_2014 filed saved!
# 8_18_2015 filed saved!
# 8_18_2016 filed saved!
# 9_18_2011 filed saved!
# 9_18_2012 filed saved!
# 9_18_2013 filed saved!
# 9_18_2014 filed saved!
# 9_18_2015 filed saved!
# 9_18_2016 filed saved!
# 4_19_2012 filed saved!
# 4_19_2013 filed saved!
# 4_19_2014 filed saved!
# 4_19_2015 filed saved!
# 4_19_2016 filed saved!
# 5_19_2012 filed saved!
# 5_19_2013 filed saved!
# 5_19_2014 filed saved!
# 5_19_2015 filed saved!
# 5_19_2016 filed saved!
# 6_19_2012 filed saved!
# 6_19_2013 filed saved!
# 6_19_2014 filed saved!
# 6_19_2015 filed saved!
# 6_19_2016 filed saved!
# 7_19_2011 filed saved!
# 7_19_2012 filed saved!
# 7_19_2013 filed saved!
# 7_19_2014 filed saved!
# 7_19_2015 filed saved!
# 7_19_2016 filed saved!
# 8_19_2011 filed saved!
# 8_19_2012 filed saved!
# 8_19_2013 filed saved!
# 8_19_2014 filed saved!
# 8_19_2015 filed saved!
# 8_19_2016 filed saved!
# 9_19_2011 filed saved!
# 9_19_2012 filed saved!
# 9_19_2013 filed saved!
# 9_19_2014 filed saved!
# 9_19_2015 filed saved!
# 9_19_2016 filed saved!
# 4_20_2012 filed saved!
# 4_20_2013 filed saved!
# 4_20_2014 filed saved!
# 4_20_2015 filed saved!
# 4_20_2016 filed saved!
# 5_20_2012 filed saved!
# 5_20_2013 filed saved!
# 5_20_2014 filed saved!
# 5_20_2015 filed saved!
# 5_20_2016 filed saved!
# 6_20_2012 filed saved!
# 6_20_2013 filed saved!
# 6_20_2014 filed saved!
# 6_20_2015 filed saved!
# 6_20_2016 filed saved!
# 7_20_2011 filed saved!
# 7_20_2012 filed saved!
# 7_20_2013 filed saved!
# 7_20_2014 filed saved!
# 7_20_2015 filed saved!
# 7_20_2016 filed saved!
# 8_20_2011 filed saved!
# 8_20_2012 filed saved!
# 8_20_2013 filed saved!
# 8_20_2014 filed saved!
# 8_20_2015 filed saved!
# 8_20_2016 filed saved!
# 9_20_2011 filed saved!
# 9_20_2012 filed saved!
# 9_20_2013 filed saved!
# 9_20_2014 filed saved!
# 9_20_2015 filed saved!
# 9_20_2016 filed saved!
# 4_21_2012 filed saved!
# 4_21_2013 filed saved!
# 4_21_2014 filed saved!
# 4_21_2015 filed saved!
# 4_21_2016 filed saved!
# 5_21_2012 filed saved!
# 5_21_2013 filed saved!
# 5_21_2014 filed saved!
# 5_21_2015 filed saved!
# 5_21_2016 filed saved!
# 6_21_2012 filed saved!
# 6_21_2013 filed saved!
# 6_21_2014 filed saved!
# 6_21_2015 filed saved!
# 6_21_2016 filed saved!
# 7_21_2011 filed saved!
# 7_21_2012 filed saved!
# 7_21_2013 filed saved!
# 7_21_2014 filed saved!
# 7_21_2015 filed saved!
# 7_21_2016 filed saved!
# 8_21_2011 filed saved!
# 8_21_2012 filed saved!
# 8_21_2013 filed saved!
# 8_21_2014 filed saved!
# 8_21_2015 filed saved!
# 8_21_2016 filed saved!
# 9_21_2011 filed saved!
# 9_21_2012 filed saved!
# 9_21_2013 filed saved!
# 9_21_2014 filed saved!
# 9_21_2015 filed saved!
# 9_21_2016 filed saved!
# 4_22_2012 filed saved!
# 4_22_2013 filed saved!
# 6_28_2015 filed saved!
# 6_28_2016 filed saved!
# 7_28_2011 filed saved!
# 7_28_2012 filed saved!
# 7_28_2013 filed saved!
# 7_28_2014 filed saved!
# 7_28_2015 filed saved!
# 7_28_2016 filed saved!
# 8_28_2011 filed saved!
# 8_28_2012 filed saved!
# 8_28_2013 filed saved!
# 8_28_2014 filed saved!
# 8_28_2015 filed saved!
# 8_28_2016 filed saved!
# 9_28_2011 filed saved!
# 9_28_2012 filed saved!
# 9_28_2013 filed saved!
# 9_28_2014 filed saved!
# 9_28_2015 filed saved!
# 9_28_2016 filed saved!
# 4_29_2012 filed saved!
# 4_29_2013 filed saved!
# 4_29_2014 filed saved!
# 4_29_2015 filed saved!
# 4_29_2016 filed saved!
# 5_29_2012 filed saved!
# 5_29_2013 filed saved!
# 5_29_2014 filed saved!
# 5_29_2015 filed saved!
# 5_29_2016 filed saved!
# 6_29_2012 filed saved!
# 6_29_2013 filed saved!
# 6_29_2014 filed saved!
# 6_29_2015 filed saved!
# 6_29_2016 filed saved!
# 7_29_2011 filed saved!
# 7_29_2012 filed saved!
# 7_29_2013 filed saved!
# 7_29_2014 filed saved!
# 7_29_2015 filed saved!
# 7_29_2016 filed saved!
# 8_29_2011 filed saved!
# 8_29_2012 filed saved!
# 8_29_2013 filed saved!
# 8_29_2014 filed saved!
# 8_29_2015 filed saved!
# 8_29_2016 filed saved!
# 9_29_2012 filed saved!
# 9_29_2013 filed saved!
# 9_29_2015 filed saved!
# 9_29_2016 filed saved!
# 4_30_2012 filed saved!
# 4_30_2013 filed saved!
# 4_30_2014 filed saved!
# 4_30_2015 filed saved!
# 4_30_2016 filed saved!
# 5_30_2012 filed saved!
# 5_30_2013 filed saved!
# 5_30_2014 filed saved!
# 5_30_2015 filed saved!
# 5_30_2016 filed saved!
# 6_30_2012 filed saved!
# 6_30_2013 filed saved!
# 6_30_2014 filed saved!
# 6_30_2015 filed saved!
# 6_30_2016 filed saved!
# 7_30_2011 filed saved!
# 7_30_2012 filed saved!
# 7_30_2013 filed saved!
# 7_30_2014 filed saved!
# 7_30_2015 filed saved!
# 7_30_2016 filed saved!
# 8_30_2011 filed saved!
# 8_30_2012 filed saved!
# 8_30_2013 filed saved!
# 8_30_2014 filed saved!
# 8_30_2015 filed saved!
# 8_30_2016 filed saved!
# 9_30_2011 filed saved!
# 9_30_2012 filed saved!
# 9_30_2013 filed saved!
# 9_30_2014 filed saved!
# 9_30_2015 filed saved!
# 9_30_2016 filed saved!
# 5_31_2012 filed saved!
# 5_31_2013 filed saved!
# 5_31_2014 filed saved!
# 5_31_2015 filed saved!
# 5_31_2016 filed saved!
# 7_31_2011 filed saved!
# 7_31_2012 filed saved!
# 7_31_2013 filed saved!
# 7_31_2014 filed saved!
# 7_31_2015 filed saved!
# 7_31_2016 filed saved!
# 8_31_2011 filed saved!
# 8_31_2012 filed saved!
# 8_31_2013 filed saved!
# 8_31_2014 filed saved!
# 8_31_2015 filed saved!
# 8_31_2016 filed saved!

# %%
now = datetime.now()
i = 45
(now - timedelta(i)).strftime('%-m_%-d_%Y')
# Out:
# '2_7_2018'
