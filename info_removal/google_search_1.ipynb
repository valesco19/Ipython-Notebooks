# %%
from googleapiclient.discovery import build
import pprint
import pandas as pd
import numpy as np
from datetime import datetime
import time

# %%
my_api_key = 'AIzaSyD9MzRxeLkpbhlKu6YWAAb9nop9lyLMV5o'
my_cse_id = '004629583369140346533:4uj3yycofhc'

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search('Kathleen Elizabeth Petersen Prairieville', my_api_key, my_cse_id, num = 10)

for result in results:
    pprint.pprint(result)
# Out:
# {'cacheId': 'VLU0GZ7GVuYJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Michael_Peterson_(murder_suspect)',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Michael_<b>Peterson</b>_(murder_suspect)',
#  'htmlSnippet': '<b>Elizabeth</b> Ratliff, the friend of the ... who&#39;d '
#                 'initially performed <b>Kathleen Peterson&#39;s</b> <br>\n'
#                 'autopsy,&nbsp;...',
#  'htmlTitle': 'Michael <b>Peterson</b> (murder suspect) - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Michael_Peterson_(murder_suspect)',
#  'pagemap': {'hcard': [{'bday': '1943-10-23',
#                         'fn': 'Michael Iver Peterson',
#                         'nickname': 'Michael Iver Peterson',
#                         'role': 'Soldier, columnist, writer'}],
#              'metatags': [{'referrer': 'origin-when-cross-origin'}],
#              'person': [{'role': 'Soldier, columnist, writer'}]},
#  'snippet': "Elizabeth Ratliff, the friend of the ... who'd initially "
#             "performed Kathleen Peterson's \n"
#             'autopsy,\xa0...',
#  'title': 'Michael Peterson (murder suspect) - Wikipedia'}
# {'cacheId': 'Cj6Q3RpVmEYJ',
#  'displayLink': 'www.wral.com',
#  'formattedUrl': 'www.wral.com/news/local/story/106673/',
#  'htmlFormattedUrl': 'www.wral.com/news/local/story/106673/',
#  'htmlSnippet': 'Sep 5, 2003 <b>...</b> DURHAM, N.C. — Prosecutors continue to '
#                 'try and link Mike <b>Peterson</b> to the death <br>\n'
#                 'of two women. On Thursday, a medical examiner told '
#                 'jurors&nbsp;...',
#  'htmlTitle': 'State Medical Examiner Believes <b>Kathleen Peterson</b>, '
#               '<b>Elizabeth</b> ...',
#  'kind': 'customsearch#result',
#  'link': 'http://www.wral.com/news/local/story/106673/',
#  'pagemap': {'cse_image': [{'src': 'https://wwwcache.wral.com/presentation/v3/images/content/social/open_graph/wral_newcom_1920x1080.jpg'}],
#              'cse_thumbnail': [{'height': '168',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQtx-uZBhd47jM0cOshn3UEtcdhU25SYeYhHUMTPkuYojrM4PsgAsajKKvB',
#                                 'width': '300'}],
#              'metatags': [{'application-name': 'WRAL.com',
#                            'article:published_time': '2003-09-05T08:22:00-04:00',
#                            'author': 'WRAL',
#                            'dcterms.created': '2003-09-05 08:22:00',
#                            'dcterms.modified': '2006-12-09 22:19:08',
#                            'fb:app_id': '334167666672300',
#                            'fb:pages': '14827657177',
#                            'msapplication-notification': 'frequency=30;polling-uri=http://notifications.buildmypinnedsite.com/?feed=http://www.wral.com/rss/48&id=1;polling-uri2=http://notifications.buildmypinnedsite.com/?feed=http://www.wral.com/rss/48&id=2;polling-uri3=http://notifications.buildmypinnedsite.com/?feed=http://www.wral.com/rss/48&id=3;polling-uri4=http://notifications.buildmypinnedsite.com/?feed=http://www.wral.com/rss/48&id=4;polling-uri5=http://notifications.buildmypinnedsite.com/?feed=http://www.wral.com/rss/48&id=5;cycle=1',
#                            'msapplication-square150x150logo': 'https://wwwcache.wral.com/favicons/mstile-150x150.png',
#                            'msapplication-square310x310logo': 'https://wwwcache.wral.com/favicons/mstile-310x310.png',
#                            'msapplication-square70x70logo': 'https://wwwcache.wral.com/favicons/mstile-70x70.png',
#                            'msapplication-tilecolor': '#041E30',
#                            'msapplication-tileimage': 'https://wwwcache.wral.com/favicons/mstile-144x144.png',
#                            'msapplication-wide310x150logo': 'https://wwwcache.wral.com/favicons/mstile-310x150.png',
#                            'og:description': 'State Medical Examiner Believes '
#                                              'Kathleen Peterson, Elizabeth '
#                                              'Ratliff Were Murdered :: '
#                                              'WRAL.com',
#                            'og:image': 'https://wwwcache.wral.com/presentation/v3/images/content/social/open_graph/wral_newcom_1920x1080.jpg',
#                            'og:site_name': 'WRAL.com',
#                            'og:title': 'State Medical Examiner Believes '
#                                        'Kathleen Peterson, Elizabeth Ratliff '
#                                        'Were Murdered :: WRAL.com',
#                            'og:type': 'article',
#                            'og:url': 'http://www.wral.com/news/local/story/106673/',
#                            'outbrain:ob_desc': 'id_asset=106673|asset_type=story',
#                            'pinterest': 'nohover',
#                            'twitter:card': 'summary_large_image',
#                            'twitter:description': 'State Medical Examiner '
#                                                   'Believes Kathleen Peterson, '
#                                                   'Elizabeth Ratliff Were '
#                                                   'Murdered :: WRAL.com',
#                            'twitter:image': 'https://wwwcache.wral.com/presentation/v3/images/content/social/open_graph/wral_newcom_1920x1080.jpg',
#                            'twitter:site': '@wral',
#                            'twitter:title': 'State Medical Examiner Believes '
#                                             'Kathleen Peterson, Elizabeth '
#                                             'Ratliff Were Murdered :: WRAL.com',
#                            'twitter:url': 'http://www.wral.com/news/local/story/106673/',
#                            'viewport': 'width=device-width, initial-scale=1'}]},
#  'snippet': 'Sep 5, 2003 ... DURHAM, N.C. — Prosecutors continue to try and '
#             'link Mike Peterson to the death \n'
#             'of two women. On Thursday, a medical examiner told jurors\xa0...',
#  'title': 'State Medical Examiner Believes Kathleen Peterson, Elizabeth ...'}
# {'cacheId': '6FXtTg2qLMcJ',
#  'displayLink': 'www.peterson-staircase.com',
#  'formattedUrl': 'www.peterson-staircase.com/coincidence.html',
#  'htmlFormattedUrl': 'www.<b>peterson</b>-staircase.com/coincidence.html',
#  'htmlSnippet': '&quot;Michael is explaining to us that this weird thing '
#                 'happened -- she had fallen down <br>\n'
#                 'the steps.&quot; -- <b>Elizabeth</b> Ratliff&#39;s neighbor, '
#                 'Cheryl Appel-Schumacher &quot;We knew&nbsp;...',
#  'htmlTitle': '<b>Elizabeth</b> Ratliff -- <b>Kathleen Peterson</b> -- '
#               'Staircases',
#  'kind': 'customsearch#result',
#  'link': 'http://www.peterson-staircase.com/coincidence.html',
#  'pagemap': {'cse_image': [{'src': 'http://www.peterson-staircase.com/mpwriter.jpg'}],
#              'cse_thumbnail': [{'height': '194',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTFGmykISR_iR86Rd1YLifPrHAHwctbZWIdGtEw-61V9EwY2-jXZu8-Jo3U',
#                                 'width': '259'}]},
#  'snippet': '"Michael is explaining to us that this weird thing happened -- '
#             'she had fallen down \n'
#             'the steps." -- Elizabeth Ratliff\'s neighbor, Cheryl '
#             'Appel-Schumacher "We knew\xa0...',
#  'title': 'Elizabeth Ratliff -- Kathleen Peterson -- Staircases'}
# {'cacheId': '_H8w-6Lhq20J',
#  'displayLink': 'www.salon.com',
#  'formattedUrl': 'https://www.salon.com/2005/04/03/staircase/',
#  'htmlFormattedUrl': 'https://www.salon.com/2005/04/03/staircase/',
#  'htmlSnippet': 'Apr 3, 2005 <b>...</b> Plus, <b>e</b>-mails were discovered '
#                 'that indicated that <b>Peterson</b> had contacted a male '
#                 '<br>\n'
#                 'prostitute shortly before <b>Kathleen&#39;s</b> death. '
#                 'Eventually, Michael&nbsp;...',
#  'htmlTitle': 'The other <b>Peterson</b> trial - Salon.com',
#  'kind': 'customsearch#result',
#  'link': 'https://www.salon.com/2005/04/03/staircase/',
#  'pagemap': {'cse_image': [{'src': 'https://media.salon.com/2005/04/the_other_peterson_trial.jpg'}],
#              'cse_thumbnail': [{'height': '196',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTgI6-DFKvDZjbVliT518Mzg5NYHkWt3vwY7kxvzoF51oFB_LogoTCAxoUM',
#                                 'width': '257'}],
#              'metatags': [{'apple-mobile-web-app-capable': 'yes',
#                            'apple-mobile-web-app-status-bar-style': 'black',
#                            'apple-mobile-web-app-title': 'Salon.com',
#                            'mobile-web-app-capable': 'yes',
#                            'og:description': 'Oscar-winning director '
#                                              'Jean-Xavier de Lestrade turns '
#                                              'unparalleled access to a murder '
#                                              'trial into an unforgettable '
#                                              'documentary series.',
#                            'og:image': 'https://media.salon.com/2005/04/the_other_peterson_trial.jpg',
#                            'og:title': 'The other Peterson trial',
#                            'og:type': 'article',
#                            'twitter:card': 'summary_large_image',
#                            'twitter:creator': '@Salon',
#                            'twitter:description': 'Oscar-winning director '
#                                                   'Jean-Xavier de Lestrade '
#                                                   'turns unparalleled access '
#                                                   'to a murder trial into an '
#                                                   'unforgettable documentary '
#                                                   'series.',
#                            'twitter:image': 'https://media.salon.com/2005/04/the_other_peterson_trial.jpg',
#                            'twitter:title': 'The other Peterson trial',
#                            'viewport': 'width=device-width, initial-scale=1'}]},
#  'snippet': 'Apr 3, 2005 ... Plus, e-mails were discovered that indicated that '
#             'Peterson had contacted a male \n'
#             "prostitute shortly before Kathleen's death. Eventually, "
#             'Michael\xa0...',
#  'title': 'The other Peterson trial - Salon.com'}
# {'cacheId': 'zwa3n7SGuPUJ',
#  'displayLink': 'www.cnn.com',
#  'formattedUrl': 'www.cnn.com/2003/LAW/08/19/ctv.novelist.trial/index.html',
#  'htmlFormattedUrl': 'www.cnn.com/2003/LAW/08/19/ctv.novelist.trial/index.html',
#  'htmlSnippet': 'Aug 19, 2003 <b>...</b> Author Michael <b>Peterson</b> is '
#                 'charged with killing his wife in their home here ... last '
#                 '<br>\n'
#                 'time she saw <b>Elizabeth</b> Ratliff during Monday&#39;s '
#                 'trial of Michael <b>Peterson</b>. ... the <br>\n'
#                 'similarities between Ratliff&#39;s death and <b>Kathleen '
#                 'Peterson&#39;s</b> are&nbsp;...',
#  'htmlTitle': 'CNN.com - Woman&#39;s death in Germany 18 years ago enters ...',
#  'kind': 'customsearch#result',
#  'link': 'http://www.cnn.com/2003/LAW/08/19/ctv.novelist.trial/index.html',
#  'pagemap': {'metatags': [{'author': 'John Springer Court TV.com',
#                            'date': '2003-08-19 09:24:40',
#                            'section': 'ROOT',
#                            'subsection': 'LAW'}]},
#  'snippet': 'Aug 19, 2003 ... Author Michael Peterson is charged with killing '
#             'his wife in their home here ... last \n'
#             "time she saw Elizabeth Ratliff during Monday's trial of Michael "
#             'Peterson. ... the \n'
#             "similarities between Ratliff's death and Kathleen Peterson's "
#             'are\xa0...',
#  'title': "CNN.com - Woman's death in Germany 18 years ago enters ..."}
# {'cacheId': 'hGr9MmFc9CcJ',
#  'displayLink': 'vanceholmes.com',
#  'formattedUrl': 'vanceholmes.com/court/trial_mp_evidence.html',
#  'htmlFormattedUrl': 'vanceholmes.com/court/trial_mp_evidence.html',
#  'htmlSnippet': '&quot;Poor <b>Kathleen</b> is undergoing the tortures of the '
#                 'damned at Nortel.&quot; -- <b>Peterson e</b>-<br>\n'
#                 'mail, Dec 3, 2001. &quot;There was no conflict about Nortel. '
#                 'There was no conflict&nbsp;...',
#  'htmlTitle': 'Who Killed <b>Kathleen Peterson</b>? -- Evidence || Vance '
#               'Holmes ...',
#  'kind': 'customsearch#result',
#  'link': 'http://vanceholmes.com/court/trial_mp_evidence.html',
#  'pagemap': {'cse_image': [{'src': 'http://vanceholmes.com/court/1stair.jpg'}],
#              'cse_thumbnail': [{'height': '276',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRVUduHXRYP9cEB4s6kYLqJK1rnfwdSG6LltmInO16QK6PtXgSQIWf01WM',
#                                 'width': '183'}]},
#  'snippet': '"Poor Kathleen is undergoing the tortures of the damned at '
#             'Nortel." -- Peterson e-\n'
#             'mail, Dec 3, 2001. "There was no conflict about Nortel. There was '
#             'no conflict\xa0...',
#  'title': 'Who Killed Kathleen Peterson? -- Evidence || Vance Holmes ...'}
# {'cacheId': 'acOJIMl1ZeUJ',
#  'displayLink': 'pview.findlaw.com',
#  'formattedUrl': 'pview.findlaw.com/view/3395617_1',
#  'htmlFormattedUrl': 'pview.findlaw.com/view/3395617_1',
#  'htmlSnippet': 'Jul 18, 2017 <b>...</b> Rowe Law Firm. 5157 Bluebonnet '
#                 'Boulevard<b>Baton Rouge</b>, LA 70809-2958. <br>\n'
#                 'Phones: 225-250-1161 800-724-1992. Fax: 225-293-7668.',
#  'htmlTitle': 'Rowe Law Firm - a <b>Baton Rouge</b>, Louisiana (LA) Bankruptcy '
#               'Law Firm',
#  'kind': 'customsearch#result',
#  'link': 'http://pview.findlaw.com/view/3395617_1',
#  'pagemap': {'attorney': [{'faxnumber': '225-293-7668',
#                            'image': 'http://wldimages.findlaw.com/images/3395617/3395617_1.jpg',
#                            'telephone': '225-250-1161',
#                            'url': 'www.rowe-lawfirm.com'}],
#              'cse_image': [{'src': 'http://wldimages.findlaw.com/images/3395617/3395617_1.jpg'}],
#              'cse_thumbnail': [{'height': '119',
#                                 'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT-3R6VbtFkxGdqirEY90tIHEruCncOKa6Lu8kRKW5TfTOyv86I5W-Diw',
#                                 'width': '216'}],
#              'metatags': [{'apple-mobile-web-app-capable': 'yes',
#                            'format-detection': 'telephone=yes',
#                            'viewport': 'width=device-width, '
#                                        'initial-scale=1.0'}],
#              'organization': [{'member': 'Hazey, Nicole Buggs'}],
#              'postaladdress': [{'addresslocality': 'Baton Rouge',
#                                 'addressregion': 'LA',
#                                 'postalcode': '70809',
#                                 'streetaddress': '5157 Bluebonnet Boulevard'},
#                                {'addresslocality': 'Baton Rouge',
#                                 'addressregion': 'LA',
#                                 'postalcode': '70809',
#                                 'streetaddress': '5157 Bluebonnet Boulevard'}]},
#  'snippet': 'Jul 18, 2017 ... Rowe Law Firm. 5157 Bluebonnet BoulevardBaton '
#             'Rouge, LA 70809-2958. \n'
#             'Phones: 225-250-1161 800-724-1992. Fax: 225-293-7668.',
#  'title': 'Rowe Law Firm - a Baton Rouge, Louisiana (LA) Bankruptcy Law Firm'}
# {'cacheId': 'I-zd8FX93HAJ',
#  'displayLink': 'vanceholmes.com',
#  'formattedUrl': 'vanceholmes.com/court/trial_m_peterson4.html',
#  'htmlFormattedUrl': 'vanceholmes.com/court/trial_m_<b>peterson</b>4.html',
#  'htmlSnippet': '<b>Elizabeth</b> Ratliff and <b>Kathleen Peterson</b> were '
#                 'independent, free spirits. Prior to <br>\n'
#                 'Michael <b>Peterson&#39;s</b> entrance, they were bright, '
#                 'fun-loving, popular, happy people.',
#  'htmlTitle': 'The Death of <b>Kathleen Peterson</b> || Poetic Justice || '
#               'Vance Holmes',
#  'kind': 'customsearch#result',
#  'link': 'http://vanceholmes.com/court/trial_m_peterson4.html',
#  'pagemap': {'cse_image': [{'src': 'http://vanceholmes.com/court/search.jpg'}],
#              'cse_thumbnail': [{'height': '169',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQ3EiaBJ1svQUtea59JbPiek2XegEvNgtiR6VoFzLrXkkhojdioYP_ntonR',
#                                 'width': '258'}]},
#  'snippet': 'Elizabeth Ratliff and Kathleen Peterson were independent, free '
#             'spirits. Prior to \n'
#             "Michael Peterson's entrance, they were bright, fun-loving, "
#             'popular, happy people.',
#  'title': 'The Death of Kathleen Peterson || Poetic Justice || Vance Holmes'}
# {'cacheId': 'K3qRYOrPQlMJ',
#  'displayLink': 'www.marykay.com',
#  'formattedUrl': 'https://www.marykay.com/en.../find-an-independent-beauty-consultant',
#  'htmlFormattedUrl': 'https://www.marykay.com/en.../find-an-independent-beauty-consultant',
#  'htmlSnippet': '... you will not use this service or website to engage in '
#                 'unsolicited advertising, <br>\n'
#                 'unlawful or commercial efforts (“spam” or “junk mail”) via '
#                 '<b>e</b>-mail or other means.',
#  'htmlTitle': 'Mary Kay Beauty Consultants Locator: Find Mary Kay Cosmetics '
#               '...',
#  'kind': 'customsearch#result',
#  'link': 'https://www.marykay.com/en-us/find-an-independent-beauty-consultant',
#  'pagemap': {'cse_image': [{'src': 'https://www.marykay.com/~/media/images/mk/united-states/usa/esuite/toolkits/2017-launches/02-17-launch/2-17-mk-parties-refresh-page/530911-mary-kay-mk-parties-refresh-marketplace-standard.jpg?h=297&w=471&la=en-US&hash=C439E42807C5E99FF7C8DC605234CE952E95E0D8'}],
#              'cse_thumbnail': [{'height': '178',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRn__BOzYBn6qHATRK6mQyz2wcPXTgbOOBK2tR8vnEWWPCzSU2fXyPfbUY',
#                                 'width': '283'}],
#              'metatags': [{'og:title': 'Mary Kay Beauty Consultants Locator: '
#                                        'Find Mary Kay Cosmetics and '
#                                        'Consultants Near You',
#                            'og:type': 'website',
#                            'og:url': 'https://www.marykay.com/en-us/find-an-independent-beauty-consultant',
#                            'viewport': 'width=device-width,minimum-scale=1.0,maximum-scale=1.0,initial-scale=1.0'}]},
#  'snippet': '... you will not use this service or website to engage in '
#             'unsolicited advertising, \n'
#             'unlawful or commercial efforts (“spam” or “junk mail”) via e-mail '
#             'or other means.',
#  'title': 'Mary Kay Beauty Consultants Locator: Find Mary Kay Cosmetics ...'}
# {'cacheId': 'iTn6Whdjvx0J',
#  'displayLink': 'fr.wikipedia.org',
#  'formattedUrl': 'https://fr.wikipedia.org/wiki/Michael_Peterson',
#  'htmlFormattedUrl': 'https://fr.wikipedia.org/wiki/Michael_<b>Peterson</b>',
#  'htmlSnippet': 'Cet article ne cite pas suffisamment ses sources (janvier '
#                 '2011). Si vous disposez <br>\n'
#                 'd&#39;ouvrages ... <b>Peterson</b> a soutenu plus tard que '
#                 '<b>Kathleen</b> avait dû tomber dans <br>\n'
#                 'les ... l&#39;accusation a fait état d&#39;éléments '
#                 'troublants entourant la mort d&#39;<b>Elizabeth</b>&nbsp;...',
#  'htmlTitle': 'Michael <b>Peterson</b> — Wikipédia',
#  'kind': 'customsearch#result',
#  'link': 'https://fr.wikipedia.org/wiki/Michael_Peterson',
#  'pagemap': {'metatags': [{'referrer': 'origin-when-cross-origin'}]},
#  'snippet': 'Cet article ne cite pas suffisamment ses sources (janvier 2011). '
#             'Si vous disposez \n'
#             "d'ouvrages ... Peterson a soutenu plus tard que Kathleen avait dû "
#             'tomber dans \n'
#             "les ... l'accusation a fait état d'éléments troublants entourant "
#             "la mort d'Elizabeth\xa0...",
#  'title': 'Michael Peterson — Wikipédia'}
