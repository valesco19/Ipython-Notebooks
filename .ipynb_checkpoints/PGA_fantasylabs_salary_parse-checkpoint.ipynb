# %%
import json
import os
import glob
import pandas as pd
import requests
import time
from datetime import datetime
from random import randint

# %%
os.chdir('/home/valesco/Datasets/PGA_Data/fantasylabs_data/salary_data/')
player_ids = pd.read_csv('/home/valesco/Datasets/PGA_Data/player_id.csv')
file_ls = glob.glob('*')

# %%
pga_salary = pd.DataFrame(columns = ['player_name', 'player_id', 'date', 'salary', 'actual_points', 'imp_points', 
            'proj_points', 'score', 'plus_minus', 'injury_status', 'source'])
count = 0

for file in file_ls:
    temp_file = open(file)
    json_data = json.load(temp_file)

    text = file.replace('_salary_data.json', '')
    date_obj = datetime.strptime(text, '%m_%d_%Y')

    for player in json_data['PlayerModels']:

        player_name = player['Properties']['Player_Name']
        player_id = player['Properties']['PlayerId']
        salary = player['Properties']['Salary']
        actual_points = player['Properties']['ActualPoints']
        imp_points = player['Properties']['ImpPts']
        proj_points = player['ProjPoints'] 
        score = player['Properties']['Score']
        injury_status = player['Properties']['InjuryStatus']
        plus_minus = player['Properties']['Plus_Minus']
        source = player['Properties']['SourceId']
        
        if source == 4:
            pga_salary.loc[count] = [player_name, player_id, date_obj, salary, actual_points, imp_points, proj_points,
                                     score, plus_minus, injury_status, source]

            count += 1

# %%
pga_salary.sort_values(by = 'salary', ascending = False)
# Out:
#               player_name  player_id       date   salary actual_points  \
# 12193           Jason Day     8899.0 2015-02-15  17700.0         118.5
# 12177        Jimmy Walker     8872.0 2015-02-15  17400.0          88.5
# 9214            Jason Day     8899.0 2015-01-18  16000.0            83
# 4110         Patrick Reed     8943.0 2015-01-25  16000.0            94
# 13289        Rory McIlroy     9140.0 2015-03-01  15700.0          19.5
# 15421        Rory McIlroy     9140.0 2015-03-08  15300.0            87
# 14601       Jordan Spieth     8938.0 2015-02-08  15200.0          22.5
# 9955         Rory McIlroy     9140.0 2015-03-22  15100.0            83
# 13531        Rory McIlroy     9140.0 2015-04-12  14900.0         105.5
# 14570           Jason Day     8899.0 2015-02-08  14700.0           106
# 13337        Bubba Watson     8875.0 2015-02-22  14500.0          66.5
# 1922         Bubba Watson     8875.0 2015-02-01  14300.0         105.5
# 11200        Rory McIlroy     9140.0 2015-05-17  14000.0           137
# 14557        Jimmy Walker     8872.0 2015-02-08  14000.0            80
# 15624       Jordan Spieth     8938.0 2015-03-29  14000.0           102
# 16479        Bubba Watson     8875.0 2015-01-11  14000.0            94
# 16487           Jason Day     8899.0 2015-01-11  13900.0           121
# 4040          Matt Kuchar     8844.0 2015-01-25  13800.0           127
# 17814       Jordan Spieth     8938.0 2015-07-12  13700.0           140
# 9197         Jimmy Walker     8872.0 2015-01-18  13700.0         146.5
# 13370      Dustin Johnson     8916.0 2015-02-22  13700.0          84.5
# 13389       Jordan Spieth     8938.0 2015-02-22  13600.0          83.5
# 7572         Rory McIlroy     9140.0 2017-01-15  13500.0         135.5
# 1969        Jordan Spieth     8938.0 2015-02-01  13400.0            86
# 3454         Rory McIlroy     9140.0 2016-07-03  13400.0            89
# 9773        Jordan Spieth     8938.0 2015-05-31  13300.0          76.5
#  'FantasyResultId': 547623,
#  'FirstPosition': 'G',
#  'FullName': '',
#  'IsExcluded': False,
#  'IsLiked': False,
#  'IsLocked': False,
#  'LineupCount': 0,
#  'MinExposure': None,
#  'PlayerId': 9312,
#  'Points': 0.0,
#  'Position': 'G',
#  'PositionCount': 1,
#  'PositionId': 501,
#  'Positions': ['G'],
#  'ProjPoints': 0.0,
#  'Properties': {'ActualPoints': 24.0,
#   'Consistency': 50,
#   'EventId': -98998325,
#   'EventTeamId': 0,
#   'FantasyResultId': 547623,
#   'FullName': '',
#   'ImpPts': 45.54,
#   'InjuryStatus': None,
#   'IsProjected': None,
#   'Month_Count': None,
#   'Month_PPG': None,
#   'Month_Salary_Change': None,
#   'Month_X0': None,
#   'Month_X1': None,
#   'Month_X2': None,
#   'MyTrends': 0,
#   'PlayerId': 9312,
#   'Player_Name': 'Timothy Crouch',
#   'Plus_Minus': 50,
#   'Position': 'G',
#   'PositionId': 501,
#   'Pro_Pct': 50,
#   'Salary': 5600,
#   'Salary_Movement': 50,
#   'Score': 50.0,
#   'Season_Count': 0,
#   'Season_PPG': None,
#   'Season_PPG_Percentile': 50,
#   'Season_Plus_Minus': None,
#   'Season_Salary_Change': 0,
#   'Season_X0': None,
#   'Season_X1': None,
#   'Season_X2': None,
#   'SourceId': 4,
#   'Team': '',
#   'Upside': 50,
#   'adjrd_c_rank': 50.0,
#   'adjrd_l_rank': 50.0,
#   'adjrd_r_rank': 50.0,
#   'birdies_l': None,
#   'birdies_l_rank': 50.0,
#   'birdies_r_rank': 50.0,
#   'bogies_l': None,
#   'bogies_l_rank': 50.0,
#   'bogies_r_rank': 50.0,
#   'cnt_c_pct': 15.2,
#   'cnt_l': 1.0,
#   'cnt_l_pct': 0.0,
#   'cnt_r_pct': 1.5,
#   'da_l': None,
#   'da_l_rank': 50.0,
#   'da_r_rank': 50.0,
#   'dd_l': None,
#   'dd_l_rank': 50.0,
#   'dd_r_rank': 50.0,
#   'eagles_l': None,
#   'eagles_l_rank': 50.0,
#   'eagles_r_rank': 50.0,
#   'gir_c_rank': 50.0,
#   'gir_l': None,
#   'gir_l_rank': 50.0,
#   'gir_r_rank': 50.0,
#   'mc_pct_l': 100.0,
#   'mc_pct_l_pct': 0.0,
#   'mc_pct_r_pct': None,
#   'odds': 0.0,
#   'odds_pct': 0.0,
#   'par3_l': None,
#   'par4_l': None,
#   'par5_l': None,
#   'ppr_l': None,
#   'ppr_l_rank': 50.0,
#   'ppr_r_rank': 50.0,
#   'sagarin_l_rank': 50.0,
#   'sagarin_r_rank': 50.0,
#   'sc_l': None,
#   'sc_l_rank': 50.0,
#   'sc_r_rank': 50.0,
#   'temp': 75.2,
#   'temp_pct': 76.2,
#   'wind': 15.4,
#   'wind_pct': 24.5},
#  'Salary': 5600,
#  'Score': 50.0,
#  'TeamName': ''}

# %%
os.chdir('/home/valesco/Datasets/PGA_Data/fantasylabs_data/sportevent_data/')
sportevent = open('1_25_2015_sportevent_data.json')
se_data = json.load(sportevent)
