# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from IPython.display import display

# %%
geo={'USA':['CHI','NYC'],'Russia':['MOW','LED']}

def print_city(city):
    print(city)

def select_city(country):
    cityW.options = geo[country]


scW = widgets.Select(options=list(geo.keys()))
init = scW.value
cityW = widgets.Select(options=geo[init])
j = widgets.interactive(print_city, city=cityW)
i = widgets.interactive(select_city, country=scW)
display(i)
display(j)

# %%
open_df = pd.read_excel('D:/data/us_open_salaries.xlsx')
player_dict = dict(zip(open_df['player'].values, open_df['salary'].values))


def print_sal(player):
    print(player_dict[player])
    
player_widget1 = widgets.Select(options = list(sorted(player_dict.keys())))
player_widget2 = widgets.Select(options = list(sorted(player_dict.keys())))
init = player_widget.value

dd_1 = widgets.interactive(print_sal, player = player_widget1)
dd_2 = widgets.interactive(print_sal, player = player_widget2)
display(dd_1), display(dd_2)
# Out:
# (None, None)

# %%
open_df
# Out:
#                      Name   Salary   GameInfo
# 0          Dustin Johnson    12000  U.S. Open
# 1           Jordan Spieth    11500  U.S. Open
# 2            Rory McIlroy    11200  U.S. Open
# 3               Jason Day    10800  U.S. Open
# 4           Rickie Fowler    10500  U.S. Open
# 5                Jon Rahm    10300  U.S. Open
# 6           Sergio Garcia    10000  U.S. Open
# 7             Justin Rose     9800  U.S. Open
# 8        Hideki Matsuyama     9600  U.S. Open
# 9          Henrik Stenson     9300  U.S. Open
# 10          Brooks Koepka     9000  U.S. Open
# 11             Adam Scott     8800  U.S. Open
# 12          Branden Grace     8600  U.S. Open
# 13             Paul Casey     8400  U.S. Open
# 14          Justin Thomas     8300  U.S. Open
# 15           Bubba Watson     8200  U.S. Open
# 16           Jason Dufner     8100  U.S. Open
# 17          Daniel Berger     8000  U.S. Open
# 18         Kevin Chappell     7900  U.S. Open
# ...
