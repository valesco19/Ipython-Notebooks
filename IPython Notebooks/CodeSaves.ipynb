# %%
# Suppose SB checks back AKQr flop in a single raised pot.  FD comes on the turn where BB is somewhat 
# polar.  Model with the PvBC decision tree and two possible river cards.
S = 15

turnEArray = EquityArray(pe.string2card(['Ah','Kd','Qs','2d','__']));
river1EArray = EquityArray(pe.string2card(['Ah','Kd','Qs','2d','6d']));
river2EArray = EquityArray(pe.string2card(['Ah','Kd','Qs','2d','6s']));

point0 = DecPt('BB', 2.0, 2.0, turnEArray,"")
point1 = DecPt('SB', 2.0, 2.0, turnEArray,"check")
point2 = DecPt('Nature', 2.0, 2.0, turnEArray,"check")
point3 = DecPt('BB', 2.0, 2.0, river1EArray,"AhKdQs2d6d")

point4 = DecPt('BB', 2.0, 2.0, river2EArray,"AhKdQs2d6s")
point5 = DecPt('SB', 2.0, 2.0, river1EArray,"check")
point6 = DecPt('BB', 2.0, 2.0, river2EArray,"check")

point7 = DecPt('Leaf', 2.0, 2.0, river1EArray,"check")
point8 = DecPt('SB', 2.0, 6.0, river1EArray,"bet")
point9 = DecPt('Leaf', 2.0, 6.0, river1EArray,"fold")

point10 = DecPt('Leaf', 6.0, 6.0, river1EArray,"call")
point11 = DecPt('Leaf', 2.0, 2.0, river2EArray,"check")
point12 = DecPt('SB', 2.0, 6.0, river2EArray,"bet")

point13 = DecPt('Leaf', 2.0, 6.0, river2EArray,"fold")
point14 = DecPt('Leaf', 6.0, 6.0, river2EArray,"call")
point15 = DecPt('SB', 2.0, 6.0, turnEArray,"bet")

point16 = DecPt('Leaf', 2.0, 6.0, turnEArray,"fold")
point17 = DecPt('Nature', 6.0, 6.0, turnEArray,"call")
point18 = DecPt('BB', 6.0, 6.0, river1EArray,"AhKdQs2d6d")

point19 = DecPt('SB', 6.0, 6.0, river1EArray,"check")
point20 = DecPt('Leaf', 6.0, 6.0, river1EArray,"check")
point21 = DecPt('SB', 6.0, 18.0, river1EArray,"bet")

point22 = DecPt('Leaf', 6.0, 18.0, river1EArray,"fold")
point23 = DecPt('Leaf', 18.0, 18.0, river1EArray,"call")
point24 = DecPt('BB', 6.0, 6.0, river2EArray,"AhKdQs2d6s")

point25 = DecPt('SB', 6.0, 6.0, river2EArray,"check")
point26 = DecPt('Leaf', 6.0, 6.0, river2EArray,"check")
point27 = DecPt('SB', 6.0, 18.0, river2EArray,"bet")
point28 = DecPt('Leaf', 6.0, 18.0, river2EArray,"fold")
point29 = DecPt('Leaf', 18.0, 18.0, river2EArray,"call")

T = Tree(S, point0)
T.addDecPt(point1, point0)
T.addDecPt(point2, point1)
T.addDecPt(point3, point2)
T.addDecPt(point4, point2)
T.addDecPt(point5, point3)
T.addDecPt(point6, point4)
T.addDecPt(point7, point5)
T.addDecPt(point8, point3)
T.addDecPt(point9, point8)
T.addDecPt(point10, point8)
T.addDecPt(point11, point6)
T.addDecPt(point12, point4)
T.addDecPt(point13, point12)
T.addDecPt(point14, point12)
T.addDecPt(point15, point0)
T.addDecPt(point16, point15)
T.addDecPt(point17, point15)
T.addDecPt(point18, point17)
T.addDecPt(point19, point18)
T.addDecPt(point20, point19)
T.addDecPt(point21, point18)
T.addDecPt(point22, point21)
T.addDecPt(point23, point21)
T.addDecPt(point24, point17)
T.addDecPt(point25, point24)
T.addDecPt(point26, point25)
T.addDecPt(point27, point24)
T.addDecPt(point28, point27)
T.addDecPt(point29, point27)

T

# %%
S = 7 

riverLimitEArray = EquityArray(pe.string2card(['Qs','6d','Ad','9c','6h']));

point0 = DecPt('BB', 3.0, 3.0, riverLimitEArray, "")
point1 = DecPt('SB', 3.0, 3.0, riverLimitEArray, "check")
point2 = DecPt('Leaf', 3.0, 3.0, riverLimitEArray, "check")
point3 = DecPt('BB', 5.0, 3.0, riverLimitEArray, "bet")
point4 = DecPt('Leaf', 5.0, 3.0, riverLimitEArray, "fold")
point5 = DecPt('Leaf', 5.0, 5.0, riverLimitEArray, "call")
point6 = DecPt('SB', 5.0, 7.0, riverLimitEArray, "raise")
point7 = DecPt('Leaf', 5.0, 7.0, riverLimitEArray, "fold")
point8 = DecPt('Leaf', 7.0, 7.0, riverLimitEArray, "call")
point9 = DecPt('SB', 3.0, 5.0, riverLimitEArray, "bet")
point10 = DecPt('Leaf', 3.0, 5.0, riverLimitEArray, "fold")
point11 = DecPt('Leaf', 5.0, 5.0, riverLimitEArray, "call")
point12 = DecPt('BB', 7.0, 5.0, riverLimitEArray, "raise")
point13 = DecPt('Leaf', 7.0, 5.0, riverLimitEArray, "fold")
point14 = DecPt('Leaf', 7.0, 7.0, riverLimitEArray, "call")


Limit = Tree(S, point0)
Limit.addDecPt(point1, point0)
Limit.addDecPt(point2, point1)
Limit.addDecPt(point3, point1)
Limit.addDecPt(point4, point3)
Limit.addDecPt(point5, point3)
Limit.addDecPt(point6, point3)
Limit.addDecPt(point7, point6)
Limit.addDecPt(point8, point6)
Limit.addDecPt(point9, point0)
Limit.addDecPt(point10, point9)
Limit.addDecPt(point11, point9)
Limit.addDecPt(point12, point9)
Limit.addDecPt(point13, point12)
Limit.addDecPt(point14, point12)


Limit

# %%
S = 15

turnEArray = EquityArray(pe.string2card(['Tc','7d','4h','2s','__']));
riverEArray = EquityArray(pe.string2card(['Tc','7d','4h','2s','Ks']));


point0 = DecPt('SB', 4.5, 4.5, turnEArray,"")
point1 = DecPt('BB', 4.5, 4.5, turnEArray,"check")


point2 = DecPt('SB', 4.5, 4.5, riverEArray,"check")
point3 = DecPt('BB', 4.5, 4.5, riverEArray,"check")
point4 = DecPt('Leaf', 4.5, 4.5, riverEArray,"check")
point5 = DecPt('SB', 4.5, 6.5, riverEArray,"bet")

point6 = DecPt('Leaf', 4.5, 6.5, riverEArray,"fold")
point7 = DecPt('Leaf', 6.5, 6.5, riverEArray,"call")
point8 = DecPt('BB', 8.5, 6.5, riverEArray,"raise")

point9 = DecPt('Leaf', 8.5, 6.5, riverEArray,"fold")
point10 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")
point11 = DecPt('BB', 6.5, 4.5, riverEArray,"bet")

point12 = DecPt('Leaf', 6.5, 4.5, riverEArray,"fold")
point13 = DecPt('Leaf', 6.5, 6.5, riverEArray,"call")
point14 = DecPt('SB', 6.5, 8.5, riverEArray,"raise")

point15 = DecPt('Leaf', 6.5, 8.5, riverEArray,"fold")
point16 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")
point17 = DecPt('SB', 4.5, 6.5, turnEArray,"bet")

point18 = DecPt('Leaf', 4.5, 6.5, turnEArray,"fold")
point19 = DecPt('BB', 8.5, 6.5, turnEArray,"raise")

point20 = DecPt('Leaf', 8.5, 6.5, turnEArray,"fold")
point21 = DecPt('SB', 6.5, 6.5, riverEArray,"call")

point22 = DecPt('BB', 6.5, 6.5, riverEArray,"check")
point23 = DecPt('Leaf', 6.5, 6.5, riverEArray,"check")
point24 = DecPt('SB', 6.5, 8.5, riverEArray,"bet")
point25 = DecPt('Leaf', 6.5, 8.5, riverEArray,"fold")
point26 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")

point27 = DecPt('BB', 10.5, 8.5, riverEArray,"raise")
point28 = DecPt('Leaf', 10.5, 8.5, riverEArray,"fold")
point29 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")

point30 = DecPt('BB', 8.5, 6.5, riverEArray,"bet")
point31 = DecPt('Leaf', 8.5, 6.5, riverEArray,"fold")
point32 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")
point33 = DecPt('SB', 8.5, 10.5, riverEArray,"raise")

point34 = DecPt('Leaf', 8.5, 10.5, riverEArray,"fold")
point35 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")
point36 = DecPt('SB', 8.5, 8.5, riverEArray,"call")

point37 = DecPt('BB', 8.5, 8.5, riverEArray,"check")
point38 = DecPt('Leaf', 8.5, 8.5, riverEArray,"check")
point39 = DecPt('SB', 8.5, 10.5, riverEArray,"bet")

point40 = DecPt('Leaf', 8.5, 10.5, riverEArray,"fold")
point41 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")
point42 = DecPt('BB', 12.5, 10.5, riverEArray,"raise")

point43 = DecPt('Leaf', 12.5, 10.5, riverEArray,"fold")
point44 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")
point45 = DecPt('BB', 10.5, 8.5, riverEArray,"bet")

point46 = DecPt('Leaf', 10.5, 8.5, riverEArray,"fold")
point47 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")
point48 = DecPt('SB', 10.5, 12.5, riverEArray,"raise")

point49 = DecPt('Leaf', 10.5, 12.5, riverEArray,"fold")
point50 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")
point51 = DecPt('BB', 6.5, 4.5, turnEArray,"bet")

point52 = DecPt('Leaf', 6.5, 4.5, turnEArray,"fold")
point53 = DecPt('SB', 6.5, 8.5, turnEArray,"raise")
point54 = DecPt('SB', 6.5, 6.5, riverEArray,"call")
point55 = DecPt('BB', 6.5, 6.5, riverEArray,"check")

point56 = DecPt('Leaf', 6.5, 6.5, riverEArray,"check")
point57 = DecPt('SB', 6.5, 8.5, riverEArray,"bet")
point58 = DecPt('Leaf', 6.5, 8.5, riverEArray,"fold")

point59 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")
point60 = DecPt('BB', 10.5, 8.5, riverEArray,"raise")
point61 = DecPt('Leaf', 10.5, 8.5, riverEArray,"fold")
point62 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")

point63 = DecPt('BB', 8.5, 6.5, riverEArray,"bet")
point64 = DecPt('Leaf', 8.5, 6.5, riverEArray,"fold")
point65 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")

point66 = DecPt('SB', 8.5, 10.5, riverEArray,"raise")
point67 = DecPt('Leaf', 8.5, 10.5, riverEArray,"fold")
point68 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")

point69 = DecPt('Leaf', 6.5, 8.5, turnEArray,"fold")
point70 = DecPt('BB', 10.5, 8.5, turnEArray,"raise")

point71 = DecPt('Leaf', 10.5, 8.5, turnEArray,"fold")
point72 = DecPt('SB', 10.5, 10.5, riverEArray,"call")

point73 = DecPt('BB', 12.5, 10.5, riverEArray,"bet")
point74 = DecPt('Leaf', 12.5, 10.5, riverEArray,"fold")
point75 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")

point76 = DecPt('SB', 12.5, 14.5, riverEArray,"raise")
point77 = DecPt('Leaf', 12.5, 14.5, riverEArray,"fold")
point78 = DecPt('Leaf', 14.5, 14.5, riverEArray,"call")

point79 = DecPt('SB', 8.5, 8.5, riverEArray,"call")
point80 = DecPt('BB', 8.5, 8.5, riverEArray,"check")
point81 = DecPt('BB', 10.5, 8.5, riverEArray,"bet")
point82 = DecPt('Leaf', 8.5, 8.5, riverEArray,"check")
point83 = DecPt('SB', 8.5, 10.5, riverEArray,"bet")

point84 = DecPt('Leaf', 8.5, 10.5, riverEArray,"fold")
point85 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")
point86 = DecPt('BB', 12.5, 10.5, riverEArray,"raise")

point87 = DecPt('Leaf', 12.5, 10.5, riverEArray,"fold")
point88 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")
point89 = DecPt('Leaf', 10.5, 8.5, riverEArray,"fold")
point90 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")

point91 = DecPt('SB', 10.5, 12.5, riverEArray,"raise")
point92 = DecPt('Leaf', 10.5, 12.5, riverEArray,"fold")
point93 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")


TurnRiverSln = Tree(S, point0)
TurnRiverSln.addDecPt(point1, point0)
TurnRiverSln.addDecPt(point2, point1)
TurnRiverSln.addDecPt(point3, point2)
TurnRiverSln.addDecPt(point4, point3)
TurnRiverSln.addDecPt(point5, point3)
TurnRiverSln.addDecPt(point6, point5)
TurnRiverSln.addDecPt(point7, point5)
TurnRiverSln.addDecPt(point8, point5)
TurnRiverSln.addDecPt(point9, point8)
TurnRiverSln.addDecPt(point10, point8)
TurnRiverSln.addDecPt(point11, point2)
TurnRiverSln.addDecPt(point12, point11)
TurnRiverSln.addDecPt(point13, point11)
TurnRiverSln.addDecPt(point14, point11)
TurnRiverSln.addDecPt(point15, point14)
TurnRiverSln.addDecPt(point16, point14)
TurnRiverSln.addDecPt(point17, point1)
TurnRiverSln.addDecPt(point18, point17)
TurnRiverSln.addDecPt(point19, point17)
TurnRiverSln.addDecPt(point20, point19)
TurnRiverSln.addDecPt(point21, point17)
TurnRiverSln.addDecPt(point22, point21)
TurnRiverSln.addDecPt(point23, point22)
TurnRiverSln.addDecPt(point24, point22)
TurnRiverSln.addDecPt(point25, point24)
TurnRiverSln.addDecPt(point26, point24)
TurnRiverSln.addDecPt(point27, point24)
TurnRiverSln.addDecPt(point28, point27)
TurnRiverSln.addDecPt(point29, point27)
TurnRiverSln.addDecPt(point30, point21)
TurnRiverSln.addDecPt(point31, point30)
TurnRiverSln.addDecPt(point32, point30)
TurnRiverSln.addDecPt(point33, point30)
TurnRiverSln.addDecPt(point34, point33)
TurnRiverSln.addDecPt(point35, point33)
TurnRiverSln.addDecPt(point36, point19)
TurnRiverSln.addDecPt(point37, point36)
TurnRiverSln.addDecPt(point38, point37)
TurnRiverSln.addDecPt(point39, point37)
TurnRiverSln.addDecPt(point40, point39)
TurnRiverSln.addDecPt(point41, point39)
TurnRiverSln.addDecPt(point42, point39)
TurnRiverSln.addDecPt(point43, point42)
TurnRiverSln.addDecPt(point44, point42)
TurnRiverSln.addDecPt(point45, point36)
TurnRiverSln.addDecPt(point46, point45)
TurnRiverSln.addDecPt(point47, point45)
TurnRiverSln.addDecPt(point48, point45)
TurnRiverSln.addDecPt(point49, point48)
TurnRiverSln.addDecPt(point50, point48)
TurnRiverSln.addDecPt(point51, point0)
TurnRiverSln.addDecPt(point52, point51)
TurnRiverSln.addDecPt(point53, point51)
TurnRiverSln.addDecPt(point54, point51)
TurnRiverSln.addDecPt(point55, point54)
TurnRiverSln.addDecPt(point56, point55)
TurnRiverSln.addDecPt(point57, point55)
TurnRiverSln.addDecPt(point58, point57)
TurnRiverSln.addDecPt(point59, point57)
TurnRiverSln.addDecPt(point60, point57)
TurnRiverSln.addDecPt(point61, point60)
TurnRiverSln.addDecPt(point62, point60)
TurnRiverSln.addDecPt(point63, point54)
TurnRiverSln.addDecPt(point64, point63)
TurnRiverSln.addDecPt(point65, point63)
TurnRiverSln.addDecPt(point66, point63)
TurnRiverSln.addDecPt(point67, point66)
TurnRiverSln.addDecPt(point68, point66)
TurnRiverSln.addDecPt(point69, point53)
TurnRiverSln.addDecPt(point70, point53)
TurnRiverSln.addDecPt(point71, point70)
TurnRiverSln.addDecPt(point72, point70)
TurnRiverSln.addDecPt(point73, point72)
TurnRiverSln.addDecPt(point74, point73)
TurnRiverSln.addDecPt(point75, point73)
TurnRiverSln.addDecPt(point76, point73)
TurnRiverSln.addDecPt(point77, point76)
TurnRiverSln.addDecPt(point78, point76)
TurnRiverSln.addDecPt(point79, point53)
TurnRiverSln.addDecPt(point80, point79)
TurnRiverSln.addDecPt(point81, point79)
TurnRiverSln.addDecPt(point82, point80)
TurnRiverSln.addDecPt(point83, point80)
TurnRiverSln.addDecPt(point84, point83)
TurnRiverSln.addDecPt(point85, point83)
TurnRiverSln.addDecPt(point86, point83)
TurnRiverSln.addDecPt(point87, point86)
TurnRiverSln.addDecPt(point88, point86)
TurnRiverSln.addDecPt(point89, point81)
TurnRiverSln.addDecPt(point90, point81)
TurnRiverSln.addDecPt(point91, point81)
TurnRiverSln.addDecPt(point92, point91)
TurnRiverSln.addDecPt(point93, point91)



TurnRiverSln

# %%
bbLimitStartingRange = Range(0.0)
bbLimitStartingRange.setRangeString("A2,A3,A4,Q9,Q8,Q7,Q5,Q4,Q3,Q2,K6,J6,T6,96,86,76,56,46,K9,K8,K7,K5,K4,K3,K2,J8,J7, \
                                J6,J5,J4,J3,J2,T9,T8,55,44,33,22", 1.0)

sbLimitStartingRange = Range()
sbLimitStartingRange.setToTop(.92, pe.string2card(['__','__','__','__','__']))

sbLimitStartingRange.removeHandsWithConflicts(pe.string2card(['Qs', '6d','Ad', '9c']))
bbLimitStartingRange.removeHandsWithConflicts(pe.string2card(['Qs', '6d','Ad', '9c']))

display(bbLimitStartingRange)
display(sbLimitStartingRange)

# %%
S = 11


flopEArray = EquityArray(pe.string2card(['Tc','7d','4h','__','__']));
turn1EArray = EquityArray(pe.string2card(['Tc','7d','4h','Ks','__']));
turn2EArray = EquityArray(pe.string2card(['Tc','7d','4h','5s','__']));

point0 = DecPt('SB', 2.25, 2.25, flopEArray,"")
point1 = DecPt('Nature', 2.25, 2.25, flopEArray,"check")
point2 = DecPt('BB', 2.25, 2.25, turn1EArray,"board1")

point3 = DecPt('SB', 2.25, 2.25, turn1EArray,"check")
point4 = DecPt('SB', 2.25, 4.25, turn1EArray,"bet")
point5 = DecPt('Leaf', 2.25, 2.25, turn1EArray,"check")

point6 = DecPt('Leaf', 2.25, 4.25, turn1EArray,"fold")
point7 = DecPt('Leaf', 4.25, 4.25, turn1EArray,"call")
point8 = DecPt('BB', 6.25, 4.25, turn1EArray,"raise")

point9 = DecPt('Leaf', 6.25, 4.25, turn1EArray,"fold")
point10 = DecPt('Leaf', 6.25, 6.25, turn1EArray,"call")
point11 = DecPt('SB', 6.25, 8.25, turn1EArray,"raise")

point12 = DecPt('Leaf', 6.25, 8.25, turn1EArray,"fold")
point13 = DecPt('Leaf', 8.25, 8.25, turn1EArray,"call")
point14 = DecPt('SB', 2.25, 2.25, turn1EArray,"bet")

point15 = DecPt('Leaf', 2.25, 2.25, turn1EArray,"check")
point16 = DecPt('BB', 4.25, 2.25, turn1EArray,"bet")
point17 = DecPt('Leaf', 4.25, 2.25, turn1EArray,"fold")

point18 = DecPt('Leaf', 4.25, 4.25, turn1EArray,"call")
point19 = DecPt('SB', 4.25, 6.25, turn1EArray,"raise")

point20 = DecPt('Leaf', 4.25, 6.25, turn1EArray,"fold")
point21 = DecPt('Leaf', 6.25, 6.25, turn1EArray,"call")

point22 = DecPt('BB', 8.25, 6.25, turn1EArray,"raise")
point23 = DecPt('Leaf', 8.25, 6.25, turn1EArray,"fold")
point24 = DecPt('Leaf', 8.25, 8.25, turn1EArray,"call")
point25 = DecPt('SB', 2.25, 2.25, turn2EArray,"check")
point26 = DecPt('Leaf', 2.25, 2.25, turn2EArray,"check")

point27 = DecPt('BB', 4.25, 2.25, turn2EArray,"bet")
point28 = DecPt('Leaf', 4.25, 2.25, turn2EArray,"fold")
point29 = DecPt('Leaf', 4.25, 4.25, turn2EArray,"call")

point30 = DecPt('SB', 4.25, 6.25, turn2EArray,"raise")
point31 = DecPt('Leaf', 4.25, 6.25, turn2EArray,"fold")
point32 = DecPt('Leaf', 6.25, 6.25, turn2EArray,"call")
point33 = DecPt('BB', 8.25, 6.25, turn2EArray,"raise")

point34 = DecPt('Leaf', 8.25, 6.25, turn2EArray,"fold")
point35 = DecPt('Leaf', 8.25, 8.25, turn2EArray,"call")
point36 = DecPt('SB', 2.25, 4.25, turn2EArray,"bet")

point37 = DecPt('Leaf', 2.25, 4.25, turn2EArray,"fold")
point38 = DecPt('Leaf', 4.25, 4.25, turn2EArray,"call")
point39 = DecPt('BB', 6.25, 4.25, turn2EArray,"raise")

point40 = DecPt('Leaf', 6.25, 4.25, turn2EArray,"fold")
point41 = DecPt('Leaf', 6.25, 6.25, turn2EArray,"call")
point42 = DecPt('SB', 6.25, 8.25, turn2EArray,"raise")

point43 = DecPt('Leaf', 6.25, 8.25, turn2EArray,"fold")
point44 = DecPt('Leaf', 8.25, 8.25, turn2EArray,"call")
point45 = DecPt('SB', 3.25, 2.25, flopEArray,"bet")

point46 = DecPt('Leaf', 3.25, 2.25, flopEArray,"fold")
point47 = DecPt('Nature', 3.25, 3.25, flopEArray,"call")
point48 = DecPt('SB', 3.25, 4.25, flopEArray,"raise")

point49 = DecPt('Leaf', 3.25, 4.25, flopEArray,"fold")
point50 = DecPt('Nature', 4.25, 4.25, flopEArray,"call")
point51 = DecPt('BB', 3.25, 3.25, turn1EArray,"board1")

point52 = DecPt('SB', 3.25, 3.25, turn1EArray,"check")
point53 = DecPt('Leaf', 3.25, 3.25, turn1EArray,"check")
point54 = DecPt('BB', 5.25, 3.25, turn1EArray,"bet")
point55 = DecPt('Leaf', 5.25, 3.25, turn1EArray,"fold")

point56 = DecPt('Leaf', 5.25, 5.25, turn1EArray,"call")
point57 = DecPt('SB', 5.25, 7.25, turn1EArray,"raise")
point58 = DecPt('Leaf', 5.25, 7.25, turn1EArray,"fold")

point59 = DecPt('Leaf', 7.25, 7.25, turn1EArray,"call")
point60 = DecPt('BB', 9.25, 7.25, turn1EArray,"raise")
point61 = DecPt('Leaf', 9.25, 7.25, turn1EArray,"fold")
point62 = DecPt('Leaf', 9.25, 9.25, turn1EArray,"call")

point63 = DecPt('SB', 3.25, 5.25, turn1EArray,"bet")
point64 = DecPt('Leaf', 3.25, 5.25, turn1EArray,"fold")
point65 = DecPt('Leaf', 5.25, 5.25, turn1EArray,"call")

point66 = DecPt('BB', 7.25, 5.25, turn1EArray,"raise")
point67 = DecPt('Leaf', 7.25, 5.25, turn1EArray,"fold")
point68 = DecPt('Leaf', 7.25, 7.25, turn1EArray,"call")

point69 = DecPt('SB', 7.25, 9.25, turn1EArray,"raise")
point70 = DecPt('Leaf', 7.25, 9.25, turn1EArray,"fold")

point71 = DecPt('Leaf', 9.25, 9.25, turn1EArray,"call")
point72 = DecPt('BB', 3.25, 3.25, turn2EArray,"turn2")

point73 = DecPt('SB', 3.25, 3.25, turn2EArray,"check")
point74 = DecPt('Leaf', 3.25, 3.25, turn2EArray,"check")
point75 = DecPt('BB', 5.25, 3.25, turn2EArray,"bet")

point76 = DecPt('Leaf', 5.25, 3.25, turn2EArray,"fold")
point77 = DecPt('Leaf', 5.25, 5.25, turn2EArray,"call")
point78 = DecPt('SB', 5.25, 7.25, turn2EArray,"raise")

point79 = DecPt('Leaf', 5.25, 7.25, turn2EArray,"fold")
point80 = DecPt('Leaf', 7.25, 7.25, turn2EArray,"call")
point81 = DecPt('BB', 9.25, 7.25, turn2EArray,"raise")
point82 = DecPt('Leaf', 9.25, 7.25, turn2EArray,"fold")
point83 = DecPt('Leaf', 9.25, 9.25, turn2EArray,"call")

point84 = DecPt('BB', 4.25, 4.25, turn1EArray,"turn1")
point85 = DecPt('SB', 4.25, 4.25, turn1EArray,"check")
point86 = DecPt('Leaf', 4.25, 4.25, turn1EArray,"check")

point87 = DecPt('BB', 6.25, 4.25, turn1EArray,"bet")
point88 = DecPt('Leaf', 6.25, 4.25, turn1EArray,"fold")
point89 = DecPt('Leaf', 6.25, 6.25, turn1EArray,"call")
point90 = DecPt('SB', 6.25, 8.25, turn1EArray,"raise")

point91 = DecPt('Leaf', 6.25, 8.25, turn1EArray,"fold")
point92 = DecPt('Leaf', 8.25, 8.25, turn1EArray,"call")
point93 = DecPt('BB', 10.25, 8.25, turn1EArray,"fold")

point94 = DecPt('Leaf', 10.25, 8.25, turn1EArray,"fold")
point95 = DecPt('Leaf', 10.25, 10.25, turn1EArray,"call")

point96 = DecPt('SB', 4.25, 6.25, turn1EArray,"bet")
point97 = DecPt('Leaf', 4.25, 6.25, turn1EArray,"fold")
point98 = DecPt('Leaf', 6.25, 6.25, turn1EArray,"call")

point99 = DecPt('BB', 8.25, 6.25, turn1EArray,"raise")
point100 = DecPt('Leaf', 8.25, 6.25, turn1EArray,"fold")
point101 = DecPt('Leaf', 8.25, 8.25, turn1EArray,"call")

point102 = DecPt('SB', 8.25, 10.25, turn1EArray,"raise")
point103 = DecPt('Leaf', 8.25, 10.25, turn1EArray,"fold")
point104 = DecPt('Leaf', 10.25, 10.25, turn1EArray,"call")
point105 = DecPt('BB', 4.25, 4.25, turn2EArray,"board")
point106 = DecPt('SB', 4.25, 4.25, turn2EArray,"check")

point107 = DecPt('Leaf', 4.25, 4.25, turn2EArray,"check")
point108 = DecPt('BB', 6.25, 4.25, turn2EArray,"bet")
point109 = DecPt('Leaf', 6.25, 4.25, turn2EArray,"fold")

point110 = DecPt('Leaf', 6.25, 6.25, turn2EArray,"call")
point111 = DecPt('SB', 6.25, 8.25, turn2EArray,"raise")
point112 = DecPt('Leaf', 6.25, 8.25, turn2EArray,"fold")
point113 = DecPt('Leaf', 8.25, 8.25, turn2EArray,"call")

point114 = DecPt('BB', 10.25, 8.25, turn2EArray,"raise")
point115 = DecPt('Leaf', 10.25, 8.25, turn2EArray,"fold")
point116 = DecPt('Leaf', 10.25, 10.25, turn2EArray,"call")

point117 = DecPt('SB', 4.25, 6.25, turn2EArray,"bet")
point118 = DecPt('Leaf', 4.25, 6.25, turn2EArray,"fold")
point119 = DecPt('Leaf', 6.25, 6.25, turn2EArray,"call")

point120 = DecPt('BB', 8.25, 6.25, turn2EArray,"raise")
point121 = DecPt('Leaf', 8.25, 6.25, turn2EArray,"fold")
point122 = DecPt('Leaf', 8.25, 8.25, turn2EArray,"call")
point123 = DecPt('SB', 8.25, 10.25, turn2EArray,"raise")

point124 = DecPt('Leaf', 8.25, 10.25, turn2EArray,"fold")
point125 = DecPt('Leaf', 10.25, 10.25, turn2EArray,"call")
point126 = DecPT('Leaf', 2.25, 2.25, turn2EArray, "board2")

point127 = DecPt('SB', 3.25, 3.25, turn2EArray,"bet")
point128 = DecPt('Leaf', 3.25, 5.25, turn2EArray,"fold")
point129 = DecPt('Leaf', 5.25, 5.25, turn2EArray,"call")
point130 = DecPt('BB', 7.25, 5.25, turn2EArray,"raise")

point131 = DecPt('Leaf', 7.25, 5.25, turn2EArray,"fold")
point132 = DecPt('Leaf', 7.25, 7.25, turn2EArray,"call")
point133 = DecPt('SB', 7.25, 9.25, turn2EArray,"raise")

point134 = DecPt('Leaf', 7.25, 9.25, turn2EArray,"fold")
point135 = DecPt('Leaf', 9.25, 9.25, turn2EArray,"call")



FlopSln = Tree(S, point0)
FlopSln.addDecPt(point1, point0)
FlopSln.addDecPt(point2, point1)
FlopSln.addDecPt(point3, point2)
FlopSln.addDecPt(point4, point2)
FlopSln.addDecPt(point5, point3)
FlopSln.addDecPt(point6, point4)
FlopSln.addDecPt(point7, point4)
FlopSln.addDecPt(point8, point4)
FlopSln.addDecPt(point9, point8)
FlopSln.addDecPt(point10, point8)
FlopSln.addDecPt(point11, point8)
FlopSln.addDecPt(point12, point11)
FlopSln.addDecPt(point13, point11)
FlopSln.addDecPt(point14, point3)
FlopSln.addDecPt(point15, point14)
FlopSln.addDecPt(point16, point14)
FlopSln.addDecPt(point17, point16)
FlopSln.addDecPt(point18, point16)
FlopSln.addDecPt(point19, point16)
FlopSln.addDecPt(point20, point19)
FlopSln.addDecPt(point21, point19)
FlopSln.addDecPt(point22, point19)
FlopSln.addDecPt(point23, point22)
FlopSln.addDecPt(point24, point22)
FlopSln.addDecPt(point25, point126)
FlopSln.addDecPt(point26, point25)
FlopSln.addDecPt(point27, point25)
FlopSln.addDecPt(point28, point27)
FlopSln.addDecPt(point29, point27)
FlopSln.addDecPt(point30, point27)
FlopSln.addDecPt(point31, point30)
FlopSln.addDecPt(point32, point30)
FlopSln.addDecPt(point33, point30)
FlopSln.addDecPt(point34, point33)
FlopSln.addDecPt(point35, point33)
FlopSln.addDecPt(point36, point126)
FlopSln.addDecPt(point37, point36)
FlopSln.addDecPt(point38, point36)
FlopSln.addDecPt(point39, point36)
FlopSln.addDecPt(point40, point39)
FlopSln.addDecPt(point41, point39)
FlopSln.addDecPt(point42, point39)
FlopSln.addDecPt(point43, point42)
FlopSln.addDecPt(point44, point42)
FlopSln.addDecPt(point45, point0)
FlopSln.addDecPt(point46, point45)
FlopSln.addDecPt(point47, point45)
FlopSln.addDecPt(point48, point45)
FlopSln.addDecPt(point49, point48)
FlopSln.addDecPt(point50, point48)
FlopSln.addDecPt(point51, point47)
FlopSln.addDecPt(point52, point51)
FlopSln.addDecPt(point53, point52)
FlopSln.addDecPt(point54, point52)
FlopSln.addDecPt(point55, point54)
FlopSln.addDecPt(point56, point54)
FlopSln.addDecPt(point57, point54)
FlopSln.addDecPt(point58, point57)
FlopSln.addDecPt(point59, point57)
FlopSln.addDecPt(point60, point57)
FlopSln.addDecPt(point61, point60)
FlopSln.addDecPt(point62, point60)
FlopSln.addDecPt(point63, point51)
FlopSln.addDecPt(point64, point63)
FlopSln.addDecPt(point65, point63)
FlopSln.addDecPt(point66, point63)
FlopSln.addDecPt(point67, point66)
FlopSln.addDecPt(point68, point66)
FlopSln.addDecPt(point69, point66)
FlopSln.addDecPt(point70, point69)
FlopSln.addDecPt(point71, point69)
FlopSln.addDecPt(point72, point47)
FlopSln.addDecPt(point73, point72)
FlopSln.addDecPt(point74, point73)
FlopSln.addDecPt(point75, point73)
FlopSln.addDecPt(point76, point75)
FlopSln.addDecPt(point77, point75)
FlopSln.addDecPt(point78, point75)
FlopSln.addDecPt(point79, point78)
FlopSln.addDecPt(point80, point78)
FlopSln.addDecPt(point81, point78)
FlopSln.addDecPt(point82, point81)
FlopSln.addDecPt(point83, point81)
FlopSln.addDecPt(point84, point50)
FlopSln.addDecPt(point85, point84)
FlopSln.addDecPt(point86, point85)
FlopSln.addDecPt(point87, point85)
FlopSln.addDecPt(point88, point87)
FlopSln.addDecPt(point89, point87)
FlopSln.addDecPt(point90, point87)
FlopSln.addDecPt(point91, point90)
FlopSln.addDecPt(point92, point90)
FlopSln.addDecPt(point93, point90)
FlopSln.addDecPt(point94, point93)
FlopSln.addDecPt(point95, point93)
FlopSln.addDecPt(point96, point84)
FlopSln.addDecPt(point97, point96)
FlopSln.addDecPt(point98, point96)
FlopSln.addDecPt(point99, point96)
FlopSln.addDecPt(point100, point99)
FlopSln.addDecPt(point101, point99)
FlopSln.addDecPt(point102, point99)
FlopSln.addDecPt(point103, point102)
FlopSln.addDecPt(point104, point102)
FlopSln.addDecPt(point105, point50)
FlopSln.addDecPt(point106, point105)
FlopSln.addDecPt(point107, point106)
FlopSln.addDecPt(point108, point106)
FlopSln.addDecPt(point109, point108)
FlopSln.addDecPt(point110, point108)
FlopSln.addDecPt(point111, point108)
FlopSln.addDecPt(point112, point111)
FlopSln.addDecPt(point113, point111)
FlopSln.addDecPt(point114, point111)
FlopSln.addDecPt(point115, point114)
FlopSln.addDecPt(point116, point114)
FlopSln.addDecPt(point117, point105)
FlopSln.addDecPt(point118, point117)
FlopSln.addDecPt(point119, point117)
FlopSln.addDecPt(point120, point117)
FlopSln.addDecPt(point121, point120)
FlopSln.addDecPt(point122, point120)
FlopSln.addDecPt(point123, point120)
FlopSln.addDecPt(point124, point123)
FlopSln.addDecPt(point125, point123)
FlopSln.addDecPt(point126, point1)
FlopSln.addDecPt(point127, point72)
FlopSln.addDecPt(point128, point127)
FlopSln.addDecPt(point129, point127)
FlopSln.addDecPt(point130, point127)
FlopSln.addDecPt(point131, point130)
FlopSln.addDecPt(point132, point130)
FlopSln.addDecPt(point133, point130)
FlopSln.addDecPt(point134, point133)
FlopSln.addDecPt(point135, point133)

FlopSln

# %%
limitStrats = StrategyPair(FlopSln, sbFlopRange, bbFlopRange) 

myLimitRange = Range()
myLimitRange.setToTop(0.35, pe.string2card(['__','__','__','__','__']))

#myZeroRange.setRangeString("72", 1.0)

myLimitRange.removeHandsWithConflicts(pe.string2card(['Tc','9h','8h','__','__']))

limitStrats.ranges[13] = myLimitRange
limitStrats.ranges
#limitStrats.ranges[1] = myZeroRange

# %%
# River tree builder
#Inputs: pot = starting pot size in SB, node = starting node number, 
# array = EQarray 

#def riverTreeBldr (tree, pot, node, array):
potSize = 10.0
array = 'riverEArray'
node = 0
for i in range(27):
    sbCIP = potSize/2
    bbCIP = potSize/2
    if i == 0:
        player = 'BB'
        action = "''"
    elif i == 1:
        player = 'SB'
        action = 'check'
    elif i == 2:
        player = 'Leaf'
        action = 'check'
    elif i == 3:
        player = 'BB'
        action = 'bet'
        sbCIP += 2.0
    elif i == 4:
        player = 'Leaf'
        action = 'fold'
        sbCIP += 2.0
    elif i == 5:
        player = 'Leaf'
        action = 'call'
        sbCIP += 2.0
        bbCIP += 2.0
    elif i == 6:
        player = 'SB'
        action = "raise"
        sbCIP += 2.0
        bbCIP += 4.0
    elif i == 7:
        player = 'Leaf'
        action = 'fold'
        sbCIP += 2.0
        bbCIP += 4.0
    elif i == 8:
        player = 'Leaf'
        action = 'call'
        sbCIP += 4.0
        bbCIP += 4.0
    elif i == 9:
        player = 'BB'
        action = 'raise'
        sbCIP += 6.0
        bbCIP += 4.0
    elif i == 10:
        player = 'Leaf'
        action = 'fold'
        sbCIP += 6.0
        bbCIP += 4.0
    elif i == 11:
        player = 'Leaf'
        action = 'call'
        sbCIP += 6.0
        bbCIP += 6.0
    elif i == 12:
        player = 'SB'
        action = 'raise'
        sbCIP += 6.0
        bbCIP += 8.0
    elif i == 13:
        player = 'Leaf'
        action = "fold"
        sbCIP += 6.0
        bbCIP += 8.0
    elif i == 14:
        player = 'Leaf'
        action = 'call'
        sbCIP += 8.0
        bbCIP += 8.0
    elif i == 15:
        player = 'SB'
        action = 'bet'
        sbCIP += 0.0
        bbCIP += 2.0
    elif i == 16:
        player = 'Leaf'
        action = 'fold'
        sbCIP += 0.0
        bbCIP += 2.0
    elif i == 17:
        player = 'Leaf'
        action = 'call'
        sbCIP += 2.0
        bbCIP += 2.0
    elif i == 18:
        player = 'BB'
        action = 'raise'
        sbCIP += 4.0
        bbCIP += 2.0
    elif i == 19:
        player = 'Leaf'
        action = 'fold'
        sbCIP += 4.0
        bbCIP += 2.0
    elif i == 20:
        player = 'Leaf'
        action = "call"
        sbCIP += 4.0
        bbCIP += 4.0
    elif i == 21:
        player = 'SB'
        action = 'raise'
        sbCIP += 4.0
        bbCIP += 6.0
    elif i == 22:
        player = 'Leaf'
        action = 'fold'
        sbCIP += 4.0
        bbCIP += 6.0
    elif i == 23:
        player = 'Leaf'
        action = 'call'
        sbCIP += 6.0
        bbCIP += 6.0
    elif i == 24:
        player = 'BB'
        action = 'raise'
        sbCIP += 8.0
        bbCIP += 6.0
    elif i == 25:
        player = 'Leaf'
        action = 'fold'
        sbCIP += 8.0
        bbCIP += 6.0
    elif i == 26:
        player = 'Leaf'
        action = 'call'
        sbCIP += 8.0
        bbCIP += 8.0
    else:
        print ("ERROR in Tree")
    print ("point" + str(node) + "= DecPt ('" + str(player) + "', " + str(sbCIP) + ", " + str(bbCIP) + ", " + \
           str(array) + ", '" + action + "')")
    node += 1

tree = 'riverSln'
child = 0
    
for i in range(27):
    sbCIP = potSize/2
    bbCIP = potSize/2
    if i == 0:
        print (" ")
    elif i == 1 or i == 2 or i == 4 or i == 7 or i == 10 or i == 13 or i == 16 or i == 19 or i == 22 or i == 25:
        child = i - 1
        print (str(tree) + ".addDecPt(point" + str(i) + ", point" + str(child) + ")")
    elif i == 3 or i == 5 or i == 8 or i == 11 or i == 14 or i == 17 or i == 20 or i == 23 or i == 26:
        child = i - 2
        print (str(tree) + ".addDecPt(point" + str(i) + ", point" + str(child) + ")")
    elif i == 6 or i == 9 or i == 12  or i == 18 or i == 21 or i == 24:
        child = i - 3
        print (str(tree) + ".addDecPt(point" + str(i) + ", point" + str(child) + ")")
    elif i == 15:
        child = i - 15
        print (str(tree) + ".addDecPt(point" + str(i) + ", point" + str(child) + ")")
    else:
        print ("ERROR in Tree")
# Out:
# point0= DecPt ('BB', 5.0, 5.0, riverEArray, '''')
# point1= DecPt ('SB', 5.0, 5.0, riverEArray, 'check')
# point2= DecPt ('Leaf', 5.0, 5.0, riverEArray, 'check')
# point3= DecPt ('BB', 7.0, 5.0, riverEArray, 'bet')
# point4= DecPt ('Leaf', 7.0, 5.0, riverEArray, 'fold')
# point5= DecPt ('Leaf', 7.0, 7.0, riverEArray, 'call')
# point6= DecPt ('SB', 7.0, 9.0, riverEArray, 'raise')
# point7= DecPt ('Leaf', 7.0, 9.0, riverEArray, 'fold')
# point8= DecPt ('Leaf', 9.0, 9.0, riverEArray, 'call')
# point9= DecPt ('BB', 11.0, 9.0, riverEArray, 'raise')
# point10= DecPt ('Leaf', 11.0, 9.0, riverEArray, 'fold')
# point11= DecPt ('Leaf', 11.0, 11.0, riverEArray, 'call')
# point12= DecPt ('SB', 11.0, 13.0, riverEArray, 'raise')
# point13= DecPt ('Leaf', 11.0, 13.0, riverEArray, 'fold')
# point14= DecPt ('Leaf', 13.0, 13.0, riverEArray, 'call')
# point15= DecPt ('SB', 5.0, 7.0, riverEArray, 'bet')
# point16= DecPt ('Leaf', 5.0, 7.0, riverEArray, 'fold')
# ...

# %% [raw]
# S = 13
#
# riverEArray = EquityArray(pe.string2card(['Tc','7d','4h','5s','9s']));
#
#
# point0= DecPt ('BB', 5.0, 5.0, riverEArray, '''')
# point1= DecPt ('SB', 5.0, 5.0, riverEArray, 'check')
# point2= DecPt ('Leaf', 5.0, 5.0, riverEArray, 'check')
# point3= DecPt ('BB', 7.0, 5.0, riverEArray, 'bet')
# point4= DecPt ('Leaf', 7.0, 5.0, riverEArray, 'fold')
# point5= DecPt ('Leaf', 7.0, 7.0, riverEArray, 'call')
# point6= DecPt ('SB', 7.0, 9.0, riverEArray, 'raise')
# point7= DecPt ('Leaf', 7.0, 9.0, riverEArray, 'fold')
# point8= DecPt ('Leaf', 9.0, 9.0, riverEArray, 'call')
# point9= DecPt ('BB', 11.0, 9.0, riverEArray, 'raise')
# point10= DecPt ('Leaf', 11.0, 9.0, riverEArray, 'fold')
# point11= DecPt ('Leaf', 11.0, 11.0, riverEArray, 'call')
# point12= DecPt ('SB', 11.0, 13.0, riverEArray, 'raise')
# point13= DecPt ('Leaf', 11.0, 13.0, riverEArray, 'fold')
# point14= DecPt ('Leaf', 13.0, 13.0, riverEArray, 'call')
# point15= DecPt ('SB', 5.0, 7.0, riverEArray, 'bet')
# point16= DecPt ('Leaf', 5.0, 7.0, riverEArray, 'fold')
# point17= DecPt ('Leaf', 7.0, 7.0, riverEArray, 'call')
# point18= DecPt ('BB', 9.0, 7.0, riverEArray, 'raise')
# point19= DecPt ('Leaf', 9.0, 7.0, riverEArray, 'fold')
# point20= DecPt ('Leaf', 9.0, 9.0, riverEArray, 'call')
# point21= DecPt ('SB', 9.0, 11.0, riverEArray, 'raise')
# point22= DecPt ('Leaf', 9.0, 11.0, riverEArray, 'fold')
# point23= DecPt ('Leaf', 11.0, 11.0, riverEArray, 'call')
# point24= DecPt ('BB', 13.0, 11.0, riverEArray, 'raise')
# point25= DecPt ('Leaf', 13.0, 11.0, riverEArray, 'fold')
# point26= DecPt ('Leaf', 13.0, 13.0, riverEArray, 'call')
#
# riverSln = Tree(S, point0)
# riverSln.addDecPt(point1, point0)
# riverSln.addDecPt(point2, point1)
# riverSln.addDecPt(point3, point1)
# riverSln.addDecPt(point4, point3)
# riverSln.addDecPt(point5, point3)
# riverSln.addDecPt(point6, point3)
# riverSln.addDecPt(point7, point6)
# riverSln.addDecPt(point8, point6)
# riverSln.addDecPt(point9, point6)
# riverSln.addDecPt(point10, point9)
# riverSln.addDecPt(point11, point9)
# riverSln.addDecPt(point12, point9)
# riverSln.addDecPt(point13, point12)
# riverSln.addDecPt(point14, point12)
# riverSln.addDecPt(point15, point0)
# riverSln.addDecPt(point16, point15)
# riverSln.addDecPt(point17, point15)
# riverSln.addDecPt(point18, point15)
# riverSln.addDecPt(point19, point18)
# riverSln.addDecPt(point20, point18)
# riverSln.addDecPt(point21, point18)
# riverSln.addDecPt(point22, point21)
# riverSln.addDecPt(point23, point21)
# riverSln.addDecPt(point24, point21)
# riverSln.addDecPt(point25, point24)
# riverSln.addDecPt(point26, point24)
#
# riverSln

# %% [raw]
# riverTreeBldr (10, 0, riverEArray)

# %%
point0= DecPt ('BB', 2.25, 2.25, flopEArray, '')
point1= DecPt ('SB', 2.25, 2.25, flopEArray, 'check')
point2= DecPt ('Nature', 2.25, 2.25, flopEArray, 'check')
point3= DecPt ('BB', 3.25, 2.25, flopEArray, 'bet')
point4= DecPt ('Leaf', 3.25, 2.25, flopEArray, 'fold')
point5= DecPt ('Nature', 3.25, 3.25, flopEArray, 'call')
point6= DecPt ('SB', 3.25, 4.25, flopEArray, 'raise')
point7= DecPt ('Leaf', 3.25, 4.25, flopEArray, 'fold')
point8= DecPt ('Nature', 4.25, 4.25, flopEArray, 'call')
point9= DecPt ('BB', 5.25, 4.25, flopEArray, 'raise')
point10= DecPt ('Leaf', 5.25, 4.25, flopEArray, 'fold')
point11= DecPt ('Nature', 5.25, 5.25, flopEArray, 'call')
point12= DecPt ('SB', 5.25, 6.25, flopEArray, 'raise')
point13= DecPt ('Leaf', 5.25, 6.25, flopEArray, 'fold')
point14= DecPt ('Nature', 6.25, 6.25, flopEArray, 'call')
point15= DecPt ('SB', 2.25, 3.25, flopEArray, 'bet')
point16= DecPt ('Leaf', 2.25, 3.25, flopEArray, 'fold')
point17= DecPt ('Nature', 3.25, 3.25, flopEArray, 'call')
point18= DecPt ('BB', 4.25, 3.25, flopEArray, 'raise')
point19= DecPt ('Leaf', 4.25, 3.25, flopEArray, 'fold')
point20= DecPt ('Nature', 4.25, 4.25, flopEArray, 'call')
point21= DecPt ('SB', 4.25, 5.25, flopEArray, 'raise')
point22= DecPt ('Leaf', 4.25, 5.25, flopEArray, 'fold')
point23= DecPt ('Nature', 5.25, 5.25, flopEArray, 'call')
point24= DecPt ('BB', 6.25, 5.25, flopEArray, 'raise')
point25= DecPt ('Leaf', 6.25, 5.25, flopEArray, 'fold')
point26= DecPt ('Nature', 6.25, 6.25, flopEArray, 'call')
point27= DecPt ('BB', 2.25, 2.25, turnAEArray, '5d7cQdJh__')
point28= DecPt ('BB', 2.25, 2.25, turnBEArray, '5d7cQd6h__')
point29= DecPt ('BB', 3.25, 3.25, turnAEArray, '5d7cQdJh__')
point30= DecPt ('BB', 3.25, 3.25, turnBEArray, '5d7cQd6h__')
point31= DecPt ('BB', 4.25, 4.25, turnAEArray, '5d7cQdJh__')
point32= DecPt ('BB', 4.25, 4.25, turnBEArray, '5d7cQd6h__')
point33= DecPt ('BB', 5.25, 5.25, turnAEArray, '5d7cQdJh__')
point34= DecPt ('BB', 5.25, 5.25, turnBEArray, '5d7cQd6h__')
point35= DecPt ('BB', 6.25, 6.25, turnAEArray, '5d7cQdJh__')
point36= DecPt ('BB', 6.25, 6.25, turnBEArray, '5d7cQd6h__')
point37= DecPt ('BB', 3.25, 3.25, turnAEArray, '5d7cQdJh__')
point38= DecPt ('BB', 3.25, 3.25, turnBEArray, '5d7cQd6h__')
point39= DecPt ('BB', 4.25, 4.25, turnAEArray, '5d7cQdJh__')
point40= DecPt ('BB', 4.25, 4.25, turnBEArray, '5d7cQd6h__')
point41= DecPt ('BB', 5.25, 5.25, turnAEArray, '5d7cQdJh__')
point42= DecPt ('BB', 5.25, 5.25, turnBEArray, '5d7cQd6h__')
point43= DecPt ('BB', 6.25, 6.25, turnAEArray, '5d7cQdJh__')
point44= DecPt ('BB', 6.25, 6.25, turnBEArray, '5d7cQd6h__')
point45= DecPt ('SB', 2.25, 2.25, turnAEArray, 'check')
point46= DecPt ('Leaf', 2.25, 2.25, turnAEArray, 'check')
point47= DecPt ('BB', 4.25, 2.25, turnAEArray, 'bet')
point48= DecPt ('Leaf', 4.25, 2.25, turnAEArray, 'fold')
point49= DecPt ('Leaf', 4.25, 4.25, turnAEArray, 'call')
point50= DecPt ('SB', 4.25, 6.25, turnAEArray, 'raise')
point51= DecPt ('Leaf', 4.25, 6.25, turnAEArray, 'fold')
point52= DecPt ('Leaf', 6.25, 6.25, turnAEArray, 'call')
point53= DecPt ('BB', 8.25, 6.25, turnAEArray, 'raise')
point54= DecPt ('Leaf', 8.25, 6.25, turnAEArray, 'fold')
point55= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point56= DecPt ('SB', 8.25, 10.25, turnAEArray, 'raise')
point57= DecPt ('Leaf', 8.25, 10.25, turnAEArray, 'fold')
point58= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point59= DecPt ('SB', 2.25, 4.25, turnAEArray, 'bet')
point60= DecPt ('Leaf', 2.25, 4.25, turnAEArray, 'fold')
point61= DecPt ('Leaf', 4.25, 4.25, turnAEArray, 'call')
point62= DecPt ('BB', 6.25, 4.25, turnAEArray, 'raise')
point63= DecPt ('Leaf', 6.25, 4.25, turnAEArray, 'fold')
point64= DecPt ('Leaf', 6.25, 6.25, turnAEArray, 'call')
point65= DecPt ('SB', 6.25, 8.25, turnAEArray, 'raise')
point66= DecPt ('Leaf', 6.25, 8.25, turnAEArray, 'fold')
point67= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point68= DecPt ('BB', 10.25, 8.25, turnAEArray, 'raise')
point69= DecPt ('Leaf', 10.25, 8.25, turnAEArray, 'fold')
point70= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point71= DecPt ('SB', 2.25, 2.25, turnBEArray, 'check')
point72= DecPt ('Leaf', 2.25, 2.25, turnBEArray, 'check')
point73= DecPt ('BB', 4.25, 2.25, turnBEArray, 'bet')
point74= DecPt ('Leaf', 4.25, 2.25, turnBEArray, 'fold')
point75= DecPt ('Leaf', 4.25, 4.25, turnBEArray, 'call')
point76= DecPt ('SB', 4.25, 6.25, turnBEArray, 'raise')
point77= DecPt ('Leaf', 4.25, 6.25, turnBEArray, 'fold')
point78= DecPt ('Leaf', 6.25, 6.25, turnBEArray, 'call')
point79= DecPt ('BB', 8.25, 6.25, turnBEArray, 'raise')
point80= DecPt ('Leaf', 8.25, 6.25, turnBEArray, 'fold')
point81= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point82= DecPt ('SB', 8.25, 10.25, turnBEArray, 'raise')
point83= DecPt ('Leaf', 8.25, 10.25, turnBEArray, 'fold')
point84= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point85= DecPt ('SB', 2.25, 4.25, turnBEArray, 'bet')
point86= DecPt ('Leaf', 2.25, 4.25, turnBEArray, 'fold')
point87= DecPt ('Leaf', 4.25, 4.25, turnBEArray, 'call')
point88= DecPt ('BB', 6.25, 4.25, turnBEArray, 'raise')
point89= DecPt ('Leaf', 6.25, 4.25, turnBEArray, 'fold')
point90= DecPt ('Leaf', 6.25, 6.25, turnBEArray, 'call')
point91= DecPt ('SB', 6.25, 8.25, turnBEArray, 'raise')
point92= DecPt ('Leaf', 6.25, 8.25, turnBEArray, 'fold')
point93= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point94= DecPt ('BB', 10.25, 8.25, turnBEArray, 'raise')
point95= DecPt ('Leaf', 10.25, 8.25, turnBEArray, 'fold')
point96= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point97= DecPt ('SB', 3.25, 3.25, turnAEArray, 'check')
point98= DecPt ('Leaf', 3.25, 3.25, turnAEArray, 'check')
point99= DecPt ('BB', 5.25, 3.25, turnAEArray, 'bet')
point100= DecPt ('Leaf', 5.25, 3.25, turnAEArray, 'fold')
point101= DecPt ('Leaf', 5.25, 5.25, turnAEArray, 'call')
point102= DecPt ('SB', 5.25, 7.25, turnAEArray, 'raise')
point103= DecPt ('Leaf', 5.25, 7.25, turnAEArray, 'fold')
point104= DecPt ('Leaf', 7.25, 7.25, turnAEArray, 'call')
point105= DecPt ('BB', 9.25, 7.25, turnAEArray, 'raise')
point106= DecPt ('Leaf', 9.25, 7.25, turnAEArray, 'fold')
point107= DecPt ('Leaf', 9.25, 9.25, turnAEArray, 'call')
point108= DecPt ('SB', 9.25, 11.25, turnAEArray, 'raise')
point109= DecPt ('Leaf', 9.25, 11.25, turnAEArray, 'fold')
point110= DecPt ('Leaf', 11.25, 11.25, turnAEArray, 'call')
point111= DecPt ('SB', 3.25, 5.25, turnAEArray, 'bet')
point112= DecPt ('Leaf', 3.25, 5.25, turnAEArray, 'fold')
point113= DecPt ('Leaf', 5.25, 5.25, turnAEArray, 'call')
point114= DecPt ('BB', 7.25, 5.25, turnAEArray, 'raise')
point115= DecPt ('Leaf', 7.25, 5.25, turnAEArray, 'fold')
point116= DecPt ('Leaf', 7.25, 7.25, turnAEArray, 'call')
point117= DecPt ('SB', 7.25, 9.25, turnAEArray, 'raise')
point118= DecPt ('Leaf', 7.25, 9.25, turnAEArray, 'fold')
point119= DecPt ('Leaf', 9.25, 9.25, turnAEArray, 'call')
point120= DecPt ('BB', 11.25, 9.25, turnAEArray, 'raise')
point121= DecPt ('Leaf', 11.25, 9.25, turnAEArray, 'fold')
point122= DecPt ('Leaf', 11.25, 11.25, turnAEArray, 'call')
point123= DecPt ('SB', 3.25, 3.25, turnBEArray, 'check')
point124= DecPt ('Leaf', 3.25, 3.25, turnBEArray, 'check')
point125= DecPt ('BB', 5.25, 3.25, turnBEArray, 'bet')
point126= DecPt ('Leaf', 5.25, 3.25, turnBEArray, 'fold')
point127= DecPt ('Leaf', 5.25, 5.25, turnBEArray, 'call')
point128= DecPt ('SB', 5.25, 7.25, turnBEArray, 'raise')
point129= DecPt ('Leaf', 5.25, 7.25, turnBEArray, 'fold')
point130= DecPt ('Leaf', 7.25, 7.25, turnBEArray, 'call')
point131= DecPt ('BB', 9.25, 7.25, turnBEArray, 'raise')
point132= DecPt ('Leaf', 9.25, 7.25, turnBEArray, 'fold')
point133= DecPt ('Leaf', 9.25, 9.25, turnBEArray, 'call')
point134= DecPt ('SB', 9.25, 11.25, turnBEArray, 'raise')
point135= DecPt ('Leaf', 9.25, 11.25, turnBEArray, 'fold')
point136= DecPt ('Leaf', 11.25, 11.25, turnBEArray, 'call')
point137= DecPt ('SB', 3.25, 5.25, turnBEArray, 'bet')
point138= DecPt ('Leaf', 3.25, 5.25, turnBEArray, 'fold')
point139= DecPt ('Leaf', 5.25, 5.25, turnBEArray, 'call')
point140= DecPt ('BB', 7.25, 5.25, turnBEArray, 'raise')
point141= DecPt ('Leaf', 7.25, 5.25, turnBEArray, 'fold')
point142= DecPt ('Leaf', 7.25, 7.25, turnBEArray, 'call')
point143= DecPt ('SB', 7.25, 9.25, turnBEArray, 'raise')
point144= DecPt ('Leaf', 7.25, 9.25, turnBEArray, 'fold')
point145= DecPt ('Leaf', 9.25, 9.25, turnBEArray, 'call')
point146= DecPt ('BB', 11.25, 9.25, turnBEArray, 'raise')
point147= DecPt ('Leaf', 11.25, 9.25, turnBEArray, 'fold')
point148= DecPt ('Leaf', 11.25, 11.25, turnBEArray, 'call')
point149= DecPt ('SB', 4.25, 4.25, turnAEArray, 'check')
point150= DecPt ('Leaf', 4.25, 4.25, turnAEArray, 'check')
point151= DecPt ('BB', 6.25, 4.25, turnAEArray, 'bet')
point152= DecPt ('Leaf', 6.25, 4.25, turnAEArray, 'fold')
point153= DecPt ('Leaf', 6.25, 6.25, turnAEArray, 'call')
point154= DecPt ('SB', 6.25, 8.25, turnAEArray, 'raise')
point155= DecPt ('Leaf', 6.25, 8.25, turnAEArray, 'fold')
point156= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point157= DecPt ('BB', 10.25, 8.25, turnAEArray, 'raise')
point158= DecPt ('Leaf', 10.25, 8.25, turnAEArray, 'fold')
point159= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point160= DecPt ('SB', 10.25, 12.25, turnAEArray, 'raise')
point161= DecPt ('Leaf', 10.25, 12.25, turnAEArray, 'fold')
point162= DecPt ('Leaf', 12.25, 12.25, turnAEArray, 'call')
point163= DecPt ('SB', 4.25, 6.25, turnAEArray, 'bet')
point164= DecPt ('Leaf', 4.25, 6.25, turnAEArray, 'fold')
point165= DecPt ('Leaf', 6.25, 6.25, turnAEArray, 'call')
point166= DecPt ('BB', 8.25, 6.25, turnAEArray, 'raise')
point167= DecPt ('Leaf', 8.25, 6.25, turnAEArray, 'fold')
point168= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point169= DecPt ('SB', 8.25, 10.25, turnAEArray, 'raise')
point170= DecPt ('Leaf', 8.25, 10.25, turnAEArray, 'fold')
point171= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point172= DecPt ('BB', 12.25, 10.25, turnAEArray, 'raise')
point173= DecPt ('Leaf', 12.25, 10.25, turnAEArray, 'fold')
point174= DecPt ('Leaf', 12.25, 12.25, turnAEArray, 'call')
point175= DecPt ('SB', 4.25, 4.25, turnBEArray, 'check')
point176= DecPt ('Leaf', 4.25, 4.25, turnBEArray, 'check')
point177= DecPt ('BB', 6.25, 4.25, turnBEArray, 'bet')
point178= DecPt ('Leaf', 6.25, 4.25, turnBEArray, 'fold')
point179= DecPt ('Leaf', 6.25, 6.25, turnBEArray, 'call')
point180= DecPt ('SB', 6.25, 8.25, turnBEArray, 'raise')
point181= DecPt ('Leaf', 6.25, 8.25, turnBEArray, 'fold')
point182= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point183= DecPt ('BB', 10.25, 8.25, turnBEArray, 'raise')
point184= DecPt ('Leaf', 10.25, 8.25, turnBEArray, 'fold')
point185= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point186= DecPt ('SB', 10.25, 12.25, turnBEArray, 'raise')
point187= DecPt ('Leaf', 10.25, 12.25, turnBEArray, 'fold')
point188= DecPt ('Leaf', 12.25, 12.25, turnBEArray, 'call')
point189= DecPt ('SB', 4.25, 6.25, turnBEArray, 'bet')
point190= DecPt ('Leaf', 4.25, 6.25, turnBEArray, 'fold')
point191= DecPt ('Leaf', 6.25, 6.25, turnBEArray, 'call')
point192= DecPt ('BB', 8.25, 6.25, turnBEArray, 'raise')
point193= DecPt ('Leaf', 8.25, 6.25, turnBEArray, 'fold')
point194= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point195= DecPt ('SB', 8.25, 10.25, turnBEArray, 'raise')
point196= DecPt ('Leaf', 8.25, 10.25, turnBEArray, 'fold')
point197= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point198= DecPt ('BB', 12.25, 10.25, turnBEArray, 'raise')
point199= DecPt ('Leaf', 12.25, 10.25, turnBEArray, 'fold')
point200= DecPt ('Leaf', 12.25, 12.25, turnBEArray, 'call')
point201= DecPt ('SB', 5.25, 5.25, turnAEArray, 'check')
point202= DecPt ('Leaf', 5.25, 5.25, turnAEArray, 'check')
point203= DecPt ('BB', 7.25, 5.25, turnAEArray, 'bet')
point204= DecPt ('Leaf', 7.25, 5.25, turnAEArray, 'fold')
point205= DecPt ('Leaf', 7.25, 7.25, turnAEArray, 'call')
point206= DecPt ('SB', 7.25, 9.25, turnAEArray, 'raise')
point207= DecPt ('Leaf', 7.25, 9.25, turnAEArray, 'fold')
point208= DecPt ('Leaf', 9.25, 9.25, turnAEArray, 'call')
point209= DecPt ('BB', 11.25, 9.25, turnAEArray, 'raise')
point210= DecPt ('Leaf', 11.25, 9.25, turnAEArray, 'fold')
point211= DecPt ('Leaf', 11.25, 11.25, turnAEArray, 'call')
point212= DecPt ('SB', 11.25, 13.25, turnAEArray, 'raise')
point213= DecPt ('Leaf', 11.25, 13.25, turnAEArray, 'fold')
point214= DecPt ('Leaf', 13.25, 13.25, turnAEArray, 'call')
point215= DecPt ('SB', 5.25, 7.25, turnAEArray, 'bet')
point216= DecPt ('Leaf', 5.25, 7.25, turnAEArray, 'fold')
point217= DecPt ('Leaf', 7.25, 7.25, turnAEArray, 'call')
point218= DecPt ('BB', 9.25, 7.25, turnAEArray, 'raise')
point219= DecPt ('Leaf', 9.25, 7.25, turnAEArray, 'fold')
point220= DecPt ('Leaf', 9.25, 9.25, turnAEArray, 'call')
point221= DecPt ('SB', 9.25, 11.25, turnAEArray, 'raise')
point222= DecPt ('Leaf', 9.25, 11.25, turnAEArray, 'fold')
point223= DecPt ('Leaf', 11.25, 11.25, turnAEArray, 'call')
point224= DecPt ('BB', 13.25, 11.25, turnAEArray, 'raise')
point225= DecPt ('Leaf', 13.25, 11.25, turnAEArray, 'fold')
point226= DecPt ('Leaf', 13.25, 13.25, turnAEArray, 'call')
point227= DecPt ('SB', 5.25, 5.25, turnBEArray, 'check')
point228= DecPt ('Leaf', 5.25, 5.25, turnBEArray, 'check')
point229= DecPt ('BB', 7.25, 5.25, turnBEArray, 'bet')
point230= DecPt ('Leaf', 7.25, 5.25, turnBEArray, 'fold')
point231= DecPt ('Leaf', 7.25, 7.25, turnBEArray, 'call')
point232= DecPt ('SB', 7.25, 9.25, turnBEArray, 'raise')
point233= DecPt ('Leaf', 7.25, 9.25, turnBEArray, 'fold')
point234= DecPt ('Leaf', 9.25, 9.25, turnBEArray, 'call')
point235= DecPt ('BB', 11.25, 9.25, turnBEArray, 'raise')
point236= DecPt ('Leaf', 11.25, 9.25, turnBEArray, 'fold')
point237= DecPt ('Leaf', 11.25, 11.25, turnBEArray, 'call')
point238= DecPt ('SB', 11.25, 13.25, turnBEArray, 'raise')
point239= DecPt ('Leaf', 11.25, 13.25, turnBEArray, 'fold')
point240= DecPt ('Leaf', 13.25, 13.25, turnBEArray, 'call')
point241= DecPt ('SB', 5.25, 7.25, turnBEArray, 'bet')
point242= DecPt ('Leaf', 5.25, 7.25, turnBEArray, 'fold')
point243= DecPt ('Leaf', 7.25, 7.25, turnBEArray, 'call')
point244= DecPt ('BB', 9.25, 7.25, turnBEArray, 'raise')
point245= DecPt ('Leaf', 9.25, 7.25, turnBEArray, 'fold')
point246= DecPt ('Leaf', 9.25, 9.25, turnBEArray, 'call')
point247= DecPt ('SB', 9.25, 11.25, turnBEArray, 'raise')
point248= DecPt ('Leaf', 9.25, 11.25, turnBEArray, 'fold')
point249= DecPt ('Leaf', 11.25, 11.25, turnBEArray, 'call')
point250= DecPt ('BB', 13.25, 11.25, turnBEArray, 'raise')
point251= DecPt ('Leaf', 13.25, 11.25, turnBEArray, 'fold')
point252= DecPt ('Leaf', 13.25, 13.25, turnBEArray, 'call')
point253= DecPt ('SB', 6.25, 6.25, turnAEArray, 'check')
point254= DecPt ('Leaf', 6.25, 6.25, turnAEArray, 'check')
point255= DecPt ('BB', 8.25, 6.25, turnAEArray, 'bet')
point256= DecPt ('Leaf', 8.25, 6.25, turnAEArray, 'fold')
point257= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point258= DecPt ('SB', 8.25, 10.25, turnAEArray, 'raise')
point259= DecPt ('Leaf', 8.25, 10.25, turnAEArray, 'fold')
point260= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point261= DecPt ('BB', 12.25, 10.25, turnAEArray, 'raise')
point262= DecPt ('Leaf', 12.25, 10.25, turnAEArray, 'fold')
point263= DecPt ('Leaf', 12.25, 12.25, turnAEArray, 'call')
point264= DecPt ('SB', 12.25, 14.25, turnAEArray, 'raise')
point265= DecPt ('Leaf', 12.25, 14.25, turnAEArray, 'fold')
point266= DecPt ('Leaf', 14.25, 14.25, turnAEArray, 'call')
point267= DecPt ('SB', 6.25, 8.25, turnAEArray, 'bet')
point268= DecPt ('Leaf', 6.25, 8.25, turnAEArray, 'fold')
point269= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point270= DecPt ('BB', 10.25, 8.25, turnAEArray, 'raise')
point271= DecPt ('Leaf', 10.25, 8.25, turnAEArray, 'fold')
point272= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point273= DecPt ('SB', 10.25, 12.25, turnAEArray, 'raise')
point274= DecPt ('Leaf', 10.25, 12.25, turnAEArray, 'fold')
point275= DecPt ('Leaf', 12.25, 12.25, turnAEArray, 'call')
point276= DecPt ('BB', 14.25, 12.25, turnAEArray, 'raise')
point277= DecPt ('Leaf', 14.25, 12.25, turnAEArray, 'fold')
point278= DecPt ('Leaf', 14.25, 14.25, turnAEArray, 'call')
point279= DecPt ('SB', 6.25, 6.25, turnBEArray, 'check')
point280= DecPt ('Leaf', 6.25, 6.25, turnBEArray, 'check')
point281= DecPt ('BB', 8.25, 6.25, turnBEArray, 'bet')
point282= DecPt ('Leaf', 8.25, 6.25, turnBEArray, 'fold')
point283= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point284= DecPt ('SB', 8.25, 10.25, turnBEArray, 'raise')
point285= DecPt ('Leaf', 8.25, 10.25, turnBEArray, 'fold')
point286= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point287= DecPt ('BB', 12.25, 10.25, turnBEArray, 'raise')
point288= DecPt ('Leaf', 12.25, 10.25, turnBEArray, 'fold')
point289= DecPt ('Leaf', 12.25, 12.25, turnBEArray, 'call')
point290= DecPt ('SB', 12.25, 14.25, turnBEArray, 'raise')
point291= DecPt ('Leaf', 12.25, 14.25, turnBEArray, 'fold')
point292= DecPt ('Leaf', 14.25, 14.25, turnBEArray, 'call')
point293= DecPt ('SB', 6.25, 8.25, turnBEArray, 'bet')
point294= DecPt ('Leaf', 6.25, 8.25, turnBEArray, 'fold')
point295= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point296= DecPt ('BB', 10.25, 8.25, turnBEArray, 'raise')
point297= DecPt ('Leaf', 10.25, 8.25, turnBEArray, 'fold')
point298= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point299= DecPt ('SB', 10.25, 12.25, turnBEArray, 'raise')
point300= DecPt ('Leaf', 10.25, 12.25, turnBEArray, 'fold')
point301= DecPt ('Leaf', 12.25, 12.25, turnBEArray, 'call')
point302= DecPt ('BB', 14.25, 12.25, turnBEArray, 'raise')
point303= DecPt ('Leaf', 14.25, 12.25, turnBEArray, 'fold')
point304= DecPt ('Leaf', 14.25, 14.25, turnBEArray, 'call')
point305= DecPt ('SB', 3.25, 3.25, turnAEArray, 'check')
point306= DecPt ('Leaf', 3.25, 3.25, turnAEArray, 'check')
point307= DecPt ('BB', 5.25, 3.25, turnAEArray, 'bet')
point308= DecPt ('Leaf', 5.25, 3.25, turnAEArray, 'fold')
point309= DecPt ('Leaf', 5.25, 5.25, turnAEArray, 'call')
point310= DecPt ('SB', 5.25, 7.25, turnAEArray, 'raise')
point311= DecPt ('Leaf', 5.25, 7.25, turnAEArray, 'fold')
point312= DecPt ('Leaf', 7.25, 7.25, turnAEArray, 'call')
point313= DecPt ('BB', 9.25, 7.25, turnAEArray, 'raise')
point314= DecPt ('Leaf', 9.25, 7.25, turnAEArray, 'fold')
point315= DecPt ('Leaf', 9.25, 9.25, turnAEArray, 'call')
point316= DecPt ('SB', 9.25, 11.25, turnAEArray, 'raise')
point317= DecPt ('Leaf', 9.25, 11.25, turnAEArray, 'fold')
point318= DecPt ('Leaf', 11.25, 11.25, turnAEArray, 'call')
point319= DecPt ('SB', 3.25, 5.25, turnAEArray, 'bet')
point320= DecPt ('Leaf', 3.25, 5.25, turnAEArray, 'fold')
point321= DecPt ('Leaf', 5.25, 5.25, turnAEArray, 'call')
point322= DecPt ('BB', 7.25, 5.25, turnAEArray, 'raise')
point323= DecPt ('Leaf', 7.25, 5.25, turnAEArray, 'fold')
point324= DecPt ('Leaf', 7.25, 7.25, turnAEArray, 'call')
point325= DecPt ('SB', 7.25, 9.25, turnAEArray, 'raise')
point326= DecPt ('Leaf', 7.25, 9.25, turnAEArray, 'fold')
point327= DecPt ('Leaf', 9.25, 9.25, turnAEArray, 'call')
point328= DecPt ('BB', 11.25, 9.25, turnAEArray, 'raise')
point329= DecPt ('Leaf', 11.25, 9.25, turnAEArray, 'fold')
point330= DecPt ('Leaf', 11.25, 11.25, turnAEArray, 'call')
point331= DecPt ('SB', 3.25, 3.25, turnBEArray, 'check')
point332= DecPt ('Leaf', 3.25, 3.25, turnBEArray, 'check')
point333= DecPt ('BB', 5.25, 3.25, turnBEArray, 'bet')
point334= DecPt ('Leaf', 5.25, 3.25, turnBEArray, 'fold')
point335= DecPt ('Leaf', 5.25, 5.25, turnBEArray, 'call')
point336= DecPt ('SB', 5.25, 7.25, turnBEArray, 'raise')
point337= DecPt ('Leaf', 5.25, 7.25, turnBEArray, 'fold')
point338= DecPt ('Leaf', 7.25, 7.25, turnBEArray, 'call')
point339= DecPt ('BB', 9.25, 7.25, turnBEArray, 'raise')
point340= DecPt ('Leaf', 9.25, 7.25, turnBEArray, 'fold')
point341= DecPt ('Leaf', 9.25, 9.25, turnBEArray, 'call')
point342= DecPt ('SB', 9.25, 11.25, turnBEArray, 'raise')
point343= DecPt ('Leaf', 9.25, 11.25, turnBEArray, 'fold')
point344= DecPt ('Leaf', 11.25, 11.25, turnBEArray, 'call')
point345= DecPt ('SB', 3.25, 5.25, turnBEArray, 'bet')
point346= DecPt ('Leaf', 3.25, 5.25, turnBEArray, 'fold')
point347= DecPt ('Leaf', 5.25, 5.25, turnBEArray, 'call')
point348= DecPt ('BB', 7.25, 5.25, turnBEArray, 'raise')
point349= DecPt ('Leaf', 7.25, 5.25, turnBEArray, 'fold')
point350= DecPt ('Leaf', 7.25, 7.25, turnBEArray, 'call')
point351= DecPt ('SB', 7.25, 9.25, turnBEArray, 'raise')
point352= DecPt ('Leaf', 7.25, 9.25, turnBEArray, 'fold')
point353= DecPt ('Leaf', 9.25, 9.25, turnBEArray, 'call')
point354= DecPt ('BB', 11.25, 9.25, turnBEArray, 'raise')
point355= DecPt ('Leaf', 11.25, 9.25, turnBEArray, 'fold')
point356= DecPt ('Leaf', 11.25, 11.25, turnBEArray, 'call')
point357= DecPt ('SB', 4.25, 4.25, turnAEArray, 'check')
point358= DecPt ('Leaf', 4.25, 4.25, turnAEArray, 'check')
point359= DecPt ('BB', 6.25, 4.25, turnAEArray, 'bet')
point360= DecPt ('Leaf', 6.25, 4.25, turnAEArray, 'fold')
point361= DecPt ('Leaf', 6.25, 6.25, turnAEArray, 'call')
point362= DecPt ('SB', 6.25, 8.25, turnAEArray, 'raise')
point363= DecPt ('Leaf', 6.25, 8.25, turnAEArray, 'fold')
point364= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point365= DecPt ('BB', 10.25, 8.25, turnAEArray, 'raise')
point366= DecPt ('Leaf', 10.25, 8.25, turnAEArray, 'fold')
point367= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point368= DecPt ('SB', 10.25, 12.25, turnAEArray, 'raise')
point369= DecPt ('Leaf', 10.25, 12.25, turnAEArray, 'fold')
point370= DecPt ('Leaf', 12.25, 12.25, turnAEArray, 'call')
point371= DecPt ('SB', 4.25, 6.25, turnAEArray, 'bet')
point372= DecPt ('Leaf', 4.25, 6.25, turnAEArray, 'fold')
point373= DecPt ('Leaf', 6.25, 6.25, turnAEArray, 'call')
point374= DecPt ('BB', 8.25, 6.25, turnAEArray, 'raise')
point375= DecPt ('Leaf', 8.25, 6.25, turnAEArray, 'fold')
point376= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point377= DecPt ('SB', 8.25, 10.25, turnAEArray, 'raise')
point378= DecPt ('Leaf', 8.25, 10.25, turnAEArray, 'fold')
point379= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point380= DecPt ('BB', 12.25, 10.25, turnAEArray, 'raise')
point381= DecPt ('Leaf', 12.25, 10.25, turnAEArray, 'fold')
point382= DecPt ('Leaf', 12.25, 12.25, turnAEArray, 'call')
point383= DecPt ('SB', 4.25, 4.25, turnBEArray, 'check')
point384= DecPt ('Leaf', 4.25, 4.25, turnBEArray, 'check')
point385= DecPt ('BB', 6.25, 4.25, turnBEArray, 'bet')
point386= DecPt ('Leaf', 6.25, 4.25, turnBEArray, 'fold')
point387= DecPt ('Leaf', 6.25, 6.25, turnBEArray, 'call')
point388= DecPt ('SB', 6.25, 8.25, turnBEArray, 'raise')
point389= DecPt ('Leaf', 6.25, 8.25, turnBEArray, 'fold')
point390= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point391= DecPt ('BB', 10.25, 8.25, turnBEArray, 'raise')
point392= DecPt ('Leaf', 10.25, 8.25, turnBEArray, 'fold')
point393= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point394= DecPt ('SB', 10.25, 12.25, turnBEArray, 'raise')
point395= DecPt ('Leaf', 10.25, 12.25, turnBEArray, 'fold')
point396= DecPt ('Leaf', 12.25, 12.25, turnBEArray, 'call')
point397= DecPt ('SB', 4.25, 6.25, turnBEArray, 'bet')
point398= DecPt ('Leaf', 4.25, 6.25, turnBEArray, 'fold')
point399= DecPt ('Leaf', 6.25, 6.25, turnBEArray, 'call')
point400= DecPt ('BB', 8.25, 6.25, turnBEArray, 'raise')
point401= DecPt ('Leaf', 8.25, 6.25, turnBEArray, 'fold')
point402= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point403= DecPt ('SB', 8.25, 10.25, turnBEArray, 'raise')
point404= DecPt ('Leaf', 8.25, 10.25, turnBEArray, 'fold')
point405= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point406= DecPt ('BB', 12.25, 10.25, turnBEArray, 'raise')
point407= DecPt ('Leaf', 12.25, 10.25, turnBEArray, 'fold')
point408= DecPt ('Leaf', 12.25, 12.25, turnBEArray, 'call')
point409= DecPt ('SB', 5.25, 5.25, turnAEArray, 'check')
point410= DecPt ('Leaf', 5.25, 5.25, turnAEArray, 'check')
point411= DecPt ('BB', 7.25, 5.25, turnAEArray, 'bet')
point412= DecPt ('Leaf', 7.25, 5.25, turnAEArray, 'fold')
point413= DecPt ('Leaf', 7.25, 7.25, turnAEArray, 'call')
point414= DecPt ('SB', 7.25, 9.25, turnAEArray, 'raise')
point415= DecPt ('Leaf', 7.25, 9.25, turnAEArray, 'fold')
point416= DecPt ('Leaf', 9.25, 9.25, turnAEArray, 'call')
point417= DecPt ('BB', 11.25, 9.25, turnAEArray, 'raise')
point418= DecPt ('Leaf', 11.25, 9.25, turnAEArray, 'fold')
point419= DecPt ('Leaf', 11.25, 11.25, turnAEArray, 'call')
point420= DecPt ('SB', 11.25, 13.25, turnAEArray, 'raise')
point421= DecPt ('Leaf', 11.25, 13.25, turnAEArray, 'fold')
point422= DecPt ('Leaf', 13.25, 13.25, turnAEArray, 'call')
point423= DecPt ('SB', 5.25, 7.25, turnAEArray, 'bet')
point424= DecPt ('Leaf', 5.25, 7.25, turnAEArray, 'fold')
point425= DecPt ('Leaf', 7.25, 7.25, turnAEArray, 'call')
point426= DecPt ('BB', 9.25, 7.25, turnAEArray, 'raise')
point427= DecPt ('Leaf', 9.25, 7.25, turnAEArray, 'fold')
point428= DecPt ('Leaf', 9.25, 9.25, turnAEArray, 'call')
point429= DecPt ('SB', 9.25, 11.25, turnAEArray, 'raise')
point430= DecPt ('Leaf', 9.25, 11.25, turnAEArray, 'fold')
point431= DecPt ('Leaf', 11.25, 11.25, turnAEArray, 'call')
point432= DecPt ('BB', 13.25, 11.25, turnAEArray, 'raise')
point433= DecPt ('Leaf', 13.25, 11.25, turnAEArray, 'fold')
point434= DecPt ('Leaf', 13.25, 13.25, turnAEArray, 'call')
point435= DecPt ('SB', 5.25, 5.25, turnBEArray, 'check')
point436= DecPt ('Leaf', 5.25, 5.25, turnBEArray, 'check')
point437= DecPt ('BB', 7.25, 5.25, turnBEArray, 'bet')
point438= DecPt ('Leaf', 7.25, 5.25, turnBEArray, 'fold')
point439= DecPt ('Leaf', 7.25, 7.25, turnBEArray, 'call')
point440= DecPt ('SB', 7.25, 9.25, turnBEArray, 'raise')
point441= DecPt ('Leaf', 7.25, 9.25, turnBEArray, 'fold')
point442= DecPt ('Leaf', 9.25, 9.25, turnBEArray, 'call')
point443= DecPt ('BB', 11.25, 9.25, turnBEArray, 'raise')
point444= DecPt ('Leaf', 11.25, 9.25, turnBEArray, 'fold')
point445= DecPt ('Leaf', 11.25, 11.25, turnBEArray, 'call')
point446= DecPt ('SB', 11.25, 13.25, turnBEArray, 'raise')
point447= DecPt ('Leaf', 11.25, 13.25, turnBEArray, 'fold')
point448= DecPt ('Leaf', 13.25, 13.25, turnBEArray, 'call')
point449= DecPt ('SB', 5.25, 7.25, turnBEArray, 'bet')
point450= DecPt ('Leaf', 5.25, 7.25, turnBEArray, 'fold')
point451= DecPt ('Leaf', 7.25, 7.25, turnBEArray, 'call')
point452= DecPt ('BB', 9.25, 7.25, turnBEArray, 'raise')
point453= DecPt ('Leaf', 9.25, 7.25, turnBEArray, 'fold')
point454= DecPt ('Leaf', 9.25, 9.25, turnBEArray, 'call')
point455= DecPt ('SB', 9.25, 11.25, turnBEArray, 'raise')
point456= DecPt ('Leaf', 9.25, 11.25, turnBEArray, 'fold')
point457= DecPt ('Leaf', 11.25, 11.25, turnBEArray, 'call')
point458= DecPt ('BB', 13.25, 11.25, turnBEArray, 'raise')
point459= DecPt ('Leaf', 13.25, 11.25, turnBEArray, 'fold')
point460= DecPt ('Leaf', 13.25, 13.25, turnBEArray, 'call')
point461= DecPt ('SB', 6.25, 6.25, turnAEArray, 'check')
point462= DecPt ('Leaf', 6.25, 6.25, turnAEArray, 'check')
point463= DecPt ('BB', 8.25, 6.25, turnAEArray, 'bet')
point464= DecPt ('Leaf', 8.25, 6.25, turnAEArray, 'fold')
point465= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point466= DecPt ('SB', 8.25, 10.25, turnAEArray, 'raise')
point467= DecPt ('Leaf', 8.25, 10.25, turnAEArray, 'fold')
point468= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point469= DecPt ('BB', 12.25, 10.25, turnAEArray, 'raise')
point470= DecPt ('Leaf', 12.25, 10.25, turnAEArray, 'fold')
point471= DecPt ('Leaf', 12.25, 12.25, turnAEArray, 'call')
point472= DecPt ('SB', 12.25, 14.25, turnAEArray, 'raise')
point473= DecPt ('Leaf', 12.25, 14.25, turnAEArray, 'fold')
point474= DecPt ('Leaf', 14.25, 14.25, turnAEArray, 'call')
point475= DecPt ('SB', 6.25, 8.25, turnAEArray, 'bet')
point476= DecPt ('Leaf', 6.25, 8.25, turnAEArray, 'fold')
point477= DecPt ('Leaf', 8.25, 8.25, turnAEArray, 'call')
point478= DecPt ('BB', 10.25, 8.25, turnAEArray, 'raise')
point479= DecPt ('Leaf', 10.25, 8.25, turnAEArray, 'fold')
point480= DecPt ('Leaf', 10.25, 10.25, turnAEArray, 'call')
point481= DecPt ('SB', 10.25, 12.25, turnAEArray, 'raise')
point482= DecPt ('Leaf', 10.25, 12.25, turnAEArray, 'fold')
point483= DecPt ('Leaf', 12.25, 12.25, turnAEArray, 'call')
point484= DecPt ('BB', 14.25, 12.25, turnAEArray, 'raise')
point485= DecPt ('Leaf', 14.25, 12.25, turnAEArray, 'fold')
point486= DecPt ('Leaf', 14.25, 14.25, turnAEArray, 'call')
point487= DecPt ('SB', 6.25, 6.25, turnBEArray, 'check')
point488= DecPt ('Leaf', 6.25, 6.25, turnBEArray, 'check')
point489= DecPt ('BB', 8.25, 6.25, turnBEArray, 'bet')
point490= DecPt ('Leaf', 8.25, 6.25, turnBEArray, 'fold')
point491= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point492= DecPt ('SB', 8.25, 10.25, turnBEArray, 'raise')
point493= DecPt ('Leaf', 8.25, 10.25, turnBEArray, 'fold')
point494= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point495= DecPt ('BB', 12.25, 10.25, turnBEArray, 'raise')
point496= DecPt ('Leaf', 12.25, 10.25, turnBEArray, 'fold')
point497= DecPt ('Leaf', 12.25, 12.25, turnBEArray, 'call')
point498= DecPt ('SB', 12.25, 14.25, turnBEArray, 'raise')
point499= DecPt ('Leaf', 12.25, 14.25, turnBEArray, 'fold')
point500= DecPt ('Leaf', 14.25, 14.25, turnBEArray, 'call')
point501= DecPt ('SB', 6.25, 8.25, turnBEArray, 'bet')
point502= DecPt ('Leaf', 6.25, 8.25, turnBEArray, 'fold')
point503= DecPt ('Leaf', 8.25, 8.25, turnBEArray, 'call')
point504= DecPt ('BB', 10.25, 8.25, turnBEArray, 'raise')
point505= DecPt ('Leaf', 10.25, 8.25, turnBEArray, 'fold')
point506= DecPt ('Leaf', 10.25, 10.25, turnBEArray, 'call')
point507= DecPt ('SB', 10.25, 12.25, turnBEArray, 'raise')
point508= DecPt ('Leaf', 10.25, 12.25, turnBEArray, 'fold')
point509= DecPt ('Leaf', 12.25, 12.25, turnBEArray, 'call')
point510= DecPt ('BB', 14.25, 12.25, turnBEArray, 'raise')
point511= DecPt ('Leaf', 14.25, 12.25, turnBEArray, 'fold')
point512= DecPt ('Leaf', 14.25, 14.25, turnBEArray, 'call')
