# %%
import pandas as pd
import os
import tqdm
import seaborn
import matplotlib.pyplot as plt
import pylab
os.chdir('/home/valesco/Datasets/NFL/Plots')
# %matplotlib inline
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
opt_df = pd.read_pickle('2015_optimal_lineups_1k.p')

# %%
opt_df.head()
# Out:
#          qb_name qb_pos qb_points qb_salary         wr1_name wr1_pos  \
# 0  Palmer,Carson     QB     28.68      6500  Hopkins,DeAndre     WR1
# 1  Palmer,Carson     QB     28.68      6500  Hopkins,DeAndre     WR1
# 2  Palmer,Carson     QB     28.68      6500  Hopkins,DeAndre     WR1
# 3  Palmer,Carson     QB     28.68      6500  Hopkins,DeAndre     WR1
# 4  Palmer,Carson     QB     28.68      6500  Hopkins,DeAndre     WR1
#
#   wr1_points wr1_salary     wr2_name wr2_pos wr2_points wr2_salary  \
# 0       32.8       7400  Jones,Julio     WR2       38.1       9300
# 1       32.8       7400  Jones,Julio     WR2       38.1       9300
# 2       32.8       7400  Jones,Julio     WR2       38.1       9300
# 3       32.8       7400  Jones,Julio     WR2       38.1       9300
# 4       32.8       7400  Jones,Julio     WR2       38.1       9300
#
#        wr3_name wr3_pos wr3_points wr3_salary      rb1_name rb1_pos  \
# 0  Allen,Keenan     WR3       34.6       7100   Hyde,Carlos     RB1
# 1  Allen,Keenan     WR3       34.6       7100   Hyde,Carlos     RB1
# 2  Allen,Keenan     WR3       34.6       7100   Hyde,Carlos     RB1
# 3  Allen,Keenan     WR3       34.6       7100   Hyde,Carlos     RB1
# 4  Allen,Keenan     WR3       34.6       7100  Reece,Marcel     RB1
#
#   rb1_points rb1_salary        rb2_name rb2_pos rb2_points rb2_salary  \
# 0       35.2       5300     Ivory,Chris     RB2         23       4100
# 1       35.2       5300   Sankey,Bishop     RB2       22.6       4300
# 2       35.2       5300  Woodhead,Danny     RB2       22.2       3700
# 3       35.2       5300   Sankey,Bishop     RB2       22.6       4300
# 4       17.6       3000     Hyde,Carlos     RB2       35.2       5300
#
#         te_name te_pos te_points te_salary                flex_name flex_pos  \
# 0  Eifert,Tyler     TE      34.4      3500  Seferian-Jenkins,Austin  flex_TE
# 1  Eifert,Tyler     TE      34.4      3500  Seferian-Jenkins,Austin  flex_TE
# 2  Eifert,Tyler     TE      34.4      3500  Seferian-Jenkins,Austin  flex_TE
# 3  Eifert,Tyler     TE      34.4      3500  Seferian-Jenkins,Austin  flex_TE
# 4  Eifert,Tyler     TE      34.4      3500             Kelce,Travis  flex_TE
#
#   flex_points flex_salary  def_name def_pos def_points def_salary  \
# 0          31        3400  Carolina     DEF         21       3100
# 1          31        3400  Carolina     DEF         21       3100
# 2          31        3400   Seattle     DEF         19       3400
# 3          31        3400  NewYorkJ     DEF         17       2900
# 4        31.6        4800  Carolina     DEF         21       3100
#
#    team_points  total_salary season_year   week
# 0       278.78         49700        2015  week1
# 1       278.38         49900        2015  week1
# 2       275.98         49600        2015  week1
# 3       274.38         49700        2015  week1
# 4       273.98         50000        2015  week1

# %%
num_df = opt_df

# %%
cols = num_df.columns
#num_df['qb_name'] = pd.to_numeric(num_df['qb_name'], errors = 'coerce')
new_ls = []

for c in cols:
    if 'salary' in c or 'points' in c:
        num_df[c] = pd.to_numeric(num_df[c], errors = 'coerce')
        
num_df.dtypes
# Out:
# qb_name          object
# qb_pos           object
# qb_points       float64
# qb_salary         int64
# wr1_name         object
# wr1_pos          object
# wr1_points      float64
# wr1_salary        int64
# wr2_name         object
# wr2_pos          object
# wr2_points      float64
# wr2_salary        int64
# wr3_name         object
# wr3_pos          object
# wr3_points      float64
# wr3_salary        int64
# rb1_name         object
# rb1_pos          object
# rb1_points      float64
# rb1_salary        int64
# rb2_name         object
# rb2_pos          object
# rb2_points      float64
# rb2_salary        int64
# te_name          object
# te_pos           object
# te_points       float64
# te_salary         int64
# flex_name        object
# flex_pos         object
# flex_points     float64
# flex_salary       int64
# def_name         object
# def_pos          object
# def_points        int64
# def_salary        int64
# team_points     float64
# total_salary    float64
# season_year      object
# week             object
# dtype: object

# %%
num_df.groupby('flex_pos').mean()
# Out:
#           qb_points    qb_salary  wr1_points   wr1_salary  wr2_points  \
# flex_pos
# flex_RB   30.118374  6144.382979   33.324957  6414.659574   33.347243
# flex_TE   34.189523  6322.631709   32.730458  6822.087559   33.084516
# flex_WR   34.472930  6359.283033   35.192891  6327.164830   34.433145
#
#            wr2_salary  wr3_points   wr3_salary  rb1_points   rb1_salary  \
# flex_pos
# flex_RB   6043.829787   29.517872  5660.553191   32.366957  4920.361702
# flex_TE   6617.363344   30.564432  6306.801880   33.783552  5281.746228
# flex_WR   6100.145331   33.685733  5912.304711   32.352247  5131.197772
#
#           rb2_points   rb2_salary  te_points    te_salary  flex_points  \
# flex_pos
# flex_RB    33.232447  5196.042553  29.548830  4272.106383    29.496255
# flex_TE    29.320678  5153.969824  29.953302  4117.412812    29.240391
# flex_WR    30.872508  4626.365508  28.653421  4202.325300    31.356970
#
#           flex_salary  def_points   def_salary  team_points  total_salary
# flex_pos
# flex_RB   4800.234043   22.527021  2862.617021   273.479957  46314.787234
# flex_TE   4218.872125   19.635914  2969.997527   272.502765  47810.883008
# flex_WR   5686.992855   21.096040  3007.872109   282.115885  47353.651447

# %%
num_df.head()
# Out:
#          qb_name qb_pos  qb_points  qb_salary         wr1_name wr1_pos  \
# 0  Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 1  Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 2  Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 3  Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 4  Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
#
#    wr1_points  wr1_salary     wr2_name wr2_pos  ...    flex_points  \
# 0        32.8        7400  Jones,Julio     WR2  ...           31.0
# 1        32.8        7400  Jones,Julio     WR2  ...           31.0
# 2        32.8        7400  Jones,Julio     WR2  ...           31.0
# 3        32.8        7400  Jones,Julio     WR2  ...           31.0
# 4        32.8        7400  Jones,Julio     WR2  ...           31.6
#
#    flex_salary  def_name def_pos  def_points  def_salary team_points  \
# 0         3400  Carolina     DEF          21        3100      278.78
# 1         3400  Carolina     DEF          21        3100      278.38
# 2         3400   Seattle     DEF          19        3400      275.98
# 3         3400  NewYorkJ     DEF          17        2900      274.38
# 4         4800  Carolina     DEF          21        3100      273.98
#
#   total_salary  season_year   week
# 0        49700         2015  week1
# 1        49900         2015  week1
# 2        49600         2015  week1
# 3        49700         2015  week1
# 4        50000         2015  week1
#
# [5 rows x 40 columns]

# %%
# %%capture
sorted_df = pd.DataFrame(columns = ['qb_name', 'qb_pos', 'qb_points', 'qb_salary',
                                 'wr1_name', 'wr1_pos', 'wr1_points', 'wr1_salary',
                                 'wr2_name', 'wr2_pos', 'wr2_points', 'wr2_salary',
                                 'wr3_name', 'wr3_pos', 'wr3_points', 'wr3_salary',
                                 'rb1_name', 'rb1_pos', 'rb1_points', 'rb1_salary',
                                 'rb2_name', 'rb2_pos', 'rb2_points', 'rb2_salary',
                                 'te_name', 'te_pos', 'te_points', 'te_salary',
                                 'flex_name', 'flex_pos', 'flex_points', 'flex_salary',
                                 'def_name', 'def_pos', 'def_points', 'def_salary',
                                 'team_points', 'total_salary', 'season_year', 'week'
                                ])

for index, row in num_df.iterrows():
    qb_name = row['qb_name']
    qb_points = row['qb_points']
    qb_salary = row['qb_salary']
    
    def_name = row['def_name']
    def_points = row['def_points']
    def_salary = row['def_salary']
    
    season_year = row['season_year']
    week = row['week']
    
    team_points = row['team_points']
    total_salary = row['total_salary']
    
    wrA = [row['wr1_name'], row['wr1_points'], row['wr1_salary']]
    wrB = [row['wr2_name'], row['wr2_points'], row['wr2_salary']]
    wrC = [row['wr3_name'], row['wr3_points'], row['wr3_salary']]

    rbA = [row['rb1_name'], row['rb1_points'], row['rb1_salary']]
    rbB = [row['rb2_name'], row['rb2_points'], row['rb2_salary']]

    teA = [row['te_name'], row['te_points'], row['te_salary']]


    if row['flex_pos'] == 'flex_WR':
        wrD = [row['flex_name'], row['flex_points'], row['flex_salary']]
        wr_ls = [wrA, wrB, wrC, wrD]
    else:
        wr_ls = [wrA, wrB, wrC]

    if row['flex_pos'] == 'flex_RB':
        rbC = [row['flex_name'], row['flex_points'], row['flex_salary']]
        rb_ls = [rbA, rbB, rbC]
    else:
        rb_ls = [rbA, rbB]

    if row['flex_pos'] == 'flex_TE':
        teB = [row['flex_name'], row['flex_points'], row['flex_salary']]
        te_ls = [teA, teB]
    else:
        te_ls = [teA]  


    wr_ls.sort(key = lambda x: x[2], reverse = True)
    rb_ls.sort(key = lambda x: x[2], reverse = True)
    te_ls.sort(key = lambda x: x[2], reverse = True)

    for i, wr in enumerate(wr_ls):
        if i == 0:
            wr1_name = wr[0]
            wr1_points = wr[1]
            wr1_salary = wr[2]
        elif i == 1:
            wr2_name = wr[0]
            wr2_points = wr[1]
            wr2_salary = wr[2]
        elif i == 2:
            wr3_name = wr[0]
            wr3_points = wr[1]
            wr3_salary = wr[2]
        else:
            flex_name = wr[0]
            flex_points = wr[1]
            flex_salary = wr[2]
            flex_pos = 'flex_WR'

    for i, rb in enumerate(rb_ls):
        if i == 0:
            rb1_name = rb[0]
            rb1_points = rb[1]
            rb1_salary = rb[2]
        elif i == 1:
            rb2_name = rb[0]
            rb2_points = rb[1]
            rb2_salary = rb[2]
        else:
            flex_name = rb[0]
            flex_points = rb[1]
            flex_salary = rb[2]
            flex_pos = 'flex_RB'
    for i, te in enumerate(te_ls):
        if i == 0:
            te_name = te[0]
            te_points = te[1]
            te_salary = te[2]
        else:
            flex_name = te[0]
            flex_points = te[1]
            flex_salary = te[2]
            flex_pos = 'flex_TE'

        
            
    sorted_df.loc[index] = [qb_name, 'QB', qb_points, qb_salary,
                         wr1_name, 'WR1', wr1_points, wr1_salary,
                         wr2_name, 'WR2', wr2_points, wr2_salary,
                         wr3_name, 'WR3', wr3_points, wr3_salary,
                         rb1_name, 'RB1', rb1_points, rb1_salary,
                         rb2_name, 'RB2', rb2_points, rb2_salary,
                         te_name, 'TE', te_points, te_salary,
                         flex_name, flex_pos, flex_points, flex_salary,
                         def_name, 'DEF', def_points, def_salary,
                         team_points, total_salary, season_year, week]
    
        
        
        
sorted_df.head()
# Out:
#          qb_name qb_pos  qb_points  qb_salary     wr1_name wr1_pos  \
# 0  Palmer,Carson     QB      28.68       6500  Jones,Julio     WR1
# 1  Palmer,Carson     QB      28.68       6500  Jones,Julio     WR1
# 2  Palmer,Carson     QB      28.68       6500  Jones,Julio     WR1
# 3  Palmer,Carson     QB      28.68       6500  Jones,Julio     WR1
# 4  Palmer,Carson     QB      28.68       6500  Jones,Julio     WR1
#
#    wr1_points  wr1_salary         wr2_name wr2_pos  wr2_points  wr2_salary  \
# 0        38.1        9300  Hopkins,DeAndre     WR2        32.8        7400
# 1        38.1        9300  Hopkins,DeAndre     WR2        32.8        7400
# 2        38.1        9300  Hopkins,DeAndre     WR2        32.8        7400
# 3        38.1        9300  Hopkins,DeAndre     WR2        32.8        7400
# 4        38.1        9300  Hopkins,DeAndre     WR2        32.8        7400
#
#        wr3_name wr3_pos  wr3_points  wr3_salary     rb1_name rb1_pos  \
# 0  Allen,Keenan     WR3        34.6        7100  Hyde,Carlos     RB1
# 1  Allen,Keenan     WR3        34.6        7100  Hyde,Carlos     RB1
# 2  Allen,Keenan     WR3        34.6        7100  Hyde,Carlos     RB1
# 3  Allen,Keenan     WR3        34.6        7100  Hyde,Carlos     RB1
# 4  Allen,Keenan     WR3        34.6        7100  Hyde,Carlos     RB1
#
#    rb1_points  rb1_salary        rb2_name rb2_pos  rb2_points  rb2_salary  \
# 0        35.2        5300     Ivory,Chris     RB2        23.0        4100
# 1        35.2        5300   Sankey,Bishop     RB2        22.6        4300
# 2        35.2        5300  Woodhead,Danny     RB2        22.2        3700
# 3        35.2        5300   Sankey,Bishop     RB2        22.6        4300
# 4        35.2        5300    Reece,Marcel     RB2        17.6        3000
#
#         te_name te_pos  te_points  te_salary                flex_name  \
# 0  Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 1  Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 2  Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 3  Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 4  Kelce,Travis     TE       31.6       4800             Eifert,Tyler
#
#   flex_pos  flex_points  flex_salary  def_name def_pos  def_points  \
# 0  flex_TE         31.0         3400  Carolina     DEF          21
# 1  flex_TE         31.0         3400  Carolina     DEF          21
# 2  flex_TE         31.0         3400   Seattle     DEF          19
# 3  flex_TE         31.0         3400  NewYorkJ     DEF          17
# 4  flex_TE         34.4         3500  Carolina     DEF          21
#
#    def_salary  team_points  total_salary season_year   week
# 0        3100       278.78         49700        2015  week1
# 1        3100       278.38         49900        2015  week1
# 2        3400       275.98         49600        2015  week1
# 3        2900       274.38         49700        2015  week1
# 4        3100       273.98         50000        2015  week1

# %%
sorted_df.to_pickle('2015_optimal_lineups_numeric.p')
#num_df = pd.read_pickle('2015_optimal_lineups_numeric.p')

# %%
avg_team = pd.DataFrame(sorted_df.mean())
avg_team
# Out:
#                          0
# qb_points        33.201622
# qb_salary      6291.152941
# wr1_points       37.070394
# wr1_salary     8195.752941
# wr2_points       32.582100
# wr2_salary     6506.982353
# wr3_points       30.383178
# wr3_salary     4785.747059
# rb1_points       32.984235
# rb1_salary     5913.794118
# rb2_points       30.708200
# rb2_salary     4348.305882
# te_points        29.214788
# te_salary      4430.676471
# flex_points      30.153149
# flex_salary    3744.058824
# def_points       21.144412
# def_salary     2958.705882
# team_points     277.442079
# total_salary  47175.176471

# %%
flex_wr_team = pd.DataFrame(sorted_df.loc[num_df['flex_pos'] == 'flex_WR'].mean())
flex_rb_team = pd.DataFrame(sorted_df.loc[num_df['flex_pos'] == 'flex_RB'].mean())
flex_te_team = pd.DataFrame(sorted_df.loc[num_df['flex_pos'] == 'flex_TE'].mean())

# %%
avg_df = pd.concat([avg_team, flex_wr_team, flex_rb_team, flex_te_team], axis = 1)

# %%
avg_df.columns = ['agg_avg','flex_wr','flex_rb', 'flex_te']
avg_df
# Out:
#                    agg_avg       flex_wr       flex_rb       flex_te
# qb_points        33.201622     34.472930     30.118374     34.189523
# qb_salary      6291.152941   6359.283033   6144.382979   6322.631709
# wr1_points       37.070394     38.291280     34.955319     37.035766
# wr1_salary     8195.752941   8263.376529   7891.106383   8411.798170
# wr2_points       32.582100     33.545707     31.371923     32.020965
# wr2_salary     6506.982353   6654.123774   6021.638298   6770.690082
# wr3_points       30.383178     32.177927     29.862830     27.322676
# wr3_salary     4785.747059   5224.270316   4206.297872   4563.764531
# rb1_points       32.984235     33.573889     31.954809     32.976700
# rb1_salary     5913.794118   5731.415768   6173.446809   5984.417512
# rb2_points       30.708200     29.650866     33.065234     30.127529
# rb2_salary     4348.305882   4026.147511   4825.680851   4451.298541
# te_points        29.214788     28.653421     29.548830     29.972941
# te_salary      4430.676471   4202.325300   4272.106383   5081.375216
# flex_points      30.153149     30.653826     30.075617     29.220752
# flex_salary    3744.058824   3884.837108   3917.510638   3254.909721
# def_points       21.144412     21.096040     22.527021     19.635914
# def_salary     2958.705882   3007.872109   2862.617021   2969.997527
# team_points     277.442079    282.115885    273.479957    272.502765
# total_salary  47175.176471  47353.651447  46314.787234  47810.883008

# %%
from bokeh.io import output_notebook, show
from bokeh.charts import Scatter
from bokeh.charts import Line
from bokeh.charts import Histogram
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="769cb4fa-8555-4a81-9486-a9015c57e20d">Loading BokehJS ...</span>
#     </div>

# %%
hist = Histogram(num_df['qb_salary'], bins = 10)
show(hist)
# Out:
#     <div class="plotdiv" id="9fcb835c-690c-46fe-b56e-a7792996862e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9fcb835c-690c-46fe-b56e-a7792996862e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9fcb835c-690c-46fe-b56e-a7792996862e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6af0c0f9-aa7f-411d-9f59-58d48b37b3db":{"roots":{"references":[{"attributes":{"data_source":{"id":"bf243338-cd2b-4576-8cf7-4c17306d6838","type":"ColumnDataSource"},"glyph":{"id":"d9515fe1-5aeb-4fef-9634-68c503eee494","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c43eb7bf-2bbb-491f-b033-d5a88fad068e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"651472ce-ae88-4c37-b2df-2ec065dad4ca","type":"ColumnDataSource"},"glyph":{"id":"347e0e6a-6c16-4327-84f2-e2e430a2ea19","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"29013759-0f08-449d-9874-532847328e00","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5ccc8302-56fd-4ac7-9d07-41321e071613","type":"ColumnDataSource"},"glyph":{"id":"11210e44-1981-4fbf-b42b-9a13f97157c9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9cea66bf-d870-4abf-8a56-e1d291b372fb","type":"GlyphRenderer"},{"attributes":{},"id":"49c413e3-be35-4fac-a039-7e820caf9224","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"98f984d5-2d64-4906-b895-c91ef83c7b71","type":"Rect"},{"attributes":{"axis_label":"Count( Qb_Salary )","formatter":{"id":"639f7ce8-5922-4057-922c-b953a51b3f42","type":"BasicTickFormatter"},"plot":{"id":"d47d6a7c-1550-4db4-86c8-7562d14c9e14","subtype":"Chart","type":"Plot"},"ticker":{"id":"1cb5a77b-d4a2-4e93-b3ec-a3efac06bb1c","type":"BasicTicker"}},"id":"dc51f763-f6d2-4cf0-b658-c266e6ab7f45","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dc163f7f-fcd5-448d-9bef-264e2636f682","type":"Rect"},{"attributes":{"data_source":{"id":"afd987b5-75ec-4627-88b8-599428efd9d4","type":"ColumnDataSource"},"glyph":{"id":"ce0a42b1-b5c2-4c20-a4b6-d887990a0c38","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4175c885-99b7-451c-9e50-f366a9a2d8c8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","color","height","line_alpha","x","y","fill_alpha","line_color"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[73.80000000000018],"x":["8420.0"],"y":[0.0]}},"id":"d31c1670-b934-48a9-9716-d9faea94bc40","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["width","color","height","line_alpha","x","y","fill_alpha","line_color"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[500.0],"line_alpha":[1.0],"line_color":["black"],"width":[241.80000000000018],"x":["8000.0"],"y":[250.0]}},"id":"6f24ffd4-5d96-4b9f-8d45-10c98d63e730","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["width","color","height","line_alpha","x","y","fill_alpha","line_color"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[583.0],"line_alpha":[1.0],"line_color":["black"],"width":[241.80000000000018],"x":["6320.0"],"y":[291.5]}},"id":"1edc93fd-acb5-42ba-998c-6bffdd37eeff","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":4555.1},"id":"acf21591-ccf5-406c-8149-cde951f15601","type":"Range1d"},{"attributes":{"data_source":{"id":"eee6f766-6ccc-4f20-9f2a-4864d093ad31","type":"ColumnDataSource"},"glyph":{"id":"359e543a-8d65-42b6-8af5-fcf6ee092c20","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"312a4b33-d81f-4cc5-9e45-770666e748ea","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0adb4273-a0a8-41f0-ae8c-465ce76101f1","type":"ColumnDataSo ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %%
new_df = sorted_df.loc[sorted_df['qb_salary'] > 8000]
filter_setting = 'Qb Salary over 8k'

fig, (qb, wr1, wr2, wr3, rb1, rb2, te, flex, flex_counts, d) = plt.subplots(nrows = 10, figsize = (12,18))

per = '{:.2f}'.format((len(new_df) / 17000) * 100)

cols = ['percent_total', 'percent_filter']
ix = ['flex_WR', 'flex_RB', 'flex_TE']

temp_df = pd.DataFrame(columns = cols, index = ix)


temp_df.loc['flex_WR']['percent_total'] = len(sorted_df.loc[sorted_df['flex_pos'] == 'flex_WR']) / len(sorted_df)
temp_df.loc['flex_RB']['percent_total'] = len(sorted_df.loc[sorted_df['flex_pos'] == 'flex_RB']) / len(sorted_df)
temp_df.loc['flex_TE']['percent_total'] = len(sorted_df.loc[sorted_df['flex_pos'] == 'flex_TE']) / len(sorted_df)


temp_df.loc['flex_WR']['percent_filter'] = len(new_df.loc[new_df['flex_pos'] == 'flex_WR']) / len(new_df)
temp_df.loc['flex_RB']['percent_filter'] = len(new_df.loc[new_df['flex_pos'] == 'flex_RB']) / len(new_df)
temp_df.loc['flex_TE']['percent_filter'] = len(new_df.loc[new_df['flex_pos'] == 'flex_TE']) / len(new_df)

seaborn.set_context('paper', font_scale = 1.5, rc = {'lines.linewidth': 3.5})

#seaborn.set(rc = {'figure.figsize': (14|, 6)})
#fig.suptitle('Filter: ' + filter_setting + '   Filtered Lineups: ' + per + '%')

seaborn.distplot(sorted_df.qb_salary, hist = False, bins = 5, label = 'QB_total', 
                 color = seaborn.color_palette("YlOrRd", 10)[2], ax = qb)
seaborn.distplot(sorted_df.wr1_salary, hist = False, bins = 5, label = 'WR1_total', 
                 color = seaborn.color_palette('PuBu', 10)[2], ax = wr1)
seaborn.distplot(sorted_df.wr2_salary, hist = False, bins = 5, label = 'WR2_total',
                 color = seaborn.color_palette('OrRd', 10)[2], ax = wr2)
seaborn.distplot(sorted_df.wr3_salary, hist = False, bins = 5, label = 'WR3_total',
                 color = seaborn.color_palette('YlGn', 10)[2], ax = wr3)
seaborn.distplot(sorted_df.rb1_salary, hist = False, bins = 5, label = 'RB1_total',
                 color = seaborn.color_palette("RdBu", 10)[2], ax = rb1)
seaborn.distplot(sorted_df.rb2_salary, hist = False, bins = 5, label = 'RB2_total',
                 color = seaborn.color_palette("PRGn", 10)[2], ax = rb2)
seaborn.distplot(sorted_df.te_salary, hist = False, bins = 5, label = 'TE_total',
                 color = seaborn.color_palette("PiYG", 10)[2], ax = te)
seaborn.distplot(sorted_df.flex_salary, hist = False, bins = 5, label = 'Flex_total',
                 color = seaborn.color_palette("BrBG", 10)[2], ax = flex)
seaborn.pointplot(x = 'percent_total', y = index, data = temp_df, ax = flex_counts, hue = index,
                 legend_out = False)

seaborn.distplot(sorted_df.def_salary, hist = False, bins = 5, label = 'Def_total',
                 color = seaborn.color_palette("YlOrBr", 10)[2], ax = d)

seaborn.distplot(new_df.qb_salary, hist = False, bins = 5, label = 'QB_filtered', 
                 color = seaborn.color_palette("YlOrRd", 10)[5], ax = qb)
seaborn.distplot(new_df.wr1_salary, hist = False, bins = 5, label = 'WR1_filtered', 
                 color = seaborn.color_palette('PuBu', 10)[5], ax = wr1)
seaborn.distplot(new_df.wr2_salary, hist = False, bins = 5, label = 'WR2_filtered',
                 color = seaborn.color_palette('OrRd', 10)[5], ax = wr2)
seaborn.distplot(new_df.wr3_salary, hist = False, bins = 5, label = 'WR3_filtered',
                 color = seaborn.color_palette('YlGn', 10)[5], ax = wr3)
seaborn.distplot(new_df.rb1_salary, hist = False, bins = 5, label = 'RB1_filtered',
                 color = seaborn.color_palette("RdBu", 10)[0], ax = rb1)
seaborn.distplot(new_df.rb2_salary, hist = False, bins = 5, label = 'RB2_filtered',
                 color = seaborn.color_palette("PRGn", 10)[0], ax = rb2)
seaborn.distplot(new_df.te_salary, hist = False, bins = 5, label = 'TE_filtered',
                 color = seaborn.color_palette("PiYG", 10)[0], ax = te)
seaborn.distplot(new_df.flex_salary, hist = False, bins = 5, label = 'Flex_filtered',
                 color = seaborn.color_palette("BrBG", 10)[0], ax = flex)
seaborn.factorplot(hue = index, x = 'percent_filter', y = index, data = temp_df, ax = flex_counts, kind = 'bar', 
                   size = 6)

seaborn.distplot(new_df.def_salary, hist = False, bins = 5, label = 'Def_filtered',
                 color = seaborn.color_palette("YlOrBr", 10)[5], ax = d)


qb.set_ylabel('QB Salary')
wr1.set_ylabel('WR1 Salary')
wr2.set_ylabel('WR2 Salary')
wr3.set_ylabel('WR3 Salary')
rb1.set_ylabel('RB1 Salary')
rb2.set_ylabel('RB2 Salary')
te.set_ylabel('TE Salary')
flex.set_ylabel('Flex Salary')
d.set_ylabel('DEF Salary')

qb.set(yticks = [])
wr1.set(yticks = [])
wr2.set(yticks = [])
wr3.set(yticks = [])
rb1.set(yticks = [])
rb2.set(yticks = [])
te.set(yticks = [])
flex.set(yticks = [])
d.set(yticks = [])



qb.set_ylim(0,0.001)
qb.set_xlim(5000,10000)
wr1.set_ylim(0,0.001)
wr1.set_xlim(5000,10000)
wr2.set_ylim(0,0.001)
wr2.set_xlim(4000,10000)
wr3.set_ylim(0,0.001)
wr3.set_xlim(2000,8000)
rb1.set_ylim(0,0.001)
rb1.set_xlim(2000,8000)
rb2.set_ylim(0,0.002)
rb2.set_xlim(2000,8000)
te.set_ylim(0,0.001)
te.set_xlim(2000,8000)
flex.set_ylim(0,0.001)
flex.set_xlim(2000,8000)
d.set_ylim(0,0.003)
d.set_xlim(1000,5000)


d.set(xlabel = 'Salary')
seaborn.despine(left = False)
plt.show()
#pylab.savefig('qb_greater_8000.png')

# %%
sorted_df.loc[sorted_df['te_salary'] > 8000]
# Out:
#                 qb_name qb_pos  qb_points  qb_salary        wr1_name wr1_pos  \
# 6000       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6001          Brady,Tom     QB      32.70       8500     Hilton,T.Y.     WR1
# 6003       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6004       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6005       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6009       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6011       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6012       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6013       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6014      Rivers,Philip     QB      30.44       6500     Hilton,T.Y.     WR1
# 6016     Tannehill,Ryan     QB      27.58       5700     Hilton,T.Y.     WR1
# 6017       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6018          Brady,Tom     QB      32.70       8500     Hilton,T.Y.     WR1
# 6020       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6021       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6022          Brady,Tom     QB      32.70       8500    Cooper,Amari     WR1
# 6024      Rivers,Philip     QB      30.44       6500     Hilton,T.Y.     WR1
# 6026       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6027       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6031      Rivers,Philip     QB      30.44       6500    Cooper,Amari     WR1
# 6032       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6033       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6034       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6035      Rivers,Philip     QB      30.44       6500     Hilton,T.Y.     WR1
# 6039        Luck,Andrew     QB      29.02       7600     Hilton,T.Y.     WR1
# 6040          Brady,Tom     QB      32.70       8500     Hilton,T.Y.     WR1
# 6042         Carr,Derek     QB      23.86       5300     Hilton,T.Y.     WR1
# 6043          Brady,Tom     QB      32.70       8500     Hilton,T.Y.     WR1
# 6044       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6045        Luck,Andrew     QB      29.02       7600     Hilton,T.Y.     WR1
# 6046       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6048       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6049       Cousins,Kirk     QB      34.18       5000     Jones,Julio     WR1
# 6051  Bridgewater,Teddy     QB      22.74       5100     Hilton,T.Y.     WR1
# 6052        Luck,Andrew     QB      29.02       7600      Evans,Mike     WR1
# 6054      Rivers,Philip     QB      30.44       6500     Hilton,T.Y.     WR1
# 6057       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6058       Cousins,Kirk     QB      34.18       5000     Hilton,T.Y.     WR1
# 6059          Brady,Tom     QB      32.70       8500     Hilton,T.Y.     WR1
# 6063       Cousins,Kirk     QB      34.18       5000     Jones,Julio     WR1
# 6064       Cousins,Kirk     QB      34.18       5000      Evans,Mike     WR1
# 6066      Rivers,Philip     QB      30.44       6500    Cooper,Amari     WR1
# 6067      Rivers,Philip     QB      30.44       6500     Hilton,T.Y.     WR1
# 
# 6985        Luck,Andrew     QB      29.02       7600     Hilton,T.Y.     WR1
# 6990       Cousins,Kirk     QB      34.18       5000    Cooper,Amari     WR1
# 6991       Cousins,Kirk     QB      34.18       5000     Jones,Julio     WR1
# 6992       Cousins,Kirk     QB      34.18       5000      Evans,Mike     WR1
# 6994  Bridgewater,Teddy     QB      22.74       5100     Hilton,T.Y.     WR1
# 6997      Rivers,Philip     QB      30.44       6500     Jones,Julio     WR1
# 6999        Luck,Andrew     QB      29.02       7600    Allen,Keenan     WR1
#
#       wr1_points  wr1_salary        wr2_name wr2_pos  wr2_points  wr2_salary  \
# 6000        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6001        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6003        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6004        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6005        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6009        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6011        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6012        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6013        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6014        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6016        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6017        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6018        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6020        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6021        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6022        27.3        6500      Evans,Mike     WR2        33.4        6400
# 6024        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6026        34.0        6500    Diggs,Stefon     WR2        26.7        4200
# 6027        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6031        27.3        6500      Evans,Mike     WR2        33.4        6400
# 6032        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6033        34.0        6500   Landry,Jarvis     WR2        25.8        6200
# 6034        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6035        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6039        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6040        34.0        6500    Diggs,Stefon     WR2        26.7        4200
# 6042        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6043        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6044        34.0        6500   Landry,Jarvis     WR2        25.8        6200
# 6045        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6046        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6048        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6049        24.2        9100     Hilton,T.Y.     WR2        34.0        6500
# 6051        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6052        33.4        6400    Diggs,Stefon     WR2        26.7        4200
# 6054        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6057        34.0        6500    Diggs,Stefon     WR2        26.7        4200
# 6058        34.0        6500    Woods,Robert     WR2        23.4        3300
# 6059        34.0        6500   Landry,Jarvis     WR2        25.8        6200
# 6063        24.2        9100     Hilton,T.Y.     WR2        34.0        6500
# 6064        33.4        6400    Diggs,Stefon     WR2        26.7        4200
# 6066        27.3        6500      Evans,Mike     WR2        33.4        6400
# 6067        34.0        6500    Diggs,Stefon     WR2        26.7        4200
# 6069        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6070        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6072        34.0        6500  Amendola,Danny     WR2        22.6        3500
# 6073        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6076        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6078        27.3        6500      Evans,Mike     WR2        33.4        6400
# 6079        34.0        6500    Cooper,Amari     WR2        27.3        6500
# ...          ...         ...             ...     ...         ...         ...
# 6916        34.0        6500  Amendola,Danny     WR2        22.6        3500
# 6918        34.0        6500    Diggs,Stefon     WR2        26.7        4200
# 6920        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6921        33.4        6400   Lockett,Tyler     WR2        18.9        3200
# 6922        34.0        6500    Conley,Chris     WR2        18.3        3000
# 6923        34.0        6500  Robinson,Allen     WR2        21.8        6400
# 6924        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6926        24.2        9100      Evans,Mike     WR2        33.4        6400
# 6927        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6929        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6930        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6932        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6934        34.0        6500    Conley,Chris     WR2        18.3        3000
# 6936        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6937        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6938        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6939        22.0        7900      Evans,Mike     WR2        33.4        6400
# 6940        33.4        6400    Woods,Robert     WR2        23.4        3300
# 6942        24.2        9100    Woods,Robert     WR2        23.4        3300
# 6943        34.0        6500    Woods,Robert     WR2        23.4        3300
# 6945        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6946        33.4        6400    Diggs,Stefon     WR2        26.7        4200
# 6947        24.2        9100      Evans,Mike     WR2        33.4        6400
# 6949        27.3        6500      Evans,Mike     WR2        33.4        6400
# 6950        27.3        6500      Evans,Mike     WR2        33.4        6400
# 6951        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6956        34.0        6500    Diggs,Stefon     WR2        26.7        4200
# 6959        24.2        9100      Evans,Mike     WR2        33.4        6400
# 6961        33.4        6400   Landry,Jarvis     WR2        25.8        6200
# 6963        33.4        6400    Woods,Robert     WR2        23.4        3300
# 6965        17.9        7700     Hilton,T.Y.     WR2        34.0        6500
# 6968        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6969        27.3        6500   Landry,Jarvis     WR2        25.8        6200
# 6970        22.6        3500    Woods,Robert     WR2        23.4        3300
# 6971        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6973        33.4        6400  Amendola,Danny     WR2        22.6        3500
# 6974        22.0        7900     Hilton,T.Y.     WR2        34.0        6500
# 6978        34.0        6500      Evans,Mike     WR2        33.4        6400
# 6979        21.8        6400   Landry,Jarvis     WR2        25.8        6200
# 6980        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6981        22.0        7900     Hilton,T.Y.     WR2        34.0        6500
# 6983        33.4        6400   Landry,Jarvis     WR2        25.8        6200
# 6984        25.8        6200    Diggs,Stefon     WR2        26.7        4200
# 6985        34.0        6500  Amendola,Danny     WR2        22.6        3500
# 6990        27.3        6500   Landry,Jarvis     WR2        25.8        6200
# 6991        24.2        9100      Evans,Mike     WR2        33.4        6400
# 6992        33.4        6400   Landry,Jarvis     WR2        25.8        6200
# 6994        34.0        6500    Cooper,Amari     WR2        27.3        6500
# 6997        24.2        9100      Evans,Mike     WR2        33.4        6400
# 6999        17.9        7700     Hilton,T.Y.     WR2        34.0        6500
#
#              wr3_name wr3_pos  wr3_points  wr3_salary        rb1_name rb1_pos  \
# 6000  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6001  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6003  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6004  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6005  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6009  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6011       Evans,Mike     WR3        33.4        6400     Gurley,Todd     RB1
# 6012  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6013  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6014  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6016  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6017       Evans,Mike     WR3        33.4        6400     Gurley,Todd     RB1
# 6018     Diggs,Stefon     WR3        26.7        4200     Gurley,Todd     RB1
# 6020  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6021  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6022  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6024       Evans,Mike     WR3        33.4        6400     Gurley,Todd     RB1
# 6026  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6027     Diggs,Stefon     WR3        26.7        4200  Woodhead,Danny     RB1
# 6031  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6032  Washington,Nate     WR3        36.7        3000     Ingram,Mark     RB1
# 6033  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6034    Landry,Jarvis     WR3        25.8        6200  Woodhead,Danny     RB1
# 6035  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6039  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6040  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6042  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6043  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6044  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6045     Diggs,Stefon     WR3        26.7        4200     Gurley,Todd     RB1
# 6046       Evans,Mike     WR3        33.4        6400    Foster,Arian     RB1
# 6048  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6049  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6051  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6052  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6054  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6057  Washington,Nate     WR3        36.7        3000  Woodhead,Danny     RB1
# 6058  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6059  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6063  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6064  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6066  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6067  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6069  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6070  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6072  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6073     Diggs,Stefon     WR3        26.7        4200     Gurley,Todd     RB1
# 6076  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6078  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6079  Washington,Nate     WR3        36.7        3000  Woodhead,Danny     RB1
# ...               ...     ...         ...         ...             ...     ...
# 6916  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6918  Washington,Nate     WR3        36.7        3000     Ingram,Mark     RB1
# 6920   Robinson,Allen     WR3        21.8        6400     Gurley,Todd     RB1
# 6921  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6922  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6923  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6924     Woods,Robert     WR3        23.4        3300    Miller,Lamar     RB1
# 6926     Woods,Robert     WR3        23.4        3300    Foster,Arian     RB1
# 6927  Washington,Nate     WR3        36.7        3000     Ingram,Mark     RB1
# 6929    Landry,Jarvis     WR3        25.8        6200     Gurley,Todd     RB1
# 6930  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6932  Washington,Nate     WR3        36.7        3000     Ingram,Mark     RB1
# 6934  Washington,Nate     WR3        36.7        3000    Miller,Lamar     RB1
# 6936     Woods,Robert     WR3        23.4        3300    Miller,Lamar     RB1
# 6937  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6938  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6939  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6940  Washington,Nate     WR3        36.7        3000     Ingram,Mark     RB1
# 6942  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6943  Washington,Nate     WR3        36.7        3000     Ingram,Mark     RB1
# 6945  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6946  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6947  Washington,Nate     WR3        36.7        3000    Miller,Lamar     RB1
# 6949  Washington,Nate     WR3        36.7        3000     Ingram,Mark     RB1
# 6950    Landry,Jarvis     WR3        25.8        6200     Gurley,Todd     RB1
# 6951     Diggs,Stefon     WR3        26.7        4200    Foster,Arian     RB1
# 6956  Washington,Nate     WR3        36.7        3000     Ingram,Mark     RB1
# 6959  Washington,Nate     WR3        36.7        3000    Miller,Lamar     RB1
# 6961  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6963  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6965  Washington,Nate     WR3        36.7        3000    Miller,Lamar     RB1
# 6968   Amendola,Danny     WR3        22.6        3500    Foster,Arian     RB1
# 6969  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6970  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6971     Woods,Robert     WR3        23.4        3300    Miller,Lamar     RB1
# 6973  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6974   Amendola,Danny     WR3        22.6        3500    Miller,Lamar     RB1
# 6978   Robinson,Allen     WR3        21.8        6400    Miller,Lamar     RB1
# 6979  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6980       Evans,Mike     WR3        33.4        6400     Gurley,Todd     RB1
# 6981   Amendola,Danny     WR3        22.6        3500     Gurley,Todd     RB1
# 6983  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6984  Washington,Nate     WR3        36.7        3000    Foster,Arian     RB1
# 6985  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6990  Washington,Nate     WR3        36.7        3000     Ingram,Mark     RB1
# 6991     Diggs,Stefon     WR3        26.7        4200     Ingram,Mark     RB1
# 6992     Woods,Robert     WR3        23.4        3300    Foster,Arian     RB1
# 6994  Washington,Nate     WR3        36.7        3000     Gurley,Todd     RB1
# 6997  Washington,Nate     WR3        36.7        3000     Martin,Doug     RB1
# 6999  Washington,Nate     WR3        36.7        3000    Miller,Lamar     RB1
#
#       rb1_points  rb1_salary         rb2_name rb2_pos  rb2_points  rb2_salary  \
# 6000        35.3        5000   Woodhead,Danny     RB2        33.1        4600
# 6001        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6003        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6004        29.5        7500      Gurley,Todd     RB2        35.3        5000
# 6005        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6009        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6011        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6012        29.5        7500   Woodhead,Danny     RB2        33.1        4600
# 6013        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6014        29.5        7500      Gurley,Todd     RB2        35.3        5000
# 6016        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6017        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6018        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6020        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6021        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6022        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6024        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6026        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6027        33.1        4600     Miller,Lamar     RB2        41.6        4600
# 6031        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6032        25.8        6300   Woodhead,Danny     RB2        33.1        4600
# 6033        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6034        33.1        4600     Miller,Lamar     RB2        41.6        4600
# 6035        29.5        7500     Miller,Lamar     RB2        41.6        4600
# 6039        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6040        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6042        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6043        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6044        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6045        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6046        29.5        7500     Miller,Lamar     RB2        41.6        4600
# 6048        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6049        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6051        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6052        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6054        29.5        7500     Miller,Lamar     RB2        41.6        4600
# 6057        33.1        4600     Miller,Lamar     RB2        41.6        4600
# 6058        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6059        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6063        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6064        29.5        7500   Woodhead,Danny     RB2        33.1        4600
# 6066        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6067        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6069        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6070        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6072        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6073        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6076        29.5        7500      Gurley,Todd     RB2        35.3        5000
# 6078        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6079        33.1        4600     Miller,Lamar     RB2        41.6        4600
# ...          ...         ...              ...     ...         ...         ...
# 6916        29.5        7500     Miller,Lamar     RB2        41.6        4600
# 6918        25.8        6300      Gurley,Todd     RB2        35.3        5000
# 6920        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6921        29.5        7500     Miller,Lamar     RB2        41.6        4600
# 6922        29.5        7500     Miller,Lamar     RB2        41.6        4600
# 6923        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6924        41.6        4600    Johnson,Chris     RB2        21.2        4300
# 6926        29.5        7500     Miller,Lamar     RB2        41.6        4600
# 6927        25.8        6300     Miller,Lamar     RB2        41.6        4600
# 6929        35.3        5000     Miller,Lamar     RB2        41.6        4600
# 6930        29.5        7500     Miller,Lamar     RB2        41.6        4600
# 
Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 1   Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 2   Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 3   Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 4   Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 5   Palmer,Carson     QB      28.68       6500    Johnson,Steve     WR1
# 6   Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 7   Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 8   Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 9   Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 10  Palmer,Carson     QB      28.68       6500  Washington,Nate     WR1
# 11  Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 12  Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 13  Palmer,Carson     QB      28.68       6500  Hopkins,DeAndre     WR1
# 14  Palmer,Carson     QB      28.68       6500    Johnson,Steve     WR1
#
#     wr1_points  wr1_salary       wr2_name wr2_pos  wr2_points  wr2_salary  \
# 0         32.8        7400    Jones,Julio     WR2        38.1        9300
# 1         32.8        7400    Jones,Julio     WR2        38.1        9300
# 2         32.8        7400    Jones,Julio     WR2        38.1        9300
# 3         32.8        7400    Jones,Julio     WR2        38.1        9300
# 4         32.8        7400    Jones,Julio     WR2        38.1        9300
# 5         20.2        3700    Jones,Julio     WR2        38.1        9300
# 6         32.8        7400    Jones,Julio     WR2        38.1        9300
# 7         32.8        7400    Jones,Julio     WR2        38.1        9300
# 8         32.8        7400    Jones,Julio     WR2        38.1        9300
# 9         32.8        7400    Jones,Julio     WR2        38.1        9300
# 10        19.5        3000    Jones,Julio     WR2        38.1        9300
# 11        32.8        7400    Jones,Julio     WR2        38.1        9300
# 12        32.8        7400  Johnson,Steve     WR2        20.2        3700
# 13        32.8        7400  Brown,Antonio     WR2        31.3        8900
# 14        20.2        3700    Jones,Julio     WR2        38.1        9300
#
#         wr3_name wr3_pos  wr3_points  wr3_salary          rb1_name rb1_pos  \
# 0   Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 1   Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 2   Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 3   Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 4   Allen,Keenan     WR3        34.6        7100      Reece,Marcel     RB1
# 5   Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 6   Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 7   Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 8   Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 9   Allen,Keenan     WR3        34.6        7100    Abdullah,Ameer     RB1
# 10  Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 11  Allen,Keenan     WR3        34.6        7100  Cunningham,Benny     RB1
# 12   Jones,Julio     WR3        38.1        9300       Hyde,Carlos     RB1
# 13  Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
# 14  Allen,Keenan     WR3        34.6        7100       Hyde,Carlos     RB1
#
#     rb1_points  rb1_salary        rb2_name rb2_pos  rb2_points  rb2_salary  \
# 0         35.2        5300     Ivory,Chris     RB2        23.0        4100
# 1         35.2        5300   Sankey,Bishop     RB2        22.6        4300
# 2         35.2        5300  Woodhead,Danny     RB2        22.2        3700
# 3         35.2        5300   Sankey,Bishop     RB2        22.6        4300
# 4         17.6        3000     Hyde,Carlos     RB2        35.2        5300
# 5         35.2        5300      Forte,Matt     RB2        30.6        7800
# 6         35.2        5300  Sproles,Darren     RB2        19.6        3300
# 7         35.2        5300   Sankey,Bishop     RB2        22.6        4300
# 8         35.2        5300   Sankey,Bishop     RB2        22.6        4300
# 9         19.4        4000     Hyde,Carlos     RB2        35.2        5300
# 10        35.2        5300      Forte,Matt     RB2        30.6        7800
# 11        16.2        3000     Hyde,Carlos     RB2        35.2        5300
# 12        35.2        5300      Forte,Matt     RB2        30.6        7800
# 13        35.2        5300     Ivory,Chris     RB2        23.0        4100
# 14        35.2        5300      Forte,Matt     RB2        30.6        7800
#
#          te_name te_pos  te_points  te_salary                flex_name  \
# 0   Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 1   Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 2   Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 3   Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 4   Eifert,Tyler     TE       34.4       3500             Kelce,Travis
# 5   Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 6   Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 7   Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 8   Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 9   Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 10  Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 11  Eifert,Tyler     TE       34.4       3500             Kelce,Travis
# 12  Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 13  Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
# 14  Eifert,Tyler     TE       34.4       3500  Seferian-Jenkins,Austin
#
#    flex_pos  flex_points  flex_salary   def_name def_pos  def_points  \
# 0   flex_TE         31.0         3400   Carolina     DEF          21
# 1   flex_TE         31.0         3400   Carolina     DEF          21
# 2   flex_TE         31.0         3400    Seattle     DEF          19
# 3   flex_TE         31.0         3400   NewYorkJ     DEF          17
# 4   flex_TE         31.6         4800   Carolina     DEF          21
# 5   flex_TE         31.0         3400   Carolina     DEF          21
# 6   flex_TE         31.0         3400    Seattle     DEF          19
# 7   flex_TE         31.0         3400  Baltimore     DEF          16
# 8   flex_TE         31.0         3400     Denver     DEF          16
# 9   flex_TE         31.0         3400    Seattle     DEF          19
# 10  flex_TE         31.0         3400   Carolina     DEF          21
# 11  flex_TE         31.6         4800   Carolina     DEF          21
# 12  flex_TE         31.0         3400   Carolina     DEF          21
# 13  flex_TE         31.0         3400   Carolina     DEF          21
# 14  flex_TE         31.0         3400    Seattle     DEF          19
#
#     def_salary  team_points  total_salary season_year   week
# 0         3100       278.78         49700        2015  week1
# 1         3100       278.38         49900        2015  week1
# 2         3400       275.98         49600        2015  week1
# 3         2900       274.38         49700        2015  week1
# 4         3100       273.98         50000        2015  week1
# 5         3100       273.78         49700        2015  week1
# 6         3400       273.38         49200        2015  week1
# 7         2700       273.38         49500        2015  week1
# 8         2800       273.38         49600        2015  week1
# 9         3400       273.18         49900        2015  week1
# 10        3100       273.08         49000        2015  week1
# 11        3100       272.58         50000        2015  week1
# 12        3100       271.98         50000        2015  week1
# 13        3100       271.98         49300        2015  week1
# 14        3400       271.78         50000        2015  week1

# %%
columns = ['percent_total', 'percent_filter']
index = ['flex_WR', 'flex_RB', 'flex_TE']

temp_df = pd.DataFrame(columns = columns, index = index)


temp_df.loc['flex_WR']['percent_total'] = len(sorted_df.loc[sorted_df['flex_pos'] == 'flex_WR']) / len(sorted_df)
temp_df.loc['flex_RB']['percent_total'] = len(sorted_df.loc[sorted_df['flex_pos'] == 'flex_RB']) / len(sorted_df)
temp_df.loc['flex_TE']['percent_total'] = len(sorted_df.loc[sorted_df['flex_pos'] == 'flex_TE']) / len(sorted_df)


temp_df.loc['flex_WR']['percent_filter'] = len(new_df.loc[new_df['flex_pos'] == 'flex_WR']) / len(new_df)
temp_df.loc['flex_RB']['percent_filter'] = len(new_df.loc[new_df['flex_pos'] == 'flex_RB']) / len(new_df)
temp_df.loc['flex_TE']['percent_filter'] = len(new_df.loc[new_df['flex_pos'] == 'flex_TE']) / len(new_df)

temp_df
# Out:
#         percent_total percent_filter
# flex_WR      0.485706       0.305842
# flex_RB      0.276471       0.560137
# flex_TE      0.237824       0.134021
