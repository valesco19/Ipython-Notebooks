# %%
import pandas as pd
import numpy as np
import os
import scipy.linalg as linalg
from pulp import *
import csv
import itertools
from tqdm import tqdm
import statsmodels.stats.moment_helpers as stats
import scipy
import matplotlib.pyplot as plt
import math
import matplotlib.mlab as mlab
from datetime import datetime
os.chdir('/home/valesco/Datasets/NFL/Week1')
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
def home_away(x):
    if '@' in x:
        return 'home'
    else:
        return 'away'
    


proj_df = pd.read_csv('2016_week1A_proj.csv')
cov_df = pd.read_csv('nfl_covariance_matrix.csv', index_col = 0)



proj_df['matchup'] = tuple(zip(proj_df['team'], proj_df['opponent']))
#proj_df['salary'] = proj_df['salary'].apply(lambda x: x.replace('$',''))
#proj_df['salary'] = proj_df['salary'].apply(lambda x: float(x.replace('K', '')))
#proj_df['salary'] = proj_df['salary'].apply(lambda x: x * 1000)
proj_df['rank'] = proj_df.groupby(['team', 'position'])['points'].rank(ascending = False, method = 'max')
proj_df['rank'].fillna(value = 9999, inplace = True)
proj_df['salary'].fillna(value = 9999, inplace = True)
proj_df['points'].fillna(value = -9.999, inplace = True)
proj_df['rank'] = proj_df['rank'].apply(lambda x: str(int(x)))
proj_df['home_away'] = proj_df['team'].apply(lambda x: home_away(x))
proj_df['rank'] = proj_df['home_away'] + '_' + proj_df['position'] + proj_df['rank']

proj_df.to_csv('2016_week1_proj_process.csv')
proj_df.head()
# Out:
#                   name  salary team position opponent  sal_diff  rank_diff  \
# 0           Cam Newton    7700  CAR       QB      DEN      -900          2
# 1     Jonathan Stewart    5100  CAR       RB      DEN     -1300          2
# 2  Cameron Artis-Payne    3000  CAR       RB      DEN     -2200         22
# 3      Kelvin Benjamin    5700  CAR       WR      DEN     -1600         17
# 4       Devin Funchess    4800  CAR       WR      DEN     -1400          5
#
#     o/u   line  total  movement  points  pt/$     matchup      rank home_away
# 0  42.0 -172.0   22.5     -0.25   19.86  2.58  (CAR, DEN)  away_QB1      away
# 1  42.0 -172.0   22.5     -0.25   13.11  2.57  (CAR, DEN)  away_RB1      away
# 2  42.0 -172.0   22.5     -0.25    4.07  1.36  (CAR, DEN)  away_RB2      away
# 3  42.0 -172.0   22.5     -0.25   11.86  2.08  (CAR, DEN)  away_WR1      away
# 4  42.0 -172.0   22.5     -0.25    9.46  1.97  (CAR, DEN)  away_WR2      away

# %%
away_teams = proj_df['team'].loc[proj_df['home_away'] == 'away'].unique()

player_cols = []
count = 0

for team in away_teams:
    temp1 = proj_df.loc[proj_df['team'] == team]
    temp2 = proj_df.loc[proj_df['opponent'] == team]
    temp_df = pd.concat([temp1, temp2], axis = 0)
    
    cols = cov_df.columns

    player_ls = []
    for c in cols:
        player = pd.DataFrame(temp_df.loc[temp_df['rank'] == c])
        
        if len(player) < 1:
            name = 'Not Available_' + str(count)
            count += 1
        else:
            name = player.iloc[0]['name']
        player_ls.append(name)
        
    player_cols.extend(player_ls)
    

arr_cov = np.asarray(cov_df)
for i in range(1,16):
    arr_new = np.asarray(cov_df)
    arr_cov = linalg.block_diag(arr_cov, arr_new)
    
comp_cov_df = pd.DataFrame(data = arr_cov, index = player_cols, columns = player_cols)
comp_cov_df.head()
# Out:
#                  Denver Broncos  Trevor Siemian  C.J. Anderson  \
# Denver Broncos             1.00           -0.08           0.11
# Trevor Siemian            -0.08            1.00           0.08
# C.J. Anderson              0.11            0.08           1.00
# Devontae Booker            0.03            0.06          -0.13
# Virgil Green              -0.08            0.33          -0.06
#
#                  Devontae Booker  Virgil Green  Demaryius Thomas  \
# Denver Broncos              0.03         -0.08              0.01
# Trevor Siemian              0.06          0.33              0.46
# C.J. Anderson              -0.13         -0.06              0.03
# Devontae Booker             1.00          0.04             -0.03
# Virgil Green                0.04          1.00             -0.04
#
#                  Emmanuel Sanders  Bennie Fowler  Carolina Panthers  \
# Denver Broncos               0.00          -0.09              -0.24
# Trevor Siemian               0.33           0.28              -0.41
# C.J. Anderson               -0.03          -0.07              -0.25
# Devontae Booker             -0.07           0.00              -0.13
# Virgil Green                -0.06           0.00              -0.09
#
#                  Cam Newton  Jonathan Stewart  Cameron Artis-Payne  \
# Denver Broncos        -0.41             -0.25                -0.13
# Trevor Siemian         0.20              0.03                -0.01
# C.J. Anderson          0.03             -0.01                -0.06
# Devontae Booker       -0.01             -0.06                -0.05
# Virgil Green           0.09              0.03                 0.00
#
#                  Greg Olsen  Kelvin Benjamin  Devin Funchess  Ted Ginn  \
# Denver Broncos        -0.09            -0.18           -0.12     -0.05
# Trevor Siemian         0.09             0.09            0.07      0.13
# C.J. Anderson          0.03             0.00            0.01      0.03
# Devontae Booker        0.00            -0.02           -0.03      0.00
# Virgil Green           0.04             0.02            0.04      0.03
#
#                  Tennessee Titans  Marcus Mariota  DeMarco Murray  \
# Denver Broncos                0.0             0.0             0.0
# Trevor Siemian                0.0             0.0             0.0
# C.J. Anderson                 0.0             0.0             0.0
# Devontae Booker               0.0             0.0             0.0
# Virgil Green                  0.0             0.0             0.0
#
#                  Derrick Henry  Delanie Walker  Tajae Sharpe  \
# Denver Broncos             0.0             0.0           0.0
# Trevor Siemian             0.0             0.0           0.0
# C.J. Anderson              0.0             0.0           0.0
# Devontae Booker            0.0             0.0           0.0
# Virgil Green               0.0             0.0           0.0
#
#                  Rishard Matthews  Kendall Wright  Minnesota Vikings  \
# Denver Broncos                0.0             0.0                0.0
# Trevor Siemian                0.0             0.0                0.0
# C.J. Anderson                 0.0             0.0                0.0
# Devontae Booker               0.0             0.0                0.0
# Virgil Green                  0.0             0.0                0.0
#
#                      ...        Josh Doctson  Pittsburgh Steelers  \
# Denver Broncos       ...                 0.0                  0.0
# Trevor Siemian       ...                 0.0                  0.0
# C.J. Anderson        ...                 0.0                  0.0
# Devontae Booker      ...                 0.0                  0.0
# Virgil Green         ...                 0.0                  0.0
#
#                  Ben Roethlisberger  DeAngelo Williams  Fitzgerald Toussaint  \
# Denver Broncos                  0.0                0.0                   0.0
# Trevor Siemian                  0.0                0.0                   0.0
# C.J. Anderson                   0.0                0.0                   0.0
# Devontae Booker                 0.0                0.0                   0.0
# Virgil Green                    0.0                0.0                   0.0
#
#                  Jesse James  Antonio Brown  Markus Wheaton  Sammie Coates  \
# Denver Broncos           0.0            0.0             0.0            0.0
# Trevor Siemian           0.0            0.0             0.0            0.0
# C.J. Anderson            0.0            0.0             0.0            0.0
# Devontae Booker          0.0            0.0             0.0            0.0
# Virgil Green             0.0            0.0             0.0            0.0
#
#                  San Francisco 49ers  Blaine Gabbert  Carlos Hyde  \
# Denver Broncos                   0.0             0.0          0.0
# Trevor Siemian                   0.0             0.0          0.0
# C.J. Anderson                    0.0             0.0          0.0
# Devontae Booker                  0.0             0.0          0.0
# Virgil Green                     0.0             0.0          0.0
#
#                  Shaun Draughn  Vance McDonald  Torrey Smith  Quinton Patton  \
# Denver Broncos             0.0             0.0           0.0             0.0
# Trevor Siemian             0.0             0.0           0.0             0.0
# C.J. Anderson              0.0             0.0           0.0             0.0
# Devontae Booker            0.0             0.0           0.0             0.0
# Virgil Green               0.0             0.0           0.0             0.0
#
#                  Jeremy Kerley  Los Angeles Rams  Case Keenum  Todd Gurley  \
# Denver Broncos             0.0               0.0          0.0          0.0
# Trevor Siemian             0.0               0.0          0.0          0.0
# C.J. Anderson              0.0               0.0          0.0          0.0
# Devontae Booker            0.0               0.0          0.0          0.0
# Virgil Green               0.0               0.0          0.0          0.0
#
#                  Benny Cunningham  Lance Kendricks  Tavon Austin  Kenny Britt  \
# Denver Broncos                0.0              0.0           0.0          0.0
# Trevor Siemian                0.0              0.0           0.0          0.0
# C.J. Anderson                 0.0              0.0           0.0          0.0
# Devontae Booker               0.0              0.0           0.0          0.0
# Virgil Green                  0.0              0.0           0.0          0.0
#
#                  Pharoh Cooper
# Denver Broncos             0.0
# Trevor Siemian             0.0
# C.J. Anderson              0.0
# Devontae Booker            0.0
# Virgil Green               0.0
#
# [5 rows x 256 columns]

# %%
position_std = {'QB': 8.096014, 'WR': 9.813933, 'RB': 8.702397, 'TE': 8.096014, 'DST': 6.09265}
position_mu = {'QB': 19.861207, 'WR': 12.67457, 'RB': 12.900904, 'TE': 12.50152, 'DST': 7.447265}

# %%
matchups = proj_df['matchup'].unique()
games = []
for game in matchups:
    if '@' in game[0] or '@' in game[1]:
        games.append(game)
    
games = games[1:14]

combo_df = pd.DataFrame(columns = ['p1_name', 'p1_points', 'p1_pos', 'p1_salary', 'p1_rank', 'p1_std', 
                                   'p2_name', 'p2_points', 'p2_pos', 'p2_salary', 'p2_rank', 'p2_std',
                                   'p3_name', 'p3_points', 'p3_pos', 'p3_salary', 'p3_rank', 'p3_std',
                                   'p4_name', 'p4_points', 'p4_pos', 'p4_salary', 'p4_rank', 'p4_std',
                                   '1_2corr', '1_3corr', '1_4corr', '2_3corr', '2_4corr', '3_4corr',
                                   'combo_salary', 'combo_points', 'qb_count', 'wr_count',
                                   'rb_count', 'te_count', 'dst_count'
                                   ])
row_count = 0
for game in tqdm(games):
    
    temp_home = proj_df.loc[proj_df['team'] == game[0]]    
    temp_away = proj_df.loc[proj_df['team'] == game[1]]
    temp = pd.concat([temp_home, temp_away], axis = 0)
    temp = temp.loc[temp['points'] > 7]

    player_ls = temp['name'].values

    combos = []

    for i in range(2,5):
        for tup in itertools.combinations(player_ls, i):
            combos.append(tup)

    for combo in combos:
        for c in range(len(combo)):
            if c == 0:
                player_temp = temp.loc[temp['name'] == combo[c]]
                name1 = player_temp.iloc[0]['name']
                points1 = player_temp.iloc[0]['points']
                pos1 = player_temp.iloc[0]['position']
                salary1 = player_temp.iloc[0]['salary']
                rank1 = player_temp.iloc[0]['rank']
                std1 = position_std[pos1]
            if c == 1:
                player_temp = temp.loc[temp['name'] == combo[c]]
                name2 = player_temp.iloc[0]['name']
                points2 = player_temp.iloc[0]['points']
                pos2 = player_temp.iloc[0]['position']
                salary2 = player_temp.iloc[0]['salary']
                rank2 = player_temp.iloc[0]['rank']
                std2 = position_std[pos2]
            if len(combo) > 2:
                if c == 2:
                    player_temp = temp.loc[temp['name'] == combo[c]]
                    name3 = player_temp.iloc[0]['name']
                    points3 = player_temp.iloc[0]['points']
                    pos3 = player_temp.iloc[0]['position']
                    salary3 = player_temp.iloc[0]['salary']
                    rank3 = player_temp.iloc[0]['rank']
                    std3 = position_std[pos3]
            else:
                name3 = 'null'
                points3 = 0
                pos3 = 'null'
                salary3 = 0
                rank3 = 'null'
                std3 = 0
            if len(combo) > 3:
                if c == 3:
                    player_temp = temp.loc[temp['name'] == combo[c]]
                    name4 = player_temp.iloc[0]['name']
                    points4 = player_temp.iloc[0]['points']
                    pos4 = player_temp.iloc[0]['position']
                    salary4 = player_temp.iloc[0]['salary']
                    rank4 = player_temp.iloc[0]['rank']
                    std4 = position_std[pos4]
            else:
                name4 = 'null'
                points4 = 0
                pos4 = 'null'
                salary4 = 0
                rank4 = 'null'
                std4 = 0

                
        try:       
            corr1_2 = comp_cov_df.loc[name1][name2]
        except:
            corr1_2 = 0
        if name3 != 'null':
            try:
                corr1_3 = comp_cov_df.loc[name1][name3]
                corr2_3 = comp_cov_df.loc[name2][name3]
            except:
                corr1_3 = 0
                corr2_3 = 0
        else:
            corr1_3 = 0
            corr2_3 = 0
        if name4 != 'null':
            try:
                corr1_4 = comp_cov_df.loc[name1][name4]
                corr2_4 = comp_cov_df.loc[name2][name4]
                corr3_4 = comp_cov_df.loc[name3][name4]
            except:
                corr1_4 = 0
                corr2_4 = 0
                corr3_4 = 0
        else:
            corr1_4 = 0
            corr2_4 = 0
            corr3_4 = 0
        
        combo_salary = salary1 + salary2 + salary3 + salary4
        combo_points = points1 + points2 + points3 + points4
        
        pos_ls = [pos1, pos2, pos3, pos4]
        
        qb_count = 0
        wr_count = 0
        rb_count = 0
        te_count = 0
        dst_count = 0
        
        for pos in pos_ls:
            if pos == 'QB':
                qb_count += 1
            elif pos == 'WR':
                wr_count += 1
            elif pos == 'RB':
                rb_count += 1
            elif pos == 'TE':
                te_count += 1
            elif pos == 'DST':
                dst_count += 1
            elif pos == 'null':
                nope = 'nope'
            else:
                print('HOOLLLLAAA!!!')
                
        if qb_count > 1:
            pass
        elif dst_count > 1:
            pass
        elif rb_count > 3:
            pass
        elif te_count > 2:
            pass
        else:
            combo_df.loc[row_count] = [name1, points1, pos1, salary1, rank1, std1,
                               name2, points2, pos2, salary2, rank2, std2,
                               name3, points3, pos3, salary3, rank3, std3,
                               name4, points4, pos4, salary4, rank4, std4,
                               corr1_2, corr1_3, corr1_4, corr2_3, corr2_4, corr3_4,
                               combo_salary, combo_points, qb_count, wr_count, rb_count,
                               te_count, dst_count]
        row_count += 1
# Out:
# 100%|██████████| 13/13 [06:48<00:00, 38.19s/it]

# %%
for index, row in tqdm(combo_df.iterrows()):
    player_count = row['qb_count'] + row['wr_count'] + row['rb_count'] + row['te_count'] + row['dst_count']
    
    if player_count == 2:
        corr1_2 = row['1_2corr']
        
        temp_mu = row['p1_points'] + row['p2_points']
        temp_array = np.array([[1, corr1_2], [corr1_2, 1]])
        temp_std = [row['p1_std'], row['p2_std']]
        cov_matrix = stats.corr2cov(temp_array, temp_std)
        temp_var = row['p1_std'] ** 2 + row['p2_std'] ** 2 + 2 * (cov_matrix[1,0])
        temp_dist = scipy.stats.norm(temp_mu, np.sqrt(temp_var))
    elif player_count == 3:
        corr1_2 = row['1_2corr']
        corr1_3 = row['1_3corr']
        corr2_3 = row['2_3corr']
        
        temp_mu = row['p1_points'] + row['p2_points'] + row['p3_points']
        temp_array = np.array([[1, corr1_2, corr1_3],[corr1_2, 1, corr2_3], [corr1_3, corr2_3, 1]])
        temp_std = [row['p1_std'], row['p2_std'], row['p3_std']]
        cov_matrix = stats.corr2cov(temp_array, temp_std)
        temp_var = row['p1_std'] ** 2 + row['p2_std'] ** 2 + row['p3_std'] ** 2 + 2 * (cov_matrix[1,0] + 
                                                            cov_matrix[2,0] + cov_matrix[2,1])
        temp_dist = scipy.stats.norm(temp_mu, np.sqrt(temp_var))
    elif player_count == 4:
        corr1_2 = row['1_2corr']
        corr1_3 = row['1_3corr']
        corr1_4 = row['1_4corr']
        corr2_3 = row['2_3corr']
        corr2_4 = row['2_4corr']
        corr3_4 = row['3_4corr']
        p1_std = row['p1_std']
        p2_std = row['p2_std']
        p3_std = row['p3_std']
        p4_std = row['p4_std']
        
        temp_mu = row['p1_points'] + row['p2_points'] + row['p3_points'] + row['p4_points']
        temp_array = np.array([[1, corr1_2, corr1_3, corr1_4], [corr1_2, 1, corr2_3, corr2_4],
                              [corr1_3, corr2_3, 1, corr3_4], [corr1_4, corr2_4, corr3_4, 1]])
        temp_std = [p1_std, p2_std, p3_std, p4_std]
        cov_matrix = stats.corr2cov(temp_array, temp_std)
        temp_var = p1_std ** 2 + p2_std ** 2 + p3_std ** 2 + p4_std ** 2 + 2 * (cov_matrix[1,0] + cov_matrix[2, 0] + 
                                        cov_matrix[3,0] + cov_matrix[2, 1] + cov_matrix[3,1] + cov_matrix[3,2])
         
        temp_dist = scipy.stats.norm(temp_mu, np.sqrt(temp_var))
    else:
        print('HOOOOLLLLLAAAA')
        
    combo_df.loc[index, 'combo_var'] = temp_var
# Out:
# 16615it [00:28, 590.01it/s]

# %%
row_count = len(combo_df)

for index, row in proj_df.iterrows():
    p1_name = row['name']
    p1_points = row['points']
    p1_pos = row['position']
    p1_salary = row['salary']
    p1_rank = row['rank']
    
    qb_count = 0
    wr_count = 0
    rb_count = 0
    te_count = 0 
    dst_count = 0
    
    if p1_pos == 'QB':
        qb_count = 1
        p1_std = position_std['QB']
    elif p1_pos == 'WR':
        wr_count = 1
        p1_std = position_std['WR']
    elif p1_pos == 'RB':
        rb_count = 1
        p1_std = position_std['RB']
    elif p1_pos == 'TE':
        te_count = 1
        p1_std = position_std['TE']
    elif p1_pos == 'DST':
        dst_count = 1
        p1_std = position_std['DST']
    else:
        print('HOOOLLAAAA')
        
    corr1_2 = 0
    corr1_3 = 0
    corr1_4 = 0
    corr2_3 = 0
    corr2_4 = 0
    corr3_4 = 0
    
    combo_salary = p1_salary
    combo_points = p1_points
    
    p1_ppf = p1_std ** 2
    
    combo_df.loc[row_count] = [p1_name, p1_points, p1_pos, p1_salary, p1_rank, p1_std,
                               'null', 0, 'null', 0, 'null', 0,
                               'null', 0, 'null', 0, 'null', 0,
                               'null', 0, 'null', 0, 'null', 0,
                               corr1_2, corr1_3, corr1_4, corr2_3, corr2_4, corr3_4,
                               combo_salary, combo_points, qb_count, wr_count, rb_count,
                               te_count, dst_count, p1_ppf]
    
    row_count += 1

# %%
combo_df['players'] = tuple(zip(combo_df['p1_name'], combo_df['p2_name'], combo_df['p3_name'], combo_df['p4_name']))

dummies = combo_df['players'].str.join(sep = '*').str.get_dummies(sep = '*')

combo_df = pd.concat([combo_df, dummys], axis = 1)

# %%
cols = combo_df.columns
cols = list(cols[39:])

combo_df.drop('players', axis = 1, inplace = True)
combo_df.to_csv('week1_ppf.csv')

# %%
in_file = "week1_ppf.csv"
reader = csv.DictReader(open(in_file, 'r'))
player_dict = []
for i , row in enumerate(reader):
    team = {k: v for k, v in row.items()}
    team['id'] = i
    player_dict.append(team)
    
players = [player['id'] for player in player_dict]
teams = [0]

# %%
start = datetime.now()

players = [player['id'] for player in player_dict]            

opt = LpProblem('Optimizer', LpMaximize)
possible_assignments = LpVariable.dicts("possible", (teams, players), 0, 1, LpBinary)

#objective
opt += sum([float(player['combo_var']) * possible_assignments[team][player['id']] for player in player_dict for team in teams])

#set player max to 1 per team:
for col in tqdm(cols):
    opt += lpSum([float(player[col]) * possible_assignments[team][player['id']] for player in player_dict]) <= 1, 'player' + col


#set constraints
for team in teams:
    opt += lpSum([float(player['combo_salary']) * possible_assignments[team][player['id']] for player in player_dict]) <= 50000
    opt += lpSum([float(player['qb_count']) * possible_assignments[team][player['id']] for player in player_dict]) == 1
    opt += lpSum([float(player['wr_count']) * possible_assignments[team][player['id']] for player in player_dict]) == 4
    opt += lpSum([float(player['rb_count']) * possible_assignments[team][player['id']] for player in player_dict]) == 2
    opt += lpSum([float(player['te_count']) * possible_assignments[team][player['id']] for player in player_dict]) == 1
    opt += lpSum([float(player['dst_count']) * possible_assignments[team][player['id']] for player in player_dict]) == 1
    
    #opt += lpSum([(float(player['dst_count']) + float(player['qb_count']) + float(player['wr_count'])
    #            + float(player['rb_count'])) * possible_assignments[team][player['id']] for player in player_dict]) == 8
    
    

opt.writeLP('fantasy_optimization.lp')
opt.solve()
status = LpStatus[opt.status]
selected = []

finish = datetime.now() - start
print(finish)
# Out:
#   0%|          | 0/320 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-207-1c46da15f643> in <module>()
#      11 #set player max to 1 per team:
#      12 for col in tqdm(cols):
# ---> 13     opt += lpSum([float(player[col]) * possible_assignments[team][player['id']] for player in player_dict]) <= 1, 'player' + col
#      14
#      15
#
# <ipython-input-207-1c46da15f643> in <listcomp>(.0)
#      11 #set player max to 1 per team:
#      12 for col in tqdm(cols):
# ---> 13     opt += lpSum([float(player[col]) * possible_assignments[team][player['id']] for player in player_dict]) <= 1, 'player' + col
#      14
#      15
#
# TypeError: unhashable type: 'dict'

# %%
print(status)
# Out:
# Optimal

# %%
team_dict = {}
for player in player_dict:
            if possible_assignments[0][player['id']].value() == 1.0:
                players = {}
                #print(player['player'] + ' salary: ' + player['salary'] + ' proj: ' + player['odds'])
                #opt_odds.append(float(player['odds']))
                p1_name = player['p1_name']
                p2_name = player['p2_name']
                p3_name = player['p3_name']
                p4_name = player['p4_name']
                
                p1_points = player['p1_points']
                p2_points = player['p2_points']
                p3_points = player['p3_points']
                p4_points = player['p4_points']
                
                p1_pos = player['p1_pos']
                p2_pos = player['p2_pos']
                p3_pos = player['p3_pos']
                p4_pos = player['p4_pos']
                
                p1_salary = player['p1_salary']
                p2_salary = player['p2_salary']
                p3_salary = player['p3_salary']
                p4_salary = player['p4_salary']
                
                p_ls = [p1_name, p2_name, p3_name, p4_name]
                
                for i, p in enumerate(p_ls):
                    if p != 'null':
                        if i == 0:
                            print('{}, {}, {}, {}'.format(p1_name, p1_points, p1_pos, p1_salary))
                            print('single player')
                        if i == 1:
                            print('{}, {}, {}, {}'.format(p2_name, p2_points, p2_pos, p2_salary))
                            print('2 man stack')
                        if i == 2:
                            print('{}, {}, {}, {}'.format(p3_name, p3_points, p3_pos, p3_salary))
                            print('3 man stack')
                        if i == 3:
                            print('{}, {}, {}, {}'.format(p4_name, p4_points, p4_pos, p4_salary))    
                            print('4 man stack')
                    
           
                team_dict[player['id']] = players
# Out:
# DeMarco Murray, 11.99, RB, 5300.0
# single player
# Tajae Sharpe, 11.83, WR, 3000.0
# 2 man stack
# Kyle Rudolph, 8.39, TE, 3000.0
# 3 man stack
# Marcus Mariota, 19.06, QB, 6400.0
# single player
# Rishard Matthews, 10.47, WR, 3300.0
# 2 man stack
# Tajae Sharpe, 11.83, WR, 3000.0
# 3 man stack
# Kendall Wright, 8.37, WR, 3400.0
# 4 man stack
# James White, 12.22, RB, 3600.0
# single player
# New England Patriots, 7.08, DST, 2900.0
# 2 man stack

# %%
player_dict[0]
# Out:
# {'': '0',
#  '1_2corr': '0.08',
#  '1_3corr': '0.0',
#  '1_4corr': '0.0',
#  '2_3corr': '0.0',
#  '2_4corr': '0.0',
#  '3_4corr': '0.0',
#  'A.J. Green': '0',
#  'Aaron Dobson': '0',
#  'Aaron Rodgers': '0',
#  'Adam Humphries': '0',
#  'Adrian Peterson': '0',
#  'Albert Wilson': '0',
#  'Alex Smith': '0',
#  'Alfred Blue': '0',
#  'Alfred Morris': '0',
#  'Allen Hurns': '0',
#  'Allen Robinson': '0',
#  'Alshon Jeffery': '0',
#  'Amari Cooper': '0',
#  'Ameer Abdullah': '0',
#  'Andre Ellington': '0',
#  'Andre Holmes': '0',
#  'Andre Johnson': '0',
#  'Andrew Hawkins': '0',
#  'Andrew Luck': '0',
#  'Andy Dalton': '0',
#  'Anquan Boldin': '0',
#  'Anthony Fasano': '0',
#  'Antonio Brown': '0',
#  'Antonio Gates': '0',
#  'Arian Foster': '0',
#  'Arizona Cardinals': '0',
#  'Atlanta Falcons': '0',
#  'Austin Seferian-Jenkins': '0',
#  'Baltimore Ravens': '0',
#  'Ben Roethlisberger': '0',
#  'Bennie Fowler': '0',
#  'Benny Cunningham': '0',
#  'Bilal Powell': '0',
#  'Blaine Gabbert': '0',
#  'Blake Bortles': '0',
#  'Brandin Cooks': '0',
#  'Brandon Coleman': '0',
#  'Brandon LaFell': '0',
#  'Brandon Marshall': '0',
#  'Brandon Pettigrew': '0',
#  'Brandon Tate': '0',
#  'Brent Celek': '0',
#  'Breshad Perriman': '0',
#  'Brian Quick': '0',
#  'Brice Butler': '0',
#  'Brock Osweiler': '0',
#  'Buffalo Bills': '0',
#  'C.J. Anderson': '0',
#  'C.J. Fiedorowicz': '0',
#  'C.J. Prosise': '0',
#  'C.J. Spiller': '0',
#  'Cam Newton': '0',
#  'Cameron Artis-Payne': '0',
#  'Cameron Brate': '0',
#  'Carlos Hyde': '0',
#  'Carolina Panthers': '0',
#  'Carson Palmer': '0',
#  'Carson Wentz': '0',
#  'Case Keenum': '0',
#  'Cecil Shorts': '0',
#  'Charcandrick West': '0',
#  'Charles Clay': '0',
#  'Charles Johnson': '0',
#  'Charles Sims': '0',
#  'Chase Daniel': '0',
#  'Chicago Bears': '0',
#  'Chris Conley': '0',
#  'Chris Hogan': '0',
#  'Chris Ivory': '0',
#  'Chris Johnson': '0',
#  'Chris Thompson': '0',
#  'Christine Michael': '0',
#  'Cincinnati Bengals': '0',
#  'Cleveland Browns': '0',
#  'Clive Walford': '0',
#  'Coby Fleener': '0',
#  'Cody Latimer': '0',
#  'Cole Beasley': '0',
#  'Corey Coleman': '0',
#  'Crockett Gillmore': '0',
#  'Dak Prescott': '0',
#  'Dallas Cowboys': '0',
#  'Danny Amendola': '0',
#  'Danny Woodhead': '0',
#  'Darren Fells': '0',
#  'Darren Sproles': '0',
#  'Darrius Heyward-Bey': '0',
#  'Davante Adams': '0',
#  'David Johnson': '0',
#  'DeAndre Hopkins': '0',
#  'DeAndre Washington': '0',
#  'DeAngelo Williams': '0',
#  'DeMarco Murray': '1',
#  'DeSean Jackson': '0',
#  'DeVante Parker': '0',
#  'Delanie Walker': '0',
#  'Demaryius Thomas': '0',
#  'Dennis Pitta': '0',
#  'Denver Broncos': '0',
#  'Derek Carr': '0',
#  'Derrick Henry': '0',
#  'Detroit Lions': '0',
#  'Devin Funchess': '0',
#  'Devonta Freeman': '0',
#  'Devontae Booker': '0',
#  'Dez Bryant': '0',
#  'Dezmin Lewis': '0',
#  'Dion Sims': '0',
#  'Donte Moncrief': '0',
#  'Dontrelle Inman': '0',
#  'Dorial Green-Beckham': '0',
#  'Doug Baldwin': '0',
#  'Doug Martin': '0',
#  'Drew Brees': '0',
#  'Duke Johnson': '0',
#  'Dwayne Allen': '0',
#  'Dwayne Harris': '0',
#  'Ed Dickson': '0',
#  'Eddie Lacy': '0',
#  'Eddie Royal': '0',
#  'Eli Manning': '0',
#  'Eli Rogers': '0',
#  'Emmanuel Sanders': '0',
#  'Eric Decker': '0',
#  'Eric Ebron': '0',
#  'Ezekiel Elliott': '0',
#  'Fitzgerald Toussaint': '0',
#  'Frank Gore': '0',
#  'Gary Barnidge': '0',
#  'Gavin Escobar': '0',
#  'Giovani Bernard': '0',
#  'Golden Tate': '0',
#  'Green Bay Packers': '0',
#  'Greg Olsen': '0',
#  'Greg Salas': '0',
#  'Houston Texans': '0',
#  'Indianapolis Colts': '0',
#  'Isaiah Crowell': '0',
#  'Jace Amaro': '0',
#  'Jack Doyle': '0',
#  'Jacksonville Jaguars': '0',
#  'Jacob Tamme': '0',
#  'Jaelen Strong': '0',
#  'Jamaal Charles': '0',
#  'Jameis Winston': '0',
#  'James Starks': '0',
#  'James White': '0',
#  'Jamison Crowder': '0',
#  'Jared Abbrederis': '0',
#  'Jared Cook': '0',
#  'Jarius Wright': '0',
#  'Jaron Brown': '0',
#  'Jarvis Landry': '0',
#  'Jason Witten': '0',
#  'Javorius Allen': '0',
#  'Jay Ajayi': '0',
#  'Jay Cutler': '0',
#  'Jeremy Hill': '0',
#  'Jeremy Kerley': '0',
#  'Jeremy Langford': '0',
#  'Jeremy Maclin': '0',
#  'Jerick McKinnon': '0',
#  'Jermaine Gresham': '0',
#  'Jermaine Kearse': '0',
#  'Jesse James': '0',
#  'Jimmy Garoppolo': '0',
#  'Jimmy Graham': '0',
#  'Joe Flacco': '0',
#  'John Brown': '0',
#  'Jonathan Stewart': '0',
#  'Jordan Cameron': '0',
#  'Jordan Howard': '0',
#  'Jordan Matthews': '0',
#  'Jordan Reed': '0',
#  'Jordy Nelson': '0',
#  'Josh Bellamy': '0',
#  'Josh Doctson': '0',
#  'Julian Edelman': '0',
#  'Julio Jones': '0',
#  'Julius Thomas': '0',
#  'Justin Forsett': '0',
#  'Justin Hardy': '0',
#  "Ka'Deem Carey": '0',
#  'Kamar Aiken': '0',
#  'Kansas City Chiefs': '0',
#  'Keenan Allen': '0',
#  'Kellen Davis': '0',
#  'Kelvin Benjamin': '0',
#  'Kenbrell Thompkins': '0',
#  'Kendall Wright': '0',
#  'Kenny Bell': '0',
#  'Kenny Britt': '0',
#  'Kenny Stills': '0',
#  'Keshawn Martin': '0',
#  'Kevin White': '0',
#  'Kirk Cousins': '0',
#  'Kyle Rudolph': '0',
#  'Lamar Miller': '0',
#  'Lance Kendricks': '0',
#  'Laquon Treadwell': '0',
#  'Larry Donnell': '0',
#  'Larry Fitzgerald': '0',
#  'Latavius Murray': '0',
#  'LeGarrette Blount': '0',
#  'LeSean McCoy': '0',
#  'Leonard Hankerson': '0',
#  'Leonte Carroo': '0',
#  'Levine Toilolo': '0',
#  'Los Angeles Rams': '0',
#  'Luke Willson': '0',
#  'Marcedes Lewis': '0',
#  'Marcus Mariota': '1',
#  'Mark Ingram': '0',
#  'Markus Wheaton': '0',
#  'Marqise Lee': '0',
#  'Martellus Bennett': '0',
#  'Marvin Jones': '0',
#  'Matt Forte': '0',
#  'Matt Jones': '0',
#  'Matt Ryan': '0',
#  'Matthew Stafford': '0',
#  'Maxx Williams': '0',
#  'Melvin Gordon': '0',
#  'Miami Dolphins': '0',
#  'Michael Crabtree': '0',
#  'Michael Floyd': '0',
#  'Michael Thomas': '0',
#  'Mike Evans': '0',
#  'Mike Gillislee': '0',
#  'Mike Wallace': '0',
#  'Minnesota Vikings': '0',
#  'Mohamed Sanu': '0',
#  'MyCole Pruitt': '0',
#  'Mychal Rivera': '0',
#  'Nelson Agholor': '0',
#  'New England Patriots': '0',
#  'New Orleans Saints': '0',
#  'New York Giants': '0',
#  'New York Jets': '0',
#  'Nick Williams': '0',
#  'Oakland Raiders': '0',
#  'Odell Beckham': '0',
#  'Paul Richardson': '0',
#  'Pharoh Cooper': '0',
#  'Philadelphia Eagles': '0',
#  'Philip Rivers': '0',
#  'Phillip Dorsett': '0',
#  'Philly Brown': '0',
#  'Pierre Garcon': '0',
#  'Pittsburgh Steelers': '0',
#  'Quincy Enunwa': '0',
#  'Quinton Patton': '0',
#  'Randall Cobb': '0',
#  'Rashad Greene': '0',
#  'Rashad Jennings': '0',
#  'Reggie Bush': '0',
#  'Richard Rodgers': '0',
#  'Rishard Matthews': '0',
#  'Rob Gronkowski': '0',
#  'Robert Griffin III': '0',
#  'Robert Turbin': '0',
#  'Robert Woods': '0',
#  'Russell Wilson': '0',
#  'Ryan Fitzpatrick': '0',
#  'Ryan Griffin': '0',
#  'Ryan Mathews': '0',
#  'Ryan Tannehill': '0',
#  'Sam Bradford': '0',
#  'Sammie Coates': '0',
#  'Sammy Watkins': '0',
#  'San Diego Chargers': '0',
#  'San Francisco 49ers': '0',
#  'Seattle Seahawks': '0',
#  'Seth Roberts': '0',
#  'Shane Vereen': '0',
#  'Shaun Draughn': '0',
#  'Shaun Hill': '0',
#  'Spencer Ware': '0',
#  'Stefon Diggs': '0',
#  'Sterling Shepard': '0',
#  'Steve Smith': '0',
#  'T.J. Yeldon': '0',
#  'T.Y. Hilton': '0',
#  'TJ Jones': '0',
#  'Taiwan Jones': '0',
#  'Tajae Sharpe': '0',
#  'Tampa Bay Buccaneers': '0',
#  'Tavon Austin': '0',
#  'Ted Ginn': '0',
#  'Tennessee Titans': '0',
#  'Terrance West': '0',
#  'Terrance Williams': '0',
#  'Terrelle Pryor': '0',
#  'Tevin Coleman': '0',
#  'Theo Riddick': '0',
#  'Thomas Rawls': '0',
#  'Tim Hightower': '0',
#  'Todd Gurley': '0',
#  'Torrey Smith': '0',
#  'Travis Benjamin': '0',
#  'Travis Kelce': '0',
#  'Trevor Siemian': '0',
#  'Tyler Boyd': '0',
#  'Tyler Kroft': '0',
#  'Tyler Lockett': '0',
#  'Tyrell Williams': '0',
#  'Tyrod Taylor': '0',
#  'Vance McDonald': '0',
#  'Vernon Davis': '0',
#  'Victor Cruz': '0',
#  'Vincent Jackson': '0',
#  'Virgil Green': '0',
#  'Washington Redskins': '0',
#  'Will Fuller': '0',
#  'Will Tye': '0',
#  'Willie Snead': '0',
#  'Zach Ertz': '0',
#  'Zach Miller': '0',
#  'Zach Zenner': '0',
#  'combo_points': '31.049999999999997',
#  'combo_salary': '11700.0',
#  'combo_var': '152.54991270509427',
#  'dst_count': '0.0',
#  'id': 0,
#  'null': '1',
#  'p1_name': 'Marcus Mariota',
#  'p1_points': '19.06',
#  'p1_pos': 'QB',
#  'p1_rank': 'home_QB1',
#  'p1_salary': '6400.0',
#  'p1_std': '8.096014',
#  'p2_name': 'DeMarco Murray',
#  'p2_points': '11.99',
#  'p2_pos': 'RB',
#  'p2_rank': 'home_RB1',
#  'p2_salary': '5300.0',
#  'p2_std': '8.702397',
#  'p3_name': 'null',
#  'p3_points': '0.0',
#  'p3_pos': 'null',
#  'p3_rank': 'null',
#  'p3_salary': '0.0',
#  'p3_std': '0.0',
#  'p4_name': 'null',
#  'p4_points': '0.0',
#  'p4_pos': 'null',
#  'p4_rank': 'null',
#  'p4_salary': '0.0',
#  'p4_std': '0.0',
#  'players': "('Marcus Mariota', 'DeMarco Murray', 'null', 'null')",
#  'qb_count': '1.0',
#  'rb_count': '1.0',
#  'te_count': '0.0',
#  'wr_count': '0.0'}
