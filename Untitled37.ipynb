# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import requests
import os
import json
import time
import re

# %%
zoom_dict = {
    0: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=14&rect=-91217638,30632779,-91188155,30659695&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=14'],
    1: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=14&rect=-91191266,30630841,-91161783,30657757&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=14'],
    2: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=14&rect=-91165988,30629622,-91136506,30656539&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=14'],
    3: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=14&rect=-91141312,30629622,-91111829,30656539&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=14'],
    4: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=14&rect=-91104319,30629474,-91074836,30656391&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=14'],
    5: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91070138,30574233,-90952206,30681916&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    6: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-90962334,30602457,-90903368,30656298&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    7: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-90919290,30592890,-90860324,30646737&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    8: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-90892725,30563222,-90774794,30670917&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    9: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-90897017,30489731,-90779085,30597508&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    10: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-90943236,30534801,-90884271,30588679&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    11: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-90989070,30541454,-90930104,30595329&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    12: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-91028380,30554390,-90969415,30608257&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    13: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-91072927,30561115,-91013961,30614979&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    14: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91158543,30544226,-91040612,30651942&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    15: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91204634,30557309,-91086702,30665011&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    16: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91283684,30567286,-91165753,30674977&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    17: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-91222873,30535318,-91163907,30589196&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    18: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-91224675,30509588,-91165709,30563480&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    19: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-91179786,30505521,-91120820,30559415&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    20: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-91128716,30504264,-91069751,30558159&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    21: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-91080480,30504560,-91021514,30558455&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    22: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-91029668,30500936,-90970702,30554833&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    #23: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=13&rect=-90991731,30500936,-90932765,30554833&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=13'],
    24: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-90964394,30471460,-90846463,30579258&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    #25: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-90874872,30469168,-90756941,30576967&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    #26: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=11&rect=-90852985,30383982,-90617123,30599651&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=11'],
    27: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=11&rect=-90909290,30207009,-90673428,30423069&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=11'],
    28: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-90980015,30249873,-90862084,30357915&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    29: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91037350,30274634,-90919419,30382649&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    30: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91137514,30292497,-91019583,30400492&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    31: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91162062,30247279,-91044130,30355324&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    32: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91072454,30231114,-90954523,30339176&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    33: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91008940,30248613,-90891008,30356657&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    34: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-90920019,30251727,-90802088,30359767&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    35: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-90851870,30222363,-90733938,30330435&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    36: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-90900278,30138373,-90782347,30246537&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    37: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91006021,30137779,-90888090,30245944&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    38: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91099577,30191505,-90981646,30299612&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    39: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91154337,30238974,-91036406,30347028&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12'],
    40: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=12&rect=-91148672,30292497,-91030741,30400492&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=12']
}

zoom_dict = {
    0: ['https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110001&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=10&rect=-91298447,30159376,-90696259,30578223&p=1&sort=days&search=map&rid=25&rt=2&listright=true&isMapSearch=1&zoom=10']
}

# %%
prop_ls = []
for key, url in zoom_dict.items():
  
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
    data = requests.get(url[0], headers = headers).json()
    properties = data['map']['properties']

    for prop in properties:
        zid = prop[0]
        if zid not in prop_ls:
            prop_ls.append(zid)
    time.sleep(1)

    
len(prop_ls)
# Out:
# 420

# %%
len(prop_ls)
# Out:
# 1041

# %%
house_df = pd.DataFrame(columns = ['listing_type', 'zpid', 'address', 'asking_price', 'zestimate', 'bedroooms', 'bathrooms',
                'square_ft', 'description', 'days_listed', 'lot_size', 'price_sqft', 'prop_type', 'year_built',
                'cooling', 'heating', 'parking'])

for p, prop in enumerate(prop_ls[:2]):
    prop_url = 'https://www.zillow.com/homes/{}_zpid'.format(prop)
    
    try:
        house_text = requests.get(prop_url, headers = user_agent).text
        soup = bs(house_text, 'lxml')


        address = soup.find('h1', {'class': 'notranslate'}).text
        spans = soup.findAll('span', {'class': ''})
        prices = []
        for span in spans:
            if '$' in span.text:
                prices.append(span)
        #asking_price = int(prices[0].text.replace('$', '').replace(',',''))
        asking_price = int(re.sub('[^0-9]', '', prices[0].text))
        try:
            zestimate = int(prices[1].text.replace('$', '').replace(',',''))
        except:
            zestimate = np.nan

        estimates_div = soup.find('div', {'class': 'estimates'})
        divs = estimates_div.findAll('div')

        for div in divs:
            if 'For' in div.text:
                listing_type = div.text    

        h3 = soup.find('h3', {'class': ''})
        h3_spans = h3.findAll('span')
        for span in h3_spans:
            if 'bed' in span.text:
                bedrooms = int(span.text.replace('beds', ''))
            if 'bath' in span.text:
                bathrooms = int(span.text.replace('baths', ''))
            if 'sqft' in span.text:
                sqft = int(span.text.replace('sqft', '').replace(',',''))
        desc = soup.find('div', {'class': 'notranslate zsg-content-item'}).text
        glance_headings = soup.findAll('p', {'class': 'hdp-fact-ataglance-heading'})
        glance_values = soup.findAll('div', {'class': 'hdp-fact-ataglance-value'})
        glance_dict = {}
        for h, heading in enumerate(glance_headings):
            glance_dict[heading.text] = glance_values[h].text
        try:
            cooling = glance_dict['Cooling']
        except:
            cooling = 'null'
        try:
            days_listed = glance_dict['Days on Zillow']
        except:
            days_listed = np.nan
        try:
            heating = glance_dict['Heating']
        except:
            heating = 'null'
        try:
            lot_size = int(re.sub('[^0-9]', '', glance_dict['Lot']))
        except:
            lot_size = np.nan
        try:
            parking = glance_dict['Parking']
        except:
            parking = 'null'
        try:
            price_sqft = int(re.sub('[^0-9]', '', glance_dict['Price/sqft']))
        except:
            price_sqft = np.nan
        try:
            prop_type = glance_dict['Type']
        except:
            prop_type = 'null'
        try:
            year_built = int(glance_dict['Year Built'])
        except:
            year_built = np.nan

        house_df.loc[p] = [listing_type, prop, address, asking_price, zestimate, bedrooms, bathrooms, sqft, desc, days_listed, 
                          lot_size, price_sqft, prop_type, year_built, cooling, heating, parking]
    except:
        pass
    
    time.sleep(1)
house_df
# Out:
#       listing_type          zpid  \
# 0     For Rent      2.090581e+09
#
#                                              address  asking_price zestimate  \
# 0  Fennwood DrIncomplete address or missing price...        1600.0       NaN
#
#    bedroooms  bathrooms  square_ft  \
# 0        3.0        2.0     1830.0
#
#                                          description days_listed lot_size  \
# 0  3bedroom home in Zachary near Rouses Super mar...         NaN      NaN
#
#   price_sqft      prop_type year_built  cooling  heating          parking
# 0        NaN  Single Family        NaN  No Data  No Data  Attached Garage

# %%
glance_dict
# Out:
# {'Cooling': 'No Data',
#  'Heating': 'No Data',
#  'Laundry': 'In Unit',
#  'Parking': 'Attached Garage',
#  'Pets': 'Large dogs, small dogs',
#  'Type': 'Single Family'}

# %%
address = soup.find('h1', {'class': 'notranslate'}).text
spans = soup.findAll('span', {'class': ''})
prices = []
for span in spans:
    if '$' in span.text:
        prices.append(span)
asking_price = int(prices[0].text.replace('$', '').replace(',',''))
zestimate = int(prices[1].text.replace('$', '').replace(',',''))
h3 = soup.find('h3', {'class': ''})
h3_spans = h3.findAll('span')
for span in h3_spans:
    if 'bed' in span.text:
        bedrooms = int(span.text.replace('beds', ''))
    if 'bath' in span.text:
        bathrooms = int(span.text.replace('baths', ''))
    if 'sqft' in span.text:
        sqft = int(span.text.replace('sqft', '').replace(',',''))
desc = soup.find('div', {'class': 'notranslate zsg-content-item'}).text
glance_headings = soup.findAll('p', {'class': 'hdp-fact-ataglance-heading'})
glance_values = soup.findAll('div', {'class': 'hdp-fact-ataglance-value'})
glance_dict = {}
for h, heading in enumerate(glance_headings):
    glance_dict[heading.text] = glance_values[h].text

cooling = glance_dict['Cooling']
days_listed = glance_dict['Days on Zillow']
heating = glance_dict['Heating']
lot_size = int(re.sub('[^0-9]', '', glance_dict['Lot']))
parking = glance_dict['Parking']
price_sqft = int(re.sub('[^0-9]', '', glance_dict['Price/sqft']))
prop_type = glance_dict['Type']
year_built = int(glance_dict['Year Built'])
# Out:
# 1123

# %%
soup.findAll()
# Out:
# [<html class="wf-loading no-js zsg-theme-modernized zsg-lightbox_scroll" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/product#">
#  <head>
# ...

# %%
https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110011&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=9&rect=-91483155,29873992,-90539704,30738294&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=9
https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110011&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=10&rect=-91360245,30206861,-90888520,30638502&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=10
https://null:null@www.zillow.com/search/GetResults.htm?spt=homes&status=110011&lt=111101&ht=111111&pr=,&mp=,&bd=0%2C&ba=0%2C&sf=,&lot=0%2C&yr=,&singlestory=0&hoa=0%2C&pho=0&pets=0&parking=0&laundry=0&income-restricted=0&fr-bldg=0&furnished-apartments=0&cheap-apartments=0&studio-apartments=0&pnd=0&red=0&zso=0&days=any&ds=all&pmf=1&pf=1&sch=100111&zoom=11&rect=-91278534,30365469,-91042672,30581179&p=1&sort=days&search=maplist&listright=true&isMapSearch=1&zoom=11
# Out:
# '2099'
