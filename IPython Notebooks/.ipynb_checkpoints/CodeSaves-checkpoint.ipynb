# %%
# Suppose SB checks back AKQr flop in a single raised pot.  FD comes on the turn where BB is somewhat 
# polar.  Model with the PvBC decision tree and two possible river cards.
S = 15

turnEArray = EquityArray(pe.string2card(['Ah','Kd','Qs','2d','__']));
river1EArray = EquityArray(pe.string2card(['Ah','Kd','Qs','2d','6d']));
river2EArray = EquityArray(pe.string2card(['Ah','Kd','Qs','2d','6s']));

point0 = DecPt('BB', 2.0, 2.0, turnEArray,"")
point1 = DecPt('SB', 2.0, 2.0, turnEArray,"check")
point2 = DecPt('Nature', 2.0, 2.0, turnEArray,"check")
point3 = DecPt('BB', 2.0, 2.0, river1EArray,"AhKdQs2d6d")

point4 = DecPt('BB', 2.0, 2.0, river2EArray,"AhKdQs2d6s")
point5 = DecPt('SB', 2.0, 2.0, river1EArray,"check")
point6 = DecPt('BB', 2.0, 2.0, river2EArray,"check")

point7 = DecPt('Leaf', 2.0, 2.0, river1EArray,"check")
point8 = DecPt('SB', 2.0, 6.0, river1EArray,"bet")
point9 = DecPt('Leaf', 2.0, 6.0, river1EArray,"fold")

point10 = DecPt('Leaf', 6.0, 6.0, river1EArray,"call")
point11 = DecPt('Leaf', 2.0, 2.0, river2EArray,"check")
point12 = DecPt('SB', 2.0, 6.0, river2EArray,"bet")

point13 = DecPt('Leaf', 2.0, 6.0, river2EArray,"fold")
point14 = DecPt('Leaf', 6.0, 6.0, river2EArray,"call")
point15 = DecPt('SB', 2.0, 6.0, turnEArray,"bet")

point16 = DecPt('Leaf', 2.0, 6.0, turnEArray,"fold")
point17 = DecPt('Nature', 6.0, 6.0, turnEArray,"call")
point18 = DecPt('BB', 6.0, 6.0, river1EArray,"AhKdQs2d6d")

point19 = DecPt('SB', 6.0, 6.0, river1EArray,"check")
point20 = DecPt('Leaf', 6.0, 6.0, river1EArray,"check")
point21 = DecPt('SB', 6.0, 18.0, river1EArray,"bet")

point22 = DecPt('Leaf', 6.0, 18.0, river1EArray,"fold")
point23 = DecPt('Leaf', 18.0, 18.0, river1EArray,"call")
point24 = DecPt('BB', 6.0, 6.0, river2EArray,"AhKdQs2d6s")

point25 = DecPt('SB', 6.0, 6.0, river2EArray,"check")
point26 = DecPt('Leaf', 6.0, 6.0, river2EArray,"check")
point27 = DecPt('SB', 6.0, 18.0, river2EArray,"bet")
point28 = DecPt('Leaf', 6.0, 18.0, river2EArray,"fold")
point29 = DecPt('Leaf', 18.0, 18.0, river2EArray,"call")

T = Tree(S, point0)
T.addDecPt(point1, point0)
T.addDecPt(point2, point1)
T.addDecPt(point3, point2)
T.addDecPt(point4, point2)
T.addDecPt(point5, point3)
T.addDecPt(point6, point4)
T.addDecPt(point7, point5)
T.addDecPt(point8, point3)
T.addDecPt(point9, point8)
T.addDecPt(point10, point8)
T.addDecPt(point11, point6)
T.addDecPt(point12, point4)
T.addDecPt(point13, point12)
T.addDecPt(point14, point12)
T.addDecPt(point15, point0)
T.addDecPt(point16, point15)
T.addDecPt(point17, point15)
T.addDecPt(point18, point17)
T.addDecPt(point19, point18)
T.addDecPt(point20, point19)
T.addDecPt(point21, point18)
T.addDecPt(point22, point21)
T.addDecPt(point23, point21)
T.addDecPt(point24, point17)
T.addDecPt(point25, point24)
T.addDecPt(point26, point25)
T.addDecPt(point27, point24)
T.addDecPt(point28, point27)
T.addDecPt(point29, point27)

T

# %%
S = 15

turnEArray = EquityArray(pe.string2card(['Tc','7d','4h','2s','__']));
riverEArray = EquityArray(pe.string2card(['Tc','7d','4h','2s','Ks']));


point0 = DecPt('SB', 4.5, 4.5, turnEArray,"")
point1 = DecPt('BB', 4.5, 4.5, turnEArray,"check")
point2 = DecPt('Nature', 4.5, 4.5, turnEArray,"check")

point3 = DecPt('SB', 4.5, 4.5, riverEArray,"Tc7d4h2sKs")
point4 = DecPt('BB', 4.5, 4.5, riverEArray,"check")
point5 = DecPt('Leaf', 4.5, 4.5, riverEArray,"check")
point6 = DecPt('SB', 4.5, 6.5, riverEArray,"bet")

point7 = DecPt('Leaf', 4.5, 6.5, riverEArray,"fold")
point8 = DecPt('Leaf', 6.5, 6.5, riverEArray,"call")
point9 = DecPt('BB', 8.5, 6.5, riverEArray,"raise")

point10 = DecPt('Leaf', 8.5, 6.5, riverEArray,"fold")
point11 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")
point12 = DecPt('BB', 6.5, 4.5, riverEArray,"bet")

point13 = DecPt('Leaf', 6.5, 4.5, riverEArray,"fold")
point14 = DecPt('Leaf', 6.5, 6.5, riverEArray,"call")
point15 = DecPt('SB', 6.5, 8.5, riverEArray,"raise")

point16 = DecPt('Leaf', 6.5, 8.5, riverEArray,"fold")
point17 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")
point18 = DecPt('SB', 4.5, 6.5, turnEArray,"bet")

point19 = DecPt('Leaf', 4.5, 6.5, turnEArray,"fold")
point20 = DecPt('Nature', 6.5, 6.5, turnEArray,"call")
point21 = DecPt('BB', 8.5, 6.5, turnEArray,"raise")

point22 = DecPt('Leaf', 8.5, 6.5, turnEArray,"fold")
point23 = DecPt('Nature', 8.5, 8.5, turnEArray,"call")
point24 = DecPt('SB', 6.5, 6.5, riverEArray,"Tc7d4h2sKs")

point25 = DecPt('BB', 6.5, 6.5, riverEArray,"check")
point26 = DecPt('Leaf', 6.5, 6.5, riverEArray,"check")
point27 = DecPt('SB', 6.5, 8.5, riverEArray,"bet")
point28 = DecPt('Leaf', 6.5, 8.5, riverEArray,"fold")
point29 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")

point30 = DecPt('BB', 10.5, 8.5, riverEArray,"raise")
point31 = DecPt('Leaf', 10.5, 8.5, riverEArray,"fold")
point32 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")

point33 = DecPt('BB', 8.5, 6.5, riverEArray,"bet")
point34 = DecPt('Leaf', 8.5, 6.5, riverEArray,"fold")
point35 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")
point36 = DecPt('SB', 8.5, 10.5, riverEArray,"raise")

point37 = DecPt('Leaf', 8.5, 10.5, riverEArray,"fold")
point38 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")
point39 = DecPt('SB', 8.5, 8.5, riverEArray,"Tc7d4h2sKs")

point40 = DecPt('BB', 8.5, 8.5, riverEArray,"check")
point41 = DecPt('Leaf', 8.5, 8.5, riverEArray,"check")
point42 = DecPt('SB', 8.5, 10.5, riverEArray,"bet")

point43 = DecPt('Leaf', 8.5, 10.5, riverEArray,"fold")
point44 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")
point45 = DecPt('BB', 12.5, 10.5, riverEArray,"raise")

point46 = DecPt('Leaf', 12.5, 10.5, riverEArray,"fold")
point47 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")
point48 = DecPt('BB', 10.5, 8.5, riverEArray,"bet")

point49 = DecPt('Leaf', 10.5, 8.5, riverEArray,"fold")
point50 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")
point51 = DecPt('SB', 10.5, 12.5, riverEArray,"raise")

point52 = DecPt('Leaf', 10.5, 12.5, riverEArray,"fold")
point53 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")
point54 = DecPt('BB', 6.5, 4.5, turnEArray,"bet")

point55 = DecPt('Leaf', 6.5, 4.5, turnEArray,"fold")
point56 = DecPt('Nature', 6.5, 6.5, turnEArray,"call")
point57 = DecPt('SB', 6.5, 8.5, turnEArray,"raise")
point58 = DecPt('SB', 6.5, 6.5, riverEArray,"Tc7d4h2sKs")
point59 = DecPt('BB', 6.5, 6.5, riverEArray,"check")

point60 = DecPt('Leaf', 6.5, 6.5, riverEArray,"check")
point61 = DecPt('SB', 6.5, 8.5, riverEArray,"bet")
point62 = DecPt('Leaf', 6.5, 8.5, riverEArray,"fold")

point63 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")
point64 = DecPt('BB', 10.5, 8.5, riverEArray,"raise")
point65 = DecPt('Leaf', 10.5, 8.5, riverEArray,"fold")
point66 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")

point67 = DecPt('BB', 8.5, 6.5, riverEArray,"bet")
point68 = DecPt('Leaf', 8.5, 6.5, riverEArray,"fold")
point69 = DecPt('Leaf', 8.5, 8.5, riverEArray,"call")

point70 = DecPt('SB', 8.5, 10.5, riverEArray,"raise")
point71 = DecPt('Leaf', 8.5, 10.5, riverEArray,"fold")
point72 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")

point73 = DecPt('Leaf', 6.5, 8.5, turnEArray,"fold")
point74 = DecPt('Nature', 8.5, 8.5, turnEArray,"call")
point75 = DecPt('BB', 10.5, 8.5, turnEArray,"raise")

point76 = DecPt('Leaf', 10.5, 8.5, turnEArray,"fold")
point77 = DecPt('Nature', 10.5, 10.5, turnEArray,"call")
point78 = DecPt('SB', 10.5, 10.5, riverEArray,"Tc7d4h2sKs")

point79 = DecPt('BB', 12.5, 10.5, riverEArray,"bet")
point80 = DecPt('Leaf', 12.5, 10.5, riverEArray,"fold")
point81 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")

point82 = DecPt('SB', 12.5, 14.5, riverEArray,"raise")
point83 = DecPt('Leaf', 12.5, 14.5, riverEArray,"fold")
point84 = DecPt('Leaf', 14.5, 14.5, riverEArray,"call")

point85 = DecPt('SB', 8.5, 8.5, riverEArray,"Tc7d4h2sKs")
point86 = DecPt('BB', 8.5, 8.5, riverEArray,"check")
point87 = DecPt('BB', 10.5, 8.5, riverEArray,"bet")
point88 = DecPt('Leaf', 8.5, 8.5, riverEArray,"check")
point89 = DecPt('SB', 8.5, 10.5, riverEArray,"bet")

point90 = DecPt('Leaf', 8.5, 10.5, riverEArray,"fold")
point91 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")
point92 = DecPt('BB', 12.5, 10.5, riverEArray,"raise")

point93 = DecPt('Leaf', 12.5, 10.5, riverEArray,"fold")
point94 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")
point95 = DecPt('Leaf', 10.5, 8.5, riverEArray,"fold")
point96 = DecPt('Leaf', 10.5, 10.5, riverEArray,"call")

point97 = DecPt('SB', 10.5, 12.5, riverEArray,"raise")
point98 = DecPt('Leaf', 10.5, 12.5, riverEArray,"fold")
point99 = DecPt('Leaf', 12.5, 12.5, riverEArray,"call")


TurnRiverSln = Tree(S, point0)
TurnRiverSln.addDecPt(point1, point0)
TurnRiverSln.addDecPt(point2, point1)
TurnRiverSln.addDecPt(point3, point2)
TurnRiverSln.addDecPt(point4, point3)
TurnRiverSln.addDecPt(point5, point4)
TurnRiverSln.addDecPt(point6, point4)
TurnRiverSln.addDecPt(point7, point6)
TurnRiverSln.addDecPt(point8, point6)
TurnRiverSln.addDecPt(point9, point6)
TurnRiverSln.addDecPt(point10, point9)
TurnRiverSln.addDecPt(point11, point9)
TurnRiverSln.addDecPt(point12, point3)
TurnRiverSln.addDecPt(point13, point12)
TurnRiverSln.addDecPt(point14, point12)
TurnRiverSln.addDecPt(point15, point12)
TurnRiverSln.addDecPt(point16, point15)
TurnRiverSln.addDecPt(point17, point15)
TurnRiverSln.addDecPt(point18, point1)
TurnRiverSln.addDecPt(point19, point18)
TurnRiverSln.addDecPt(point20, point18)
TurnRiverSln.addDecPt(point21, point18)
TurnRiverSln.addDecPt(point22, point21)
TurnRiverSln.addDecPt(point23, point21)
TurnRiverSln.addDecPt(point24, point20)
TurnRiverSln.addDecPt(point25, point24)
TurnRiverSln.addDecPt(point26, point25)
TurnRiverSln.addDecPt(point27, point25)
TurnRiverSln.addDecPt(point28, point27)
TurnRiverSln.addDecPt(point29, point27)
TurnRiverSln.addDecPt(point30, point27)
TurnRiverSln.addDecPt(point31, point30)
TurnRiverSln.addDecPt(point32, point30)
TurnRiverSln.addDecPt(point33, point24)
TurnRiverSln.addDecPt(point34, point33)
TurnRiverSln.addDecPt(point35, point33)
TurnRiverSln.addDecPt(point36, point33)
TurnRiverSln.addDecPt(point37, point36)
TurnRiverSln.addDecPt(point38, point36)
TurnRiverSln.addDecPt(point39, point23)
TurnRiverSln.addDecPt(point40, point39)
TurnRiverSln.addDecPt(point41, point40)
TurnRiverSln.addDecPt(point42, point40)
TurnRiverSln.addDecPt(point43, point42)
TurnRiverSln.addDecPt(point44, point42)
TurnRiverSln.addDecPt(point45, point42)
TurnRiverSln.addDecPt(point46, point45)
TurnRiverSln.addDecPt(point47, point45)
TurnRiverSln.addDecPt(point48, point39)
TurnRiverSln.addDecPt(point49, point48)
TurnRiverSln.addDecPt(point50, point48)
TurnRiverSln.addDecPt(point51, point48)
TurnRiverSln.addDecPt(point52, point51)
TurnRiverSln.addDecPt(point53, point51)
TurnRiverSln.addDecPt(point54, point0)
TurnRiverSln.addDecPt(point55, point54)
TurnRiverSln.addDecPt(point56, point54)
TurnRiverSln.addDecPt(point57, point54)
TurnRiverSln.addDecPt(point58, point56)
TurnRiverSln.addDecPt(point59, point58)
TurnRiverSln.addDecPt(point60, point59)
TurnRiverSln.addDecPt(point61, point59)
TurnRiverSln.addDecPt(point62, point61)
TurnRiverSln.addDecPt(point63, point61)
TurnRiverSln.addDecPt(point64, point61)
TurnRiverSln.addDecPt(point65, point64)
TurnRiverSln.addDecPt(point66, point64)
TurnRiverSln.addDecPt(point67, point58)
TurnRiverSln.addDecPt(point68, point67)
TurnRiverSln.addDecPt(point69, point67)
TurnRiverSln.addDecPt(point70, point67)
TurnRiverSln.addDecPt(point71, point70)
TurnRiverSln.addDecPt(point72, point70)
TurnRiverSln.addDecPt(point73, point59)
TurnRiverSln.addDecPt(point74, point59)
TurnRiverSln.addDecPt(point75, point59)
TurnRiverSln.addDecPt(point76, point75)
TurnRiverSln.addDecPt(point77, point75)
TurnRiverSln.addDecPt(point78, point77)
TurnRiverSln.addDecPt(point79, point78)
TurnRiverSln.addDecPt(point80, point79)
TurnRiverSln.addDecPt(point81, point79)
TurnRiverSln.addDecPt(point82, point79)
TurnRiverSln.addDecPt(point83, point82)
TurnRiverSln.addDecPt(point84, point82)
TurnRiverSln.addDecPt(point85, point74)
TurnRiverSln.addDecPt(point86, point85)
TurnRiverSln.addDecPt(point87, point85)
TurnRiverSln.addDecPt(point88, point86)
TurnRiverSln.addDecPt(point89, point86)
TurnRiverSln.addDecPt(point90, point89)
TurnRiverSln.addDecPt(point91, point89)
TurnRiverSln.addDecPt(point92, point89)
TurnRiverSln.addDecPt(point93, point92)
TurnRiverSln.addDecPt(point94, point92)
TurnRiverSln.addDecPt(point95, point87)
TurnRiverSln.addDecPt(point96, point87)
TurnRiverSln.addDecPt(point97, point87)
TurnRiverSln.addDecPt(point98, point97)
TurnRiverSln.addDecPt(point99, point97)


TurnRiverSln

# %%
bbLimitStartingRange = Range(0.0)
bbLimitStartingRange.setRangeString("A2,A3,A4,Q9,Q8,Q7,Q5,Q4,Q3,Q2,K6,J6,T6,96,86,76,56,46,K9,K8,K7,K5,K4,K3,K2,J8,J7, \
                                J6,J5,J4,J3,J2,T9,T8,55,44,33,22", 1.0)

sbLimitStartingRange = Range()
sbLimitStartingRange.setToTop(.92, pe.string2card(['__','__','__','__','__']))

sbLimitStartingRange.removeHandsWithConflicts(pe.string2card(['Qs', '6d','Ad', '9c']))
bbLimitStartingRange.removeHandsWithConflicts(pe.string2card(['Qs', '6d','Ad', '9c']))

display(bbLimitStartingRange)
display(sbLimitStartingRange)
