# %%
from selenium import webdriver
import os
import time
from datetime import datetime
from datetime import timedelta
import json
import sys
os.chdir('/home/valesco/Datasets/PGA_Data/pga_odds')

# %%
while True:
    
    try:
        url_bovada = 'https://sports.bovada.lv/golf/pga-tour'

        bov_browser = webdriver.Chrome()
        bov_browser.get(url_bovada)
        
        time.sleep(3)
        tourny_button = bov_browser.find_element_by_class_name('ng-binding')
        tourny_name = tourny_button.text

        try:
            view_all = bov_browser.find_element_by_xpath("//*[@id='spaNavigationComponents_content_center']/div/section/div/div/footer/a")
            view_all.click()
        except:
            pass

        for i in range(30):
            bov_browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(.5)

        body = bov_browser.find_elements_by_class_name('ng-isolate-scope')
        body_text = []
        for b in body:
            body_text.append(b.text)

        time_now = datetime.now()
        time_now = time_now.strftime('%Y_%m_%d_%H_%M')

        file_name = 'Bovada_' + tourny_name + '_' + time_now + '.txt'

        with open(file_name, mode = 'wt', encoding = 'utf-8') as myfile:
            for b in body:
                myfile.write(b.text)
            myfile.close

        bov_browser.close()


        url = 'http://www.pinnacle.com/'

        browser = webdriver.Chrome()
        browser.get(url)

        sidebar_ls = []
        for i in range(1,4):
            string = ('//*[@id="sidebar"]/div/ul/li['+ str(i) +']/ul/li')
            side_bar = browser.find_elements_by_xpath(string)
            for side in side_bar:
                if 'Golf' in side.text:
                    side.click()
                    sidebar_ls.append(side)
        try:
            for i in range(1,4):
                string = ('//*[@id="sidebar"]/div/ul/li['+ str(i) +']/ul/li')
                side_bar = browser.find_element_by_xpath('//*[@title="PGA Tour"]')
                side_bar.click()
        except:
            pass

        golf = browser.find_elements_by_css_selector('a[href*="golf"]')

        golf_url = []
        for g in golf:
            golf_url.append(g.get_attribute('href'))


        odds_text = {}
        for g in golf_url:
            try:
                if '/pga' in g:
                    pga_browser = webdriver.Chrome()
                    pga_browser.get(g)

                    header = pga_browser.find_element_by_class_name('toolbar')
                    key = header.text

                    odds_data = pga_browser.find_element_by_class_name('odds-data')
                    pinny = odds_data.text

                    odds_string = pinny.split('\\n')

                    temp_ls = []
                    for odds in odds_string:
                        temp_ls.append(odds)

                    odds_text[key] = temp_ls

                    pga_browser.close()
            except:
                pga_browser.close()
                pass

        time_now = datetime.now()
        time_now = time_now.strftime('%Y_%m_%d_%H_%M')

        json_name = 'Pinny_' + time_now + '.json'

        with open(json_name, 'w') as outfile:
            json.dump(odds_text, outfile)

        browser.close()   
        print('scrape success!!!')
        time.sleep(36000)
    except Exception as e:
        print('scrape failed', e)
        browser.close()
        time.sleep(1000)
# Out:
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape success!!!
# scrape failed Message: timeout
#   (Session info: chrome=64.0.3282.140)
#   (Driver info: chromedriver=2.35.528139 (47ead77cb35ad2a9a83248b292151462a66cd881),platform=Linux 4.13.0-37-generic x86_64)
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-2-bd2542d53be0> in <module>()
#      10         time.sleep(3)
# ---> 11         tourny_button = bov_browser.find_element_by_class_name('ng-binding')
#      12         tourny_name = tourny_button.text
#
# /home/valesco/anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     414         """
# --> 415         return self.find_element(by=By.CLASS_NAME, value=name)
#     416
#
# /home/valesco/anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     755             'using': by,
# --> 756             'value': value})['value']
#     757
#
# /home/valesco/anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     237         if response:
# --> 238             self.error_handler.check_response(response)
#     239             response['value'] = self._unwrap_value(
#
# /home/valesco/anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     192             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 193         raise exception_class(message, screen, stacktrace)
#     194
#
# TimeoutException: Message: timeout
#   (Session info: chrome=64.0.3282.140)
#   (Driver info: chromedriver=2.35.528139 (47ead77cb35ad2a9a83248b292151462a66cd881),platform=Linux 4.13.0-37-generic x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-2-bd2542d53be0> in <module>()
#     107     except Exception as e:
#     108         print('scrape failed', e)
# --> 109         browser.close()
#     110         time.sleep(1000)
#     111
#
# /home/valesco/anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in close(self)
#     510             driver.close()
#     511         """
# --> 512         self.execute(Command.CLOSE)
#     513
#     514     def quit(self):
#
# /home/valesco/anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     236         response = self.command_executor.execute(driver_command, params)
#     237         if response:
# --> 238             self.error_handler.check_response(response)
#     239             response['value'] = self._unwrap_value(
#     240                 response.get('value', None))
#
# /home/valesco/anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     191         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     192             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 193         raise exception_class(message, screen, stacktrace)
#     194
#     195     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: no such session
#   (Driver info: chromedriver=2.35.528139 (47ead77cb35ad2a9a83248b292151462a66cd881),platform=Linux 4.13.0-37-generic x86_64)

# %%
url_bovada = 'https://sports.bovada.lv/golf/pga-tour'

bov_browser = webdriver.Chrome()
bov_browser.get(url_bovada)
