# %%
import pandas as pd
import numpy as np

# %%
payout_dict = {
    1: 1000000,
    2: 150000,
    3: 75000,
    4: 40000,
    5: 25000,
    6: 15000,
    7: 10000,
    8: 7500,
    9: 5000,
    11: 3000,
    16: 2000,
    26: 1500,
    41: 1000,
    66: 700,
    101: 500,
    151: 300,
    251: 200,
    501: 150,
    1001: 100,
    2251: 80,
    5251: 65,
    12001: 50,
    26456: 0,
    110200: 0
}

key_ls = sorted(list(payout_dict.keys()))

# %%
payout_array = []
buyin = 33
for i in range(len(key_ls) - 1):
    start = key_ls[i]
    end = key_ls[i + 1]
    
    for r in range(end - start):
        payout_array.append(payout_dict[key_ls[i]] - buyin)
# Out:
# [999967,
#  149967,
#  74967,
#  39967,
#  24967,
#  14967,
#  9967,
#  7467,
#  4967,
#  4967,
#  2967,
#  2967,
#  2967,
#  2967,
#  2967,
#  1967,
#  1967,
#  1967,
#  1967,
#  1967,
#  1967,
#  1967,
#  1967,
#  1967,
#  1967,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  1467,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  967,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  667,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
#  467,
# ...

# %%
payout_array[-30:]
# Out:
# [-33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33,
#  -33]
