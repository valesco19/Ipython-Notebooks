# %%
from pulp import *
import csv
import numpy as np
import pandas as pd
import os
import time
import collections
from tqdm import tqdm
os.chdir('/home/valesco/Datasets/')
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
nfl_df = pd.read_csv('2015_NFL_DK')

# %%
nfl_df.head()
# Out:
#   home_away opponent player_first player_last       full_name  total_points  \
# 0      home      nor      Palmer,      Carson   Palmer,Carson         28.68
# 1      home      pit       Brady,         Tom       Brady,Tom         27.62
# 2      home      nyg        Romo,        Tony       Romo,Tony         27.14
# 3      away      tam     Mariota,      Marcus  Mariota,Marcus         24.96
# 4      home      det      Rivers,      Philip   Rivers,Philip         24.96
#
#   position  salary team   week
# 0       QB    6500  ari  week1
# 1       QB    7700  nwe  week1
# 2       QB    7300  dal  week1
# 3       QB    6000  ten  week1
# 4       QB    7100  sdg  week1

# %%
in_file = "2015_NFL_DK"
reader = csv.DictReader(open(in_file, 'r'))
player_dict_pre = []
for i , row in enumerate(reader):
    team = {k: v for k, v in row.items()}
    team['id'] = i
    player_dict_pre.append(team)
    
players = [player['id'] for player in player_dict_pre]
teams = [0]

# %%
num_teams = 10000
row_count = 0
opt_df = []
opt_df = pd.DataFrame(columns = ['qb_name', 'qb_pos', 'qb_points', 'qb_salary',
                                 'wr1_name', 'wr1_pos', 'wr1_points', 'wr1_salary',
                                 'wr2_name', 'wr2_pos', 'wr2_points', 'wr2_salary',
                                 'wr3_name', 'wr3_pos', 'wr3_points', 'wr3_salary',
                                 'rb1_name', 'rb1_pos', 'rb1_points', 'rb1_salary',
                                 'rb2_name', 'rb2_pos', 'rb2_points', 'rb2_salary',
                                 'te_name', 'te_pos', 'te_points', 'te_salary',
                                 'flex_name', 'flex_pos', 'flex_points', 'flex_salary',
                                 'def_name', 'def_pos', 'def_points', 'def_salary',
                                 'team_points', 'total_salary', 'season_year', 'week'
                                ])

time_ls = ['week1', 'week2', 'week3', 'week4', 'week5', 'week6', 'week7', 'week8', 'week9',
           'week10', 'week11', 'week12', 'week13', 'week14', 'week15', 'week16', 'week17']

#player_dict = []
#for player in player_dict_pre:
#    if player['season_year'] == '2015' and player['week'] == '17':
#        player_dict.append(player)

master_ls = {}
        
for time in time_ls:
    for i, t1 in enumerate(range(num_teams)):
        team_dict = {}
        
        player_dict = []
        for player in player_dict_pre:
            if player['week'] == time:
                player_dict.append(player)
        
        
        if i == 0:
            # Set objective
            players = [player['id'] for player in player_dict]            
            
            opt = LpProblem('Optimizer', LpMaximize)
            possible_assignments = LpVariable.dicts("possible", (teams, players), 0, 1, LpBinary)

            #objective
            opt += sum([float(player['total_points']) * possible_assignments[team][player['id']] for player in player_dict for team in teams])

            #set constraints
            for team in teams:
                opt += lpSum([possible_assignments[team][player['id']] for player in player_dict]) == 9, '6 players per team '+str(team)
                opt += lpSum([float(player['salary']) * possible_assignments[team][player['id']] for player in player_dict]) <= 50000
                opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'QB']) == 1, 'one QB per team '
                opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'WR']) >= 3, 'two or more WR per team '
                opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'RB']) >= 2, 'two or more RB per team '
                opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'TE']) >= 1, 'two or more TE per team '
                opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'DEF']) == 1, 'two or more DEF per team '
                #opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['time_line'] == time]) == 9, 'same week'
                
            opt.writeLP('fantasy_optimization.lp')
            opt.solve()
            status = LpStatus[opt.status]
            selected = []
            

            for player in player_dict:
                if possible_assignments[0][player['id']].value() == 1.0:
                    players = {}
                    #print(player['player'] + ' salary: ' + player['salary'] + ' proj: ' + player['odds'])
                    #opt_odds.append(float(player['odds']))
                    name = player['full_name']
                    players['full_name'] = player['full_name']
                    players['position'] = player['position']
                    players['total_points'] = player['total_points']
                    players['year'] = '2015'
                    players['week'] = player['week']
                    players['salary'] = player['salary']
                    #players['time_line'] = player['time_line']
                    selected.append(player['id'])
                    team_dict[player['id']] = players
                    
            master_ls[i] = team_dict

        else:
            # Set objective
            players = [player['id'] for player in player_dict]
            
            opt = LpProblem('Optimizer', LpMaximize)
            possible_assignments = LpVariable.dicts("possible", (teams, players), 0, 1, LpBinary)

            #objective
            opt += sum([float(player['total_points']) * possible_assignments[team][player['id']] for player in player_dict for team in teams])
            
            c = 0
            for s in range(int(len(selected)/6)):
                opt += lpSum(possible_assignments[0][selected[c]] + possible_assignments[0][selected[c+1]] +
                              possible_assignments[0][selected[c+2]] + possible_assignments[0][selected[c+3]] +
                              possible_assignments[0][selected[c+4]] + possible_assignments[0][selected[c+5]]) <= 5, 'selected' + str(s)
                c += 6

            #set constraints
            
            opt += lpSum([possible_assignments[team][player['id']] for player in player_dict]) == 9, '6 players per team '+str(team)
            opt += lpSum([float(player['salary']) * possible_assignments[team][player['id']] for player in player_dict]) <= 50000
            opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'QB']) == 1, 'one QB per team '
            opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'WR']) >= 3, 'two or more WR per team '
            opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'RB']) >= 2, 'two or more RB per team '
            opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'TE']) >= 1, 'two or more TE per team '
            opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['position'] == 'DEF']) == 1, 'two or more DEF per team '
            #opt += lpSum([possible_assignments[team][player['id']] for player in player_dict if player['time_line'] == time]) == 9, 'same week'
                
            opt.writeLP('fantasy_optimization.lp')
            opt.solve()
            status = LpStatus[opt.status]
            

            for player in player_dict:
                if possible_assignments[0][player['id']].value() == 1.0:
                    players = {}
                    #print(player['player'] + ' salary: ' + player['salary'] + ' proj: ' + player['odds'])
                    #opt_odds.append(float(player['odds']))
                    name = player['full_name']
                    players['full_name'] = player['full_name']
                    players['position'] = player['position']
                    players['total_points'] = player['total_points']
                    players['season_year'] = '2015'
                    players['week'] = player['week']
                    players['salary'] = player['salary']
                    #players['time_line'] = player['time_line']
                    selected.append(player['id'])
                    team_dict[player['id']] = players
            
            master_ls[i] = team_dict
            
    for k, v in master_ls.items():
        points = 0
        salary = 0
        wr_count = 0
        rb_count = 0
        te_count = 0
        for k1, v1 in master_ls[k].items(): 
            points += float(v1['total_points'])
            salary += float(v1['salary'])
            if v1['position'] == 'QB':
                qb_name = v1['full_name']
                qb_pos = 'QB'
                qb_points = v1['total_points']
                qb_salary = v1['salary']
                #year = v1['season_year']
                year = '2015'
                week = v1['week']
                #timeline = v1['time_line']
            elif v1['position'] == 'WR':
                if wr_count == 0:
                    wr1_name = v1['full_name']
                    wr1_pos = 'WR1'
                    wr1_points = v1['total_points']
                    wr1_salary = v1['salary']
                elif wr_count == 1:
                    wr2_name = v1['full_name']
                    wr2_pos = 'WR2'
                    wr2_points = v1['total_points']
                    wr2_salary = v1['salary']
                elif wr_count == 2:
                    wr3_name = v1['full_name']
                    wr3_pos = 'WR3'
                    wr3_points = v1['total_points']
                    wr3_salary = v1['salary']
                else:
                    flex_name = v1['full_name']
                    flex_pos = 'flex_WR'
                    flex_points = v1['total_points']
                    flex_salary = v1['salary']
                wr_count += 1
            elif v1['position'] == 'RB':
                if rb_count == 0:
                    rb1_name = v1['full_name']
                    rb1_pos = 'RB1'
                    rb1_points = v1['total_points']
                    rb1_salary = v1['salary']
                elif rb_count == 1:
                    rb2_name = v1['full_name']
                    rb2_pos = 'RB2'
                    rb2_points = v1['total_points']
                    rb2_salary = v1['salary']
                else:
                    flex_name = v1['full_name']
                    flex_pos = 'flex_RB'
                    flex_points = v1['total_points']
                    flex_salary = v1['salary']
                rb_count += 1
            elif v1['position'] == 'TE':
                if te_count == 0:
                    te_name = v1['full_name']
                    te_pos = 'TE'
                    te_points = v1['total_points']
                    te_salary = v1['salary']
                else:
                    flex_name = v1['full_name']
                    flex_pos = 'flex_TE'
                    flex_points = v1['total_points']
                    flex_salary = v1['salary']
                te_count += 1
            elif v1['position'] == 'DEF':
                def_name = v1['full_name']
                def_pos = 'DEF'
                def_points = v1['total_points']
                def_salary = v1['salary']
            else:
                print('ERROR!!!')


        opt_df.loc[row_count] = [qb_name, qb_pos, qb_points, qb_salary, wr1_name, wr1_pos, wr1_points, wr1_salary,
                                 wr2_name, wr2_pos, wr2_points, wr2_salary, wr3_name, wr3_pos, wr3_points, wr3_salary,
                                 rb1_name, rb1_pos, rb1_points, rb1_salary, rb2_name, rb2_pos, rb2_points, rb2_salary,
                                te_name, te_pos, te_points, te_salary, flex_name, flex_pos, flex_points, flex_salary,
                                 def_name, def_pos, def_points, def_salary, points, salary, year, week]
        
        row_count += 1

# %%
opt_df
# Out:
#                 qb_name qb_pos qb_points qb_salary              wr1_name  \
# 0         Palmer,Carson     QB     28.68      6500       Hopkins,DeAndre
# 1         Palmer,Carson     QB     28.68      6500       Hopkins,DeAndre
# 2         Palmer,Carson     QB     28.68      6500       Hopkins,DeAndre
# 3         Palmer,Carson     QB     28.68      6500       Hopkins,DeAndre
# 4         Palmer,Carson     QB     28.68      6500       Hopkins,DeAndre
# 5         Palmer,Carson     QB     28.68      6500         Johnson,Steve
# 6         Palmer,Carson     QB     28.68      6500       Hopkins,DeAndre
# 7         Palmer,Carson     QB     28.68      6500       Hopkins,DeAndre
# 8         Palmer,Carson     QB     28.68      6500       Hopkins,DeAndre
# 9         Palmer,Carson     QB     28.68      6500       Hopkins,DeAndre
# 10   Roethlisberger,Ben     QB     33.66      7200      Fitzgerald,Larry
# 11            Brady,Tom     QB     32.24      7500         Brown,Antonio
# 12            Brady,Tom     QB     32.24      7500         Brown,Antonio
# 13   Roethlisberger,Ben     QB     33.66      7200      Fitzgerald,Larry
# 14     Kaepernick,Colin     QB      30.5      6600      Fitzgerald,Larry
# 15           Carr,Derek     QB     30.34      5500       Benjamin,Travis
# 16           Carr,Derek     QB     30.34      5500       Benjamin,Travis
# 17   Roethlisberger,Ben     QB     33.66      7200      Fitzgerald,Larry
# 18   Roethlisberger,Ben     QB     33.66      7200      Fitzgerald,Larry
# 19     Kaepernick,Colin     QB      30.5      6600      Fitzgerald,Larry
# 20          Dalton,Andy     QB     35.32      5700            Green,A.J.
# 21          Dalton,Andy     QB     35.32      5700            Green,A.J.
# 22          Dalton,Andy     QB     35.32      5700      Matthews,Rishard
# 165     WR1       39.7       9300      Watkins,Sammy     WR2       27.6
# 166     WR1       39.7       9300  Williams,Terrance     WR2       28.3
# 167     WR1       39.7       9300   Marshall,Brandon     WR2       29.6
# 168     WR1       39.7       9300  Williams,Terrance     WR2       28.3
# 169     WR1       39.7       9300   Marshall,Brandon     WR2       29.6
#
#     wr2_salary           wr3_name wr3_pos wr3_points wr3_salary  \
# 0         9300       Allen,Keenan     WR3       34.6       7100
# 1         9300       Allen,Keenan     WR3       34.6       7100
# 2         9300       Allen,Keenan     WR3       34.6       7100
# 3         9300       Allen,Keenan     WR3       34.6       7100
# 4         9300       Allen,Keenan     WR3       34.6       7100
# 5         9300       Allen,Keenan     WR3       34.6       7100
# 6         9300       Allen,Keenan     WR3       34.6       7100
# 7         9300       Allen,Keenan     WR3       34.6       7100
# 8         9300       Allen,Keenan     WR3       34.6       7100
# 9         9300       Allen,Keenan     WR3       34.6       7100
# 10        8800     Robinson,Allen     WR3       36.5       4900
# 11        5400     Robinson,Allen     WR3       36.5       4900
# 12        5400     Robinson,Allen     WR3       36.5       4900
# 13        8800    Benjamin,Travis     WR3       35.5       3400
# 14        8800    Benjamin,Travis     WR3       35.5       3400
# 15        5400      Brown,Antonio     WR3       39.5       8800
# 16        5400      Brown,Antonio     WR3       39.5       8800
# 17        8800    Benjamin,Travis     WR3       35.5       3400
# 18        4900    Benjamin,Travis     WR3       35.5       3400
# 19        8800    Benjamin,Travis     WR3       35.5       3400
# 20        6300   Fitzgerald,Larry     WR3       37.4       5800
# 21        6300       Allen,Keenan     WR3       40.3       6800
# 22        7200        Smith,Steve     WR3       46.6       6300
# 23        6300   Matthews,Rishard     WR3       32.3       3800
# 24        6300        Jones,Julio     WR3       43.4       9000
# 25        6300       Allen,Keenan     WR3       40.3       6800
# 26        6300        Jones,Julio     WR3       43.4       9000
# 27        7200        Smith,Steve     WR3       46.6       6300
# 28        7200        Smith,Steve     WR3       46.6       6300
# 29        6300       Allen,Keenan     WR3       40.3       6800
# 30        3900       Austin,Tavon     WR3       29.6       3700
# 31        3900      Maclin,Jeremy     WR3       28.8       5800
# 32        3900      Maclin,Jeremy     WR3       28.8       5800
# 33        3900      Maclin,Jeremy     WR3       28.8       5800
# 34        3900       Austin,Tavon     WR3       29.6       3700
# 35        3900       Austin,Tavon     WR3       29.6       3700
# 36        3900       Austin,Tavon     WR3       29.6       3700
# 37        3900       Austin,Tavon     WR3       29.6       3700
# 38        3900      Maclin,Jeremy     WR3       28.8       5800
# 39        3900    Hopkins,DeAndre     WR3       27.7       7300
# 40        9000      Boldin,Anquan     WR3       27.7       4400
# 41        9000     Robinson,Allen     WR3       26.2       5500
# 42        9000      Johnson,Andre     WR3       25.7       4100
# 43        7200     Robinson,Allen     WR3       26.2       5500
# 44        9000     Robinson,Allen     WR3       26.2       5500
# 45        9000      Johnson,Andre     WR3       25.7       4100
# 46        4500    Hopkins,DeAndre     WR3       30.9       7200
# 47        7200       BeckhamOdell     WR3       28.4       9000
# 48        5500    Hopkins,DeAndre     WR3       30.9       7200
# 168       21.7       5500          Ertz,Zach     TE      27.2      3600
# 169       23.7       4200          Ertz,Zach     TE      27.2      3600
#
#                    flex_name flex_pos flex_points flex_salary      def_name  \
# 0    Seferian-Jenkins,Austin  flex_TE          31        3400      Carolina
# 1    Seferian-Jenkins,Austin  flex_TE          31        3400      Carolina
# 2    Seferian-Jenkins,Austin  flex_TE          31        3400       Seattle
# 3    Seferian-Jenkins,Austin  flex_TE          31        3400      NewYorkJ
# 4               Kelce,Travis  flex_TE        31.6        4800      Carolina
# 5    Seferian-Jenkins,Austin  flex_TE          31        3400      Carolina
# 6    Seferian-Jenkins,Austin  flex_TE          31        3400       Seattle
# 7    Seferian-Jenkins,Austin  flex_TE          31        3400     Baltimore
# 8    Seferian-Jenkins,Austin  flex_TE          31        3400        Denver
# 9    Seferian-Jenkins,Austin  flex_TE          31        3400       Seattle
# 10           Benjamin,Travis  flex_WR        35.5        3400        Denver
# 11           Benjamin,Travis  flex_WR        35.5        3400        Denver
# 12           Benjamin,Travis  flex_WR        35.5        3400     Cleveland
# 13            Edelman,Julian  flex_WR        33.9        6700        Denver
# 14            Robinson,Allen  flex_WR        36.5        4900     Cleveland
# 15            Robinson,Allen  flex_WR        36.5        4900     Cleveland
# 16            Robinson,Allen  flex_WR        36.5        4900        Denver
# 17            Edelman,Julian  flex_WR        33.9        6700     Cleveland
# 18            Edelman,Julian  flex_WR        33.9        6700        Denver
# 19            Edelman,Julian  flex_WR        33.9        6700        Denver
# 20              Allen,Keenan  flex_WR        40.3        6800       Arizona
# 21          Fitzgerald,Larry  flex_WR        37.4        5800       Arizona
# 22               Jones,Julio  flex_WR        43.4        9000       Arizona
# 23              Allen,Keenan  flex_WR        40.3        6800       Arizona
# 24          Matthews,Rishard  flex_WR        32.3        3800       Arizona
# 25             Johnson,Chris  flex_RB          31        4000       Arizona
# 26          Fitzgerald,Larry  flex_WR        37.4        5800       Arizona
# 27               Jones,Julio  flex_WR        43.4        9000       Arizona
# 28              Allen,Keenan  flex_WR        40.3        6800       Arizona
# 29              Cobb,Randall  flex_WR        35.3        7300       Arizona
# 30             Maclin,Jeremy  flex_WR        28.8        5800       Detroit
# 31               Martin,Doug  flex_RB        28.3        4400       Detroit
# 32               Martin,Doug  flex_RB        28.3        4400       Atlanta
# 33           Hopkins,DeAndre  flex_WR        27.7        7300       Atlanta
# 34             Maclin,Jeremy  flex_WR        28.8        5800       Detroit
# 35             Maclin,Jeremy  flex_WR        28.8        5800       Atlanta
# 36           Hopkins,DeAndre  flex_WR        27.7        7300       Detroit
# 37             Maclin,Jeremy  flex_WR        28.8        5800       Detroit
# 38           Hopkins,DeAndre  flex_WR        27.7        7300       Detroit
# 39              Johnson,Duke  flex_RB        26.6        3100       Detroit
# 40             Gates,Antonio  flex_TE        30.2        4200      GreenBay
# 41             Gates,Antonio  flex_TE        30.2        4200      GreenBay
# 42            Forsett,Justin  flex_RB          30        5800      GreenBay
# 43            Forsett,Justin  flex_RB          30        5800      GreenBay
# 44             Gates,Antonio  flex_TE        30.2        4200        Denver
# 45             Barnidge,Gary  flex_TE        30.9        3800        Denver
# 46            Forsett,Justin  flex_RB          30        5800      GreenBay
# 47             Barnidge,Gary  flex_TE        30.9        3800      GreenBay
# 48              Eifert,Tyler  flex_TE          29        4600      GreenBay
# 49             Gates,Antonio  flex_TE        30.2        4200      GreenBay
# ..                       ...      ...         ...         ...           ...
# 120            Brown,Antonio  flex_WR        40.8        8600  Philadelphia
# 121         Marshall,Brandon  flex_WR        34.1        7100  Philadelphia
# 122         Marshall,Brandon  flex_WR        34.1        7100  Philadelphia
# 123             BeckhamOdell  flex_WR        29.9        8900  Philadelphia
# 124         Marshall,Brandon  flex_WR        34.1        7100  Philadelphia
# 125         Marshall,Brandon  flex_WR        34.1        7100  Philadelphia
# 126            Brown,Antonio  flex_WR        40.8        8600  Philadelphia
# 127         Marshall,Brandon  flex_WR        34.1        7100  Philadelphia
# 128             BeckhamOdell  flex_WR        29.9        8900  Philadelphia
# 129         Marshall,Brandon  flex_WR        34.1        7100        Denver
# 130            Lockett,Tyler  flex_WR        31.4        3500  Jacksonville
# 131             Baldwin,Doug  flex_WR        32.2        4500  Jacksonville
# 132             Baldwin,Doug  flex_WR        32.2        4500      Carolina
# 133             Baldwin,Doug  flex_WR        32.2        4500  Jacksonville
# 134             Baldwin,Doug  flex_WR        32.2        4500  Jacksonville
# 135            Lockett,Tyler  flex_WR        31.4        3500  Jacksonville
# 136             Baldwin,Doug  flex_WR        32.2        4500      Carolina
# 137            Lockett,Tyler  flex_WR        31.4        3500      Carolina
# 138            Lockett,Tyler  flex_WR        31.4        3500      Carolina
# 139            Lockett,Tyler  flex_WR        31.4        3500  Jacksonville
# 140          Matthews,Jordan  flex_WR        32.9        4300    KansasCity
# 141            Cooks,Brandin  flex_WR        31.4        5900    KansasCity
# 142           Jackson,DeSean  flex_WR        30.3        4500    Cincinnati
# 143          Matthews,Jordan  flex_WR        32.9        4300    KansasCity
# 144           Jackson,DeSean  flex_WR        30.3        4500    KansasCity
# 145           Jackson,DeSean  flex_WR        30.3        4500    KansasCity
# 146            Watkins,Sammy  flex_WR        31.1        6200    KansasCity
# 147            Cooks,Brandin  flex_WR        31.4        5900    KansasCity
# 148            Watkins,Sammy  flex_WR        31.1        6200    KansasCity
# 149           Jackson,DeSean  flex_WR        30.3        4500    KansasCity
# 150                Ertz,Zach  flex_TE        27.2        3100       Arizona
# 151                Ertz,Zach  flex_TE        27.2        3100       Arizona
# 152              Reed,Jordan  flex_TE        36.9        6500       Arizona
# 153              Reed,Jordan  flex_TE        36.9        6500       Arizona
# 154              Hurns,Allen  flex_WR        33.6        5300       Arizona
# 155          Matthews,Jordan  flex_WR        25.4        4400       Arizona
# 156          McKinnon,Jerick  flex_RB        23.7        3500       Arizona
# 157          Inman,Dontrelle  flex_WR        22.2        3000       Arizona
# 158          McKinnon,Jerick  flex_RB        23.7        3500       Arizona
# 159               Gore,Frank  flex_RB        23.5        4000       Arizona
# 160           Johnson,Calvin  flex_WR        32.7        6900       Houston
# 161           Johnson,Calvin  flex_WR        32.7        6900       Houston
# 162           Johnson,Calvin  flex_WR        32.7        6900       Houston
# 163           Johnson,Calvin  flex_WR        32.7        6900       Houston
# 164           Johnson,Calvin  flex_WR        32.7        6900       Houston
# 165           Johnson,Calvin  flex_WR        32.7        6900       Houston
# 166         Thomas,Demaryius  flex_WR        25.7        6700       Houston
# 167           Johnson,Calvin  flex_WR        32.7        6900       Houston
#