# %%
import pandas as pd
import numpy as np
from scipy import stats
from random import randint

# %%
mu = 95
std = 15

dist = np.random.normal(mu, std, 1000)

# %%
np.round(dist.reshape((1, 1000)), decimals = 0)
# Out:
# array([[  97.,  100.,   87.,  102.,  111.,   86.,   88.,   97.,   75.,
#          123.,  102.,  108.,   91.,   99.,   80.,   94.,  110.,  116.,
#           99.,   98.,   72.,   93.,  100.,   76.,   98.,   92.,   92.,
#           85.,   99.,  121.,  116.,  112.,   83.,   63.,   94.,   86.,
#           97.,   87.,   87.,   77.,  107.,   91.,   97.,   73.,   87.,
#           90.,   79.,   86.,  116.,   99.,   91.,  107.,   86.,   92.,
#          104.,   77.,   92.,  105.,  121.,   86.,   85.,  110.,  101.,
#           77.,   96.,   99.,  119.,   70.,  114.,  103.,   90.,  104.,
#          116.,  123.,  105.,   72.,  101.,  108.,  103.,   86.,   96.,
#          100.,  102.,   90.,  108.,   90.,  114.,   89.,   76.,  102.,
#           99.,  131.,   76.,   67.,  101.,   73.,  111.,  116.,  111.,
#           90.,  112.,   75.,  102.,  117.,  101.,   86.,  115.,   89.,
#          123.,  105.,  106.,  109.,  135.,   78.,   96.,   94.,  101.,
# ...

# %%
# Out:
# array([  49.65192894,   49.74172709,   53.13080636,   54.8053987 ,
#          56.03881735,   56.5356547 ,   57.11375153,   58.57176568,
#          58.71172578,   59.44013704,   60.08339846,   60.90658482,
#          60.96310058,   61.27827136,   61.39856106,   61.72317658,
#          61.97738482,   62.22783035,   63.07677648,   63.14974553,
#          63.59340037,   63.71146111,   64.07071179,   64.10285233,
#          64.26645492,   64.48161272,   64.60456091,   64.7293505 ,
#          65.04968762,   65.0536084 ,   65.09916346,   65.23052998,
#          65.29436211,   66.27114614,   66.33221591,   66.4668233 ,
#          66.62886092,   66.9644589 ,   67.16282391,   67.80722746,
#          68.18066604,   68.26781124,   68.28851768,   68.3692515 ,
#          68.46739847,   68.58500076,   68.66301721,   68.76873274,
#          68.77971358,   68.97309054,   69.33913575,   69.39455655,
#          69.60992039,   69.65838714,   69.67666183,   69.99391167,
# ...
